# %%
# imports

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd
import folium
import osmnx as ox

import warnings
warnings.filterwarnings('ignore')


# %matplotlib inline
pd.options.mode.chained_assignment = None  # default='warn'
# Out:
# /home/mijka/.pyenv/versions/3.9.7/envs/oclass2/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
pd.set_option('display.max_rows', 750)
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_colwidth', None)

# %%
### but :
### tenter de prédire les émissions de CO2 et la consommation totale d’énergie de bâtiments 
### non destinés à l’habitation pour lesquels elles n’ont pas encore été mesurées.

# %%
## source : contains KPI description
## https://data.seattle.gov/dataset/2016-Building-Energy-Benchmarking/2bpz-gwpy

# %% [markdown]
# # Extract & Load

# %%
ls -lh ./data
# Out:
# total 1,4M
# -rw-r--r-- 1 mijka mijka 1,2M  5 févr. 09:37 2016_Building_Energy_Benchmarking.csv
# -rw-r--r-- 1 mijka mijka 136K 12 févr. 09:54 clean_seattle_buildings.csv

# %%
path = './data/'
csv_path = path + '2016_Building_Energy_Benchmarking.csv'
df = pd.read_csv(csv_path, on_bad_lines='skip', low_memory=False)

# %% [markdown]
# # Explore

# %% [markdown]
# ## Functions

# %%
def get_df_columns_na(df):
    counts = df.isna().sum()
    percentages = round(df.isna().mean() * 100, 1)
    null_values = pd.concat([counts, percentages], axis = 1, keys = ["count", "null_percent"])
    null_values['columns'] = null_values.index
    null_values = null_values[['columns', 'count', 'null_percent']]
    return null_values

# %%
def plot_df_xy(df, x_val, y_val, height_val = 20, width_val = 13):
    sns.catplot(data=df, x= x_val, y= y_val, kind="bar", height=height_val, aspect=width_val/height_val)
    sns.set(rc={'figure.figsize':(width_val,height_val)})
    plt.xticks(rotation=70)
    plt.tight_layout()

# %%
def show_nulls(df):
    top_sm_df_sort = get_df_columns_na(df).sort_values(by='null_percent',ascending=False)
    print(top_sm_df_sort)
    return plot_df_xy(top_sm_df_sort.reset_index(), 'null_percent', 'columns', 8)

# %% [markdown]
# ## Cardinality

# %%
df.head()
# Out:
#    OSEBuildingID  DataYear    BuildingType PrimaryPropertyType  \
# 0              1      2016  NonResidential               Hotel
# 1              2      2016  NonResidential               Hotel
# 2              3      2016  NonResidential               Hotel
# 3              5      2016  NonResidential               Hotel
# 4              8      2016  NonResidential               Hotel
#
#                   PropertyName          Address     City State  ZipCode  \
# 0         Mayflower park hotel    405 Olive way  Seattle    WA  98101.0
# 1              Paramount Hotel  724 Pine street  Seattle    WA  98101.0
# 2      5673-The Westin Seattle  1900 5th Avenue  Seattle    WA  98101.0
# 3                    HOTEL MAX   620 STEWART ST  Seattle    WA  98101.0
# 4  WARWICK SEATTLE HOTEL (ID8)    401 LENORA ST  Seattle    WA  98121.0
#
#   TaxParcelIdentificationNumber  CouncilDistrictCode Neighborhood  Latitude  \
# 0                    0659000030                    7     DOWNTOWN  47.61220
# 1                    0659000220                    7     DOWNTOWN  47.61317
# 2                    0659000475                    7     DOWNTOWN  47.61393
# 3                    0659000640                    7     DOWNTOWN  47.61412
# 4                    0659000970                    7     DOWNTOWN  47.61375
#
#    Longitude  YearBuilt  NumberofBuildings  NumberofFloors  PropertyGFATotal  \
# 0 -122.33799       1927                1.0              12             88434
# 1 -122.33393       1996                1.0              11            103566
# 2 -122.33810       1969                1.0              41            956110
# 3 -122.33664       1926                1.0              10             61320
# 4 -122.34047       1980                1.0              18            175580
#
#    PropertyGFAParking  PropertyGFABuilding(s)      ListOfAllPropertyUseTypes  \
# 0                   0                   88434                          Hotel
# 1               15064                   88502     Hotel, Parking, Restaurant
# 2              196718                  759392                          Hotel
# 3                   0                   61320                          Hotel
# 4               62000                  113580  Hotel, Parking, Swimming Pool
#
#   LargestPropertyUseType  LargestPropertyUseTypeGFA  \
# 0                  Hotel                    88434.0
# 1                  Hotel                    83880.0
# 2                  Hotel                   756493.0
# 3                  Hotel                    61320.0
# 4                  Hotel                   123445.0
#
#   SecondLargestPropertyUseType  SecondLargestPropertyUseTypeGFA  \
# 0                          NaN                              NaN
# 1                      Parking                          15064.0
# 2                          NaN                              NaN
# 3                          NaN                              NaN
# 4                      Parking                          68009.0
#
#   ThirdLargestPropertyUseType  ThirdLargestPropertyUseTypeGFA  \
# 0                         NaN                             NaN
# 1                  Restaurant                          4622.0
# 2                         NaN                             NaN
# 3                         NaN                             NaN
# 4               Swimming Pool                             0.0
#
#   YearsENERGYSTARCertified  ENERGYSTARScore  SiteEUI(kBtu/sf)  \
# 0                      NaN             60.0         81.699997
# 1                      NaN             61.0         94.800003
# 2                      NaN             43.0         96.000000
# 3                      NaN             56.0        110.800003
# 4                      NaN             75.0        114.800003
#
#    SiteEUIWN(kBtu/sf)  SourceEUI(kBtu/sf)  SourceEUIWN(kBtu/sf)  \
# 0           84.300003          182.500000            189.000000
# 1           97.900002          176.100006            179.399994
# 2           97.699997          241.899994            244.100006
# 3          113.300003          216.199997            224.000000
# 4          118.699997          211.399994            215.600006
#
#    SiteEnergyUse(kBtu)  SiteEnergyUseWN(kBtu)  SteamUse(kBtu)  \
# 0            7226362.5              7456910.0      2003882.00
# 1            8387933.0              8664479.0            0.00
# 2           72587024.0             73937112.0     21566554.00
# 3            6794584.0              6946800.5      2214446.25
# 4           14172606.0             14656503.0            0.00
#
#    Electricity(kWh)  Electricity(kBtu)  NaturalGas(therms)  NaturalGas(kBtu)  \
# 0      1.156514e+06          3946027.0         12764.52930         1276453.0
# 1      9.504252e+05          3242851.0         51450.81641         5145082.0
# 2      1.451544e+07         49526664.0         14938.00000         1493800.0
# 3      8.115253e+05          2768924.0         18112.13086         1811213.0
# 4      1.573449e+06          5368607.0         88039.98438         8803998.0
#
#    DefaultData  Comments ComplianceStatus Outlier  TotalGHGEmissions  \
# 0        False       NaN        Compliant     NaN             249.98
# 1        False       NaN        Compliant     NaN             295.86
# 2        False       NaN        Compliant     NaN            2089.28
# 3        False       NaN        Compliant     NaN             286.43
# 4        False       NaN        Compliant     NaN             505.01
#
#    GHGEmissionsIntensity
# 0                   2.83
# 1                   2.86
# 2                   2.19
# 3                   4.67
# 4                   2.88

# %%
df.shape
# Out:
# (3376, 46)

# %%
df.columns
# Out:
# Index(['OSEBuildingID', 'DataYear', 'BuildingType', 'PrimaryPropertyType',
#        'PropertyName', 'Address', 'City', 'State', 'ZipCode',
#        'TaxParcelIdentificationNumber', 'CouncilDistrictCode', 'Neighborhood',
#        'Latitude', 'Longitude', 'YearBuilt', 'NumberofBuildings',
#        'NumberofFloors', 'PropertyGFATotal', 'PropertyGFAParking',
#        'PropertyGFABuilding(s)', 'ListOfAllPropertyUseTypes',
#        'LargestPropertyUseType', 'LargestPropertyUseTypeGFA',
#        'SecondLargestPropertyUseType', 'SecondLargestPropertyUseTypeGFA',
#        'ThirdLargestPropertyUseType', 'ThirdLargestPropertyUseTypeGFA',
#        'YearsENERGYSTARCertified', 'ENERGYSTARScore', 'SiteEUI(kBtu/sf)',
#        'SiteEUIWN(kBtu/sf)', 'SourceEUI(kBtu/sf)', 'SourceEUIWN(kBtu/sf)',
#        'SiteEnergyUse(kBtu)', 'SiteEnergyUseWN(kBtu)', 'SteamUse(kBtu)',
#        'Electricity(kWh)', 'Electricity(kBtu)', 'NaturalGas(therms)',
#        'NaturalGas(kBtu)', 'DefaultData', 'Comments', 'ComplianceStatus',
#        'Outlier', 'TotalGHGEmissions', 'GHGEmissionsIntensity'],
#       dtype='object')

# %%
df.dtypes
# Out:
# OSEBuildingID                        int64
# DataYear                             int64
# BuildingType                        object
# PrimaryPropertyType                 object
# PropertyName                        object
# Address                             object
# City                                object
# State                               object
# ZipCode                            float64
# TaxParcelIdentificationNumber       object
# CouncilDistrictCode                  int64
# Neighborhood                        object
# Latitude                           float64
# Longitude                          float64
# YearBuilt                            int64
# NumberofBuildings                  float64
# NumberofFloors                       int64
# PropertyGFATotal                     int64
# PropertyGFAParking                   int64
# PropertyGFABuilding(s)               int64
# ListOfAllPropertyUseTypes           object
# LargestPropertyUseType              object
# LargestPropertyUseTypeGFA          float64
# SecondLargestPropertyUseType        object
# SecondLargestPropertyUseTypeGFA    float64
# ThirdLargestPropertyUseType         object
# ThirdLargestPropertyUseTypeGFA     float64
# YearsENERGYSTARCertified            object
# ENERGYSTARScore                    float64
# SiteEUI(kBtu/sf)                   float64
# SiteEUIWN(kBtu/sf)                 float64
# SourceEUI(kBtu/sf)                 float64
# SourceEUIWN(kBtu/sf)               float64
# SiteEnergyUse(kBtu)                float64
# SiteEnergyUseWN(kBtu)              float64
# SteamUse(kBtu)                     float64
# Electricity(kWh)                   float64
# Electricity(kBtu)                  float64
# NaturalGas(therms)                 float64
# NaturalGas(kBtu)                   float64
# DefaultData                           bool
# Comments                           float64
# ComplianceStatus                    object
# Outlier                             object
# TotalGHGEmissions                  float64
# GHGEmissionsIntensity              float64
# dtype: object

# %%
df.describe()
# Out:
#        OSEBuildingID  DataYear       ZipCode  CouncilDistrictCode  \
# count    3376.000000    3376.0   3360.000000          3376.000000
# mean    21208.991114    2016.0  98116.949107             4.439277
# std     12223.757015       0.0     18.615205             2.120625
# min         1.000000    2016.0  98006.000000             1.000000
# 25%     19990.750000    2016.0  98105.000000             3.000000
# 50%     23112.000000    2016.0  98115.000000             4.000000
# 75%     25994.250000    2016.0  98122.000000             7.000000
# max     50226.000000    2016.0  98272.000000             7.000000
#
#           Latitude    Longitude    YearBuilt  NumberofBuildings  \
# count  3376.000000  3376.000000  3376.000000        3368.000000
# mean     47.624033  -122.334795  1968.573164           1.106888
# std       0.047758     0.027203    33.088156           2.108402
# min      47.499170  -122.414250  1900.000000           0.000000
# 25%      47.599860  -122.350662  1948.000000           1.000000
# 50%      47.618675  -122.332495  1975.000000           1.000000
# 75%      47.657115  -122.319407  1997.000000           1.000000
# max      47.733870  -122.220966  2015.000000         111.000000
#
#        NumberofFloors  PropertyGFATotal  PropertyGFAParking  \
# count     3376.000000      3.376000e+03         3376.000000
# mean         4.709123      9.483354e+04         8001.526066
# std          5.494465      2.188376e+05        32326.723928
# min          0.000000      1.128500e+04            0.000000
# 25%          2.000000      2.848700e+04            0.000000
# 50%          4.000000      4.417500e+04            0.000000
# 75%          5.000000      9.099200e+04            0.000000
# max         99.000000      9.320156e+06       512608.000000
#
#        PropertyGFABuilding(s)  LargestPropertyUseTypeGFA  \
# count            3.376000e+03               3.356000e+03
# mean             8.683201e+04               7.917764e+04
# std              2.079398e+05               2.017034e+05
# min              3.636000e+03               5.656000e+03
# 25%              2.775600e+04               2.509475e+04
# 50%              4.321600e+04               3.989400e+04
# 75%              8.427625e+04               7.620025e+04
# max              9.320156e+06               9.320156e+06
#
#        SecondLargestPropertyUseTypeGFA  ThirdLargestPropertyUseTypeGFA  \
# count                      1679.000000                      596.000000
# mean                      28444.075817                    11738.675166
# std                       54392.917928                    29331.199286
# min                           0.000000                        0.000000
# 25%                        5000.000000                     2239.000000
# 50%                       10664.000000                     5043.000000
# 75%                       26640.000000                    10138.750000
# max                      686750.000000                   459748.000000
#
#        ENERGYSTARScore  SiteEUI(kBtu/sf)  SiteEUIWN(kBtu/sf)  \
# count      2533.000000       3369.000000         3370.000000
# mean         67.918674         54.732116           57.033798
# std          26.873271         56.273124           57.163330
# min           1.000000          0.000000            0.000000
# 25%          53.000000         27.900000           29.400000
# 50%          75.000000         38.599998           40.900002
# 75%          90.000000         60.400002           64.275002
# max         100.000000        834.400024          834.400024
#
#        SourceEUI(kBtu/sf)  SourceEUIWN(kBtu/sf)  SiteEnergyUse(kBtu)  \
# count         3367.000000           3367.000000         3.371000e+03
# mean           134.232848            137.783932         5.403667e+06
# std            139.287554            139.109807         2.161063e+07
# min              0.000000             -2.100000         0.000000e+00
# 25%             74.699997             78.400002         9.251286e+05
# 50%             96.199997            101.099998         1.803753e+06
# 75%            143.899994            148.349998         4.222455e+06
# max           2620.000000           2620.000000         8.739237e+08
#
#        SiteEnergyUseWN(kBtu)  SteamUse(kBtu)  Electricity(kWh)  \
# count           3.370000e+03    3.367000e+03      3.367000e+03
# mean            5.276726e+06    2.745959e+05      1.086639e+06
# std             1.593879e+07    3.912173e+06      4.352478e+06
# min             0.000000e+00    0.000000e+00     -3.382680e+04
# 25%             9.701822e+05    0.000000e+00      1.874229e+05
# 50%             1.904452e+06    0.000000e+00      3.451299e+05
# 75%             4.381429e+06    0.000000e+00      8.293178e+05
# max             4.716139e+08    1.349435e+08      1.925775e+08
#
#        Electricity(kBtu)  NaturalGas(therms)  NaturalGas(kBtu)  Comments  \
# count       3.367000e+03        3.367000e+03      3.367000e+03       0.0
# mean        3.707612e+06        1.368505e+04      1.368505e+06       NaN
# std         1.485066e+07        6.709781e+04      6.709781e+06       NaN
# min        -1.154170e+05        0.000000e+00      0.000000e+00       NaN
# 25%         6.394870e+05        0.000000e+00      0.000000e+00       NaN
# 50%         1.177583e+06        3.237538e+03      3.237540e+05       NaN
# 75%         2.829632e+06        1.189033e+04      1.189034e+06       NaN
# max         6.570744e+08        2.979090e+06      2.979090e+08       NaN
#
#        TotalGHGEmissions  GHGEmissionsIntensity
# count        3367.000000            3367.000000
# mean          119.723971               1.175916
# std           538.832227               1.821452
# min            -0.800000              -0.020000
# 25%             9.495000               0.210000
# 50%            33.920000               0.610000
# 75%            93.940000               1.370000
# max         16870.980000              34.090000

# %%
show_nulls(df)
# Out:
#                                                          columns  count  \
# Comments                                                Comments   3376
# Outlier                                                  Outlier   3344
# YearsENERGYSTARCertified                YearsENERGYSTARCertified   3257
# ThirdLargestPropertyUseType          ThirdLargestPropertyUseType   2780
# ThirdLargestPropertyUseTypeGFA    ThirdLargestPropertyUseTypeGFA   2780
# SecondLargestPropertyUseType        SecondLargestPropertyUseType   1697
# SecondLargestPropertyUseTypeGFA  SecondLargestPropertyUseTypeGFA   1697
# ENERGYSTARScore                                  ENERGYSTARScore    843
# LargestPropertyUseTypeGFA              LargestPropertyUseTypeGFA     20
# LargestPropertyUseType                    LargestPropertyUseType     20
# ZipCode                                                  ZipCode     16
# ListOfAllPropertyUseTypes              ListOfAllPropertyUseTypes      9
# SourceEUIWN(kBtu/sf)                        SourceEUIWN(kBtu/sf)      9
# SourceEUI(kBtu/sf)                            SourceEUI(kBtu/sf)      9
# Electricity(kWh)                                Electricity(kWh)      9
# Electricity(kBtu)                              Electricity(kBtu)      9
# NaturalGas(therms)                            NaturalGas(therms)      9
# NaturalGas(kBtu)                                NaturalGas(kBtu)      9
# TotalGHGEmissions                              TotalGHGEmissions      9
# SteamUse(kBtu)                                    SteamUse(kBtu)      9
# GHGEmissionsIntensity                      GHGEmissionsIntensity      9
# NumberofBuildings                              NumberofBuildings      8
# SiteEUI(kBtu/sf)                                SiteEUI(kBtu/sf)      7
# SiteEUIWN(kBtu/sf)                            SiteEUIWN(kBtu/sf)      6
# SiteEnergyUseWN(kBtu)                      SiteEnergyUseWN(kBtu)      6
# SiteEnergyUse(kBtu)                          SiteEnergyUse(kBtu)      5
# TaxParcelIdentificationNumber      TaxParcelIdentificationNumber      0
# BuildingType                                        BuildingType      0
# PrimaryPropertyType                          PrimaryPropertyType      0
# ComplianceStatus                                ComplianceStatus      0
# PropertyName                                        PropertyName      0
# DefaultData                                          DefaultData      0
# Address                                                  Address      0
# City                                                        City      0
# State                                                      State      0
# PropertyGFABuilding(s)                    PropertyGFABuilding(s)      0
# CouncilDistrictCode                          CouncilDistrictCode      0
# PropertyGFAParking                            PropertyGFAParking      0
# Neighborhood                                        Neighborhood      0
# Latitude                                                Latitude      0
# Longitude                                              Longitude      0
# YearBuilt                                              YearBuilt      0
# NumberofFloors                                    NumberofFloors      0
# PropertyGFATotal                                PropertyGFATotal      0
# DataYear                                                DataYear      0
# OSEBuildingID                                      OSEBuildingID      0
#
#                                  null_percent
# Comments                                100.0
# Outlier                                  99.1
# YearsENERGYSTARCertified                 96.5
# ThirdLargestPropertyUseType              82.3
# ThirdLargestPropertyUseTypeGFA           82.3
# SecondLargestPropertyUseType             50.3
# SecondLargestPropertyUseTypeGFA          50.3
# ENERGYSTARScore                          25.0
# LargestPropertyUseTypeGFA                 0.6
# LargestPropertyUseType                    0.6
# ZipCode                                   0.5
# ListOfAllPropertyUseTypes                 0.3
# SourceEUIWN(kBtu/sf)                      0.3
# SourceEUI(kBtu/sf)                        0.3
# Electricity(kWh)                          0.3
# Electricity(kBtu)                         0.3
# NaturalGas(therms)                        0.3
# NaturalGas(kBtu)                          0.3
# TotalGHGEmissions                         0.3
# SteamUse(kBtu)                            0.3
# GHGEmissionsIntensity                     0.3
# NumberofBuildings                         0.2
# SiteEUI(kBtu/sf)                          0.2
# SiteEUIWN(kBtu/sf)                        0.2
# SiteEnergyUseWN(kBtu)                     0.2
# SiteEnergyUse(kBtu)                       0.1
# TaxParcelIdentificationNumber             0.0
# BuildingType                              0.0
# PrimaryPropertyType                       0.0
# ComplianceStatus                          0.0
# PropertyName                              0.0
# DefaultData                               0.0
# Address                                   0.0
# City                                      0.0
# State                                     0.0
# PropertyGFABuilding(s)                    0.0
# CouncilDistrictCode                       0.0
# PropertyGFAParking                        0.0
# Neighborhood                              0.0
# Latitude                                  0.0
# Longitude                                 0.0
# YearBuilt                                 0.0
# NumberofFloors                            0.0
# PropertyGFATotal                          0.0
# DataYear                                  0.0
# OSEBuildingID                             0.0

# %% [markdown]
# ## Duplicates

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3371    False
# 3372    False
# 3373    False
# 3374    False
# 3375    False
# Length: 3376, dtype: bool

# %%
len(df)-len(df.drop_duplicates())
# Out:
# 0

# %%
df.groupby(df.columns.tolist(),as_index=False).size()
# Out:
# Empty DataFrame
# Columns: [OSEBuildingID, DataYear, BuildingType, PrimaryPropertyType, PropertyName, Address, City, State, ZipCode, TaxParcelIdentificationNumber, CouncilDistrictCode, Neighborhood, Latitude, Longitude, YearBuilt, NumberofBuildings, NumberofFloors, PropertyGFATotal, PropertyGFAParking, PropertyGFABuilding(s), ListOfAllPropertyUseTypes, LargestPropertyUseType, LargestPropertyUseTypeGFA, SecondLargestPropertyUseType, SecondLargestPropertyUseTypeGFA, ThirdLargestPropertyUseType, ThirdLargestPropertyUseTypeGFA, YearsENERGYSTARCertified, ENERGYSTARScore, SiteEUI(kBtu/sf), SiteEUIWN(kBtu/sf), SourceEUI(kBtu/sf), SourceEUIWN(kBtu/sf), SiteEnergyUse(kBtu), SiteEnergyUseWN(kBtu), SteamUse(kBtu), Electricity(kWh), Electricity(kBtu), NaturalGas(therms), NaturalGas(kBtu), DefaultData, Comments, ComplianceStatus, Outlier, TotalGHGEmissions, GHGEmissionsIntensity, size]
# Index: []

# %%
##df.groupby(['Longitude', 'Latitude'])['Crime type'].value_counts().to_frame('count')

# %% [markdown]
# ## categories

# %%
df.select_dtypes(['category','object']).nunique()
# Out:
# BuildingType                        8
# PrimaryPropertyType                24
# PropertyName                     3362
# Address                          3354
# City                                1
# State                               1
# TaxParcelIdentificationNumber    3268
# Neighborhood                       19
# ListOfAllPropertyUseTypes         466
# LargestPropertyUseType             56
# SecondLargestPropertyUseType       50
# ThirdLargestPropertyUseType        44
# YearsENERGYSTARCertified           65
# ComplianceStatus                    4
# Outlier                             2
# dtype: int64

# %%
df['ZipCode'].unique()
# Out:
# array([98101., 98121., 98104., 98154., 98118., 98105., 98112., 98125.,
#        98109., 98070., 98108., 98199., 98115., 98107., 98144., 98103.,
#        98119., 98136., 98122., 98126., 98133., 98146., 98033., 98106.,
#        98111., 98134., 98117., 98116., 98191., 98164., 98195., 98185.,
#        98181., 98102., 98168., 98155., 98006., 98124., 98053., 98012.,
#        98013., 98028., 98178., 98114., 98127., 98165., 98011., 98198.,
#        98113., 98040., 98204., 98177., 98020., 98272., 98145.,    nan])

# %%
df['Comments'].unique()
# Out:
# array([nan])

# %%
df['Comments'].nunique()
# Out:
# 0

# %%
for column in df.columns:
    if df[column].nunique()<20:
        print('Colonne {}, valeurs uniques :\n{}\n'.format(column, df[column].unique()))
    else:
        print('Colonne {}, {} valeurs uniques'.format(column, df[column].nunique()))
# Out:
# Colonne OSEBuildingID, 3376 valeurs uniques
# Colonne DataYear, valeurs uniques :
# [2016]
#
# Colonne BuildingType, valeurs uniques :
# ['NonResidential' 'Nonresidential COS' 'Multifamily MR (5-9)'
#  'SPS-District K-12' 'Campus' 'Multifamily LR (1-4)'
#  'Multifamily HR (10+)' 'Nonresidential WA']
#
# Colonne PrimaryPropertyType, 24 valeurs uniques
# Colonne PropertyName, 3362 valeurs uniques
# Colonne Address, 3354 valeurs uniques
# Colonne City, valeurs uniques :
# ['Seattle']
#
# Colonne State, valeurs uniques :
# ['WA']
#
# Colonne ZipCode, 55 valeurs uniques
# Colonne TaxParcelIdentificationNumber, 3268 valeurs uniques
# Colonne CouncilDistrictCode, valeurs uniques :
# [7 3 2 4 5 6 1]
#
# Colonne Neighborhood, valeurs uniques :
# ['DOWNTOWN' 'SOUTHEAST' 'NORTHEAST' 'EAST' 'Central' 'NORTH'
#  'MAGNOLIA / QUEEN ANNE' 'LAKE UNION' 'GREATER DUWAMISH' 'BALLARD'
#  'NORTHWEST' 'CENTRAL' 'SOUTHWEST' 'DELRIDGE' 'Ballard' 'North' 'Delridge'
#  'Northwest' 'DELRIDGE NEIGHBORHOODS']
#
# Colonne Latitude, 2876 valeurs uniques
# Colonne Longitude, 2656 valeurs uniques
# Colonne YearBuilt, 113 valeurs uniques
# Colonne NumberofBuildings, valeurs uniques :
# [  1.   3.   0.   2.   4.  27.   6.  11.  14.   9.   5.  nan   7.   8.
#   16.  23.  10. 111.]
#
# Colonne NumberofFloors, 50 valeurs uniques
# Colonne PropertyGFATotal, 3195 valeurs uniques
# Colonne PropertyGFAParking, 496 valeurs uniques
# Colonne PropertyGFABuilding(s), 3193 valeurs uniques
# Colonne ListOfAllPropertyUseTypes, 466 valeurs uniques
# Colonne LargestPropertyUseType, 56 valeurs uniques
# Colonne LargestPropertyUseTypeGFA, 3122 valeurs uniques
# Colonne SecondLargestPropertyUseType, 50 valeurs uniques
# Colonne SecondLargestPropertyUseTypeGFA, 1352 valeurs uniques
# Colonne ThirdLargestPropertyUseType, 44 valeurs uniques
# Colonne ThirdLargestPropertyUseTypeGFA, 501 valeurs uniques
# Colonne YearsENERGYSTARCertified, 65 valeurs uniques
# Colonne ENERGYSTARScore, 100 valeurs uniques
# Colonne SiteEUI(kBtu/sf), 1085 valeurs uniques
# Colonne SiteEUIWN(kBtu/sf), 1105 valeurs uniques
# Colonne SourceEUI(kBtu/sf), 1648 valeurs uniques
# Colonne SourceEUIWN(kBtu/sf), 1694 valeurs uniques
# Colonne SiteEnergyUse(kBtu), 3354 valeurs uniques
# Colonne SiteEnergyUseWN(kBtu), 3341 valeurs uniques
# Colonne SteamUse(kBtu), 131 valeurs uniques
# Colonne Electricity(kWh), 3352 valeurs uniques
# Colonne Electricity(kBtu), 3351 valeurs uniques
# Colonne NaturalGas(therms), 2109 valeurs uniques
# Colonne NaturalGas(kBtu), 2109 valeurs uniques
# Colonne DefaultData, valeurs uniques :
# [False  True]
#
# Colonne Comments, valeurs uniques :
# [nan]
#
# Colonne ComplianceStatus, valeurs uniques :
# ['Compliant' 'Error - Correct Default Data' 'Missing Data' 'Non-Compliant']
#
# Colonne Outlier, valeurs uniques :
# [nan 'High outlier' 'Low outlier']
#
# Colonne TotalGHGEmissions, 2818 valeurs uniques
# Colonne GHGEmissionsIntensity, 511 valeurs uniques

# %% [markdown]
# ## Scatter coordonnées

# %%
countries = gpd.read_file(
               gpd.datasets.get_path("naturalearth_lowres"))
#countries.head()

# %%
#countries.plot(color="lightgrey")

# %%
#countries.loc[countries.iso_a3 == 'USA'].plot(color="lightgrey")

# %%
gdf = gpd.GeoDataFrame(
    df, geometry=gpd.points_from_xy(df.Longitude, df.Latitude))

# %%
ax = countries.plot(
    color='white', edgecolor='black')

# plot``GeoDataFrame``.
gdf.plot(ax=ax, color='red')

plt.show()

# %%
mean_lat = df['Latitude'].describe()['mean']
mean_lat
# Out:
# 47.62403312098933

# %%
mean_lon = df['Longitude'].describe()['mean']
mean_lon
# Out:
# -122.33479519780805

# %%
#place_name = 'Seattle, USA'
#tags = {'building': True}
#area = ox.geometries.geometries_from_place(place_name, tags)
#area.plot()

# %%
map = folium.Map(location=[mean_lat, mean_lon], zoom_start=11)

locations = df[['Latitude', 'Longitude']]
locationlist = locations.values.tolist()

for coord in locationlist:
    folium.Marker(
            location=[ coord[0], coord[1] ], 
            fill_color='#43d9de', radius=8).add_to(map)

map.save( 'map_s.html')

# %%
## uncomment "map" to display map

# map

# %%
### avec coordonnées vérifier existence de quartiers / groupes

# %%
# folium doc : https://python-visualization.github.io/folium/modules.html
# article : https://towardsdatascience.com/folium-mapping-displaying-markers-on-a-map-6bd56f3e3420

# %%
colors_list = ['beige', 'black', 'blue', 'cadetblue', 'darkblue', 'darkgreen', 'darkpurple', 
 'darkred', 'gray', 'green', 'lightblue', 'lightgray', 'lightgreen', 'lightred', 
 'orange', 'pink', 'purple', 'red', 'white']

# %%
len(colors_list)
# Out:
# 19

# %%
df['Neighborhood'].nunique()
# Out:
# 19

# %%
df['Neighborhood'].nunique()
# Out:
# 19

# %%
cat_cols = df.columns[df.dtypes == 'object']
cat_cols
# Out:
# Index(['BuildingType', 'PrimaryPropertyType', 'PropertyName', 'Address',
#        'City', 'State', 'TaxParcelIdentificationNumber', 'Neighborhood',
#        'ListOfAllPropertyUseTypes', 'LargestPropertyUseType',
#        'SecondLargestPropertyUseType', 'ThirdLargestPropertyUseType',
#        'YearsENERGYSTARCertified', 'ComplianceStatus', 'Outlier'],
#       dtype='object')

# %%
df[cat_cols].describe()
# Out:
#           BuildingType   PrimaryPropertyType     PropertyName  \
# count             3376                  3376             3376
# unique               8                    24             3362
# top     NonResidential  Low-Rise Multifamily  Northgate Plaza
# freq              1460                   987                3
#
#                   Address     City State TaxParcelIdentificationNumber  \
# count                3376     3376  3376                          3376
# unique               3354        1     1                          3268
# top     2600 SW Barton St  Seattle    WA                    1625049001
# freq                    4     3376  3376                             8
#
#        Neighborhood ListOfAllPropertyUseTypes LargestPropertyUseType  \
# count          3376                      3367                   3356
# unique           19                       466                     56
# top        DOWNTOWN       Multifamily Housing    Multifamily Housing
# freq            573                       866                   1667
#
#        SecondLargestPropertyUseType ThirdLargestPropertyUseType  \
# count                          1679                         596
# unique                           50                          44
# top                         Parking                Retail Store
# freq                            976                         110
#
#        YearsENERGYSTARCertified ComplianceStatus      Outlier
# count                       119             3376           32
# unique                       65                4            2
# top                        2016        Compliant  Low outlier
# freq                         14             3211           23

# %%
quartiers = df['Neighborhood'].unique()
quartiers
# Out:
# array(['DOWNTOWN', 'SOUTHEAST', 'NORTHEAST', 'EAST', 'Central', 'NORTH',
#        'MAGNOLIA / QUEEN ANNE', 'LAKE UNION', 'GREATER DUWAMISH',
#        'BALLARD', 'NORTHWEST', 'CENTRAL', 'SOUTHWEST', 'DELRIDGE',
#        'Ballard', 'North', 'Delridge', 'Northwest',
#        'DELRIDGE NEIGHBORHOODS'], dtype=object)

# %%
df['Neighborhood'].value_counts()
# Out:
# DOWNTOWN                  573
# EAST                      453
# MAGNOLIA / QUEEN ANNE     423
# GREATER DUWAMISH          375
# NORTHEAST                 280
# LAKE UNION                251
# NORTHWEST                 210
# SOUTHWEST                 166
# NORTH                     145
# BALLARD                   126
# CENTRAL                   107
# SOUTHEAST                  95
# DELRIDGE                   80
# North                      42
# Central                    27
# Northwest                  11
# Ballard                     7
# Delridge                    4
# DELRIDGE NEIGHBORHOODS      1
# Name: Neighborhood, dtype: int64

# %%
df['Neighborhood'] = df['Neighborhood'].str.upper()
df['Neighborhood'].loc[df['Neighborhood'] == 'DELRIDGE NEIGHBORHOODS'] = 'DELRIDGE'

# %%
df['Neighborhood'].value_counts()
# Out:
# DOWNTOWN                 573
# EAST                     453
# MAGNOLIA / QUEEN ANNE    423
# GREATER DUWAMISH         375
# NORTHEAST                280
# LAKE UNION               251
# NORTHWEST                221
# NORTH                    187
# SOUTHWEST                166
# CENTRAL                  134
# BALLARD                  133
# SOUTHEAST                 95
# DELRIDGE                  85
# Name: Neighborhood, dtype: int64

# %%
## => dict fonction zip

# %%
dict_cols = dict(zip(quartiers, colors_list))

dict_cols
# Out:
# {'DOWNTOWN': 'beige',
#  'SOUTHEAST': 'black',
#  'NORTHEAST': 'blue',
#  'EAST': 'cadetblue',
#  'Central': 'darkblue',
#  'NORTH': 'darkgreen',
#  'MAGNOLIA / QUEEN ANNE': 'darkpurple',
#  'LAKE UNION': 'darkred',
#  'GREATER DUWAMISH': 'gray',
#  'BALLARD': 'green',
#  'NORTHWEST': 'lightblue',
#  'CENTRAL': 'lightgray',
#  'SOUTHWEST': 'lightgreen',
#  'DELRIDGE': 'lightred',
#  'Ballard': 'orange',
#  'North': 'pink',
#  'Delridge': 'purple',
#  'Northwest': 'red',
#  'DELRIDGE NEIGHBORHOODS': 'white'}

# %%
dict_cols.values()
# Out:
# dict_values(['beige', 'black', 'blue', 'cadetblue', 'darkblue', 'darkgreen', 'darkpurple', 'darkred', 'gray', 'green', 'lightblue', 'lightgray', 'lightgreen', 'lightred', 'orange', 'pink', 'purple', 'red', 'white'])

# %%
dict_cols["DOWNTOWN"]
# Out:
# 'beige'

# %%
for i,row in df.iterrows():
    #Setup the content of the popup
    iframe = folium.IFrame(f'Neighborhood: {str(row["Neighborhood"])} \n Type: {str(row["PrimaryPropertyType"])}')
    
    #Initialise the popup using the iframe
    popup = folium.Popup(iframe, min_width=300, max_width=300)
    
    try:
        icon_color = dict_cols[row['Neighborhood']]
    except:
        #Catch nans
        icon_color = 'gray'
    
    #Add each row to the map
    folium.Marker(location=[row['Latitude'],row['Longitude']],
                  popup = popup, 
                  icon=folium.Icon(color=icon_color, icon='')).add_to(map)

# %%
## uncomment "map" to display map

#map

# %% [markdown]
# # Cleaning

# %% [markdown]
# ## Distribution pre-cleaning

# %% [markdown]
# ### Fonctions

# %%
def UVA_numeric2(data, i):
  '''
  Univariate_Analysis_numeric
  takes a group of variables (INTEGER and FLOAT) and plot/print all the descriptives and properties along with KDE.

  Runs a loop: calculate all the descriptives of i(th) variable and plot/print it
  '''
  # calculating descriptives of variable
  mini = data[i].min()
  maxi = data[i].max()
  ran = data[i].max()-data[i].min()
  mean = data[i].mean()
  median = data[i].median()
  st_dev = data[i].std()
  skew = data[i].skew()
  kurt = data[i].kurtosis()

  # calculating points of standard deviation
  points = mean-st_dev, mean+st_dev

  #Plotting the variable with every information
  sns.kdeplot(data[i], shade=True)
  sns.lineplot(points, [0,0], color = 'black', label = "std_dev")
  sns.scatterplot([mini,maxi], [0,0], color = 'orange', label = "min/max")
  sns.scatterplot([mean], [0], color = 'red', label = "mean")
  sns.scatterplot([median], [0], color = 'blue', label = "median")
  plt.xlabel('{}'.format(i), fontsize = 20)
  plt.ylabel('density')
  plt.title('std_dev = {}; kurtosis = {};\nskew = {}; range = {}\nmean = {}; median = {}'.format((round(points[0],2),round(points[1],2)),
                                                                                                   round(kurt,2),
                                                                                                   round(skew,2),
                                                                                                   (round(mini,2),round(maxi,2),round(ran,2)),
                                                                                                   round(mean,2),
                                                                                                   round(median,2)))

# %%
# afficher détail Boxplot / UVA_num pour chaque indicateur par ligne

def UVA_num_plus(df, indicators_list):
  
    for i in indicators_list:
        plt.figure(figsize = (15, 20))
        df_indic = df[i]

        plt.subplot(5,2,1)
        sns.boxplot(y=df_indic)
        plt.xlabel(f'{i}', fontsize = 20)


        plt.subplot(5,2,2)
        UVA_numeric2(df, i)

# %% [markdown]
# ### Infos

# %%
num_cols = df.columns[df.dtypes == 'float64']
num_cols
# Out:
# Index(['ZipCode', 'Latitude', 'Longitude', 'NumberofBuildings',
#        'LargestPropertyUseTypeGFA', 'SecondLargestPropertyUseTypeGFA',
#        'ThirdLargestPropertyUseTypeGFA', 'ENERGYSTARScore', 'SiteEUI(kBtu/sf)',
#        'SiteEUIWN(kBtu/sf)', 'SourceEUI(kBtu/sf)', 'SourceEUIWN(kBtu/sf)',
#        'SiteEnergyUse(kBtu)', 'SiteEnergyUseWN(kBtu)', 'SteamUse(kBtu)',
#        'Electricity(kWh)', 'Electricity(kBtu)', 'NaturalGas(therms)',
#        'NaturalGas(kBtu)', 'Comments', 'TotalGHGEmissions',
#        'GHGEmissionsIntensity'],
#       dtype='object')

# %%
UVA_num_plus(df, num_cols)

# %%
num_cols
# Out:
# Index(['ZipCode', 'Latitude', 'Longitude', 'NumberofBuildings',
#        'LargestPropertyUseTypeGFA', 'SecondLargestPropertyUseTypeGFA',
#        'ThirdLargestPropertyUseTypeGFA', 'ENERGYSTARScore', 'SiteEUI(kBtu/sf)',
#        'SiteEUIWN(kBtu/sf)', 'SourceEUI(kBtu/sf)', 'SourceEUIWN(kBtu/sf)',
#        'SiteEnergyUse(kBtu)', 'SiteEnergyUseWN(kBtu)', 'SteamUse(kBtu)',
#        'Electricity(kWh)', 'Electricity(kBtu)', 'NaturalGas(therms)',
#        'NaturalGas(kBtu)', 'Comments', 'TotalGHGEmissions',
#        'GHGEmissionsIntensity'],
#       dtype='object')

# %%
df['NumberofBuildings'].value_counts()
# Out:
# 1.0      3175
# 0.0        92
# 2.0        37
# 3.0        22
# 4.0        12
# 5.0        10
# 6.0         5
# 8.0         3
# 10.0        2
# 14.0        2
# 9.0         2
# 7.0         1
# 11.0        1
# 16.0        1
# 23.0        1
# 27.0        1
# 111.0       1
# Name: NumberofBuildings, dtype: int64

# %%
# si volonté de réduire skewness => faire log
# bonus : faire log pour comparer (s'approche de la distribution normale)
# skewness négative => check doc

# %% [markdown]
# ## Feature reduction

# %%
df.head()
# Out:
#    OSEBuildingID  DataYear    BuildingType PrimaryPropertyType  \
# 0              1      2016  NonResidential               Hotel
# 1              2      2016  NonResidential               Hotel
# 2              3      2016  NonResidential               Hotel
# 3              5      2016  NonResidential               Hotel
# 4              8      2016  NonResidential               Hotel
#
#                   PropertyName          Address     City State  ZipCode  \
# 0         Mayflower park hotel    405 Olive way  Seattle    WA  98101.0
# 1              Paramount Hotel  724 Pine street  Seattle    WA  98101.0
# 2      5673-The Westin Seattle  1900 5th Avenue  Seattle    WA  98101.0
# 3                    HOTEL MAX   620 STEWART ST  Seattle    WA  98101.0
# 4  WARWICK SEATTLE HOTEL (ID8)    401 LENORA ST  Seattle    WA  98121.0
#
#   TaxParcelIdentificationNumber  CouncilDistrictCode Neighborhood  Latitude  \
# 0                    0659000030                    7     DOWNTOWN  47.61220
# 1                    0659000220                    7     DOWNTOWN  47.61317
# 2                    0659000475                    7     DOWNTOWN  47.61393
# 3                    0659000640                    7     DOWNTOWN  47.61412
# 4                    0659000970                    7     DOWNTOWN  47.61375
#
#    Longitude  YearBuilt  NumberofBuildings  NumberofFloors  PropertyGFATotal  \
# 0 -122.33799       1927                1.0              12             88434
# 1 -122.33393       1996                1.0              11            103566
# 2 -122.33810       1969                1.0              41            956110
# 3 -122.33664       1926                1.0              10             61320
# 4 -122.34047       1980                1.0              18            175580
#
#    PropertyGFAParking  PropertyGFABuilding(s)      ListOfAllPropertyUseTypes  \
# 0                   0                   88434                          Hotel
# 1               15064                   88502     Hotel, Parking, Restaurant
# 2              196718                  759392                          Hotel
# 3                   0                   61320                          Hotel
# 4               62000                  113580  Hotel, Parking, Swimming Pool
#
#   LargestPropertyUseType  LargestPropertyUseTypeGFA  \
# 0                  Hotel                    88434.0
# 1                  Hotel                    83880.0
# 2                  Hotel                   756493.0
# 3                  Hotel                    61320.0
# 4                  Hotel                   123445.0
#
#   SecondLargestPropertyUseType  SecondLargestPropertyUseTypeGFA  \
# 0                          NaN                              NaN
# 1                      Parking                          15064.0
# 2                          NaN                              NaN
# 3                          NaN                              NaN
# 4                      Parking                          68009.0
#
#   ThirdLargestPropertyUseType  ThirdLargestPropertyUseTypeGFA  \
# 0                         NaN                             NaN
# 1                  Restaurant                          4622.0
# 2                         NaN                             NaN
# 3                         NaN                             NaN
# 4               Swimming Pool                             0.0
#
#   YearsENERGYSTARCertified  ENERGYSTARScore  SiteEUI(kBtu/sf)  \
# 0                      NaN             60.0         81.699997
# 1                      NaN             61.0         94.800003
# 2                      NaN             43.0         96.000000
# 3                      NaN             56.0        110.800003
# 4                      NaN             75.0        114.800003
#
#    SiteEUIWN(kBtu/sf)  SourceEUI(kBtu/sf)  SourceEUIWN(kBtu/sf)  \
# 0           84.300003          182.500000            189.000000
# 1           97.900002          176.100006            179.399994
# 2           97.699997          241.899994            244.100006
# 3          113.300003          216.199997            224.000000
# 4          118.699997          211.399994            215.600006
#
#    SiteEnergyUse(kBtu)  SiteEnergyUseWN(kBtu)  SteamUse(kBtu)  \
# 0            7226362.5              7456910.0      2003882.00
# 1            8387933.0              8664479.0            0.00
# 2           72587024.0             73937112.0     21566554.00
# 3            6794584.0              6946800.5      2214446.25
# 4           14172606.0             14656503.0            0.00
#
#    Electricity(kWh)  Electricity(kBtu)  NaturalGas(therms)  NaturalGas(kBtu)  \
# 0      1.156514e+06          3946027.0         12764.52930         1276453.0
# 1      9.504252e+05          3242851.0         51450.81641         5145082.0
# 2      1.451544e+07         49526664.0         14938.00000         1493800.0
# 3      8.115253e+05          2768924.0         18112.13086         1811213.0
# 4      1.573449e+06          5368607.0         88039.98438         8803998.0
#
#    DefaultData  Comments ComplianceStatus Outlier  TotalGHGEmissions  \
# 0        False       NaN        Compliant     NaN             249.98
# 1        False       NaN        Compliant     NaN             295.86
# 2        False       NaN        Compliant     NaN            2089.28
# 3        False       NaN        Compliant     NaN             286.43
# 4        False       NaN        Compliant     NaN             505.01
#
#    GHGEmissionsIntensity                     geometry
# 0                   2.83  POINT (-122.33799 47.61220)
# 1                   2.86  POINT (-122.33393 47.61317)
# 2                   2.19  POINT (-122.33810 47.61393)
# 3                   4.67  POINT (-122.33664 47.61412)
# 4                   2.88  POINT (-122.34047 47.61375)

# %% [markdown]
# ### Retrait colonne 'Outlier'

# %%
df.shape
# Out:
# (3376, 47)

# %%
df['Outlier'].head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: Outlier, dtype: object

# %%
df = df[df['Outlier'].isnull()]

# %%
df.shape
# Out:
# (3344, 47)

# %%
df['Outlier'].value_counts()
# Out:
# Series([], Name: Outlier, dtype: int64)

# %% [markdown]
# ### PropertyName

# %%
df['PropertyName'].nunique()
# Out:
# 3330

# %%
df['PropertyName'].unique()
# Out:
# array(['Mayflower park hotel', 'Paramount Hotel',
#        '5673-The Westin Seattle', ..., 'Queen Anne Pool',
#        'South Park Community Center', 'Van Asselt Community Center'],
#       dtype=object)

# %%
# => to delete, is unique / pretty much and ID

# %% [markdown]
# ### Retrait des colonnes non-utilisables / redondantes

# %%
df.columns
# Out:
# Index(['OSEBuildingID', 'DataYear', 'BuildingType', 'PrimaryPropertyType',
#        'PropertyName', 'Address', 'City', 'State', 'ZipCode',
#        'TaxParcelIdentificationNumber', 'CouncilDistrictCode', 'Neighborhood',
#        'Latitude', 'Longitude', 'YearBuilt', 'NumberofBuildings',
#        'NumberofFloors', 'PropertyGFATotal', 'PropertyGFAParking',
#        'PropertyGFABuilding(s)', 'ListOfAllPropertyUseTypes',
#        'LargestPropertyUseType', 'LargestPropertyUseTypeGFA',
#        'SecondLargestPropertyUseType', 'SecondLargestPropertyUseTypeGFA',
#        'ThirdLargestPropertyUseType', 'ThirdLargestPropertyUseTypeGFA',
#        'YearsENERGYSTARCertified', 'ENERGYSTARScore', 'SiteEUI(kBtu/sf)',
#        'SiteEUIWN(kBtu/sf)', 'SourceEUI(kBtu/sf)', 'SourceEUIWN(kBtu/sf)',
#        'SiteEnergyUse(kBtu)', 'SiteEnergyUseWN(kBtu)', 'SteamUse(kBtu)',
#        'Electricity(kWh)', 'Electricity(kBtu)', 'NaturalGas(therms)',
#        'NaturalGas(kBtu)', 'DefaultData', 'Comments', 'ComplianceStatus',
#        'Outlier', 'TotalGHGEmissions', 'GHGEmissionsIntensity', 'geometry'],
#       dtype='object')

# %%
df['geometry'].nunique()
# Out:
# 3253

# %%
cols_to_drop = [
    'DataYear', #annee collecte donnees
    'OSEBuildingID', # inutilisé
    'City', #une seule valeur unique
    'State', #une seule valeur unique
    'PropertyName', #inutilisé, nom de la propriété
    'TaxParcelIdentificationNumber', #inutilisé
    'Address', #redondant avec latitude / longitude
    #'ZipCode', #redondant avec adresse
    'CouncilDistrictCode', #redondant adresse
    'Latitude', #redondant adresse
    'Longitude', #redondant adresse
    #'Neighborhood',
    'Comments', # 100% de données manquantes
    'Outlier', # 99% de données manquantes, a permis de retirer précedemment les lignes libellées "outlier"
    'YearsENERGYSTARCertified', #96.5% de données manquantes
    #'ENERGYSTARScore', # 25% de données manquantes, à garder pour évaluer si il permet d'améliorer pred ou pas des modèles
    'ListOfAllPropertyUseTypes' # redondant
]

# %%
df.shape
# Out:
# (3344, 47)

# %%
cols_to_drop += [
    'LargestPropertyUseTypeGFA',
    'SecondLargestPropertyUseTypeGFA',
    'ThirdLargestPropertyUseTypeGFA',
    'ComplianceStatus',
    'DefaultData',
    'geometry'
]

# %%
cols_to_drop += [
    'SiteEUI(kBtu/sf)',
    'SiteEUIWN(kBtu/sf)',
    'SourceEUI(kBtu/sf)',
    'SourceEUIWN(kBtu/sf)',
    'SiteEnergyUse(kBtu)',
    #'SiteEnergyUseWN(kBtu)', -- comporte une prédiction
    'SteamUse(kBtu)',
    'Electricity(kWh)',
    'Electricity(kBtu)',
    'NaturalGas(therms)',
    'NaturalGas(kBtu)',
    'GHGEmissionsIntensity'
]

# %%
df['SiteEnergyUseWN(kBtu)'].nunique()
# Out:
# 3309

# %%
df['SiteEnergyUseWN(kBtu)'].value_counts()
# Out:
# 0.000          29
# 2127889.250     2
# 630412.625      1
# 1355995.250     1
# 1439042.250     1
#                ..
# 1325461.750     1
# 3859690.500     1
# 1214408.750     1
# 6853384.500     1
# 1293722.375     1
# Name: SiteEnergyUseWN(kBtu), Length: 3309, dtype: int64

# %%
cols_to_drop
# Out:
# ['DataYear',
#  'OSEBuildingID',
#  'City',
#  'State',
#  'PropertyName',
#  'TaxParcelIdentificationNumber',
#  'Address',
#  'CouncilDistrictCode',
#  'Latitude',
#  'Longitude',
#  'Comments',
#  'Outlier',
#  'YearsENERGYSTARCertified',
#  'ListOfAllPropertyUseTypes',
#  'LargestPropertyUseTypeGFA',
#  'SecondLargestPropertyUseTypeGFA',
#  'ThirdLargestPropertyUseTypeGFA',
#  'ComplianceStatus',
#  'DefaultData',
#  'geometry',
#  'SiteEUI(kBtu/sf)',
#  'SiteEUIWN(kBtu/sf)',
#  'SourceEUI(kBtu/sf)',
#  'SourceEUIWN(kBtu/sf)',
#  'SiteEnergyUse(kBtu)',
#  'SteamUse(kBtu)',
#  'Electricity(kWh)',
#  'Electricity(kBtu)',
#  'NaturalGas(therms)',
#  'NaturalGas(kBtu)',
#  'GHGEmissionsIntensity']

# %%
df.shape
# Out:
# (3344, 47)

# %%
df.drop(cols_to_drop, axis=1, inplace=True)

# %%
df.shape
# Out:
# (3344, 16)

# %%
show_nulls(df)
# Out:
#                                                    columns  count  \
# ThirdLargestPropertyUseType    ThirdLargestPropertyUseType   2755
# SecondLargestPropertyUseType  SecondLargestPropertyUseType   1681
# ENERGYSTARScore                            ENERGYSTARScore    834
# LargestPropertyUseType              LargestPropertyUseType     20
# ZipCode                                            ZipCode     16
# TotalGHGEmissions                        TotalGHGEmissions      9
# NumberofBuildings                        NumberofBuildings      8
# SiteEnergyUseWN(kBtu)                SiteEnergyUseWN(kBtu)      6
# BuildingType                                  BuildingType      0
# PrimaryPropertyType                    PrimaryPropertyType      0
# Neighborhood                                  Neighborhood      0
# YearBuilt                                        YearBuilt      0
# NumberofFloors                              NumberofFloors      0
# PropertyGFATotal                          PropertyGFATotal      0
# PropertyGFAParking                      PropertyGFAParking      0
# PropertyGFABuilding(s)              PropertyGFABuilding(s)      0
#
#                               null_percent
# ThirdLargestPropertyUseType           82.4
# SecondLargestPropertyUseType          50.3
# ENERGYSTARScore                       24.9
# LargestPropertyUseType                 0.6
# ZipCode                                0.5
# TotalGHGEmissions                      0.3
# NumberofBuildings                      0.2
# SiteEnergyUseWN(kBtu)                  0.2
# BuildingType                           0.0
# PrimaryPropertyType                    0.0
# Neighborhood                           0.0
# YearBuilt                              0.0
# NumberofFloors                         0.0
# PropertyGFATotal                       0.0
# PropertyGFAParking                     0.0
# PropertyGFABuilding(s)                 0.0

# %%
### remplir vides

# %% [markdown]
# ### garder uniquement batiments non-résidentiels

# %% [markdown]
# #### Col BuildingType

# %%
# garder uniquement batiments non-résidentiels
df['BuildingType'].unique()
# Out:
# array(['NonResidential', 'Nonresidential COS', 'Multifamily MR (5-9)',
#        'SPS-District K-12', 'Campus', 'Multifamily LR (1-4)',
#        'Multifamily HR (10+)', 'Nonresidential WA'], dtype=object)

# %%
# get rows with BuildingType with 'Multifamily' prefix
# count code values with 200 prefix
df['BuildingType'].loc[df['BuildingType'].str.startswith('Multifamily')]
# Out:
# 9       Multifamily MR (5-9)
# 165     Multifamily MR (5-9)
# 173     Multifamily MR (5-9)
# 188     Multifamily LR (1-4)
# 189     Multifamily MR (5-9)
#                 ...
# 3353    Multifamily MR (5-9)
# 3354    Multifamily MR (5-9)
# 3355    Multifamily MR (5-9)
# 3357    Multifamily MR (5-9)
# 3358    Multifamily LR (1-4)
# Name: BuildingType, Length: 1693, dtype: object

# %%
df.shape
# Out:
# (3344, 16)

# %%
# remove "MultiFamily" related rows
df = df.loc[~df['BuildingType'].str.startswith('Multifamily')]

# %%
df['BuildingType'].unique()
# Out:
# array(['NonResidential', 'Nonresidential COS', 'SPS-District K-12',
#        'Campus', 'Nonresidential WA'], dtype=object)

# %%
#df['BuildingType'].unique()

# %%
df.shape
# Out:
# (1651, 16)

# %%
df['BuildingType'].unique()
# Out:
# array(['NonResidential', 'Nonresidential COS', 'SPS-District K-12',
#        'Campus', 'Nonresidential WA'], dtype=object)

# %%
df['BuildingType'].value_counts()
# Out:
# NonResidential        1445
# SPS-District K-12       97
# Nonresidential COS      84
# Campus                  24
# Nonresidential WA        1
# Name: BuildingType, dtype: int64

# %%
#from sklearn import preprocessing
#le = preprocessing.LabelEncoder()

# %%
#df[cat_cols] = le.fit_transform(df[cat_cols].astype(str))

# %% [markdown]
# #### PrimaryPropertyType

# %%
df['PrimaryPropertyType'].isna().sum()
# Out:
# 0

# %%
df['PrimaryPropertyType'].value_counts()
# Out:
# Small- and Mid-Sized Office    289
# Other                          247
# Warehouse                      187
# Large Office                   170
# K-12 School                    137
# Mixed Use Property             114
# Retail Store                    89
# Hotel                           75
# Worship Facility                69
# Distribution Center             53
# Supermarket / Grocery Store     40
# Medical Office                  39
# Self-Storage Facility           28
# University                      24
# Residence Hall                  21
# Senior Care Community           20
# Refrigerated Warehouse          12
# Restaurant                      12
# Hospital                        10
# Laboratory                      10
# Office                           3
# Low-Rise Multifamily             2
# Name: PrimaryPropertyType, dtype: int64

# %%
search_strings = ["housing", "residence", "residential", "Dormitory", "senior care community", "family"]
df.loc[df['PrimaryPropertyType'].str.lower().str.contains('|'.join(search_strings), na=False)]
# Out:
#         BuildingType    PrimaryPropertyType  ZipCode           Neighborhood  \
# 59    NonResidential  Senior Care Community  98126.0              SOUTHWEST
# 60    NonResidential  Senior Care Community  98133.0              NORTHWEST
# 115   NonResidential         Residence Hall  98119.0  MAGNOLIA / QUEEN ANNE
# 171   NonResidential  Senior Care Community  98104.0               DOWNTOWN
# 186   NonResidential         Residence Hall  98101.0               DOWNTOWN
# 644   NonResidential   Low-Rise Multifamily  98103.0             LAKE UNION
# 858   NonResidential         Residence Hall  98105.0              NORTHEAST
# 888   NonResidential  Senior Care Community  98104.0                   EAST
# 890   NonResidential         Residence Hall  98105.0              NORTHEAST
# 934   NonResidential         Residence Hall  98105.0              NORTHEAST
# 952   NonResidential         Residence Hall  98104.0                   EAST
# 966   NonResidential  Senior Care Community  98144.0              SOUTHEAST
# 1104  NonResidential         Residence Hall  98103.0             LAKE UNION
# 1109  NonResidential  Senior Care Community  98117.0                BALLARD
# 1123  NonResidential  Senior Care Community  98118.0              SOUTHEAST
# 1208  NonResidential  Senior Care Community  98109.0  MAGNOLIA / QUEEN ANNE
# 1210  NonResidential         Residence Hall  98121.0               DOWNTOWN
# 1300          Campus   Low-Rise Multifamily  98101.0               DOWNTOWN
# 1418  NonResidential  Senior Care Community  98109.0             LAKE UNION
# 1456  NonResidential  Senior Care Community  98133.0              NORTHWEST
# 1643  NonResidential  Senior Care Community  98125.0                  NORTH
# 1745  NonResidential         Residence Hall  98104.0                   EAST
# 2202  NonResidential  Senior Care Community  98133.0                  NORTH
# 2467  NonResidential  Senior Care Community  98101.0                   EAST
# 2524  NonResidential  Senior Care Community  98112.0                   EAST
# 2540  NonResidential         Residence Hall  98109.0  MAGNOLIA / QUEEN ANNE
# 2584  NonResidential  Senior Care Community  98118.0              SOUTHEAST
# 2623  NonResidential  Senior Care Community  98103.0              NORTHWEST
# 2628  NonResidential  Senior Care Community  98125.0                  NORTH
# 2775  NonResidential         Residence Hall  98105.0              NORTHEAST
# 2778  NonResidential         Residence Hall  98105.0              NORTHEAST
# 2779  NonResidential         Residence Hall  98105.0              NORTHEAST
# 2781  NonResidential         Residence Hall  98105.0              NORTHEAST
# 2783  NonResidential  Senior Care Community  98122.0                CENTRAL
# 2805  NonResidential         Residence Hall  98177.0              NORTHEAST
# 3175  NonResidential         Residence Hall  98195.0              NORTHEAST
# 3176  NonResidential         Residence Hall  98195.0              NORTHEAST
# 3228  NonResidential  Senior Care Community  98112.0                CENTRAL
# 3267  NonResidential  Senior Care Community  98101.0               DOWNTOWN
# 3276  NonResidential         Residence Hall  98105.0              NORTHEAST
# 3278  NonResidential         Residence Hall  98195.0              NORTHEAST
# 3279  NonResidential         Residence Hall  98195.0              NORTHEAST
# 3280  NonResidential         Residence Hall  98195.0              NORTHEAST
#
#       YearBuilt  NumberofBuildings  NumberofFloors  PropertyGFATotal  \
# 59         1922                1.0               5            217603
# 60         1970                1.0               2             93397
# 115        2001                1.0               4            139600
# 171        1999                1.0               5            102796
# 186        1913                1.0               9            107572
# 644        2000                1.0               3             93079
# 858        1921                1.0               3             21499
# 888        2006                1.0               6             62334
# 890        1930                1.0               3             20960
# 934        1993                1.0               3             28572
# 952        1982                0.0              15            115775
# 966        1981                1.0               3             78374
# 1104       1988                1.0               3             21118
# 1109       1966                1.0               2             34636
# 1123       1966                1.0               2             48882
# 1208       1970                1.0               2             46539
# 1210       1909                1.0               4             29796
# 1300       1942                1.0               4             45500
# 1418       2006                1.0              14            724148
# 1456       1954                1.0               2             51298
# 1643       1998                1.0               5             43661
# 1745       1904                1.0               1             44086
# 2202       2009                1.0               6            244500
# 2467       1969                1.0               6             95117
# 2524       1963                1.0              16            153312
# 2540       1981                1.0               4             23513
# 2584       1967                1.0               1            141297
# 2623       1961                1.0               2             55974
# 2628       1954                1.0               1             22583
# 2775       1929                1.0               3             22124
# 2778       1926                1.0               3             27487
# 2779       1926                1.0               4             23616
# 2781       1976                1.0               3             33448
# 2783       1987                1.0               2             74840
# 2805       1950                1.0               3             29084
# 3175       2012                1.0               5            136758
# 3176       2012                1.0               7            192259
# 3228       2013                1.0               6             79805
# 3267       1989                1.0               3            197395
# 3276       2011                1.0               0            176225
# 3278       1953                1.0               0            166991
# 3279       1970                1.0               0             89392
# 3280       2011                1.0               0             97040
#
#       PropertyGFAParking  PropertyGFABuilding(s)    LargestPropertyUseType  \
# 59                     0                  217603     Senior Care Community
# 60                     0                   93397     Senior Care Community
# 115                37500                  102100  Residence Hall/Dormitory
# 171                12611                   90185     Senior Care Community
# 186                    0                  107572  Residence Hall/Dormitory
# 644                36093                   56986       Multifamily Housing
# 858                    0                   21499  Residence Hall/Dormitory
# 888                    0                   62334     Senior Care Community
# 890                    0                   20960  Residence Hall/Dormitory
# 934                    0                   28572  Residence Hall/Dormitory
# 952                31535                   84240  Residence Hall/Dormitory
# 966                    0                   78374     Senior Care Community
# 1104                   0                   21118  Residence Hall/Dormitory
# 1109               31000                    3636     Senior Care Community
# 1123                7233                   41649     Senior Care Community
# 1208                   0                   46539     Senior Care Community
# 1210                   0                   29796  Residence Hall/Dormitory
# 1300                   0                   45500       Multifamily Housing
# 1418                   0                  724148     Senior Care Community
# 1456                   0                   51298     Senior Care Community
# 1643                   0                   43661     Senior Care Community
# 1745                   0                   44086  Residence Hall/Dormitory
# 2202                   0                  244500     Senior Care Community
# 2467               26082                   69035     Senior Care Community
# 2524                   0                  153312     Senior Care Community
# 2540                2211                   21302  Residence Hall/Dormitory
# 2584                   0                  141297     Senior Care Community
# 2623                   0                   55974     Senior Care Community
# 2628                   0                   22583     Senior Care Community
# 2775                   0                   22124  Residence Hall/Dormitory
# 2778                   0                   27487  Residence Hall/Dormitory
# 2779                   0                   23616  Residence Hall/Dormitory
# 2781                   0                   33448  Residence Hall/Dormitory
# 2783                   0                   74840     Senior Care Community
# 2805                   0                   29084  Residence Hall/Dormitory
# 3175                   0                  136758  Residence Hall/Dormitory
# 3176                   0                  192259  Residence Hall/Dormitory
# 3228                   0                   79805     Senior Care Community
# 3267              156000                   41395     Senior Care Community
# 3276                   0                  176225  Residence Hall/Dormitory
# 3278                   0                  166991  Residence Hall/Dormitory
# 3279                   0                   89392  Residence Hall/Dormitory
# 3280                   0                   97040  Residence Hall/Dormitory
#
#      SecondLargestPropertyUseType ThirdLargestPropertyUseType  \
# 59                        Parking                         NaN
# 60                            NaN                         NaN
# 115                           NaN                         NaN
# 171                Medical Office                 K-12 School
# 186                        Office                Retail Store
# 644                           NaN                         NaN
# 858                           NaN                         NaN
# 888                   Bank Branch                     Parking
# 890                           NaN                         NaN
# 934                       Parking                         NaN
# 952                        Office                         NaN
# 966                       Parking                         NaN
# 1104                          NaN                         NaN
# 1109                      Parking                         NaN
# 1123                      Parking                         NaN
# 1208                          NaN                         NaN
# 1210                          NaN                         NaN
# 1300                 Retail Store                  Restaurant
# 1418                          NaN                         NaN
# 1456                          NaN                         NaN
# 1643                      Parking                         NaN
# 1745                          NaN                         NaN
# 2202                          NaN                         NaN
# 2467                      Parking                         NaN
# 2524                      Parking            Worship Facility
# 2540                       Office         Social/Meeting Hall
# 2584                          NaN                         NaN
# 2623                          NaN                         NaN
# 2628                          NaN                         NaN
# 2775                          NaN                         NaN
# 2778                          NaN                         NaN
# 2779                          NaN                         NaN
# 2781                          NaN                         NaN
# 2783                          NaN                         NaN
# 2805                          NaN                         NaN
# 3175                          NaN                         NaN
# 3176    Supermarket/Grocery Store                         NaN
# 3228                      Parking                         NaN
# 3267      Other - Public Services                      Office
# 3276                      Parking                         NaN
# 3278                          NaN                         NaN
# 3279                          NaN                         NaN
# 3280                          NaN                         NaN
#
#       ENERGYSTARScore  SiteEnergyUseWN(kBtu)  TotalGHGEmissions
# 59               54.0           4.554725e+07            1727.11
# 60                1.0           1.695975e+07             609.10
# 115              89.0           4.800620e+06             129.39
# 171               NaN           1.028140e+07             193.94
# 186              76.0           5.879083e+06             254.87
# 644              32.0           2.090012e+06              25.60
# 858              85.0           6.051307e+05               4.22
# 888             100.0           1.147752e+06              34.98
# 890               NaN           1.667310e+06              64.51
# 934              16.0           2.759012e+06              89.57
# 952              94.0           3.042217e+06              20.09
# 966              98.0           3.397766e+06              23.15
# 1104             49.0           1.427645e+06              39.50
# 1109              3.0           1.280571e+07             480.90
# 1123             51.0           7.048919e+06             235.26
# 1208             73.0           5.589312e+06             180.38
# 1210             47.0           2.309753e+06              79.58
# 1300              NaN           3.778355e+06              26.34
# 1418              8.0           3.912083e+07             913.07
# 1456             85.0           5.847878e+06             203.73
# 1643              4.0           4.141925e+06              82.57
# 1745             29.0           4.056816e+06             184.00
# 2202            100.0           1.131474e+07             292.80
# 2467              1.0           7.437745e+06             183.79
# 2524             51.0           2.209284e+07             792.60
# 2540              NaN           1.778252e+06              49.79
# 2584             76.0           2.037884e+07             717.93
# 2623             98.0           6.412428e+06             203.21
# 2628             95.0           2.123592e+06              70.92
# 2775             82.0           6.520600e+05               4.45
# 2778             82.0           1.753312e+06              65.95
# 2779             55.0           1.771038e+06              53.65
# 2781             78.0           1.073833e+06               6.96
# 2783             48.0           8.485438e+06             249.46
# 2805             66.0           1.741865e+06              60.83
# 3175             90.0           6.662918e+06             175.46
# 3176             72.0           9.286532e+06             191.97
# 3228             25.0           7.692164e+06             184.81
# 3267              NaN           2.842128e+06              58.28
# 3276             91.0           5.209464e+06             103.65
# 3278             19.0           1.659197e+07             437.20
# 3279             16.0           7.483350e+06              48.53
# 3280             69.0           4.075094e+06              62.41

# %%
df.loc[df['PrimaryPropertyType'].str.lower().str.contains('|'.join(search_strings), na=False)].any(1).count()
# Out:
# 43

# %%
df.shape
# Out:
# (1651, 16)

# %%
df.loc[~df['PrimaryPropertyType'].str.lower().str.contains('|'.join(search_strings), na=False)].any(1).count()
# Out:
# 1608

# %%
df = df.loc[~df['PrimaryPropertyType'].str.lower().str.contains('|'.join(search_strings), na=False)]

# %%
df.shape
# Out:
# (1608, 16)

# %% [markdown]
# ##### col LargestPropertyUseType

# %%
# fill nas with "No UseType"
df[['LargestPropertyUseType', 'SecondLargestPropertyUseType', 'ThirdLargestPropertyUseType']] = df[['LargestPropertyUseType', 'SecondLargestPropertyUseType', 'ThirdLargestPropertyUseType']].fillna('No UseType')

# %%
df['LargestPropertyUseType'].isna().sum()
# Out:
# 0

# %%
df['LargestPropertyUseType'].unique()
# Out:
# array(['Hotel', 'Police Station', 'Other - Entertainment/Public Assembly',
#        'Library', 'Fitness Center/Health Club/Gym', 'Social/Meeting Hall',
#        'Courthouse', 'Other', 'K-12 School', 'College/University',
#        'Automobile Dealership', 'Office', 'Self-Storage Facility',
#        'Non-Refrigerated Warehouse', 'Other - Mall', 'Medical Office',
#        'Retail Store', 'Hospital (General Medical & Surgical)', 'Museum',
#        'Repair Services (Vehicle, Shoe, Locksmith, etc)',
#        'Other - Lodging/Residential', 'Other/Specialty Hospital',
#        'Financial Office', 'Distribution Center', 'Parking',
#        'Multifamily Housing', 'Worship Facility', 'Restaurant',
#        'Data Center', 'Laboratory', 'Supermarket/Grocery Store',
#        'Convention Center', 'Urgent Care/Clinic/Other Outpatient',
#        'No UseType', 'Other - Services', 'Strip Mall',
#        'Wholesale Club/Supercenter', 'Refrigerated Warehouse',
#        'Manufacturing/Industrial Plant', 'Other - Recreation',
#        'Lifestyle Center', 'Other - Public Services', 'Other - Education',
#        'Fire Station', 'Performing Arts', 'Residential Care Facility',
#        'Bank Branch', 'Other - Restaurant/Bar', 'Food Service',
#        'Adult Education', 'Other - Utility', 'Movie Theater',
#        'Personal Services (Health/Beauty, Dry Cleaning, etc)',
#        'Residence Hall/Dormitory', 'Pre-school/Daycare',
#        'Prison/Incarceration'], dtype=object)

# %%
search_strings = ["housing", "residence", "residential", "dormitory"]
df['LargestPropertyUseType'].str.lower().str.contains('|'.join(search_strings)).sum()
# Out:
# 16

# %%
df.loc[df['LargestPropertyUseType'].str.lower().str.contains('|'.join(search_strings), na=False)]
# Out:
#             BuildingType PrimaryPropertyType  ZipCode           Neighborhood  \
# 113       NonResidential               Other  98118.0       GREATER DUWAMISH
# 164       NonResidential  Mixed Use Property  98119.0  MAGNOLIA / QUEEN ANNE
# 1159      NonResidential  Mixed Use Property  98103.0             LAKE UNION
# 1194  Nonresidential COS               Other  98133.0              NORTHWEST
# 1839      NonResidential  Mixed Use Property  98104.0               DOWNTOWN
# 1928      NonResidential               Other  98134.0       GREATER DUWAMISH
# 2314      NonResidential  Mixed Use Property  98101.0               DOWNTOWN
# 2394      NonResidential  Mixed Use Property  98105.0              NORTHEAST
# 2407      NonResidential  Mixed Use Property  98104.0               DOWNTOWN
# 2711      NonResidential               Other  98104.0               DOWNTOWN
# 2748      NonResidential  Mixed Use Property  98104.0               DOWNTOWN
# 2774      NonResidential               Other  98105.0              NORTHEAST
# 2995      NonResidential               Other  98122.0                CENTRAL
# 3003      NonResidential  Mixed Use Property  98122.0                   EAST
# 3041      NonResidential  Mixed Use Property  98122.0                CENTRAL
# 3087      NonResidential  Mixed Use Property  98104.0                   EAST
#
#       YearBuilt  NumberofBuildings  NumberofFloors  PropertyGFATotal  \
# 113        2009                1.0               5             89821
# 164        2002                1.0               4            110785
# 1159       2001                5.0               3             41827
# 1194       1970                1.0               4             25557
# 1839       1913                1.0               3             43878
# 1928       1992                1.0               3             47836
# 2314       2009                1.0              39           1074552
# 2394       1997                1.0               4             32282
# 2407       2005                0.0               5             57600
# 2711       1904                1.0               6             29820
# 2748       1909                1.0               3             20620
# 2774       1924                1.0               3             20686
# 2995       1911                1.0               3             25200
# 3003       1998                1.0               5             53034
# 3041       2004                1.0               6             97229
# 3087       1900                1.0               3             22168
#
#       PropertyGFAParking  PropertyGFABuilding(s)       LargestPropertyUseType  \
# 113                    0                   89821  Other - Lodging/Residential
# 164                    0                  110785          Multifamily Housing
# 1159                9226                   32601          Multifamily Housing
# 1194                   0                   25557    Residential Care Facility
# 1839                   0                   43878          Multifamily Housing
# 1928                7572                   40264  Other - Lodging/Residential
# 2314              112124                  962428          Multifamily Housing
# 2394                6985                   25297          Multifamily Housing
# 2407                   0                   57600     Residence Hall/Dormitory
# 2711                   0                   29820  Other - Lodging/Residential
# 2748                   0                   20620          Multifamily Housing
# 2774                   0                   20686  Other - Lodging/Residential
# 2995                   0                   25200  Other - Lodging/Residential
# 3003               14625                   38409          Multifamily Housing
# 3041                   0                   97229          Multifamily Housing
# 3087                   0                   22168          Multifamily Housing
#
#                SecondLargestPropertyUseType ThirdLargestPropertyUseType  \
# 113                                  Office                Food Service
# 164               Supermarket/Grocery Store                     Parking
# 1159                                 Office                     Parking
# 1194                             No UseType                  No UseType
# 1839                                 Office                Retail Store
# 1928                                Parking                  No UseType
# 2314                                  Hotel                     Parking
# 2394                                Parking                       Other
# 2407                    Multifamily Housing            Financial Office
# 2711                             No UseType                  No UseType
# 2748                           Retail Store         Social/Meeting Hall
# 2774                             No UseType                  No UseType
# 2995                             No UseType                  No UseType
# 3003              Supermarket/Grocery Store                     Parking
# 3041                                Parking                Retail Store
# 3087  Other - Entertainment/Public Assembly                  No UseType
#
#       ENERGYSTARScore  SiteEnergyUseWN(kBtu)  TotalGHGEmissions
# 113               NaN           2.220796e+06             100.46
# 164               NaN           1.086403e+07              92.91
# 1159              NaN           4.288602e+06             110.17
# 1194              NaN           2.280352e+06              15.90
# 1839              NaN           7.697713e+05               5.37
# 1928              NaN           3.647847e+06             109.59
# 2314             65.0           2.693220e+07             449.59
# 2394              NaN           1.500695e+06              34.62
# 2407              NaN           7.355579e+06             223.36
# 2711              NaN           1.624991e+06              35.72
# 2748              NaN           7.919269e+05              20.78
# 2774              NaN           1.321763e+06              42.71
# 2995              NaN           1.407295e+06              53.02
# 3003             93.0           3.518100e+06              83.65
# 3041            100.0           1.056508e+06               7.12
# 3087              NaN           1.904848e+06              49.44

# %%
df.shape
# Out:
# (1608, 16)

# %%
df.loc[df['LargestPropertyUseType'].str.lower().str.contains('|'.join(search_strings), na=False)].any(1).sum()
# Out:
# 16

# %%
df.loc[~df['LargestPropertyUseType'].str.lower().str.contains('|'.join(search_strings), na=False)].any(1).sum()
# Out:
# 1592

# %%
df = df.loc[~df['LargestPropertyUseType'].str.lower().str.contains('|'.join(search_strings), na=False)]

# %%
df.shape
# Out:
# (1592, 16)

# %% [markdown]
# #### SecondLargestPropertyUseType

# %%
df['SecondLargestPropertyUseType'].isna().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (1592, 16)

# %%
df['SecondLargestPropertyUseType'].unique()
# Out:
# array(['No UseType', 'Parking', 'Office', 'Restaurant', 'K-12 School',
#        'Laboratory', 'Refrigerated Warehouse',
#        'Non-Refrigerated Warehouse', 'Other - Education',
#        'Vocational School', 'Retail Store',
#        'Personal Services (Health/Beauty, Dry Cleaning, etc)',
#        'Other - Entertainment/Public Assembly', 'Data Center',
#        'Swimming Pool', 'Other', 'Courthouse', 'Residence Hall/Dormitory',
#        'Distribution Center', 'Self-Storage Facility', 'Other - Services',
#        'Movie Theater', 'Other - Recreation',
#        'Convenience Store without Gas Station', 'Performing Arts',
#        'College/University', 'Supermarket/Grocery Store',
#        'Other - Restaurant/Bar', 'Adult Education', 'Medical Office',
#        'Enclosed Mall', 'Multifamily Housing', 'Bar/Nightclub',
#        'Financial Office',
#        'Repair Services (Vehicle, Shoe, Locksmith, etc)',
#        'Manufacturing/Industrial Plant', 'Other - Lodging/Residential',
#        'Bank Branch', 'Fitness Center/Health Club/Gym', 'Hotel',
#        'Worship Facility', 'Food Sales', 'Other - Public Services',
#        'Food Service', 'Pre-school/Daycare', 'Social/Meeting Hall',
#        'Hospital (General Medical & Surgical)', 'Automobile Dealership'],
#       dtype=object)

# %%
search_strings = ["housing", "residence", "residential", "dormitory"]
df['SecondLargestPropertyUseType'].str.lower().str.contains('|'.join(search_strings)).sum()
# Out:
# 13

# %%
df.loc[df['SecondLargestPropertyUseType'].str.lower().str.contains('|'.join(search_strings), na=False)]
# Out:
#             BuildingType          PrimaryPropertyType  ZipCode  \
# 146   Nonresidential COS                    Warehouse  98109.0
# 488       NonResidential           Mixed Use Property  98121.0
# 511       NonResidential                 Large Office  98134.0
# 541       NonResidential           Mixed Use Property  98134.0
# 731       NonResidential  Small- and Mid-Sized Office  98121.0
# 912       NonResidential           Mixed Use Property  98107.0
# 922       NonResidential                        Other  98105.0
# 1167      NonResidential  Small- and Mid-Sized Office  98103.0
# 1315      NonResidential           Mixed Use Property  98121.0
# 1773      NonResidential           Mixed Use Property  98011.0
# 2530      NonResidential           Mixed Use Property  98121.0
# 2791      NonResidential           Mixed Use Property  98104.0
# 3163      NonResidential           Mixed Use Property  98104.0
#
#                Neighborhood  YearBuilt  NumberofBuildings  NumberofFloors  \
# 146   MAGNOLIA / QUEEN ANNE       1926                1.0               2
# 488                DOWNTOWN       2006                0.0               0
# 511        GREATER DUWAMISH       2007                1.0               1
# 541        GREATER DUWAMISH       1930                3.0               2
# 731                DOWNTOWN       1917                1.0               2
# 912                 BALLARD       1960                1.0               4
# 922               NORTHEAST       1921                1.0               3
# 1167             LAKE UNION       1981                1.0               2
# 1315               DOWNTOWN       1910                1.0               3
# 1773               DOWNTOWN       1909                1.0              11
# 2530               DOWNTOWN       2009                1.0              19
# 2791               DOWNTOWN       1909                1.0               3
# 3163               DOWNTOWN       1902                1.0               6
#
#       PropertyGFATotal  PropertyGFAParking  PropertyGFABuilding(s)  \
# 146              50292                   0                   50292
# 488             516407                   0                  516407
# 511             158931               28381                  130550
# 541             108753               18860                   89893
# 731              21600                   0                   21600
# 912              20539                   0                   20539
# 922              29636                   0                   29636
# 1167             22388                   0                   22388
# 1315             29340                   0                   29340
# 1773            111137                   0                  111137
# 2530           1206670              201857                 1004813
# 2791             49299                   0                   49299
# 3163             74211                   0                   74211
#
#                      LargestPropertyUseType SecondLargestPropertyUseType  \
# 146              Non-Refrigerated Warehouse     Residence Hall/Dormitory
# 488                                 Parking          Multifamily Housing
# 511                                  Office          Multifamily Housing
# 541              Non-Refrigerated Warehouse          Multifamily Housing
# 731                                  Office  Other - Lodging/Residential
# 912                            Retail Store          Multifamily Housing
# 922   Other - Entertainment/Public Assembly          Multifamily Housing
# 1167                                 Office          Multifamily Housing
# 1315                                 Office          Multifamily Housing
# 1773                                 Office          Multifamily Housing
# 2530                                 Office          Multifamily Housing
# 2791                                 Office          Multifamily Housing
# 3163                                 Office          Multifamily Housing
#
#      ThirdLargestPropertyUseType  ENERGYSTARScore  SiteEnergyUseWN(kBtu)  \
# 146                       Office              NaN           4.304737e+05
# 488                        Hotel             31.0           4.075436e+07
# 511                      Parking             12.0           9.336260e+06
# 541                 Retail Store              NaN           3.714717e+06
# 731                   No UseType              NaN           1.636649e+06
# 912                   Restaurant              NaN           1.695248e+06
# 922                   No UseType              NaN           6.886418e+05
# 1167                  No UseType              NaN           6.051827e+05
# 1315                  Restaurant              NaN           2.370772e+06
# 1773                 Bank Branch              NaN           9.946297e+06
# 2530                     Parking             87.0           2.791769e+07
# 2791                  Restaurant              NaN           4.821852e+06
# 3163                     Parking             97.0           1.438857e+06
#
#       TotalGHGEmissions
# 146                3.00
# 488              734.72
# 511               98.54
# 541               25.37
# 731               29.62
# 912               37.31
# 922                4.80
# 1167               9.46
# 1315              75.99
# 1773             294.65
# 2530             393.29
# 2791               9.23
# 3163               9.46

# %%
df.shape
# Out:
# (1592, 16)

# %%
df.loc[df['SecondLargestPropertyUseType'].str.lower().str.contains('|'.join(search_strings), na=False)].any(1).sum()
# Out:
# 13

# %%
df.loc[~df['SecondLargestPropertyUseType'].str.lower().str.contains('|'.join(search_strings), na=False)].any(1).sum()
# Out:
# 1579

# %%
df = df.loc[~df['SecondLargestPropertyUseType'].str.lower().str.contains('|'.join(search_strings), na=False)]

# %%
df.shape
# Out:
# (1579, 16)

# %% [markdown]
# ##### ThirdLargestPropertyUseType

# %%
df['ThirdLargestPropertyUseType'].isna().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (1579, 16)

# %%
df['ThirdLargestPropertyUseType'].unique()
# Out:
# array(['No UseType', 'Restaurant', 'Swimming Pool', 'Data Center',
#        'Office', 'Retail Store', 'Other - Entertainment/Public Assembly',
#        'Non-Refrigerated Warehouse', 'Other', 'Distribution Center',
#        'Other - Services', 'Medical Office', 'Parking', 'Food Service',
#        'Other - Utility', 'Fitness Center/Health Club/Gym',
#        'Social/Meeting Hall', 'Pre-school/Daycare',
#        'Convenience Store without Gas Station', 'Financial Office',
#        'Other - Restaurant/Bar', 'Other - Education',
#        'Multifamily Housing', 'Laboratory', 'Bank Branch',
#        'Personal Services (Health/Beauty, Dry Cleaning, etc)',
#        'Other - Recreation', 'Self-Storage Facility',
#        'Other - Technology/Science', 'Refrigerated Warehouse',
#        'Bar/Nightclub', 'Manufacturing/Industrial Plant',
#        'Other/Specialty Hospital', 'Fast Food Restaurant', 'K-12 School',
#        'Supermarket/Grocery Store', 'Strip Mall', 'Vocational School'],
#       dtype=object)

# %%
search_strings = ["housing", "residence", "residential", "dormitory"]
df['ThirdLargestPropertyUseType'].str.lower().str.contains('|'.join(search_strings)).sum()
# Out:
# 12

# %%
df.loc[df['ThirdLargestPropertyUseType'].str.lower().str.contains('|'.join(search_strings), na=False)]
# Out:
#         BuildingType          PrimaryPropertyType  ZipCode      Neighborhood  \
# 289           Campus           Mixed Use Property  98101.0          DOWNTOWN
# 440   NonResidential           Mixed Use Property  98103.0        LAKE UNION
# 466   NonResidential  Small- and Mid-Sized Office  98134.0  GREATER DUWAMISH
# 612   NonResidential           Mixed Use Property  98105.0         NORTHEAST
# 1328  NonResidential           Mixed Use Property  98109.0        LAKE UNION
# 1599  NonResidential           Mixed Use Property  98107.0           BALLARD
# 2398  NonResidential                 Large Office  98104.0          DOWNTOWN
# 2506  NonResidential  Small- and Mid-Sized Office  98121.0          DOWNTOWN
# 2759  NonResidential  Small- and Mid-Sized Office  98104.0          DOWNTOWN
# 3134  NonResidential           Mixed Use Property  98102.0              EAST
# 3199  NonResidential                 Large Office  98121.0          DOWNTOWN
# 3312  NonResidential  Small- and Mid-Sized Office  98122.0              EAST
#
#       YearBuilt  NumberofBuildings  NumberofFloors  PropertyGFATotal  \
# 289        1908                1.0               4            137400
# 440        1904                1.0               2             53002
# 466        1904                1.0               4             58970
# 612        2009                1.0               6            122400
# 1328       2008                1.0               4            274442
# 1599       1909                1.0               3             27085
# 2398       1983                1.0              13            307557
# 2506       1989                1.0               7             47415
# 2759       1909                1.0               3             31432
# 3134       1916                1.0               2            140823
# 3199       1988                1.0              13            354086
# 3312       2015                1.0               5             37873
#
#       PropertyGFAParking  PropertyGFABuilding(s) LargestPropertyUseType  \
# 289                    0                  137400           Retail Store
# 440                    0                   53002           Retail Store
# 466                    0                   58970                 Office
# 612                54300                   68100                 Office
# 1328                   0                  274442                  Hotel
# 1599                   0                   27085             Strip Mall
# 2398               83064                  224493                 Office
# 2506                   0                   47415                 Office
# 2759                   0                   31432                 Office
# 3134               59401                   81422                Parking
# 3199              149326                  204760                 Office
# 3312                   0                   37873                 Office
#
#      SecondLargestPropertyUseType ThirdLargestPropertyUseType  \
# 289        Other - Restaurant/Bar         Multifamily Housing
# 440                       Parking         Multifamily Housing
# 466    Non-Refrigerated Warehouse         Multifamily Housing
# 612                       Parking         Multifamily Housing
# 1328                      Parking         Multifamily Housing
# 1599                       Office         Multifamily Housing
# 2398                      Parking         Multifamily Housing
# 2506                      Parking         Multifamily Housing
# 2759                        Other         Multifamily Housing
# 3134    Supermarket/Grocery Store         Multifamily Housing
# 3199                      Parking         Multifamily Housing
# 3312                      Parking         Multifamily Housing
#
#       ENERGYSTARScore  SiteEnergyUseWN(kBtu)  TotalGHGEmissions
# 289               NaN           1.487976e+07             316.20
# 440              75.0           3.591768e+06              64.00
# 466               NaN           1.916863e+06              41.18
# 612              63.0           5.034998e+06              79.39
# 1328              NaN           9.512996e+06             220.26
# 1599              NaN           2.151546e+06              60.67
# 2398              NaN           9.691704e+06              66.32
# 2506              NaN           1.552851e+06              10.31
# 2759              NaN           1.439572e+06              10.04
# 3134              NaN           2.778833e+06              28.85
# 3199             88.0           1.407037e+07             147.84
# 3312              NaN           2.346692e+06              65.01

# %%
df = df.loc[~df['ThirdLargestPropertyUseType'].str.lower().str.contains('|'.join(search_strings), na=False)]

# %%
df.shape
# Out:
# (1567, 16)

# %%
df.columns
# Out:
# Index(['BuildingType', 'PrimaryPropertyType', 'ZipCode', 'Neighborhood',
#        'YearBuilt', 'NumberofBuildings', 'NumberofFloors', 'PropertyGFATotal',
#        'PropertyGFAParking', 'PropertyGFABuilding(s)',
#        'LargestPropertyUseType', 'SecondLargestPropertyUseType',
#        'ThirdLargestPropertyUseType', 'ENERGYSTARScore',
#        'SiteEnergyUseWN(kBtu)', 'TotalGHGEmissions'],
#       dtype='object')

# %% [markdown]
# ### Categories reduction

# %%
cat_cols.unique()
# Out:
# Index(['BuildingType', 'PrimaryPropertyType', 'PropertyName', 'Address',
#        'City', 'State', 'TaxParcelIdentificationNumber', 'Neighborhood',
#        'ListOfAllPropertyUseTypes', 'LargestPropertyUseType',
#        'SecondLargestPropertyUseType', 'ThirdLargestPropertyUseType',
#        'YearsENERGYSTARCertified', 'ComplianceStatus', 'Outlier'],
#       dtype='object')

# %%
cat_cols = df.columns[df.dtypes == 'object']
df[cat_cols].nunique()
# Out:
# BuildingType                     5
# PrimaryPropertyType             19
# Neighborhood                    13
# LargestPropertyUseType          52
# SecondLargestPropertyUseType    45
# ThirdLargestPropertyUseType     37
# dtype: int64

# %%
df['LargestPropertyUseType'].unique()
# Out:
# array(['Hotel', 'Police Station', 'Other - Entertainment/Public Assembly',
#        'Library', 'Fitness Center/Health Club/Gym', 'Social/Meeting Hall',
#        'Courthouse', 'Other', 'K-12 School', 'College/University',
#        'Automobile Dealership', 'Office', 'Self-Storage Facility',
#        'Non-Refrigerated Warehouse', 'Other - Mall', 'Medical Office',
#        'Retail Store', 'Hospital (General Medical & Surgical)', 'Museum',
#        'Repair Services (Vehicle, Shoe, Locksmith, etc)',
#        'Other/Specialty Hospital', 'Financial Office',
#        'Distribution Center', 'Parking', 'Worship Facility', 'Restaurant',
#        'Data Center', 'Laboratory', 'Supermarket/Grocery Store',
#        'Convention Center', 'Urgent Care/Clinic/Other Outpatient',
#        'No UseType', 'Other - Services', 'Strip Mall',
#        'Wholesale Club/Supercenter', 'Refrigerated Warehouse',
#        'Manufacturing/Industrial Plant', 'Other - Recreation',
#        'Lifestyle Center', 'Other - Public Services', 'Other - Education',
#        'Fire Station', 'Performing Arts', 'Bank Branch',
#        'Other - Restaurant/Bar', 'Food Service', 'Adult Education',
#        'Other - Utility', 'Movie Theater',
#        'Personal Services (Health/Beauty, Dry Cleaning, etc)',
#        'Pre-school/Daycare', 'Prison/Incarceration'], dtype=object)

# %%
df['LargestPropertyUseType'].replace([
                                'Other - Entertainment/Public Assembly',
                                'Worship Facility',
                                'Restaurant',
                                'Convention Center',
                                'Social/Meeting Hall',
                                'Fitness Center/Health Club/Gym'

                            ], 'Social / Entertainement', inplace=True)

# %%
df['SecondLargestPropertyUseType'].unique()
# Out:
# array(['No UseType', 'Parking', 'Office', 'Restaurant', 'K-12 School',
#        'Laboratory', 'Refrigerated Warehouse',
#        'Non-Refrigerated Warehouse', 'Other - Education',
#        'Vocational School', 'Retail Store',
#        'Personal Services (Health/Beauty, Dry Cleaning, etc)',
#        'Other - Entertainment/Public Assembly', 'Data Center',
#        'Swimming Pool', 'Other', 'Courthouse', 'Distribution Center',
#        'Self-Storage Facility', 'Other - Services', 'Movie Theater',
#        'Other - Recreation', 'Convenience Store without Gas Station',
#        'Performing Arts', 'College/University',
#        'Supermarket/Grocery Store', 'Adult Education', 'Medical Office',
#        'Enclosed Mall', 'Bar/Nightclub', 'Financial Office',
#        'Repair Services (Vehicle, Shoe, Locksmith, etc)',
#        'Manufacturing/Industrial Plant', 'Bank Branch',
#        'Fitness Center/Health Club/Gym', 'Hotel', 'Worship Facility',
#        'Food Sales', 'Other - Public Services', 'Food Service',
#        'Pre-school/Daycare', 'Other - Restaurant/Bar',
#        'Social/Meeting Hall', 'Hospital (General Medical & Surgical)',
#        'Automobile Dealership'], dtype=object)

# %%
df['ThirdLargestPropertyUseType'].unique()
# Out:
# array(['No UseType', 'Restaurant', 'Swimming Pool', 'Data Center',
#        'Office', 'Retail Store', 'Other - Entertainment/Public Assembly',
#        'Non-Refrigerated Warehouse', 'Other', 'Distribution Center',
#        'Other - Services', 'Medical Office', 'Parking', 'Food Service',
#        'Other - Utility', 'Fitness Center/Health Club/Gym',
#        'Social/Meeting Hall', 'Pre-school/Daycare',
#        'Convenience Store without Gas Station', 'Financial Office',
#        'Other - Restaurant/Bar', 'Other - Education', 'Laboratory',
#        'Bank Branch',
#        'Personal Services (Health/Beauty, Dry Cleaning, etc)',
#        'Other - Recreation', 'Self-Storage Facility',
#        'Other - Technology/Science', 'Refrigerated Warehouse',
#        'Bar/Nightclub', 'Manufacturing/Industrial Plant',
#        'Other/Specialty Hospital', 'Fast Food Restaurant', 'K-12 School',
#        'Supermarket/Grocery Store', 'Strip Mall', 'Vocational School'],
#       dtype=object)

# %%
# => réencoder manuellement en classes générales

# %% [markdown]
# ## données aberrantes / normalisation

# %% [markdown]
# ### Valeurs catégorielles

# %% [markdown]
# #### General infos

# %%
cat_cols = df.columns[df.dtypes == 'object']
cat_cols
# Out:
# Index(['BuildingType', 'PrimaryPropertyType', 'Neighborhood',
#        'LargestPropertyUseType', 'SecondLargestPropertyUseType',
#        'ThirdLargestPropertyUseType'],
#       dtype='object')

# %%
df[cat_cols].describe()
# Out:
#           BuildingType   PrimaryPropertyType Neighborhood  \
# count             3344                  3344         3344
# unique               8                    24           13
# top     NonResidential  Low-Rise Multifamily     DOWNTOWN
# freq              1445                   975          565
#
#        LargestPropertyUseType SecondLargestPropertyUseType  \
# count                    3324                         1663
# unique                     56                           50
# top       Multifamily Housing                      Parking
# freq                     1651                          968
#
#        ThirdLargestPropertyUseType
# count                          589
# unique                          44
# top                   Retail Store
# freq                           109

# %%
df[cat_cols]
# Out:
#             BuildingType PrimaryPropertyType           Neighborhood  \
# 0         NonResidential               Hotel               DOWNTOWN
# 1         NonResidential               Hotel               DOWNTOWN
# 2         NonResidential               Hotel               DOWNTOWN
# 3         NonResidential               Hotel               DOWNTOWN
# 4         NonResidential               Hotel               DOWNTOWN
# ...                  ...                 ...                    ...
# 3371  Nonresidential COS              Office       GREATER DUWAMISH
# 3372  Nonresidential COS               Other               DOWNTOWN
# 3373  Nonresidential COS               Other  MAGNOLIA / QUEEN ANNE
# 3374  Nonresidential COS  Mixed Use Property       GREATER DUWAMISH
# 3375  Nonresidential COS  Mixed Use Property       GREATER DUWAMISH
#
#      LargestPropertyUseType    SecondLargestPropertyUseType  \
# 0                     Hotel                             NaN
# 1                     Hotel                         Parking
# 2                     Hotel                             NaN
# 3                     Hotel                             NaN
# 4                     Hotel                         Parking
# ...                     ...                             ...
# 3371                 Office                             NaN
# 3372     Other - Recreation                             NaN
# 3373     Other - Recreation  Fitness Center/Health Club/Gym
# 3374     Other - Recreation  Fitness Center/Health Club/Gym
# 3375     Other - Recreation  Fitness Center/Health Club/Gym
#
#      ThirdLargestPropertyUseType
# 0                            NaN
# 1                     Restaurant
# 2                            NaN
# 3                            NaN
# 4                  Swimming Pool
# ...                          ...
# 3371                         NaN
# 3372                         NaN
# 3373               Swimming Pool
# 3374          Pre-school/Daycare
# 3375          Pre-school/Daycare
#
# [3344 rows x 6 columns]

# %%
#df['ENERGYSTARScore'].value_counts()

# %%
def print_cats(df, cat_cols):
    for column in cat_cols:
        print('--------------------------------------------')
        print('--------------------------------------------')
        print(f'Column : {column}')
        print('----')
        #print(df[f'{column}'].value_counts())
        nunique = df[f'{column}'].nunique()
        uni_list = df[f'{column}'].unique()
        #print(sorted(uni_list))
        print(f'nunique : {nunique}')
        print(uni_list)
        print('')
        print('')

# %%
print_cats(df, cat_cols)
# Out:
# --------------------------------------------
# --------------------------------------------
# Column : BuildingType
# ----
# nunique : 8
# ['NonResidential' 'Nonresidential COS' 'Multifamily MR (5-9)'
#  'SPS-District K-12' 'Campus' 'Multifamily LR (1-4)'
#  'Multifamily HR (10+)' 'Nonresidential WA']
#
#
# --------------------------------------------
# --------------------------------------------
# Column : PrimaryPropertyType
# ----
# nunique : 24
# ['Hotel' 'Other' 'Mid-Rise Multifamily' 'Mixed Use Property' 'K-12 School'
#  'University' 'Small- and Mid-Sized Office' 'Self-Storage Facility'
#  'Warehouse' 'Large Office' 'Senior Care Community' 'Medical Office'
#  'Retail Store' 'Hospital' 'Residence Hall' 'Distribution Center'
#  'Worship Facility' 'Low-Rise Multifamily' 'Supermarket / Grocery Store'
#  'Laboratory' 'Refrigerated Warehouse' 'Restaurant'
#  'High-Rise Multifamily' 'Office']
#
#
# --------------------------------------------
# --------------------------------------------
# Column : Neighborhood
# ----
# nunique : 13
# ['DOWNTOWN' 'SOUTHEAST' 'NORTHEAST' 'EAST' 'CENTRAL' 'NORTH'
#  'MAGNOLIA / QUEEN ANNE' 'LAKE UNION' 'GREATER DUWAMISH' 'BALLARD'
#  'NORTHWEST' 'SOUTHWEST' 'DELRIDGE']
#
#
# --------------------------------------------
# --------------------------------------------
# Column : LargestPropertyUseType
# ----
# nunique : 56
# ['Hotel' 'Police Station' 'Other - Entertainment/Public Assembly'
#  'Multifamily Housing' 'Library' 'Fitness Center/Health Club/Gym'
#  'Social/Meeting Hall' 'Courthouse' 'Other' 'K-12 School'
#  'College/University' 'Automobile Dealership' 'Office'
#  'Self-Storage Facility' 'Non-Refrigerated Warehouse' 'Other - Mall'
#  'Senior Care Community' 'Medical Office' 'Retail Store'
#  'Hospital (General Medical & Surgical)' 'Museum'
#  'Repair Services (Vehicle, Shoe, Locksmith, etc)'
#  'Other - Lodging/Residential' 'Residence Hall/Dormitory'
#  'Other/Specialty Hospital' 'Financial Office' 'Distribution Center'
#  'Parking' 'Worship Facility' 'Restaurant' 'Data Center' 'Laboratory'
#  'Supermarket/Grocery Store' 'Convention Center'
#  'Urgent Care/Clinic/Other Outpatient' nan 'Other - Services' 'Strip Mall'
#  'Wholesale Club/Supercenter' 'Refrigerated Warehouse'
#  'Manufacturing/Industrial Plant' 'Other - Recreation' 'Lifestyle Center'
#  'Other - Public Services' 'Other - Education' 'Fire Station'
#  'Performing Arts' 'Residential Care Facility' 'Bank Branch'
#  'Other - Restaurant/Bar' 'Food Service' 'Adult Education'
#  'Other - Utility' 'Movie Theater'
#  'Personal Services (Health/Beauty, Dry Cleaning, etc)'
#  'Pre-school/Daycare' 'Prison/Incarceration']
#
#
# --------------------------------------------
# --------------------------------------------
# Column : SecondLargestPropertyUseType
# ----
# nunique : 50
# [nan 'Parking' 'Office' 'Restaurant' 'K-12 School' 'Laboratory'
#  'Refrigerated Warehouse' 'Non-Refrigerated Warehouse' 'Other - Education'
#  'Vocational School' 'Retail Store'
#  'Personal Services (Health/Beauty, Dry Cleaning, etc)'
#  'Other - Entertainment/Public Assembly' 'Data Center' 'Swimming Pool'
#  'Other' 'Courthouse' 'Residence Hall/Dormitory' 'Distribution Center'
#  'Self-Storage Facility' 'Other - Services' 'Movie Theater'
#  'Supermarket/Grocery Store' 'Medical Office' 'Other - Recreation'
#  'Convenience Store without Gas Station' 'Performing Arts'
#  'College/University' 'Other - Restaurant/Bar' 'Adult Education'
#  'Enclosed Mall' 'Multifamily Housing' 'Bar/Nightclub' 'Financial Office'
#  'Repair Services (Vehicle, Shoe, Locksmith, etc)'
#  'Manufacturing/Industrial Plant' 'Other - Lodging/Residential'
#  'Bank Branch' 'Food Service' 'Worship Facility' 'Senior Care Community'
#  'Fitness Center/Health Club/Gym' 'Hotel' 'Food Sales'
#  'Other/Specialty Hospital' 'Other - Public Services' 'Pre-school/Daycare'
#  'Social/Meeting Hall' 'Museum' 'Hospital (General Medical & Surgical)'
#  'Automobile Dealership']
#
#
# --------------------------------------------
# --------------------------------------------
# Column : ThirdLargestPropertyUseType
# ----
# nunique : 44
# [nan 'Restaurant' 'Swimming Pool' 'Data Center' 'Office' 'Retail Store'
#  'Other - Entertainment/Public Assembly' 'Non-Refrigerated Warehouse'
#  'Other' 'Distribution Center' 'Food Service' 'Other - Services'
#  'Medical Office' 'Parking' 'Other - Utility'
#  'Other - Lodging/Residential' 'K-12 School'
#  'Fitness Center/Health Club/Gym' 'Social/Meeting Hall'
#  'Pre-school/Daycare' 'Convenience Store without Gas Station'
#  'Financial Office' 'Other - Restaurant/Bar' 'Other - Education'
#  'Multifamily Housing' 'Laboratory' 'Bank Branch' 'Hotel'
#  'Personal Services (Health/Beauty, Dry Cleaning, etc)'
#  'Other - Recreation' 'Self-Storage Facility' 'Other - Technology/Science'
#  'Refrigerated Warehouse' 'Fast Food Restaurant' 'Bar/Nightclub'
#  'Manufacturing/Industrial Plant' 'Food Sales' 'Supermarket/Grocery Store'
#  'Other/Specialty Hospital' 'Worship Facility' 'Strip Mall'
#  'Residence Hall/Dormitory' 'Vocational School' 'College/University'
#  'Other - Public Services']

# %% [markdown]
# #### Neighborhood

# %%
#df['ENERGYSTARScore'].value_counts()

# %%
#from sklearn import preprocessing
#le = preprocessing.LabelEncoder()

# %%
#df[cat_cols] = le.fit_transform(df[cat_cols].astype(str))

# %%
#df['Neighborhood'].value_counts()
print(sorted(df['Neighborhood'].unique()))
# Out:
# ['BALLARD', 'CENTRAL', 'DELRIDGE', 'DOWNTOWN', 'EAST', 'GREATER DUWAMISH', 'LAKE UNION', 'MAGNOLIA / QUEEN ANNE', 'NORTH', 'NORTHEAST', 'NORTHWEST', 'SOUTHEAST', 'SOUTHWEST']

# %%
# TotalGHGEmissions

# %%
df['Neighborhood'] = df['Neighborhood'].str.upper()
df['Neighborhood'].loc[df['Neighborhood'] == 'DELRIDGE NEIGHBORHOODS'] = 'DELRIDGE'

# %%
df['Neighborhood'].value_counts()
# Out:
# DOWNTOWN                 565
# EAST                     449
# MAGNOLIA / QUEEN ANNE    419
# GREATER DUWAMISH         371
# NORTHEAST                277
# LAKE UNION               251
# NORTHWEST                221
# NORTH                    186
# SOUTHWEST                160
# BALLARD                  133
# CENTRAL                  132
# SOUTHEAST                 95
# DELRIDGE                  85
# Name: Neighborhood, dtype: int64

# %%
df['Neighborhood'].nunique()
# Out:
# 13

# %%
#### PropertyTypes

# %%
#df['ENERGYSTARScore'].value_counts()

# %%
#from sklearn import preprocessing
#le = preprocessing.LabelEncoder()

# %%
#df[cat_cols] = le.fit_transform(df[cat_cols].astype(str))

# %%
#df[df.columns[df.isnull().any()]].isnull().sum()

# %%
#df[df.columns[df.isnull().any()]].isnull().sum() * 100 / df.shape[0]

# %%
df['ThirdLargestPropertyUseType'].unique()
# Out:
# array([nan, 'Restaurant', 'Swimming Pool', 'Data Center', 'Office',
#        'Retail Store', 'Other - Entertainment/Public Assembly',
#        'Non-Refrigerated Warehouse', 'Other', 'Distribution Center',
#        'Food Service', 'Other - Services', 'Medical Office', 'Parking',
#        'Other - Utility', 'Other - Lodging/Residential', 'K-12 School',
#        'Fitness Center/Health Club/Gym', 'Social/Meeting Hall',
#        'Pre-school/Daycare', 'Convenience Store without Gas Station',
#        'Financial Office', 'Other - Restaurant/Bar', 'Other - Education',
#        'Multifamily Housing', 'Laboratory', 'Bank Branch', 'Hotel',
#        'Personal Services (Health/Beauty, Dry Cleaning, etc)',
#        'Other - Recreation', 'Self-Storage Facility',
#        'Other - Technology/Science', 'Refrigerated Warehouse',
#        'Fast Food Restaurant', 'Bar/Nightclub',
#        'Manufacturing/Industrial Plant', 'Food Sales',
#        'Supermarket/Grocery Store', 'Other/Specialty Hospital',
#        'Worship Facility', 'Strip Mall', 'Residence Hall/Dormitory',
#        'Vocational School', 'College/University',
#        'Other - Public Services'], dtype=object)

# %%
df['ThirdLargestPropertyUseType'].nunique()
# Out:
# 44

# %%
# check error
#UVA_num_plus(df, ['DefaultData'])

# %%
df['SecondLargestPropertyUseType'].unique()
# Out:
# array([nan, 'Parking', 'Office', 'Restaurant', 'K-12 School',
#        'Laboratory', 'Refrigerated Warehouse',
#        'Non-Refrigerated Warehouse', 'Other - Education',
#        'Vocational School', 'Retail Store',
#        'Personal Services (Health/Beauty, Dry Cleaning, etc)',
#        'Other - Entertainment/Public Assembly', 'Data Center',
#        'Swimming Pool', 'Other', 'Courthouse', 'Residence Hall/Dormitory',
#        'Distribution Center', 'Self-Storage Facility', 'Other - Services',
#        'Movie Theater', 'Supermarket/Grocery Store', 'Medical Office',
#        'Other - Recreation', 'Convenience Store without Gas Station',
#        'Performing Arts', 'College/University', 'Other - Restaurant/Bar',
#        'Adult Education', 'Enclosed Mall', 'Multifamily Housing',
#        'Bar/Nightclub', 'Financial Office',
#        'Repair Services (Vehicle, Shoe, Locksmith, etc)',
#        'Manufacturing/Industrial Plant', 'Other - Lodging/Residential',
#        'Bank Branch', 'Food Service', 'Worship Facility',
#        'Senior Care Community', 'Fitness Center/Health Club/Gym', 'Hotel',
#        'Food Sales', 'Other/Specialty Hospital',
#        'Other - Public Services', 'Pre-school/Daycare',
#        'Social/Meeting Hall', 'Museum',
#        'Hospital (General Medical & Surgical)', 'Automobile Dealership'],
#       dtype=object)

# %%
#df['LargestPropertyUseType'].value_counts()

# %%
df['LargestPropertyUseType'].isna().count()
# Out:
# 3344

# %%
df['SecondLargestPropertyUseType'].nunique()
# Out:
# 50

# %%
#df['ThirdLargestPropertyUseType'].value_counts()

# %%
df['ThirdLargestPropertyUseType'].isna().count()
# Out:
# 3344

# %%
df.loc[df['LargestPropertyUseType'].isna()]
# Out:
#               BuildingType          PrimaryPropertyType  ZipCode  \
# 353         NonResidential        Self-Storage Facility  98107.0
# 578         NonResidential  Small- and Mid-Sized Office  98104.0
# 758   Multifamily LR (1-4)         Low-Rise Multifamily  98115.0
# 1077  Multifamily HR (10+)        High-Rise Multifamily  98121.0
# 1147        NonResidential                        Hotel  98121.0
# 1483  Multifamily MR (5-9)         Mid-Rise Multifamily  98119.0
# 1756  Multifamily HR (10+)        High-Rise Multifamily  98104.0
# 1768  Multifamily LR (1-4)         Low-Rise Multifamily  98136.0
# 1792  Multifamily LR (1-4)         Low-Rise Multifamily  98119.0
# 2321  Multifamily LR (1-4)         Low-Rise Multifamily  98105.0
# 2336  Multifamily LR (1-4)         Low-Rise Multifamily  98103.0
# 2414        NonResidential  Small- and Mid-Sized Office  98103.0
# 2459        NonResidential                   Restaurant  98104.0
# 2474  Multifamily LR (1-4)         Low-Rise Multifamily  98103.0
# 2480  Multifamily LR (1-4)         Low-Rise Multifamily  98116.0
# 2545  Multifamily LR (1-4)         Low-Rise Multifamily  98106.0
# 2670        NonResidential           Mixed Use Property  98105.0
# 2886  Multifamily LR (1-4)         Low-Rise Multifamily  98115.0
# 3040  Multifamily LR (1-4)         Low-Rise Multifamily  98125.0
# 3348  Multifamily LR (1-4)         Low-Rise Multifamily  98112.0
#
#                Neighborhood  YearBuilt  NumberofBuildings  NumberofFloors  \
# 353                 BALLARD       1946                2.0               2
# 578                DOWNTOWN       1924                NaN               4
# 758               NORTHEAST       1977                NaN               3
# 1077               DOWNTOWN       1999                1.0              13
# 1147               DOWNTOWN       1910                1.0               8
# 1483  MAGNOLIA / QUEEN ANNE       2000                1.0               5
# 1756                   EAST       1982                1.0              17
# 1768              SOUTHWEST       1992                NaN               4
# 1792  MAGNOLIA / QUEEN ANNE       1957                NaN               4
# 2321              NORTHEAST       1963                NaN               4
# 2336              NORTHWEST       1978                1.0               4
# 2414             LAKE UNION       2008                1.0               4
# 2459               DOWNTOWN       1913                1.0               3
# 2474              NORTHWEST       1989                NaN               4
# 2480              SOUTHWEST       1969                NaN               3
# 2545               DELRIDGE       1981                1.0               3
# 2670              NORTHEAST       1928                NaN               2
# 2886              NORTHEAST       1981                1.0               3
# 3040                  NORTH       1997                1.0               4
# 3348                   EAST       2015                1.0               4
#
#       PropertyGFATotal  PropertyGFAParking  PropertyGFABuilding(s)  \
# 353             111445                   0                  111445
# 578              63150                   0                   63150
# 758              33166                   0                   33166
# 1077            219874                   0                  219874
# 1147             61721                   0                   61721
# 1483             45715                   0                   45715
# 1756             76855                   0                   76855
# 1768             29357                   0                   29357
# 1792             23636                   0                   23636
# 2321             28472                   0                   28472
# 2336             20844                   0                   20844
# 2414             48350                   0                   48350
# 2459             28800                   0                   28800
# 2474             29562                8531                   21031
# 2480             30420                   0                   30420
# 2545             35122                   0                   35122
# 2670             20760                   0                   20760
# 2886             42448                   0                   42448
# 3040             23175                   0                   23175
# 3348             36685                8254                   28431
#
#      LargestPropertyUseType SecondLargestPropertyUseType  \
# 353                     NaN                          NaN
# 578                     NaN                          NaN
# 758                     NaN                          NaN
# 1077                    NaN                          NaN
# 1147                    NaN                          NaN
# 1483                    NaN                          NaN
# 1756                    NaN                          NaN
# 1768                    NaN                          NaN
# 1792                    NaN                          NaN
# 2321                    NaN                          NaN
# 2336                    NaN                          NaN
# 2414                    NaN                          NaN
# 2459                    NaN                          NaN
# 2474                    NaN                          NaN
# 2480                    NaN                          NaN
# 2545                    NaN                          NaN
# 2670                    NaN                          NaN
# 2886                    NaN                          NaN
# 3040                    NaN                          NaN
# 3348                    NaN                          NaN
#
#      ThirdLargestPropertyUseType  ENERGYSTARScore  SiteEnergyUseWN(kBtu)  \
# 353                          NaN              NaN           6.076957e+06
# 578                          NaN              NaN                    NaN
# 758                          NaN              NaN                    NaN
# 1077                         NaN             17.0           1.399351e+07
# 1147                         NaN             93.0           2.968430e+06
# 1483                         NaN             72.0           1.329285e+06
# 1756                         NaN             10.0           2.959676e+06
# 1768                         NaN              NaN           5.937986e+05
# 1792                         NaN              NaN                    NaN
# 2321                         NaN              NaN           7.975070e+05
# 2336                         NaN              NaN           6.059075e+05
# 2414                         NaN             45.0           3.280956e+06
# 2459                         NaN              NaN           9.358332e+05
# 2474                         NaN              NaN                    NaN
# 2480                         NaN              NaN           1.126782e+06
# 2545                         NaN             43.0           1.020896e+06
# 2670                         NaN              NaN                    NaN
# 2886                         NaN             66.0           1.333831e+06
# 3040                         NaN              NaN           7.643831e+05
# 3348                         NaN              NaN           8.576127e+05
#
#       TotalGHGEmissions
# 353              163.83
# 578                 NaN
# 758                 NaN
# 1077             408.82
# 1147              36.92
# 1483               8.99
# 1756              18.95
# 1768                NaN
# 1792                NaN
# 2321                NaN
# 2336               3.90
# 2414              22.09
# 2459              29.21
# 2474                NaN
# 2480                NaN
# 2545               6.53
# 2670                NaN
# 2886               8.70
# 3040              16.31
# 3348                NaN

# %%
#df['ENERGYSTARScore'].value_counts()

# %%
### check valeurs erronnées / outliers (negatives ?)

# %% [markdown]
# ### Valeurs numériques

# %%
num_cols = df.columns[df.dtypes == 'float64']
num_cols
# Out:
# Index(['ZipCode', 'NumberofBuildings', 'ENERGYSTARScore',
#        'SiteEnergyUseWN(kBtu)', 'TotalGHGEmissions'],
#       dtype='object')

# %%
df[num_cols].describe()
# Out:
#             ZipCode  NumberofBuildings  ENERGYSTARScore  \
# count   1551.000000        1565.000000      1035.000000
# mean   98116.838169           1.175080        65.394203
# std       17.998035           3.020394        28.185987
# min    98006.000000           0.000000         1.000000
# 25%    98105.000000           1.000000        48.500000
# 50%    98111.000000           1.000000        73.000000
# 75%    98125.000000           1.000000        89.000000
# max    98199.000000         111.000000       100.000000
#
#        SiteEnergyUseWN(kBtu)  TotalGHGEmissions
# count           1.564000e+03        1565.000000
# mean            8.163789e+06         187.637188
# std             2.261167e+07         773.398653
# min             0.000000e+00          -0.800000
# 25%             1.293143e+06          20.100000
# 50%             2.679932e+06          49.250000
# 75%             7.066871e+06         138.850000
# max             4.716139e+08       16870.980000

# %%
df.sort_values(by='NumberofBuildings', ascending=False).head(50)
# Out:
#             BuildingType          PrimaryPropertyType  ZipCode  \
# 3274              Campus                   University  98105.0
# 105               Campus                   University  98106.0
# 1862              Campus                        Other  98119.0
# 2325              Campus                   University  98119.0
# 162               Campus                 Large Office  98108.0
# 128               Campus                   University  98103.0
# 1993              Campus                        Other  98134.0
# 170       NonResidential                     Hospital  98104.0
# 3168  Nonresidential COS                        Other  98115.0
# 1672      NonResidential                     Hospital  98133.0
# 618       NonResidential                     Hospital  98122.0
# 124       NonResidential                     Hospital  98105.0
# 2901      NonResidential  Small- and Mid-Sized Office  98122.0
# 167       NonResidential                     Hospital  98122.0
# 364       NonResidential                        Other  98133.0
# 3000      NonResidential                        Other  98122.0
# 1732              Campus                        Other  98134.0
# 954               Campus                  K-12 School  98115.0
# 1692              Campus                        Other  98108.0
# 3136  Nonresidential COS           Mixed Use Property  98134.0
# 1670      NonResidential                        Other  98133.0
# 2359      NonResidential                  K-12 School  98122.0
# 3252              Campus                   University  98108.0
# 195               Campus                        Other  98125.0
# 98        NonResidential                     Hospital  98107.0
# 2147      NonResidential                    Warehouse  98134.0
# 619       NonResidential                        Other  98121.0
# 117       NonResidential                        Other  98122.0
# 1265      NonResidential          Distribution Center  98107.0
# 661               Campus                        Other  98155.0
# 301               Campus           Mixed Use Property  98101.0
# 502       NonResidential                        Other  98118.0
# 540       NonResidential                        Other  98134.0
# 36        NonResidential                    Warehouse  98118.0
# 1613      NonResidential                  K-12 School  98105.0
# 506       NonResidential                        Other  98109.0
# 1182      NonResidential          Distribution Center  98106.0
# 353       NonResidential        Self-Storage Facility  98107.0
# 80        NonResidential                        Hotel  98105.0
# 3178  Nonresidential COS                        Other  98108.0
# 3110      NonResidential                   University  98144.0
# 631       NonResidential                   University  98144.0
# 463       NonResidential                        Other  98134.0
# 319       NonResidential                 Large Office  98109.0
# 1658      NonResidential        Self-Storage Facility  98125.0
# 2051      NonResidential               Medical Office  98105.0
# 867       NonResidential                        Hotel  98105.0
# 2138      NonResidential                        Other  98134.0
# 1059      NonResidential        Self-Storage Facility  98125.0
# 1659  Nonresidential COS                        Other  98125.0
#
#                Neighborhood  YearBuilt  NumberofBuildings  NumberofFloors  \
# 3274              NORTHEAST       1900              111.0               0
# 105                DELRIDGE       1970               27.0               2
# 1862  MAGNOLIA / QUEEN ANNE       1955               23.0               1
# 2325  MAGNOLIA / QUEEN ANNE       1945               14.0               2
# 162        GREATER DUWAMISH       1980               14.0               2
# 128               NORTHWEST       1970               11.0               2
# 1993       GREATER DUWAMISH       1991               10.0               0
# 170                    EAST       2000                9.0               8
# 3168              NORTHEAST       1929                8.0               0
# 1672              NORTHWEST       1966                8.0               1
# 618                    EAST       1994                7.0              14
# 124               NORTHEAST       1953                6.0              10
# 2901                CENTRAL       1956                6.0               2
# 167                 CENTRAL       1990                6.0               5
# 364               NORTHWEST       1964                6.0               1
# 3000                   EAST       1975                5.0               2
# 1732       GREATER DUWAMISH       1989                5.0               2
# 954               NORTHEAST       1989                5.0               3
# 1692               DELRIDGE       2005                5.0               1
# 3136       GREATER DUWAMISH       1966                5.0               1
# 1670              NORTHWEST       1970                5.0               1
# 2359                CENTRAL       2009                4.0               2
# 3252       GREATER DUWAMISH       2007                4.0               2
# 195                DOWNTOWN       1995                4.0               3
# 98                  BALLARD       1954                4.0               5
# 2147       GREATER DUWAMISH       1988                3.0               1
# 619   MAGNOLIA / QUEEN ANNE       1928                3.0               4
# 117                 CENTRAL       1971                3.0               6
# 1265                BALLARD       1951                3.0               1
# 661        GREATER DUWAMISH       1994                3.0               1
# 301                DOWNTOWN       1913                3.0              10
# 502               SOUTHEAST       1994                3.0               1
# 540        GREATER DUWAMISH       1986                3.0               2
# 36         GREATER DUWAMISH       1961                3.0               2
# 1613              NORTHEAST       2004                3.0               2
# 506   MAGNOLIA / QUEEN ANNE       1994                3.0               2
# 1182               DELRIDGE       1971                2.0               2
# 353                 BALLARD       1946                2.0               2
# 80                NORTHEAST       1962                2.0               4
# 3178       GREATER DUWAMISH       2012                2.0               2
# 3110                CENTRAL       2013                2.0               1
# 631                 CENTRAL       1974                2.0               4
# 463        GREATER DUWAMISH       1941                2.0               2
# 319   MAGNOLIA / QUEEN ANNE       1996                2.0               5
# 1658                  NORTH       1977                2.0               2
# 2051              NORTHEAST       1987                2.0               4
# 867               NORTHEAST       1961                2.0               2
# 2138       GREATER DUWAMISH       1916                2.0               1
# 1059                  NORTH       1988                2.0               2
# 1659                  NORTH       2005                2.0               1
#
#       PropertyGFATotal  PropertyGFAParking  PropertyGFABuilding(s)  \
# 3274           9320156                   0                 9320156
# 105             441071                   0                  441071
# 1862            260241                   0                  260241
# 2325            537000                   0                  537000
# 162             334368               31874                  302494
# 128             694072              111625                  582447
# 1993            230971                   0                  230971
# 170            1158691                   0                 1158691
# 3168            502030                   0                  502030
# 1672            415632                   0                  415632
# 618            1765970                   0                 1765970
# 124             879000                   0                  879000
# 2901             75868                   0                   75868
# 167             597519                   0                  597519
# 364             111900                   0                  111900
# 3000             38879               11328                   27551
# 1732            138907                   0                  138907
# 954              21500                   0                   21500
# 1692             57952                   0                   57952
# 3136             87458                   0                   87458
# 1670             23166                   0                   23166
# 2359             28500                   0                   28500
# 3252            149856                   0                  149856
# 195             215476                   0                  215476
# 98              285333                   0                  285333
# 2147             51664                   0                   51664
# 619              62600                   0                   62600
# 117             250981                   0                  250981
# 1265             57310                   0                   57310
# 661              22800                   0                   22800
# 301             258497                   0                  258497
# 502             102133                   0                  102133
# 540              63644                   0                   63644
# 36              714095                   0                  714095
# 1613             31343                   0                   31343
# 506              81336                   0                   81336
# 1182             28368                   0                   28368
# 353             111445                   0                  111445
# 80               50017                   0                   50017
# 3178            137138                   0                  137138
# 3110             57468                   0                   57468
# 631             114000                   0                  114000
# 463             125519                   0                  125519
# 319             213283              115228                   98055
# 1658             33344                   0                   33344
# 2051             36932               14576                   22356
# 867              24100                   0                   24100
# 2138             27760                   0                   27760
# 1059             50368                   0                   50368
# 1659             30498                   0                   30498
#
#                      LargestPropertyUseType SecondLargestPropertyUseType  \
# 3274                     College/University                   No UseType
# 105                      College/University                   No UseType
# 1862                                  Other                   No UseType
# 2325                     College/University                   No UseType
# 162                                  Office                   Laboratory
# 128                      College/University                   No UseType
# 1993                                  Other                      Parking
# 170   Hospital (General Medical & Surgical)                      Parking
# 3168                     Other - Recreation                   No UseType
# 1672  Hospital (General Medical & Surgical)                      Parking
# 618   Hospital (General Medical & Surgical)                      Parking
# 124   Hospital (General Medical & Surgical)                   No UseType
# 2901                                 Office                   Restaurant
# 167   Hospital (General Medical & Surgical)                      Parking
# 364                              Strip Mall                      Parking
# 3000    Urgent Care/Clinic/Other Outpatient                   No UseType
# 1732                                  Other                   No UseType
# 954                             K-12 School                   No UseType
# 1692                        Adult Education                   No UseType
# 3136                                 Office          Distribution Center
# 1670                                  Other                   No UseType
# 2359                            K-12 School                   No UseType
# 3252                     College/University                   No UseType
# 195                                   Other                   No UseType
# 98    Hospital (General Medical & Surgical)                      Parking
# 2147             Non-Refrigerated Warehouse                   No UseType
# 619                                   Other                   No UseType
# 117                                   Other                   Courthouse
# 1265                    Distribution Center                   No UseType
# 661          Manufacturing/Industrial Plant                   No UseType
# 301                                 Parking                       Office
# 502                              Strip Mall                      Parking
# 540                 Other - Public Services                      Parking
# 36               Non-Refrigerated Warehouse       Refrigerated Warehouse
# 1613                            K-12 School                   No UseType
# 506                        Lifestyle Center                   No UseType
# 1182                    Distribution Center                       Office
# 353                              No UseType                   No UseType
# 80                                    Hotel                Swimming Pool
# 3178                        Other - Utility                   No UseType
# 3110                     College/University                   No UseType
# 631                      College/University                   No UseType
# 463          Manufacturing/Industrial Plant                   No UseType
# 319                                  Office                      Parking
# 1658                  Self-Storage Facility                       Office
# 2051                         Medical Office                   No UseType
# 867                                   Hotel                   No UseType
# 2138                                  Other                       Office
# 1059                  Self-Storage Facility                   No UseType
# 1659                     Other - Recreation                   No UseType
#
#      ThirdLargestPropertyUseType  ENERGYSTARScore  SiteEnergyUseWN(kBtu)  \
# 3274                  No UseType              NaN           0.000000e+00
# 105                   No UseType              NaN           4.115173e+07
# 1862                  No UseType              NaN           3.603458e+07
# 2325                  No UseType              NaN           9.677546e+07
# 162              Other - Utility              NaN           5.413607e+07
# 128                   No UseType              NaN           3.741080e+07
# 1993                  No UseType              NaN           2.223084e+07
# 170                   No UseType             29.0           2.966717e+08
# 3168                  No UseType              NaN           2.067295e+07
# 1672                  No UseType             85.0           1.003283e+08
# 618                   No UseType             54.0           2.959299e+08
# 124                   No UseType             10.0           2.577642e+08
# 2901                Retail Store              NaN           3.605750e+06
# 167                   No UseType             34.0           1.472991e+08
# 364                   No UseType              NaN           1.007999e+07
# 3000                  No UseType              NaN           3.564728e+06
# 1732                  No UseType              NaN           8.551562e+06
# 954                   No UseType             44.0           7.109712e+06
# 1692                  No UseType              NaN           3.347245e+06
# 3136                       Other              NaN           9.271981e+06
# 1670                  No UseType              NaN           3.648466e+06
# 2359                  No UseType             92.0           1.300766e+06
# 3252                  No UseType              NaN           6.759240e+06
# 195                   No UseType              NaN           2.460637e+07
# 98                    No UseType             14.0           4.760272e+07
# 2147                  No UseType              NaN           3.743867e+06
# 619                   No UseType              NaN           1.263798e+07
# 117                   No UseType              NaN           1.419619e+07
# 1265                  No UseType              NaN           1.395638e+06
# 661                   No UseType              NaN           2.660377e+06
# 301                 Retail Store              NaN           2.153613e+07
# 502                   No UseType              NaN           2.140623e+07
# 540                   No UseType              NaN           7.448018e+06
# 36                        Office              NaN           4.411002e+07
# 1613                  No UseType              5.0           4.277566e+06
# 506                   No UseType              NaN           1.336035e+07
# 1182                  No UseType              NaN           1.931831e+06
# 353                   No UseType              NaN           6.076957e+06
# 80                    No UseType             53.0           5.528580e+06
# 3178                  No UseType              NaN           5.574345e+06
# 3110                  No UseType              NaN           3.778966e+06
# 631                   No UseType              NaN           7.575080e+06
# 463                   No UseType              NaN           2.244317e+06
# 319                   No UseType             83.0           5.661690e+06
# 1658                     Parking              NaN           1.294669e+05
# 2051                  No UseType              NaN           2.824097e+06
# 867                   No UseType             91.0           1.640279e+06
# 2138                Retail Store              NaN           3.262533e+06
# 1059                  No UseType              NaN           8.978229e+05
# 1659                  No UseType              NaN           2.652254e+06
#
#       TotalGHGEmissions
# 3274           11140.56
# 105              866.23
# 1862             565.55
# 2325            3768.66
# 162              748.55
# 128              362.82
# 1993             405.05
# 170            10734.57
# 3168             549.11
# 1672            3278.11
# 618            12307.16
# 124             8145.52
# 2901              25.14
# 167             4906.33
# 364              226.43
# 3000              28.79
# 1732             179.55
# 954              202.65
# 1692              96.15
# 3136             270.63
# 1670             184.60
# 2359              28.64
# 3252             107.29
# 195              639.39
# 98              1990.50
# 2147              66.77
# 619              406.04
# 117              422.39
# 1265              34.87
# 661              101.50
# 301              418.90
# 502              530.62
# 540              168.50
# 36               311.84
# 1613             128.66
# 506              270.17
# 1182              30.02
# 353              163.83
# 80               191.20
# 3178              38.17
# 3110              89.80
# 631              109.71
# 463               15.65
# 319               39.47
# 1658               0.86
# 2051              19.69
# 867               46.57
# 2138             112.82
# 1059              28.58
# 1659              80.19

# %% [markdown]
# #### Valeurs négatives

# %%
df.min()
# Out:
# BuildingType                                 Campus
# PrimaryPropertyType             Distribution Center
# ZipCode                                     98006.0
# Neighborhood                                BALLARD
# YearBuilt                                      1900
# NumberofBuildings                               0.0
# NumberofFloors                                    0
# PropertyGFATotal                              11285
# PropertyGFAParking                                0
# PropertyGFABuilding(s)                        10925
# LargestPropertyUseType              Adult Education
# SecondLargestPropertyUseType        Adult Education
# ThirdLargestPropertyUseType             Bank Branch
# ENERGYSTARScore                                 1.0
# SiteEnergyUseWN(kBtu)                           0.0
# TotalGHGEmissions                              -0.8
# dtype: object

# %% [markdown]
# #### TotalGHGEmissions : valeurs manquantes

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1567 entries, 0 to 3375
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   BuildingType                  1567 non-null   object
#  1   PrimaryPropertyType           1567 non-null   object
#  2   ZipCode                       1551 non-null   float64
#  3   Neighborhood                  1567 non-null   object
#  4   YearBuilt                     1567 non-null   int64
#  5   NumberofBuildings             1565 non-null   float64
#  6   NumberofFloors                1567 non-null   int64
#  7   PropertyGFATotal              1567 non-null   int64
#  8   PropertyGFAParking            1567 non-null   int64
#  9   PropertyGFABuilding(s)        1567 non-null   int64
#  10  LargestPropertyUseType        1567 non-null   object
#  11  SecondLargestPropertyUseType  1567 non-null   object
#  12  ThirdLargestPropertyUseType   1567 non-null   object
#  13  ENERGYSTARScore               1035 non-null   float64
#  14  SiteEnergyUseWN(kBtu)         1564 non-null   float64
#  15  TotalGHGEmissions             1565 non-null   float64
# dtypes: float64(5), int64(5), object(6)
# memory usage: 208.1+ KB

# %% [markdown]
# Colonnes pertinentes comme cibles/target pour les 2 entraînements sujets de l'étude demandée.
#
# description : https://data.seattle.gov/dataset/2016-Building-Energy-Benchmarking/2bpz-gwpy
#
# emissions CO2 :
# - TotalGHGEmissions
# - The total amount of greenhouse gas emissions, including carbon dioxide, methane, and nitrous oxide gases released into the atmosphere as a result of energy consumption at the property, measured in metric tons of carbon dioxide equivalent.
#
# consommation :
# - SiteEnergyUseWN(kBtu) / SiteEnergyUse(kBtu) => 1ère est une pred, à vérifier
# - The annual amount of energy consumed by the property from all sources of energy, adjusted to what the property would have consumed during 30-year average weather conditions.

# %%
df['TotalGHGEmissions'].isna().sum()
# Out:
# 2

# %%
df.loc[df['TotalGHGEmissions'].isna()]
# Out:
#         BuildingType          PrimaryPropertyType  ZipCode Neighborhood  \
# 578   NonResidential  Small- and Mid-Sized Office  98104.0     DOWNTOWN
# 2670  NonResidential           Mixed Use Property  98105.0    NORTHEAST
#
#       YearBuilt  NumberofBuildings  NumberofFloors  PropertyGFATotal  \
# 578        1924                NaN               4             63150
# 2670       1928                NaN               2             20760
#
#       PropertyGFAParking  PropertyGFABuilding(s) LargestPropertyUseType  \
# 578                    0                   63150             No UseType
# 2670                   0                   20760             No UseType
#
#      SecondLargestPropertyUseType ThirdLargestPropertyUseType  \
# 578                    No UseType                  No UseType
# 2670                   No UseType                  No UseType
#
#       ENERGYSTARScore  SiteEnergyUseWN(kBtu)  TotalGHGEmissions
# 578               NaN                    NaN                NaN
# 2670              NaN                    NaN                NaN

# %%
df['TotalGHGEmissions'].nunique()
# Out:
# 1499

# %%
df['TotalGHGEmissions'].value_counts()
# Out:
# 0.00      6
# 6.30      3
# 4.95      2
# 38.87     2
# 30.22     2
#          ..
# 33.58     1
# 293.56    1
# 168.50    1
# 178.62    1
# 41.27     1
# Name: TotalGHGEmissions, Length: 1499, dtype: int64

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1567 entries, 0 to 3375
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   BuildingType                  1567 non-null   object
#  1   PrimaryPropertyType           1567 non-null   object
#  2   ZipCode                       1551 non-null   float64
#  3   Neighborhood                  1567 non-null   object
#  4   YearBuilt                     1567 non-null   int64
#  5   NumberofBuildings             1565 non-null   float64
#  6   NumberofFloors                1567 non-null   int64
#  7   PropertyGFATotal              1567 non-null   int64
#  8   PropertyGFAParking            1567 non-null   int64
#  9   PropertyGFABuilding(s)        1567 non-null   int64
#  10  LargestPropertyUseType        1567 non-null   object
#  11  SecondLargestPropertyUseType  1567 non-null   object
#  12  ThirdLargestPropertyUseType   1567 non-null   object
#  13  ENERGYSTARScore               1035 non-null   float64
#  14  SiteEnergyUseWN(kBtu)         1564 non-null   float64
#  15  TotalGHGEmissions             1565 non-null   float64
# dtypes: float64(5), int64(5), object(6)
# memory usage: 208.1+ KB

# %% [markdown]
# Colonnes pertinentes comme cibles/target pour les 2 entraînements sujets de l'étude demandée.
#
# description : https://data.seattle.gov/dataset/2016-Building-Energy-Benchmarking/2bpz-gwpy
#
# emissions CO2 :
# - TotalGHGEmissions
# - The total amount of greenhouse gas emissions, including carbon dioxide, methane, and nitrous oxide gases released into the atmosphere as a result of energy consumption at the property, measured in metric tons of carbon dioxide equivalent.
#
# consommation :
# - SiteEnergyUseWN(kBtu) / SiteEnergyUse(kBtu) => 1ère est une pred, à vérifier
# - The annual amount of energy consumed by the property from all sources of energy, adjusted to what the property would have consumed during 30-year average weather conditions.

# %%
df['TotalGHGEmissions'].nunique()
# Out:
# 1499

# %%
df['TotalGHGEmissions'].value_counts()
# Out:
# 0.00      6
# 6.30      3
# 4.95      2
# 38.87     2
# 30.22     2
#          ..
# 33.58     1
# 293.56    1
# 168.50    1
# 178.62    1
# 41.27     1
# Name: TotalGHGEmissions, Length: 1499, dtype: int64

# %%
df.loc[df['TotalGHGEmissions'] == 0]
# Out:
#            BuildingType          PrimaryPropertyType  ZipCode  \
# 28    SPS-District K-12                  K-12 School  98112.0
# 152   SPS-District K-12                  K-12 School  98115.0
# 304      NonResidential                        Other  98101.0
# 513      NonResidential  Supermarket / Grocery Store  98119.0
# 746      NonResidential                        Other  98133.0
# 1361  SPS-District K-12                  K-12 School  98125.0
#
#                Neighborhood  YearBuilt  NumberofBuildings  NumberofFloors  \
# 28                  CENTRAL       1955                1.0               1
# 152                   NORTH       1989                1.0               2
# 304                DOWNTOWN       1990                1.0               6
# 513   MAGNOLIA / QUEEN ANNE       2008                1.0               1
# 746               NORTHWEST       2002                1.0               1
# 1361                  NORTH       1954                1.0               1
#
#       PropertyGFATotal  PropertyGFAParking  PropertyGFABuilding(s)  \
# 28              126351                   0                  126351
# 152              52792                   0                   52792
# 304            1400000                   0                 1400000
# 513              57176                   0                   57176
# 746              29924                   0                   29924
# 1361             42292                   0                   42292
#
#          LargestPropertyUseType SecondLargestPropertyUseType  \
# 28                  K-12 School                   No UseType
# 152                 K-12 School                   No UseType
# 304           Convention Center                      Parking
# 513   Supermarket/Grocery Store                 Retail Store
# 746           Other - Education                   No UseType
# 1361                K-12 School                   No UseType
#
#                                ThirdLargestPropertyUseType  ENERGYSTARScore  \
# 28                                              No UseType              NaN
# 152                                             No UseType              NaN
# 304                                             No UseType              NaN
# 513   Personal Services (Health/Beauty, Dry Cleaning, etc)             31.0
# 746                                             No UseType              NaN
# 1361                                            No UseType            100.0
#
#       SiteEnergyUseWN(kBtu)  TotalGHGEmissions
# 28                      0.0                0.0
# 152                     0.0                0.0
# 304                     0.0                0.0
# 513              12843856.0                0.0
# 746                     0.0                0.0
# 1361                    0.0                0.0

# %%
filter_list = [0]

# %%
df = df.loc[~df['TotalGHGEmissions'].isin(filter_list)]

# %%
df.shape
# Out:
# (1561, 16)

# %%
df
# Out:
#             BuildingType PrimaryPropertyType  ZipCode           Neighborhood  \
# 0         NonResidential               Hotel  98101.0               DOWNTOWN
# 1         NonResidential               Hotel  98101.0               DOWNTOWN
# 2         NonResidential               Hotel  98101.0               DOWNTOWN
# 3         NonResidential               Hotel  98101.0               DOWNTOWN
# 4         NonResidential               Hotel  98121.0               DOWNTOWN
# ...                  ...                 ...      ...                    ...
# 3371  Nonresidential COS              Office      NaN       GREATER DUWAMISH
# 3372  Nonresidential COS               Other      NaN               DOWNTOWN
# 3373  Nonresidential COS               Other      NaN  MAGNOLIA / QUEEN ANNE
# 3374  Nonresidential COS  Mixed Use Property      NaN       GREATER DUWAMISH
# 3375  Nonresidential COS  Mixed Use Property      NaN       GREATER DUWAMISH
#
#       YearBuilt  NumberofBuildings  NumberofFloors  PropertyGFATotal  \
# 0          1927                1.0              12             88434
# 1          1996                1.0              11            103566
# 2          1969                1.0              41            956110
# 3          1926                1.0              10             61320
# 4          1980                1.0              18            175580
# ...         ...                ...             ...               ...
# 3371       1990                1.0               1             12294
# 3372       2004                1.0               1             16000
# 3373       1974                1.0               1             13157
# 3374       1989                1.0               1             14101
# 3375       1938                1.0               1             18258
#
#       PropertyGFAParking  PropertyGFABuilding(s) LargestPropertyUseType  \
# 0                      0                   88434                  Hotel
# 1                  15064                   88502                  Hotel
# 2                 196718                  759392                  Hotel
# 3                      0                   61320                  Hotel
# 4                  62000                  113580                  Hotel
# ...                  ...                     ...                    ...
# 3371                   0                   12294                 Office
# 3372                   0                   16000     Other - Recreation
# 3373                   0                   13157     Other - Recreation
# 3374                   0                   14101     Other - Recreation
# 3375                   0                   18258     Other - Recreation
#
#         SecondLargestPropertyUseType ThirdLargestPropertyUseType  \
# 0                         No UseType                  No UseType
# 1                            Parking                  Restaurant
# 2                         No UseType                  No UseType
# 3                         No UseType                  No UseType
# 4                            Parking               Swimming Pool
# ...                              ...                         ...
# 3371                      No UseType                  No UseType
# 3372                      No UseType                  No UseType
# 3373  Fitness Center/Health Club/Gym               Swimming Pool
# 3374  Fitness Center/Health Club/Gym          Pre-school/Daycare
# 3375  Fitness Center/Health Club/Gym          Pre-school/Daycare
#
#       ENERGYSTARScore  SiteEnergyUseWN(kBtu)  TotalGHGEmissions
# 0                60.0           7.456910e+06             249.98
# 1                61.0           8.664479e+06             295.86
# 2                43.0           7.393711e+07            2089.28
# 3                56.0           6.946800e+06             286.43
# 4                75.0           1.465650e+07             505.01
# ...               ...                    ...                ...
# 3371             46.0           9.430032e+05              20.94
# 3372              NaN           1.053706e+06              32.17
# 3373              NaN           6.053764e+06             223.54
# 3374              NaN           7.828413e+05              22.11
# 3375              NaN           1.293722e+06              41.27
#
# [1561 rows x 16 columns]

# %%
df.loc[df['TotalGHGEmissions'] == 0]
# Out:
# Empty DataFrame
# Columns: [BuildingType, PrimaryPropertyType, ZipCode, Neighborhood, YearBuilt, NumberofBuildings, NumberofFloors, PropertyGFATotal, PropertyGFAParking, PropertyGFABuilding(s), LargestPropertyUseType, SecondLargestPropertyUseType, ThirdLargestPropertyUseType, ENERGYSTARScore, SiteEnergyUseWN(kBtu), TotalGHGEmissions]
# Index: []

# %%
filter_list = [0]

# %%
df = df.loc[~df['TotalGHGEmissions'].isin(filter_list)]

# %%
df.shape
# Out:
# (1561, 16)

# %%
df
# Out:
#             BuildingType PrimaryPropertyType  ZipCode           Neighborhood  \
# 0         NonResidential               Hotel  98101.0               DOWNTOWN
# 1         NonResidential               Hotel  98101.0               DOWNTOWN
# 2         NonResidential               Hotel  98101.0               DOWNTOWN
# 3         NonResidential               Hotel  98101.0               DOWNTOWN
# 4         NonResidential               Hotel  98121.0               DOWNTOWN
# ...                  ...                 ...      ...                    ...
# 3371  Nonresidential COS              Office      NaN       GREATER DUWAMISH
# 3372  Nonresidential COS               Other      NaN               DOWNTOWN
# 3373  Nonresidential COS               Other      NaN  MAGNOLIA / QUEEN ANNE
# 3374  Nonresidential COS  Mixed Use Property      NaN       GREATER DUWAMISH
# 3375  Nonresidential COS  Mixed Use Property      NaN       GREATER DUWAMISH
#
#       YearBuilt  NumberofBuildings  NumberofFloors  PropertyGFATotal  \
# 0          1927                1.0              12             88434
# 1          1996                1.0              11            103566
# 2          1969                1.0              41            956110
# 3          1926                1.0              10             61320
# 4          1980                1.0              18            175580
# ...         ...                ...             ...               ...
# 3371       1990                1.0               1             12294
# 3372       2004                1.0               1             16000
# 3373       1974                1.0               1             13157
# 3374       1989                1.0               1             14101
# 3375       1938                1.0               1             18258
#
#       PropertyGFAParking  PropertyGFABuilding(s) LargestPropertyUseType  \
# 0                      0                   88434                  Hotel
# 1                  15064                   88502                  Hotel
# 2                 196718                  759392                  Hotel
# 3                      0                   61320                  Hotel
# 4                  62000                  113580                  Hotel
# ...                  ...                     ...                    ...
# 3371                   0                   12294                 Office
# 3372                   0                   16000     Other - Recreation
# 3373                   0                   13157     Other - Recreation
# 3374                   0                   14101     Other - Recreation
# 3375                   0                   18258     Other - Recreation
#
#         SecondLargestPropertyUseType ThirdLargestPropertyUseType  \
# 0                         No UseType                  No UseType
# 1                            Parking                  Restaurant
# 2                         No UseType                  No UseType
# 3                         No UseType                  No UseType
# 4                            Parking               Swimming Pool
# ...                              ...                         ...
# 3371                      No UseType                  No UseType
# 3372                      No UseType                  No UseType
# 3373  Fitness Center/Health Club/Gym               Swimming Pool
# 3374  Fitness Center/Health Club/Gym          Pre-school/Daycare
# 3375  Fitness Center/Health Club/Gym          Pre-school/Daycare
#
#       ENERGYSTARScore  SiteEnergyUseWN(kBtu)  TotalGHGEmissions
# 0                60.0           7.456910e+06             249.98
# 1                61.0           8.664479e+06             295.86
# 2                43.0           7.393711e+07            2089.28
# 3                56.0           6.946800e+06             286.43
# 4                75.0           1.465650e+07             505.01
# ...               ...                    ...                ...
# 3371             46.0           9.430032e+05              20.94
# 3372              NaN           1.053706e+06              32.17
# 3373              NaN           6.053764e+06             223.54
# 3374              NaN           7.828413e+05              22.11
# 3375              NaN           1.293722e+06              41.27
#
# [1561 rows x 16 columns]

# %% [markdown]
# #### ZipCode

# %%
df['ZipCode'].nunique()
# Out:
# 47

# %%
df['ZipCode'].unique()
# Out:
# array([98101., 98121., 98104., 98154., 98118., 98105., 98125., 98109.,
#        98070., 98108., 98199., 98115., 98107., 98144., 98103., 98119.,
#        98136., 98122., 98146., 98033., 98106., 98112., 98133., 98111.,
#        98134., 98117., 98126., 98116., 98191., 98164., 98195., 98185.,
#        98181., 98102., 98168., 98155., 98006., 98124., 98053., 98013.,
#        98178., 98114., 98165., 98113., 98177., 98020., 98145.,    nan])

# %%
#df['ZipCode'].value_counts()

# %%
UVA_num_plus(df, ['ZipCode'])

# %%
df['ZipCode'].isna().sum()
# Out:
# 16

# %%
df.loc[df['ZipCode'].isna()]
# Out:
#             BuildingType PrimaryPropertyType  ZipCode           Neighborhood  \
# 3360  Nonresidential COS  Mixed Use Property      NaN                  NORTH
# 3361  Nonresidential COS               Other      NaN                CENTRAL
# 3362  Nonresidential COS               Other      NaN                BALLARD
# 3363  Nonresidential COS               Other      NaN                  NORTH
# 3364  Nonresidential COS               Other      NaN                BALLARD
# 3365  Nonresidential COS               Other      NaN                BALLARD
# 3366  Nonresidential COS              Office      NaN  MAGNOLIA / QUEEN ANNE
# 3367  Nonresidential COS               Other      NaN                   EAST
# 3368  Nonresidential COS  Mixed Use Property      NaN                CENTRAL
# 3369  Nonresidential COS              Office      NaN              SOUTHEAST
# 3370  Nonresidential COS               Other      NaN               DELRIDGE
# 3371  Nonresidential COS              Office      NaN       GREATER DUWAMISH
# 3372  Nonresidential COS               Other      NaN               DOWNTOWN
# 3373  Nonresidential COS               Other      NaN  MAGNOLIA / QUEEN ANNE
# 3374  Nonresidential COS  Mixed Use Property      NaN       GREATER DUWAMISH
# 3375  Nonresidential COS  Mixed Use Property      NaN       GREATER DUWAMISH
#
#       YearBuilt  NumberofBuildings  NumberofFloors  PropertyGFATotal  \
# 3360       2005                1.0               1             20616
# 3361       2013                1.0               1             11685
# 3362       2010                1.0               1             11968
# 3363       1949                1.0               1             11285
# 3364       1911                1.0               1             16795
# 3365       1972                1.0               1             12769
# 3366       1952                1.0               1             13661
# 3367       1912                1.0               1             23445
# 3368       1994                1.0               1             20050
# 3369       1960                1.0               1             15398
# 3370       1982                1.0               1             18261
# 3371       1990                1.0               1             12294
# 3372       2004                1.0               1             16000
# 3373       1974                1.0               1             13157
# 3374       1989                1.0               1             14101
# 3375       1938                1.0               1             18258
#
#       PropertyGFAParking  PropertyGFABuilding(s) LargestPropertyUseType  \
# 3360                   0                   20616     Other - Recreation
# 3361                   0                   11685   Prison/Incarceration
# 3362                   0                   11968   Prison/Incarceration
# 3363                   0                   11285   Prison/Incarceration
# 3364                   0                   16795     Other - Recreation
# 3365                   0                   12769     Other - Recreation
# 3366                   0                   13661                 Office
# 3367                   0                   23445     Other - Recreation
# 3368                   0                   20050     Other - Recreation
# 3369                   0                   15398                 Office
# 3370                   0                   18261     Other - Recreation
# 3371                   0                   12294                 Office
# 3372                   0                   16000     Other - Recreation
# 3373                   0                   13157     Other - Recreation
# 3374                   0                   14101     Other - Recreation
# 3375                   0                   18258     Other - Recreation
#
#         SecondLargestPropertyUseType ThirdLargestPropertyUseType  \
# 3360  Fitness Center/Health Club/Gym          Pre-school/Daycare
# 3361                      No UseType                  No UseType
# 3362                      No UseType                  No UseType
# 3363                      No UseType                  No UseType
# 3364  Fitness Center/Health Club/Gym          Pre-school/Daycare
# 3365  Fitness Center/Health Club/Gym                      Office
# 3366                      No UseType                  No UseType
# 3367                      No UseType                  No UseType
# 3368  Fitness Center/Health Club/Gym                      Office
# 3369                      No UseType                  No UseType
# 3370                      No UseType                  No UseType
# 3371                      No UseType                  No UseType
# 3372                      No UseType                  No UseType
# 3373  Fitness Center/Health Club/Gym               Swimming Pool
# 3374  Fitness Center/Health Club/Gym          Pre-school/Daycare
# 3375  Fitness Center/Health Club/Gym          Pre-school/Daycare
#
#       ENERGYSTARScore  SiteEnergyUseWN(kBtu)  TotalGHGEmissions
# 3360              NaN           6.369655e+05               4.44
# 3361              NaN           9.691420e+05              29.18
# 3362              NaN           8.587730e+05              23.00
# 3363              NaN           7.059837e+05              14.37
# 3364              NaN           9.905455e+05              24.73
# 3365              NaN           5.370264e+06             216.18
# 3366             75.0           5.585251e+05               3.50
# 3367              NaN           6.716330e+06             259.22
# 3368              NaN           1.993137e+06              60.81
# 3369             93.0           4.141724e+05               7.79
# 3370              NaN           1.025432e+06              20.33
# 3371             46.0           9.430032e+05              20.94
# 3372              NaN           1.053706e+06              32.17
# 3373              NaN           6.053764e+06             223.54
# 3374              NaN           7.828413e+05              22.11
# 3375              NaN           1.293722e+06              41.27

# %%
df.shape
# Out:
# (1561, 16)

# %%
df = df.loc[~df['ZipCode'].isna()]

# %%
df.shape
# Out:
# (1545, 16)

# %% [markdown]
# ##### ENERGYSTARScore

# %%
df['ENERGYSTARScore'].nunique()
# Out:
# 100

# %%
df['ENERGYSTARScore'].unique()
# Out:
# array([ 60.,  61.,  43.,  56.,  75.,  nan,  27.,  30.,  36.,  48.,  58.,
#         35.,  31.,  39.,  76.,  95.,  84.,  57.,  29.,   8.,  97.,  88.,
#         83.,  67.,  78.,  14.,  71.,  63.,  98.,  99.,  86.,  80.,  81.,
#         94.,  74.,  96.,  37.,  91.,  93.,  68.,  53.,  34., 100.,  89.,
#         92.,  90.,  79.,  21.,  10.,  72.,  87.,  70.,  64.,  49.,  62.,
#         46.,  42.,  77.,   1.,  20.,  85.,  66.,  69.,  28.,  65.,   3.,
#         54.,  45.,   2.,  55.,  25.,   6.,  59.,  19.,   7.,   5.,  23.,
#         38.,  73.,  33.,  26.,  41.,  32.,  82.,  15.,  16.,  50.,  51.,
#         12.,  13.,  11.,  47.,  18.,  24.,  17.,  52.,  44.,   4.,  40.,
#         22.,   9.])

# %%
UVA_num_plus(df,['ENERGYSTARScore'])

# %%
df.shape
# Out:
# (1545, 16)

# %%
df = df.loc[~df['ENERGYSTARScore'].isna()]

# %%
df.shape
# Out:
# (1030, 16)

# %%
df['ZipCode'].nunique()
# Out:
# 40

# %% [markdown]
# #### SiteEnergyUseWN(kBtu)

# %%
UVA_num_plus(df, ['SiteEnergyUseWN(kBtu)'])

# %%
df['SiteEnergyUseWN(kBtu)'].isna().sum()
# Out:
# 1

# %%
df['SiteEnergyUseWN(kBtu)'].value_counts()
# Out:
# 0.000000e+00    6
# 2.127889e+06    2
# 7.456910e+06    1
# 6.656819e+05    1
# 1.745284e+06    1
#                ..
# 1.549100e+07    1
# 8.455976e+06    1
# 3.065954e+06    1
# 2.739122e+06    1
# 1.397742e+06    1
# Name: SiteEnergyUseWN(kBtu), Length: 1023, dtype: int64

# %%
df.shape
# Out:
# (1030, 16)

# %%
df.loc[df['SiteEnergyUseWN(kBtu)'].isna()]
# Out:
#        BuildingType PrimaryPropertyType  ZipCode Neighborhood  YearBuilt  \
# 563  NonResidential        Large Office  98121.0     DOWNTOWN       1979
#
#      NumberofBuildings  NumberofFloors  PropertyGFATotal  PropertyGFAParking  \
# 563                1.0               7            131143               87160
#
#      PropertyGFABuilding(s) LargestPropertyUseType  \
# 563                   43983                 Office
#
#     SecondLargestPropertyUseType ThirdLargestPropertyUseType  ENERGYSTARScore  \
# 563                 Retail Store                  No UseType             93.0
#
#      SiteEnergyUseWN(kBtu)  TotalGHGEmissions
# 563                    NaN             109.16

# %%
df = df.loc[~df['SiteEnergyUseWN(kBtu)'].isna()]

# %%
df.shape
# Out:
# (1029, 16)

# %%
df.loc[df['SiteEnergyUseWN(kBtu)'] == 0]
# Out:
#        BuildingType          PrimaryPropertyType  ZipCode  \
# 220  NonResidential                 Large Office  98104.0
# 247  NonResidential                 Large Office  98101.0
# 284  NonResidential                 Large Office  98101.0
# 350  NonResidential  Small- and Mid-Sized Office  98119.0
# 882  NonResidential             Worship Facility  98115.0
# 953  NonResidential             Worship Facility  98115.0
#
#               Neighborhood  YearBuilt  NumberofBuildings  NumberofFloors  \
# 220               DOWNTOWN       1958                1.0              17
# 247               DOWNTOWN       1988                1.0              20
# 284               DOWNTOWN       1929                1.0              15
# 350  MAGNOLIA / QUEEN ANNE       1971                1.0               5
# 882              NORTHWEST       1910                1.0               2
# 953              NORTHEAST       2000                1.0               2
#
#      PropertyGFATotal  PropertyGFAParking  PropertyGFABuilding(s)  \
# 220            378525               84600                  293925
# 247            497513              118744                  378769
# 284            151039                   0                  151039
# 350             88000               21600                   66400
# 882             23931                   0                   23931
# 953             31386                   0                   31386
#
#     LargestPropertyUseType SecondLargestPropertyUseType  \
# 220                 Office                      Parking
# 247                 Office                      Parking
# 284                 Office                   No UseType
# 350                 Office                      Parking
# 882       Worship Facility                   No UseType
# 953       Worship Facility                   No UseType
#
#     ThirdLargestPropertyUseType  ENERGYSTARScore  SiteEnergyUseWN(kBtu)  \
# 220                  Restaurant             69.0                    0.0
# 247                  No UseType             65.0                    0.0
# 284                  No UseType             84.0                    0.0
# 350                  No UseType             75.0                    0.0
# 882                  No UseType             88.0                    0.0
# 953                  No UseType             52.0                    0.0
#
#      TotalGHGEmissions
# 220             940.47
# 247             197.19
# 284             238.09
# 350              24.29
# 882              18.66
# 953              27.14

# %%
df.loc[df['SiteEnergyUseWN(kBtu)'] == 0].any(1).count()
# Out:
# 6

# %%
df.loc[df['SiteEnergyUseWN(kBtu)'] > 0].shape
# Out:
# (1023, 16)

# %%
df = df.loc[df['SiteEnergyUseWN(kBtu)'] > 0]

# %%
df.shape
# Out:
# (1023, 16)

# %% [markdown]
# #### NumberOfBuildings

# %%
UVA_num_plus(df, ['NumberofBuildings'])

# %%
df['NumberofBuildings'].isna().sum()
# Out:
# 0

# %%
df.loc[df['NumberofBuildings'].isna()]
# Out:
# Empty DataFrame
# Columns: [BuildingType, PrimaryPropertyType, ZipCode, Neighborhood, YearBuilt, NumberofBuildings, NumberofFloors, PropertyGFATotal, PropertyGFAParking, PropertyGFABuilding(s), LargestPropertyUseType, SecondLargestPropertyUseType, ThirdLargestPropertyUseType, ENERGYSTARScore, SiteEnergyUseWN(kBtu), TotalGHGEmissions]
# Index: []

# %%
df['NumberofBuildings'].fillna(1, inplace=True)

# %%
df['NumberofBuildings'].value_counts()
# Out:
# 1.0    989
# 0.0     22
# 2.0      3
# 4.0      2
# 6.0      2
# 9.0      1
# 7.0      1
# 5.0      1
# 3.0      1
# 8.0      1
# Name: NumberofBuildings, dtype: int64

# %%
nb_build_outl = df.loc[df['NumberofBuildings'] >= 5]

# %%
nb_build_outl.all(1).count()
# Out:
# 6

# %%
nb_build_outl
# Out:
#         BuildingType PrimaryPropertyType  ZipCode Neighborhood  YearBuilt  \
# 124   NonResidential            Hospital  98105.0    NORTHEAST       1953
# 167   NonResidential            Hospital  98122.0      CENTRAL       1990
# 170   NonResidential            Hospital  98104.0         EAST       2000
# 618   NonResidential            Hospital  98122.0         EAST       1994
# 954           Campus         K-12 School  98115.0    NORTHEAST       1989
# 1672  NonResidential            Hospital  98133.0    NORTHWEST       1966
#
#       NumberofBuildings  NumberofFloors  PropertyGFATotal  PropertyGFAParking  \
# 124                 6.0              10            879000                   0
# 167                 6.0               5            597519                   0
# 170                 9.0               8           1158691                   0
# 618                 7.0              14           1765970                   0
# 954                 5.0               3             21500                   0
# 1672                8.0               1            415632                   0
#
#       PropertyGFABuilding(s)                 LargestPropertyUseType  \
# 124                   879000  Hospital (General Medical & Surgical)
# 167                   597519  Hospital (General Medical & Surgical)
# 170                  1158691  Hospital (General Medical & Surgical)
# 618                  1765970  Hospital (General Medical & Surgical)
# 954                    21500                            K-12 School
# 1672                  415632  Hospital (General Medical & Surgical)
#
#      SecondLargestPropertyUseType ThirdLargestPropertyUseType  \
# 124                    No UseType                  No UseType
# 167                       Parking                  No UseType
# 170                       Parking                  No UseType
# 618                       Parking                  No UseType
# 954                    No UseType                  No UseType
# 1672                      Parking                  No UseType
#
#       ENERGYSTARScore  SiteEnergyUseWN(kBtu)  TotalGHGEmissions
# 124              10.0            257764208.0            8145.52
# 167              34.0            147299056.0            4906.33
# 170              29.0            296671744.0           10734.57
# 618              54.0            295929888.0           12307.16
# 954              44.0              7109712.5             202.65
# 1672             85.0            100328264.0            3278.11

# %%
nb_build_outl[['BuildingType', 'PrimaryPropertyType',
       'YearBuilt', 'NumberofBuildings', 'NumberofFloors', 'PropertyGFATotal',
       'LargestPropertyUseType','SiteEnergyUseWN(kBtu)', 
       'TotalGHGEmissions']].sort_values(by=['NumberofBuildings'], ascending=False)
# Out:
#         BuildingType PrimaryPropertyType  YearBuilt  NumberofBuildings  \
# 170   NonResidential            Hospital       2000                9.0
# 1672  NonResidential            Hospital       1966                8.0
# 618   NonResidential            Hospital       1994                7.0
# 124   NonResidential            Hospital       1953                6.0
# 167   NonResidential            Hospital       1990                6.0
# 954           Campus         K-12 School       1989                5.0
#
#       NumberofFloors  PropertyGFATotal                 LargestPropertyUseType  \
# 170                8           1158691  Hospital (General Medical & Surgical)
# 1672               1            415632  Hospital (General Medical & Surgical)
# 618               14           1765970  Hospital (General Medical & Surgical)
# 124               10            879000  Hospital (General Medical & Surgical)
# 167                5            597519  Hospital (General Medical & Surgical)
# 954                3             21500                            K-12 School
#
#       SiteEnergyUseWN(kBtu)  TotalGHGEmissions
# 170             296671744.0           10734.57
# 1672            100328264.0            3278.11
# 618             295929888.0           12307.16
# 124             257764208.0            8145.52
# 167             147299056.0            4906.33
# 954               7109712.5             202.65

# %%
# replace NumberofBuildings value from 0 to 1
df['NumberofBuildings'].loc[df['NumberofBuildings'] == 0] = 1

# %%
df['NumberofBuildings'].value_counts()
# Out:
# 1.0    1011
# 2.0       3
# 4.0       2
# 6.0       2
# 9.0       1
# 7.0       1
# 5.0       1
# 3.0       1
# 8.0       1
# Name: NumberofBuildings, dtype: int64

# %%
df.head()
# Out:
#      BuildingType PrimaryPropertyType  ZipCode Neighborhood  YearBuilt  \
# 0  NonResidential               Hotel  98101.0     DOWNTOWN       1927
# 1  NonResidential               Hotel  98101.0     DOWNTOWN       1996
# 2  NonResidential               Hotel  98101.0     DOWNTOWN       1969
# 3  NonResidential               Hotel  98101.0     DOWNTOWN       1926
# 4  NonResidential               Hotel  98121.0     DOWNTOWN       1980
#
#    NumberofBuildings  NumberofFloors  PropertyGFATotal  PropertyGFAParking  \
# 0                1.0              12             88434                   0
# 1                1.0              11            103566               15064
# 2                1.0              41            956110              196718
# 3                1.0              10             61320                   0
# 4                1.0              18            175580               62000
#
#    PropertyGFABuilding(s) LargestPropertyUseType SecondLargestPropertyUseType  \
# 0                   88434                  Hotel                   No UseType
# 1                   88502                  Hotel                      Parking
# 2                  759392                  Hotel                   No UseType
# 3                   61320                  Hotel                   No UseType
# 4                  113580                  Hotel                      Parking
#
#   ThirdLargestPropertyUseType  ENERGYSTARScore  SiteEnergyUseWN(kBtu)  \
# 0                  No UseType             60.0              7456910.0
# 1                  Restaurant             61.0              8664479.0
# 2                  No UseType             43.0             73937112.0
# 3                  No UseType             56.0              6946800.5
# 4               Swimming Pool             75.0             14656503.0
#
#    TotalGHGEmissions
# 0             249.98
# 1             295.86
# 2            2089.28
# 3             286.43
# 4             505.01

# %% [markdown]
# ## Catégories : simplification

# %%
categorical_columns = df.select_dtypes(['category','object']).columns
categorical_columns
# Out:
# Index(['BuildingType', 'PrimaryPropertyType', 'Neighborhood',
#        'LargestPropertyUseType', 'SecondLargestPropertyUseType',
#        'ThirdLargestPropertyUseType'],
#       dtype='object')

# %%
print_cats(df, categorical_columns)
# Out:
# --------------------------------------------
# --------------------------------------------
# Column : BuildingType
# ----
# nunique : 4
# ['NonResidential' 'SPS-District K-12' 'Campus' 'Nonresidential COS']
#
#
# --------------------------------------------
# --------------------------------------------
# Column : PrimaryPropertyType
# ----
# nunique : 14
# ['Hotel' 'Other' 'K-12 School' 'Mixed Use Property'
#  'Small- and Mid-Sized Office' 'Large Office' 'Medical Office'
#  'Retail Store' 'Hospital' 'Warehouse' 'Worship Facility'
#  'Supermarket / Grocery Store' 'Distribution Center'
#  'Refrigerated Warehouse']
#
#
# --------------------------------------------
# --------------------------------------------
# Column : Neighborhood
# ----
# nunique : 13
# ['DOWNTOWN' 'SOUTHEAST' 'NORTHEAST' 'NORTH' 'GREATER DUWAMISH'
#  'MAGNOLIA / QUEEN ANNE' 'BALLARD' 'NORTHWEST' 'LAKE UNION' 'EAST'
#  'CENTRAL' 'DELRIDGE' 'SOUTHWEST']
#
#
# --------------------------------------------
# --------------------------------------------
# Column : LargestPropertyUseType
# ----
# nunique : 19
# ['Hotel' 'Courthouse' 'K-12 School' 'Office' 'Medical Office'
#  'Retail Store' 'Hospital (General Medical & Surgical)' 'Financial Office'
#  'Non-Refrigerated Warehouse' 'Worship Facility' 'Data Center' 'Parking'
#  'Supermarket/Grocery Store' 'Distribution Center'
#  'Wholesale Club/Supercenter' 'Refrigerated Warehouse' 'Other'
#  'No UseType' 'Bank Branch']
#
#
# --------------------------------------------
# --------------------------------------------
# Column : SecondLargestPropertyUseType
# ----
# nunique : 31
# ['No UseType' 'Parking' 'Laboratory' 'Non-Refrigerated Warehouse'
#  'Other - Education' 'Retail Store'
#  'Other - Entertainment/Public Assembly' 'Restaurant' 'Swimming Pool'
#  'Self-Storage Facility' 'Office' 'Other - Services' 'Other - Recreation'
#  'Convenience Store without Gas Station' 'Other' 'Performing Arts'
#  'College/University' 'Supermarket/Grocery Store' 'Data Center'
#  'Adult Education' 'Distribution Center' 'Bar/Nightclub'
#  'Financial Office' 'Manufacturing/Industrial Plant' 'Bank Branch'
#  'K-12 School' 'Hotel' 'Worship Facility' 'Medical Office'
#  'Pre-school/Daycare' 'Other - Restaurant/Bar']
#
#
# --------------------------------------------
# --------------------------------------------
# Column : ThirdLargestPropertyUseType
# ----
# nunique : 29
# ['No UseType' 'Restaurant' 'Swimming Pool' 'Non-Refrigerated Warehouse'
#  'Data Center' 'Retail Store' 'Other' 'Other - Services' 'Medical Office'
#  'Food Service' 'Parking' 'Fitness Center/Health Club/Gym'
#  'Social/Meeting Hall' 'Pre-school/Daycare'
#  'Convenience Store without Gas Station' 'Financial Office'
#  'Other - Restaurant/Bar' 'Other - Education' 'Distribution Center'
#  'Office' 'Laboratory' 'Bank Branch'
#  'Other - Entertainment/Public Assembly' 'Other - Recreation'
#  'Personal Services (Health/Beauty, Dry Cleaning, etc)'
#  'Other - Technology/Science' 'Refrigerated Warehouse' 'Bar/Nightclub'
#  'Other/Specialty Hospital']

# %%
# Simplify most complex / redundant usetypes

# %%
df['LargestPropertyUseType'].unique()
# Out:
# array(['Hotel', 'Courthouse', 'K-12 School', 'Office', 'Medical Office',
#        'Retail Store', 'Hospital (General Medical & Surgical)',
#        'Financial Office', 'Non-Refrigerated Warehouse',
#        'Worship Facility', 'Data Center', 'Parking',
#        'Supermarket/Grocery Store', 'Distribution Center',
#        'Wholesale Club/Supercenter', 'Refrigerated Warehouse', 'Other',
#        'No UseType', 'Bank Branch'], dtype=object)

# %%
df['SecondLargestPropertyUseType'].unique()
# Out:
# array(['No UseType', 'Parking', 'Laboratory',
#        'Non-Refrigerated Warehouse', 'Other - Education', 'Retail Store',
#        'Other - Entertainment/Public Assembly', 'Restaurant',
#        'Swimming Pool', 'Self-Storage Facility', 'Office',
#        'Other - Services', 'Other - Recreation',
#        'Convenience Store without Gas Station', 'Other',
#        'Performing Arts', 'College/University',
#        'Supermarket/Grocery Store', 'Data Center', 'Adult Education',
#        'Distribution Center', 'Bar/Nightclub', 'Financial Office',
#        'Manufacturing/Industrial Plant', 'Bank Branch', 'K-12 School',
#        'Hotel', 'Worship Facility', 'Medical Office',
#        'Pre-school/Daycare', 'Other - Restaurant/Bar'], dtype=object)

# %%
df['ThirdLargestPropertyUseType'].unique()
# Out:
# array(['No UseType', 'Restaurant', 'Swimming Pool',
#        'Non-Refrigerated Warehouse', 'Data Center', 'Retail Store',
#        'Other', 'Other - Services', 'Medical Office', 'Food Service',
#        'Parking', 'Fitness Center/Health Club/Gym', 'Social/Meeting Hall',
#        'Pre-school/Daycare', 'Convenience Store without Gas Station',
#        'Financial Office', 'Other - Restaurant/Bar', 'Other - Education',
#        'Distribution Center', 'Office', 'Laboratory', 'Bank Branch',
#        'Other - Entertainment/Public Assembly', 'Other - Recreation',
#        'Personal Services (Health/Beauty, Dry Cleaning, etc)',
#        'Other - Technology/Science', 'Refrigerated Warehouse',
#        'Bar/Nightclub', 'Other/Specialty Hospital'], dtype=object)

# %% [markdown]
# # Explore post-cleaning

# %%
df.head()
# Out:
#      BuildingType PrimaryPropertyType  ZipCode Neighborhood  YearBuilt  \
# 0  NonResidential               Hotel  98101.0     DOWNTOWN       1927
# 1  NonResidential               Hotel  98101.0     DOWNTOWN       1996
# 2  NonResidential               Hotel  98101.0     DOWNTOWN       1969
# 3  NonResidential               Hotel  98101.0     DOWNTOWN       1926
# 4  NonResidential               Hotel  98121.0     DOWNTOWN       1980
#
#    NumberofBuildings  NumberofFloors  PropertyGFATotal  PropertyGFAParking  \
# 0                1.0              12             88434                   0
# 1                1.0              11            103566               15064
# 2                1.0              41            956110              196718
# 3                1.0              10             61320                   0
# 4                1.0              18            175580               62000
#
#    PropertyGFABuilding(s) LargestPropertyUseType SecondLargestPropertyUseType  \
# 0                   88434                  Hotel                   No UseType
# 1                   88502                  Hotel                      Parking
# 2                  759392                  Hotel                   No UseType
# 3                   61320                  Hotel                   No UseType
# 4                  113580                  Hotel                      Parking
#
#   ThirdLargestPropertyUseType  ENERGYSTARScore  SiteEnergyUseWN(kBtu)  \
# 0                  No UseType             60.0              7456910.0
# 1                  Restaurant             61.0              8664479.0
# 2                  No UseType             43.0             73937112.0
# 3                  No UseType             56.0              6946800.5
# 4               Swimming Pool             75.0             14656503.0
#
#    TotalGHGEmissions
# 0             249.98
# 1             295.86
# 2            2089.28
# 3             286.43
# 4             505.01

# %%
show_nulls(df)
# Out:
#                                                    columns  count  \
# BuildingType                                  BuildingType      0
# PrimaryPropertyType                    PrimaryPropertyType      0
# ZipCode                                            ZipCode      0
# Neighborhood                                  Neighborhood      0
# YearBuilt                                        YearBuilt      0
# NumberofBuildings                        NumberofBuildings      0
# NumberofFloors                              NumberofFloors      0
# PropertyGFATotal                          PropertyGFATotal      0
# PropertyGFAParking                      PropertyGFAParking      0
# PropertyGFABuilding(s)              PropertyGFABuilding(s)      0
# LargestPropertyUseType              LargestPropertyUseType      0
# SecondLargestPropertyUseType  SecondLargestPropertyUseType      0
# ThirdLargestPropertyUseType    ThirdLargestPropertyUseType      0
# ENERGYSTARScore                            ENERGYSTARScore      0
# SiteEnergyUseWN(kBtu)                SiteEnergyUseWN(kBtu)      0
# TotalGHGEmissions                        TotalGHGEmissions      0
#
#                               null_percent
# BuildingType                           0.0
# PrimaryPropertyType                    0.0
# ZipCode                                0.0
# Neighborhood                           0.0
# YearBuilt                              0.0
# NumberofBuildings                      0.0
# NumberofFloors                         0.0
# PropertyGFATotal                       0.0
# PropertyGFAParking                     0.0
# PropertyGFABuilding(s)                 0.0
# LargestPropertyUseType                 0.0
# SecondLargestPropertyUseType           0.0
# ThirdLargestPropertyUseType            0.0
# ENERGYSTARScore                        0.0
# SiteEnergyUseWN(kBtu)                  0.0
# TotalGHGEmissions                      0.0

# %%
num_cols = df.columns[df.dtypes == 'float64']
num_cols
# Out:
# Index(['ZipCode', 'NumberofBuildings', 'ENERGYSTARScore',
#        'SiteEnergyUseWN(kBtu)', 'TotalGHGEmissions'],
#       dtype='object')

# %%
UVA_num_plus(df, num_cols)

# %% [markdown]
# ## Heatmap / matrice corrélation

# %%
### années de construction / influence sur autres params ?
## (heatmap de seaborn)

# %%
num_cols = df.columns[df.dtypes == 'float64']
num_cols
# Out:
# Index(['ZipCode', 'NumberofBuildings', 'ENERGYSTARScore',
#        'SiteEnergyUseWN(kBtu)', 'TotalGHGEmissions'],
#       dtype='object')

# %%
plt.figure(figsize=(8,8))
sns.set(font_scale=1.5)
plt.title('Matrice de corrélation de Pearson entre les variables numériques')


corr = df.corr()
#corr = df[[num_cols]].corr()

#numpy deprecated bool : https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
mask = np.zeros_like(corr, dtype=np.bool_)
mask[np.triu_indices_from(mask)] = True 

ax = sns.heatmap(corr, mask=mask, vmin=-1, cmap='coolwarm')
plt.show()
sns.set(font_scale=1)

# %%
# https://www.kdnuggets.com/2019/07/annotated-heatmaps-correlation-matrix.html
f, ax = plt.subplots(figsize=(13, 18))

corr_matrix = df.corr()

heatmap = sns.heatmap(corr_matrix,
                      mask = mask,
                      square = True,
                      linewidths = .5,
                      cmap = "coolwarm",
                      cbar_kws = {'shrink': .4,
                                "ticks" : [-1, -.5, 0, 0.5, 1]},
                      vmin = -1,
                      vmax = 1,
                      annot = True,
                      annot_kws = {"size": 12})

#add the column names as labels
ax.set_yticklabels(corr_matrix.columns, rotation = 0)
ax.set_xticklabels(corr_matrix.columns)

sns.set_style({'xtick.bottom': True}, {'ytick.left': True})

# %%
df.head()
# Out:
#      BuildingType PrimaryPropertyType  ZipCode Neighborhood  YearBuilt  \
# 0  NonResidential               Hotel  98101.0     DOWNTOWN       1927
# 1  NonResidential               Hotel  98101.0     DOWNTOWN       1996
# 2  NonResidential               Hotel  98101.0     DOWNTOWN       1969
# 3  NonResidential               Hotel  98101.0     DOWNTOWN       1926
# 4  NonResidential               Hotel  98121.0     DOWNTOWN       1980
#
#    NumberofBuildings  NumberofFloors  PropertyGFATotal  PropertyGFAParking  \
# 0                1.0              12             88434                   0
# 1                1.0              11            103566               15064
# 2                1.0              41            956110              196718
# 3                1.0              10             61320                   0
# 4                1.0              18            175580               62000
#
#    PropertyGFABuilding(s) LargestPropertyUseType SecondLargestPropertyUseType  \
# 0                   88434                  Hotel                   No UseType
# 1                   88502                  Hotel                      Parking
# 2                  759392                  Hotel                   No UseType
# 3                   61320                  Hotel                   No UseType
# 4                  113580                  Hotel                      Parking
#
#   ThirdLargestPropertyUseType  ENERGYSTARScore  SiteEnergyUseWN(kBtu)  \
# 0                  No UseType             60.0              7456910.0
# 1                  Restaurant             61.0              8664479.0
# 2                  No UseType             43.0             73937112.0
# 3                  No UseType             56.0              6946800.5
# 4               Swimming Pool             75.0             14656503.0
#
#    TotalGHGEmissions
# 0             249.98
# 1             295.86
# 2            2089.28
# 3             286.43
# 4             505.01

# %% [markdown]
# # Export to CSV

# %%
df.reset_index()

df.to_csv(path + 'clean_seattle_buildings.csv', index=False)
print('export finished !')
# Out:
# export finished !

# %%
pwd
# Out:
# '/home/mijka/code/openclassrooms/projets/projet_4'

# %%
ls -lh ./data
# Out:
# total 1,4M
# -rw-r--r-- 1 mijka mijka 1,2M  5 févr. 09:37 2016_Building_Energy_Benchmarking.csv
# -rw-r--r-- 1 mijka mijka 136K 12 févr. 09:54 clean_seattle_buildings.csv

# %%
## 2023-02-05 mentorat :
## 
## /!\ si valeurs nan cible => pas remplacer, supprimer
##
