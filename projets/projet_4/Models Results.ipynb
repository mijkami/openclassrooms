# %%
import pandas as pd

# %%
csv_name_1 = 'energy_no_scarscore_performances.csv'
csv_name_2 = 'energy_with_scarscore_performances.csv'
csv_name_3 = 'emissions_no_scarscore_performances.csv'
csv_name_4 = 'emissions_with_scarscore_performances.csv'

# %%
df1 = pd.read_csv(csv_name_1, low_memory=False)
df2 = pd.read_csv(csv_name_2, low_memory=False)
df3 = pd.read_csv(csv_name_3, low_memory=False)
df4 = pd.read_csv(csv_name_4, low_memory=False)

# %%
df_results = pd.concat([df1, df2, df3, df4], axis=0, ignore_index=True)

# %%
df_results
# Out:
#                     Label                      Model  Star Score  \
# 0   SiteEnergyUseWN(kBtu)           LinearRegression       False
# 1   SiteEnergyUseWN(kBtu)                 ElasticNet       False
# 2   SiteEnergyUseWN(kBtu)      RandomForestRegressor       False
# 3   SiteEnergyUseWN(kBtu)  GradientBoostingRegressor       False
# 4   SiteEnergyUseWN(kBtu)                        SVR       False
# 5   SiteEnergyUseWN(kBtu)           LinearRegression        True
# 6   SiteEnergyUseWN(kBtu)                 ElasticNet        True
# 7   SiteEnergyUseWN(kBtu)      RandomForestRegressor        True
# 8   SiteEnergyUseWN(kBtu)  GradientBoostingRegressor        True
# 9   SiteEnergyUseWN(kBtu)                        SVR        True
# 10      TotalGHGEmissions           LinearRegression       False
# 11      TotalGHGEmissions                 ElasticNet       False
# 12      TotalGHGEmissions      RandomForestRegressor       False
# 13      TotalGHGEmissions  GradientBoostingRegressor       False
# 14      TotalGHGEmissions                        SVR       False
# 15      TotalGHGEmissions           LinearRegression        True
# 16      TotalGHGEmissions                 ElasticNet        True
# 17      TotalGHGEmissions      RandomForestRegressor        True
# 18      TotalGHGEmissions  GradientBoostingRegressor        True
# 19      TotalGHGEmissions                        SVR        True
#
#     Duration seconds           MAE          RMSE        R2
# 0           0.080685  5.612983e+06  1.349879e+07  0.658055
# 1          38.414795  5.612983e+06  1.349879e+07  0.658055
# 2          78.410653  3.952876e+06  1.274192e+07  0.695326
# 3          28.526511  3.654189e+06  9.730581e+06  0.822318
# 4         259.685375  7.019155e+06  2.375534e+07 -0.058982
# 5           0.053334  5.772626e+06  1.338405e+07  0.663843
# 6          39.382556  5.772626e+06  1.338405e+07  0.663843
# 7          81.981404  3.169095e+06  9.127058e+06  0.843675
# 8          30.168188  2.850673e+06  8.924212e+06  0.850546
# 9         274.036355  7.019155e+06  2.375534e+07 -0.058982
# 10          0.228793  1.852826e+02  4.233491e+02  0.638671
# 11         22.793008  1.852826e+02  4.233491e+02  0.638671
# 12         82.302663  9.788578e+01  2.752500e+02  0.847257
# 13         29.420794  1.237500e+02  4.909598e+02  0.514044
# 14        252.252685  1.764299e+02  7.071273e+02 -0.008093
# 15          0.058059  2.048064e+02  4.299539e+02  0.627309
# 16         25.027866  2.048064e+02  4.299539e+02  0.627309
# 17         81.809023  9.628136e+01  2.627044e+02  0.860864
# 18         30.182199  8.928112e+01  2.722754e+02  0.850541
# 19        242.247354  1.765338e+02  7.071045e+02 -0.008028

# %%
df1
