# %%
# imports
# %matplotlib inline

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
#import datetime as dt
#import scipy.stats as st
#from pandas_profiling import ProfileReport
#import missingno as msno
import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_rows', 750)
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# # Extract & Load

# %%
csv_path = './data/'

# %%
def get_data(csv_path):
    file_names = [x for x in os.listdir(csv_path) if ".csv" in x]
    # file_names_base = file_names
    key_names = [
        key_name.removesuffix('.csv').removeprefix('EdStats')
        for key_name in file_names
    ]

    data_dict = {}
    for k, f in zip(key_names, file_names):
        data_dict[k] = pd.read_csv(os.path.join(csv_path, f))

    return data_dict

# %%
data = get_data(csv_path)

# %% [markdown]
# # Assess Dataset

# %% [markdown]
# ## Fct build

# %%
ls -lh ./data
# Out:
# total 353M
# -rw-r--r-- 1 mijka mijka 137K 22 janv.  2018 EdStatsCountry.csv
# -rw-r--r-- 1 mijka mijka  48K 22 janv.  2018 EdStatsCountry-Series.csv
# -rw-r--r-- 1 mijka mijka 312M 22 janv.  2018 EdStatsData.csv
# -rw-r--r-- 1 mijka mijka  38M 22 janv.  2018 EdStatsFootNote.csv
# -rw-r--r-- 1 mijka mijka 3,6M 22 janv.  2018 EdStatsSeries.csv

# %%
import enum
from os import listdir
from os.path import isfile, join

class SIZE_UNIT(enum.Enum):
   BYTES = 1
   KB = 2
   MB = 3
   GB = 4

def convert_unit(size_in_bytes, unit):
  # Convert the size from bytes to other units like KB, MB or GB
   if unit == SIZE_UNIT.KB:
       return size_in_bytes/1024
   elif unit == SIZE_UNIT.MB:
       return size_in_bytes/(1024*1024)
   elif unit == SIZE_UNIT.GB:
       return size_in_bytes/(1024*1024*1024)
   else:
       return size_in_bytes

def get_file_size(file_name, size_type = SIZE_UNIT.BYTES ):
   # Get file in size in given unit like KB, MB or GB
   size = os.path.getsize(file_name)
   return convert_unit(size, size_type)

def get_folder_files_size(folder_path):
    files_list = [f for f in listdir(folder_path) if isfile(join(folder_path, f))]
    for i in files_list:
        size = get_file_size(f'{folder_path + i}', SIZE_UNIT.MB)
        print(f'Size of {i}: ', round(size,2),'MB')

# %%
def get_shape(dict):
    for key in dict:
        print(key, dict[f'{key}'].shape)

# %%
def type_df(df):
    type_dct = {str(k): list(v) for k, v in df.groupby(df.dtypes, axis=1)}
    print(
        str(type_dct)
        .replace('], ', '\n \n')
        .replace('[', '\n')
        #.replace(', ', '\n')
        .replace(': ', ':\t')
        .replace('{', '')
        .replace('}', '')
    )
    
def get_info(df):
    nb_na = df.isnull().sum()
    nb_na_full = nb_na.sum().astype(str)
    duplicates_count = len(df)-len(df.drop_duplicates())
    
    print('// Dataframe shape :' + '\n')
    print(df.shape)
    print('_' * 20 + '\n')
    print('// Dataframe types :' + '\n')
    print(type_df(df))
    print('_' * 20 + '\n')
    print('// Dataframe duplicates count : ' + '\n')
    print(duplicates_count)
    print('_' * 20 + '\n')
    print('// Dataframe null count : ' + nb_na_full + '\n')
    print(nb_na[nb_na>0])

# %% [markdown]
# ## Cardinality

# %%
data.keys()
# Out:
# dict_keys(['Data', 'Country-Series', 'Series', 'Country', 'FootNote'])

# %% [markdown]
# ### Files size & shape

# %%
get_folder_files_size(csv_path)
# Out:
# Size of EdStatsData.csv:  311.3 MB
# Size of EdStatsCountry-Series.csv:  0.05 MB
# Size of EdStatsSeries.csv:  3.54 MB
# Size of EdStatsCountry.csv:  0.13 MB
# Size of EdStatsFootNote.csv:  37.87 MB

# %%
get_shape(data)
# Out:
# Data (886930, 70)
# Country-Series (613, 4)
# Series (3665, 21)
# Country (241, 32)
# FootNote (643638, 5)

# %% [markdown]
# ### Main source ('Data' dataset)

# %%
#data['Data'].columns

# %%
get_info(data['Data'])
# Out:
# // Dataframe shape :
#
# (886930, 70)
# ____________________
#
# // Dataframe types :
#
# 'float64':
# '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2020', '2025', '2030', '2035', '2040', '2045', '2050', '2055', '2060', '2065', '2070', '2075', '2080', '2085', '2090', '2095', '2100', 'Unnamed:	69'
#
# 'object':
# 'Country Name', 'Country Code', 'Indicator Name', 'Indicator Code']
# None
# ____________________
#
# // Dataframe duplicates count :
#
# 0
# ____________________
#
# // Dataframe null count : 53455179
#
# 1970           814642
# 1971           851393
# 1972           851311
# 1973           851385
# 1974           851200
# ...

# %%
data['Data'].nunique()
# Out:
# Country Name         242
# Country Code         242
# Indicator Name      3665
# Indicator Code      3665
# 1970               24595
# 1971               30892
# 1972               30982
# 1973               30988
# 1974               31139
# 1975               37838
# 1976               32679
# 1977               32808
# 1978               32887
# 1979               32359
# 1980               39456
# 1981               34090
# 1982               32969
# 1983               33683
# 1984               33903
# 1985               41133
# 1986               34774
# 1987               34021
# 1988               34013
# 1989               33181
# 1990               72800
# 1991               67172
# 1992               68026
# 1993               68440
# 1994               69974
# 1995               79225
# 1996               69787
# 1997               66665
# 1998               77746
# 1999              104452
# 2000              115971
# 2001              108633
# 2002              108974
# ...

# %%
data['Data'].head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                                             Indicator Name  \
# 0             Adjusted net enrolment rate, lower secondary, both sexes (%)
# 1                 Adjusted net enrolment rate, lower secondary, female (%)
# 2  Adjusted net enrolment rate, lower secondary, gender parity index (GPI)
# 3                   Adjusted net enrolment rate, lower secondary, male (%)
# 4                     Adjusted net enrolment rate, primary, both sexes (%)
#
#    Indicator Code       1970       1971       1972       1973       1974  \
# 0      UIS.NERA.2        NaN        NaN        NaN        NaN        NaN
# 1    UIS.NERA.2.F        NaN        NaN        NaN        NaN        NaN
# 2  UIS.NERA.2.GPI        NaN        NaN        NaN        NaN        NaN
# ...

# %%
data['Data'].describe()
# Out:
#                1970          1971          1972          1973          1974  \
# count  7.228800e+04  3.553700e+04  3.561900e+04  3.554500e+04  3.573000e+04
# mean   1.974772e+09  4.253638e+09  4.592365e+09  5.105006e+09  5.401493e+09
# std    1.211687e+11  1.804814e+11  1.914083e+11  2.059170e+11  2.112150e+11
# min   -1.435564e+00 -1.594625e+00 -3.056522e+00 -4.032582e+00 -4.213563e+00
# 25%    8.900000e-01  8.853210e+00  9.240920e+00  9.595200e+00  9.861595e+00
# 50%    6.317724e+00  6.316240e+01  6.655139e+01  6.969595e+01  7.087760e+01
# 75%    6.251250e+01  5.655200e+04  5.863650e+04  6.202900e+04  6.383675e+04
# max    1.903929e+13  1.986457e+13  2.100916e+13  2.238367e+13  2.282991e+13
#
#                1975          1976          1977          1978          1979  \
# count  8.730600e+04  3.748300e+04  3.757400e+04  3.757600e+04  3.680900e+04
# mean   2.314288e+09  5.731808e+09  6.124437e+09  6.671489e+09  7.436724e+09
# ...

# %%
#data['Data'].info()

# %%
# count unique indicators
data['Data']['Indicator Name'].nunique()
# Out:
# 3665

# %%
# count unique countries
data['Data']['Country Name'].nunique()
# Out:
# 242

# %% [markdown]
# ### Secondary sources

# %%
get_info(data['Country-Series'])
# Out:
# // Dataframe shape :
#
# (613, 4)
# ____________________
#
# // Dataframe types :
#
# 'float64':
# 'Unnamed:	3'
#
# 'object':
# 'CountryCode', 'SeriesCode', 'DESCRIPTION']
# None
# ____________________
#
# // Dataframe duplicates count :
#
# 0
# ____________________
#
# // Dataframe null count : 613
#
# Unnamed: 3    613
# dtype: int64

# %%
get_info(data['Series'])
# Out:
# // Dataframe shape :
#
# (3665, 21)
# ____________________
#
# // Dataframe types :
#
# 'float64':
# 'Unit of measure', 'Notes from original source', 'Other web links', 'Related indicators', 'License Type', 'Unnamed:	20'
#
# 'object':
# 'Series Code', 'Topic', 'Indicator Name', 'Short definition', 'Long definition', 'Periodicity', 'Base Period', 'Other notes', 'Aggregation method', 'Limitations and exceptions', 'General comments', 'Source', 'Statistical concept and methodology', 'Development relevance', 'Related source links']
# None
# ____________________
#
# // Dataframe duplicates count :
#
# 0
# ____________________
#
# // Dataframe null count : 55203
#
# Short definition                       1509
# Unit of measure                        3665
# Periodicity                            3566
# Base Period                            3351
# Other notes                            3113
# Aggregation method                     3618
# Limitations and exceptions             3651
# ...

# %%
get_info(data['Country'])
# Out:
# // Dataframe shape :
#
# (241, 32)
# ____________________
#
# // Dataframe types :
#
# 'float64':
# 'National accounts reference year', 'Latest industrial data', 'Latest trade data', 'Unnamed:	31'
#
# 'object':
# 'Country Code', 'Short Name', 'Table Name', 'Long Name', '2-alpha code', 'Currency Unit', 'Special Notes', 'Region', 'Income Group', 'WB-2 code', 'National accounts base year', 'SNA price valuation', 'Lending category', 'Other groups', 'System of National Accounts', 'Alternative conversion factor', 'PPP survey year', 'Balance of Payments Manual in use', 'External debt Reporting status', 'System of trade', 'Government Accounting concept', 'IMF data dissemination standard', 'Latest population census', 'Latest household survey', 'Source of most recent Income and expenditure data', 'Vital registration complete', 'Latest agricultural census', 'Latest water withdrawal data']
# None
# ____________________
#
# // Dataframe duplicates count :
#
# 0
# ____________________
#
# ...

# %%
get_info(data['FootNote'])
# Out:
# // Dataframe shape :
#
# (643638, 5)
# ____________________
#
# // Dataframe types :
#
# 'float64':
# 'Unnamed:	4'
#
# 'object':
# 'CountryCode', 'SeriesCode', 'Year', 'DESCRIPTION']
# None
# ____________________
#
# // Dataframe duplicates count :
#
# 0
# ____________________
#
# // Dataframe null count : 643638
#
# Unnamed: 4    643638
# dtype: int64

# %%
data['FootNote'].head()
# Out:
#   CountryCode      SeriesCode    Year          DESCRIPTION  Unnamed: 4
# 0         ABW  SE.PRE.ENRL.FE  YR2001  Country estimation.         NaN
# 1         ABW  SE.TER.TCHR.FE  YR2005  Country estimation.         NaN
# 2         ABW  SE.PRE.TCHR.FE  YR2000  Country estimation.         NaN
# 3         ABW  SE.SEC.ENRL.GC  YR2004  Country estimation.         NaN
# 4         ABW     SE.PRE.TCHR  YR2006  Country estimation.         NaN

# %% [markdown]
# ### Income Groups ('Country' dataset)

# %%
data['Country'].head(1)
# Out:
#   Country Code Short Name Table Name Long Name 2-alpha code  Currency Unit  \
# 0          ABW      Aruba      Aruba     Aruba           AW  Aruban florin
#
#                                                                                                                                    Special Notes  \
# 0  SNA data for 2000-2011 are updated from official government statistics; 1994-1999 from UN databases. Base year has changed from 1995 to 2000.
#
#                       Region          Income Group WB-2 code  \
# 0  Latin America & Caribbean  High income: nonOECD        AW
#
#   National accounts base year  National accounts reference year  \
# 0                        2000                               NaN
#
#                  SNA price valuation Lending category Other groups  \
# 0  Value added at basic prices (VAB)              NaN          NaN
#
#                                       System of National Accounts  \
# ...

# %%
# cherrypick data from data['Country']
country2 = data['Country'][['Country Code','Short Name','Income Group','Region']]
country2.head()
# Out:
#   Country Code   Short Name          Income Group                     Region
# 0          ABW        Aruba  High income: nonOECD  Latin America & Caribbean
# 1          AFG  Afghanistan            Low income                 South Asia
# 2          AGO       Angola   Upper middle income         Sub-Saharan Africa
# 3          ALB      Albania   Upper middle income      Europe & Central Asia
# 4          AND      Andorra  High income: nonOECD      Europe & Central Asia

# %%
# find distribution of different "Income Group"
country2[['Country Code', 'Income Group']].groupby(['Income Group']).count()
# Out:
#                       Country Code
# Income Group
# High income: OECD               31
# High income: nonOECD            44
# Low income                      34
# Lower middle income             50
# Upper middle income             55

# %%
country2[['Country Code', 'Region']].groupby(['Region']).count()
# Out:
#                             Country Code
# Region
# East Asia & Pacific                   36
# Europe & Central Asia                 57
# Latin America & Caribbean             41
# Middle East & North Africa            21
# North America                          3
# South Asia                             8
# Sub-Saharan Africa                    48

# %%
# count main Data df rows per region

# %%
data['Data'].columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978',
#        '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987',
#        '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017', '2020', '2025', '2030', '2035', '2040', '2045',
#        '2050', '2055', '2060', '2065', '2070', '2075', '2080', '2085', '2090',
#        '2095', '2100', 'Unnamed: 69'],
#       dtype='object')

# %%
data['Data'].shape
# Out:
# (886930, 70)

# %%
country2.columns
# Out:
# Index(['Country Code', 'Short Name', 'Income Group', 'Region'], dtype='object')

# %%
DF_merge = data['Data'].merge(country2, on='Country Code', how='left')
DF_merge.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978',
#        '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987',
#        '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017', '2020', '2025', '2030', '2035', '2040', '2045',
#        '2050', '2055', '2060', '2065', '2070', '2075', '2080', '2085', '2090',
#        '2095', '2100', 'Unnamed: 69', 'Short Name', 'Income Group', 'Region'],
#       dtype='object')

# %%
years = ['1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978',
       '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987',
       '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
       '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
       '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
       '2015', '2016', '2017', '2020', '2025', '2030', '2035', '2040', '2045',
       '2050', '2055', '2060', '2065', '2070', '2075', '2080', '2085', '2090',
       '2095', '2100']

# %%
region_rows = DF_merge.groupby(['Region'])[years].count().sum(axis=1).sort_values()
region_rows
# Out:
# Region
# North America                   59112
# South Asia                     182299
# Middle East & North Africa     556251
# East Asia & Pacific            659306
# Latin America & Caribbean      861381
# Sub-Saharan Africa            1149170
# Europe & Central Asia         1320150
# dtype: int64

# %%
plt.figure(figsize=(14,7))
#plt.barh(y = region_rows.index, width = region_rows.values)
plot = sns.barplot(x = region_rows.values, y = region_rows.index, palette = 'colorblind')
plt.title('Décompte de données par Région')
#ax.bar_label(ax.containers[0])
plt.show()

# %%
#fig, ax = plt.subplots(figsize=(6, 8))
#g = sns.barplot(x=region_rows.values, y=region_rows.index)
#ax.bar_label(ax.containers[0])

# %%
# footnote data count

# %%
#DF_merge.groupby(['Region'])['Country Name'].count().sort_values()

# %%
#data['FootNote'].loc[~(data['FootNote']["Year"] == 'yr2012')]

# %%
data['FootNote'].replace('yr2012', 'YR2012', inplace=True)

# %%
data['FootNote']
# Out:
#        CountryCode      SeriesCode    Year  \
# 0              ABW  SE.PRE.ENRL.FE  YR2001
# 1              ABW  SE.TER.TCHR.FE  YR2005
# 2              ABW  SE.PRE.TCHR.FE  YR2000
# 3              ABW  SE.SEC.ENRL.GC  YR2004
# 4              ABW     SE.PRE.TCHR  YR2006
# ...            ...             ...     ...
# 643633         ZWE     SH.DYN.MORT  YR2007
# 643634         ZWE     SH.DYN.MORT  YR2014
# 643635         ZWE     SH.DYN.MORT  YR2015
# 643636         ZWE     SH.DYN.MORT  YR2017
# 643637         ZWE     SP.POP.GROW  YR2017
#
#                                    DESCRIPTION  Unnamed: 4
# 0                          Country estimation.         NaN
# 1                          Country estimation.         NaN
# 2                          Country estimation.         NaN
# 3                          Country estimation.         NaN
# 4                          Country estimation.         NaN
# ...                                        ...         ...
# ...

# %%
data['FootNote']['Year'] = data['FootNote']['Year'].apply(lambda x : x[2:])

# %%
years_footnote = data['FootNote']['Year'].sort_values().unique()
years_footnote
# Out:
# array(['1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985',
#        '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993',
#        '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001',
#        '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
#        '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
#        '2020', '2025', '2030', '2035', '2040', '2045', '2050'],
#       dtype=object)

# %%
data_footnote = data['FootNote'].groupby('Year').count().reset_index()
data_footnote
# Out:
#     Year  CountryCode  SeriesCode  DESCRIPTION  Unnamed: 4
# 0   1970         5374        5374         5374           0
# 1   1971         8507        8507         8507           0
# 2   1972         8661        8661         8661           0
# 3   1973         8571        8571         8571           0
# 4   1974         8512        8512         8512           0
# 5   1975         8627        8627         8627           0
# 6   1976         8729        8729         8729           0
# 7   1977         8593        8593         8593           0
# 8   1978         8585        8585         8585           0
# 9   1979         8742        8742         8742           0
# 10  1980         8950        8950         8950           0
# 11  1981         9465        9465         9465           0
# 12  1982         9014        9014         9014           0
# 13  1983         9227        9227         9227           0
# 14  1984         9386        9386         9386           0
# ...

# %%
plt.figure(figsize=(18, 8))
plt.title('Décompte de données par année', size=15)
plot = sns.barplot(y = 'CountryCode', x='Year', data = data_footnote)
plot.set_xticklabels(labels = years_footnote, rotation=50, size=12)
plt.show()

# %%
# décompte par année data['Data'] / EdStatsData

present = data['Data'].loc[:,'1970':'2100'].notnull().sum()

plt.figure(figsize=(18, 8))
present.plot(kind = 'bar')
#ax1 = present.plot(kind='bar', color='SteelBlue')
plt.title('Répartition du nombre de données par années')
plt.ylabel('Nombre de données')
plt.show()

# %%
## décompte par décennie

# Regroupement
decade=data['Data'].loc[:,'1970':'2020'].copy().count()
ans=['1970s','1980s','1990s','2000s','2010s']
for i in range(5):
    j=i*10
    k=j+10
    decade[ans[i]]=decade[j:k,].sum()
    
# Affichage
plt.figure(figsize=(15, 10))
width = 0.4   
plt.bar(decade[ans].index, decade[ans].values, width, color='SteelBlue')
# plt = sns.barplot(y = decade[ans].values, x = decade[ans].index, color='SteelBlue')
plt.xlabel('Décénnies')
plt.ylabel('Nombre de données')
plt.title('Décompte de données par décennie', size=12)
plt.show()

# %% [markdown]
# ## Missing Data

# %% [markdown]
# ### Check years/columns nan values

# %% [markdown]
# #### Fct : count rows / cols nans, plotting

# %%
def get_df_avalaible_values(df):
    indicators_list = df['Indicator Code'].unique()
    available_values_list = []
    
    for i in range(len(indicators_list)):
        indicator_full_data = df.loc[df['Indicator Code'] == indicators_list[i]]
        indicator_years_data = indicator_full_data.loc[:, ~indicator_full_data.columns.isin(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'])]
        df_nan_count = indicator_years_data.isna().values.sum()
        df_non_nan_count = indicator_years_data.count().sum()
        available_values_percent = round((df_non_nan_count / (df_non_nan_count + df_nan_count) * 100), 2)
        available_values_list.append(available_values_percent)
        
    
    available_values_df = pd.DataFrame({'Indicator Code':indicators_list,
                                  'percent_available': available_values_list
                                 })   
    return available_values_df

# %%
def get_df_columns_na(df):
    counts = df.isna().sum()
    percentages = round(df.isna().mean() * 100, 1)
    null_values = pd.concat([counts, percentages], axis = 1, keys = ["count", "null %"])
    null_values['columns'] = null_values.index
    null_values = null_values[['columns', 'count', 'null %']]
    return null_values

# %%
def plot_df_xy(df, x_val, y_val, height_val = 20, width_val = 13):
    sns.catplot(data=df, x= x_val, y= y_val, kind="bar", height=height_val, aspect=width_val/height_val)
    sns.set(rc={'figure.figsize':(width_val,height_val)})
    plt.xticks(rotation=70)
    plt.tight_layout()

# %% [markdown]
# #### Check + Plot data['Data'] : years (columns) & indicators (rows)

# %%
data['Data'].isna().mean()
# Out:
# Country Name      0.000000
# Country Code      0.000000
# Indicator Name    0.000000
# Indicator Code    0.000000
# 1970              0.918496
# 1971              0.959933
# 1972              0.959840
# 1973              0.959924
# 1974              0.959715
# 1975              0.901564
# 1976              0.957738
# 1977              0.957636
# 1978              0.957634
# 1979              0.958498
# 1980              0.899516
# 1981              0.956280
# 1982              0.957707
# 1983              0.956637
# 1984              0.956472
# 1985              0.898193
# 1986              0.955609
# 1987              0.956433
# 1988              0.956533
# 1989              0.957674
# 1990              0.859735
# 1991              0.916073
# 1992              0.914826
# 1993              0.914545
# 1994              0.912663
# 1995              0.851892
# 1996              0.913401
# 1997              0.917183
# 1998              0.904261
# 1999              0.866011
# ...

# %%
data_na = get_df_columns_na(data['Data'])
data_na
# Out:
#                        columns   count  null %
# Country Name      Country Name       0     0.0
# Country Code      Country Code       0     0.0
# Indicator Name  Indicator Name       0     0.0
# Indicator Code  Indicator Code       0     0.0
# 1970                      1970  814642    91.8
# 1971                      1971  851393    96.0
# 1972                      1972  851311    96.0
# 1973                      1973  851385    96.0
# 1974                      1974  851200    96.0
# 1975                      1975  799624    90.2
# 1976                      1976  849447    95.8
# 1977                      1977  849356    95.8
# 1978                      1978  849354    95.8
# 1979                      1979  850121    95.8
# 1980                      1980  797808    90.0
# 1981                      1981  848153    95.6
# 1982                      1982  849419    95.8
# 1983                      1983  848470    95.7
# 1984                      1984  848324    95.6
# ...

# %%
plot_df_xy(data_na, 'null %', 'columns', 12)

# %%
available_count = get_df_avalaible_values(data['Data']).sort_values(by='percent_available',ascending=False)
available_count
# Out:
#                  Indicator Code  percent_available
# 2533                SP.POP.TOTL              69.84
# 2307                SP.POP.GROW              69.80
# 2483          SP.POP.1564.TO.ZS              64.13
# 2532          SP.POP.TOTL.MA.ZS              64.07
# 2530          SP.POP.TOTL.FE.ZS              64.07
# ...                         ...                ...
# 881     LO.EGRA.LSTN.0.FAN.2GRD               0.01
# 880     LO.EGRA.LSTN.0.EWE.2GRD               0.01
# 879     LO.EGRA.LSTN.0.ENG.6GRD               0.01
# 878     LO.EGRA.LSTN.0.ENG.4GRD               0.01
# 1038  LO.EGRA.READ.GON.ADV.2GRD               0.01
#
# [3665 rows x 2 columns]

# %%
available_count.head(200)
# Out:
#             Indicator Code  percent_available
# 2533           SP.POP.TOTL              69.84
# 2307           SP.POP.GROW              69.80
# 2483     SP.POP.1564.TO.ZS              64.13
# 2532     SP.POP.TOTL.MA.ZS              64.07
# 2530     SP.POP.TOTL.FE.ZS              64.07
# 2419     SP.POP.0014.TO.ZS              64.07
# 2484     SP.POP.1564.FE.IN              63.87
# 2486        SP.POP.1564.TO              63.87
# 2529     SP.POP.TOTL.FE.IN              63.87
# 2422        SP.POP.0014.TO              63.87
# 2531     SP.POP.TOTL.MA.IN              63.87
# 2421     SP.POP.0014.MA.IN              63.87
# 2420     SP.POP.0014.FE.IN              63.87
# 2485     SP.POP.1564.MA.IN              63.87
# 2317        SP.PRE.TOTL.IN              63.01
# 2319     SP.PRE.TOTL.MA.IN              62.92
# 2318     SP.PRE.TOTL.FE.IN              62.92
# 2332        SP.SEC.UTOT.IN              62.91
# 2311        SP.SEC.LTOT.IN              62.90
# ...

# %%
# take top 200 results from dataframe and plot them
plot_df_xy(available_count.head(200), 'percent_available', 'Indicator Code', 35, 13)

# %%
## données totales

nb_tot=data['Data'].shape[0]

# Regroupement
annees = [f'{x}' for x in range(2000, 2018)]
nb_available = data['Data'].copy()[annees].count()
df_years = pd.DataFrame({'annee':nb_available.index, 'nb_available':nb_available.values})

# Taux de données disponibles / non-nulles par année de la décénnie 2010
df_years['%_available']=round((df_years['nb_available'])*100/nb_tot,2)

# Calcul nombre de NaN par année de la décénnie 2010
df_years['%_nan']=round(100-df_years['%_available'],2)     
annes = df_years.index
taux_remplissage = df_years['%_available']
taux_nan = df_years['%_nan']

plt.figure(figsize=(15, 8))
plt.bar(annees, taux_remplissage, width, label='Données')
plt.bar(annees, taux_nan, width, bottom=taux_remplissage, label='NaN')
plt.ylabel('%')
plt.title('Taux de remplissage par année 2000-2017')
plt.legend(bbox_to_anchor=(1.05, 1),loc = 2)
plt.show()

# %% [markdown]
# => on voit un pic de données tous les 5 ans
#
# => les décennies des années 2000s et 2010 comportent le plus de données
#
# => 2010 est l'année le plus exploitable
#
# => plus de données exploitables après 2015
#
# => années les plus récentes avec données exploitables : 2010- 2015

# %%
#cols_annees = data['Data'].columns[44:-20].tolist()
cols_annees = [f'{x}' for x in range(2010, 2016)]
cols_annees
# Out:
# ['2010', '2011', '2012', '2013', '2014', '2015']

# %% [markdown]
# ### Get indicators with most avalaible data

# %% [markdown]
# #### Select top indicators ( >45% available data)

# %%
available_count
# Out:
#                  Indicator Code  percent_available
# 2533                SP.POP.TOTL              69.84
# 2307                SP.POP.GROW              69.80
# 2483          SP.POP.1564.TO.ZS              64.13
# 2532          SP.POP.TOTL.MA.ZS              64.07
# 2530          SP.POP.TOTL.FE.ZS              64.07
# ...                         ...                ...
# 881     LO.EGRA.LSTN.0.FAN.2GRD               0.01
# 880     LO.EGRA.LSTN.0.EWE.2GRD               0.01
# 879     LO.EGRA.LSTN.0.ENG.6GRD               0.01
# 878     LO.EGRA.LSTN.0.ENG.4GRD               0.01
# 1038  LO.EGRA.READ.GON.ADV.2GRD               0.01
#
# [3665 rows x 2 columns]

# %%
results_top = available_count.loc[available_count['percent_available'] > 45].sort_values(by='percent_available',ascending=False)
results_top.shape
# Out:
# (70, 2)

# %%
results_top.head()
# Out:
#          Indicator Code  percent_available
# 2533        SP.POP.TOTL              69.84
# 2307        SP.POP.GROW              69.80
# 2483  SP.POP.1564.TO.ZS              64.13
# 2532  SP.POP.TOTL.MA.ZS              64.07
# 2530  SP.POP.TOTL.FE.ZS              64.07

# %%
# vérifier le taux de null dans les colonnes / années des indicateurs de results_top

## lister indicateurs du top filtré
results_top_col = [results_top['Indicator Code'].unique()][0]

## obtenir data['Data'] avec uniquement indicateurs filtrés
top_data = data['Data'].loc[data['Data']['Indicator Code'].isin(results_top_col)]

# %%
top_data_na = get_df_columns_na(top_data)
plot_df_xy(top_data_na, 'null %', 'columns', 12)

# %% [markdown]
# #### Drop empty columns (years)

# %%
# find columns with 100% missing values
top_data_high_miss = top_data_na.loc[top_data_na["null %"] >= 100].index

# drop columns with 100% missing values
top_data_2 = top_data.drop(top_data_high_miss, axis = 1)
top_data_2.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978',
#        '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987',
#        '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016'],
#       dtype='object')

# %%
top_data_2[['Country Code']]
# Out:
#        Country Code
# 1183            ARB
# 1184            ARB
# 1191            ARB
# 1197            ARB
# 1198            ARB
# ...             ...
# 886247          ZWE
# 886249          ZWE
# 886250          ZWE
# 886251          ZWE
# 886252          ZWE
#
# [16940 rows x 1 columns]

# %%
values_top_data_2 = get_df_avalaible_values(top_data_2).sort_values(by='percent_available',ascending=False)
values_top_data_2
# Out:
#           Indicator Code  percent_available
# 61           SP.POP.TOTL              98.07
# 21           SP.POP.GROW              98.02
# 53     SP.POP.1564.TO.ZS              90.06
# 49     SP.POP.0014.TO.ZS              89.97
# 60     SP.POP.TOTL.MA.ZS              89.97
# 58     SP.POP.TOTL.FE.ZS              89.97
# 50     SP.POP.0014.FE.IN              89.70
# 54     SP.POP.1564.FE.IN              89.70
# 51     SP.POP.0014.MA.IN              89.70
# 52        SP.POP.0014.TO              89.70
# 55     SP.POP.1564.MA.IN              89.70
# 56        SP.POP.1564.TO              89.70
# 57     SP.POP.TOTL.FE.IN              89.70
# 59     SP.POP.TOTL.MA.IN              89.70
# 25        SP.PRE.TOTL.IN              88.48
# 26     SP.PRE.TOTL.FE.IN              88.35
# 27     SP.PRE.TOTL.MA.IN              88.35
# 40        SP.SEC.UTOT.IN              88.34
# 22        SP.SEC.LTOT.IN              88.32
# 31        SP.SEC.TOTL.IN              88.30
# ...

# %%
plot_df_xy(values_top_data_2, 'percent_available', 'Indicator Code', 13)

# %%
# describe de ces kpi
# plot value vs time pour chaque kpi
# sélectionner ceux qui semblent cohérents par rapport à ce que l'on voit

pd.set_option('display.max_colwidth', None)
pd.options.display.max_rows = None
values_indicator_2 = values_top_data_2.join(top_data_2[['Indicator Code', 'Indicator Name']].set_index('Indicator Code'), on='Indicator Code', how = 'right')
val_indic_desc = values_indicator_2.drop_duplicates(subset = ['Indicator Code'], keep = 'first').sort_values(by='percent_available',ascending=False)
val_indic_desc.reset_index(drop=True, inplace=True)
val_indic_desc
# Out:
#           Indicator Code  percent_available  \
# 0            SP.POP.TOTL              98.07
# 1            SP.POP.GROW              98.02
# 2      SP.POP.1564.TO.ZS              90.06
# 3      SP.POP.0014.TO.ZS              89.97
# 4      SP.POP.TOTL.MA.ZS              89.97
# 5      SP.POP.TOTL.FE.ZS              89.97
# 6      SP.POP.0014.FE.IN              89.70
# 7      SP.POP.1564.FE.IN              89.70
# 8      SP.POP.0014.MA.IN              89.70
# 9         SP.POP.0014.TO              89.70
# 10     SP.POP.1564.MA.IN              89.70
# 11        SP.POP.1564.TO              89.70
# 12     SP.POP.TOTL.FE.IN              89.70
# 13     SP.POP.TOTL.MA.IN              89.70
# 14        SP.PRE.TOTL.IN              88.48
# 15     SP.PRE.TOTL.FE.IN              88.35
# 16     SP.PRE.TOTL.MA.IN              88.35
# 17        SP.SEC.UTOT.IN              88.34
# 18        SP.SEC.LTOT.IN              88.32
# 19        SP.SEC.TOTL.IN              88.30
# ...

# %%
# cherrypick indicators regarding their value towards current business questions
## reminder criterias :
## find countries with high "market potential" for distance learning
## be able to figure out the evolution of the "market potential" for each country
## find which (1) country the company should focus on first


## for money income, the income group from data['Country'] should be enough
## => we can remove most income / GDP related data from indicators in data['Data']

#country2.groupby(['Income Group']).count()
country_incomes = country2.groupby(['Income Group'])['Country Code'].count().sort_values()
country_incomes
# Out:
# Income Group
# High income: OECD       31
# Low income              34
# High income: nonOECD    44
# Lower middle income     50
# Upper middle income     55
# Name: Country Code, dtype: int64

# %%
plt.figure(figsize=(14,7))
plt.barh(y = country_incomes.index, width = country_incomes.values)
plt.title('Nombre de pays par groupe de revenu')
plt.show()

# %%
country2.groupby('Income Group')[['Short Name']].count().reset_index().sort_values(by='Short Name')['Income Group']
# Out:
# 0       High income: OECD
# 2              Low income
# 1    High income: nonOECD
# 3     Lower middle income
# 4     Upper middle income
# Name: Income Group, dtype: object

# %%
country2.groupby('Income Group')[['Short Name']].count()['Short Name']
# Out:
# Income Group
# High income: OECD       31
# High income: nonOECD    44
# Low income              34
# Lower middle income     50
# Upper middle income     55
# Name: Short Name, dtype: int64

# %%
#country2high = country2.loc[country2['Income Group'].str.contains('High', na=False)]
country2high = country2.loc[country2['Income Group'] == 'High income: OECD']
country2high
# Out:
#     Country Code       Short Name       Income Group  \
# 11           AUS        Australia  High income: OECD
# 12           AUT          Austria  High income: OECD
# 15           BEL          Belgium  High income: OECD
# 33           CAN           Canada  High income: OECD
# 34           CHE      Switzerland  High income: OECD
# 36           CHL            Chile  High income: OECD
# 50           CZE   Czech Republic  High income: OECD
# 51           DEU          Germany  High income: OECD
# 54           DNK          Denmark  High income: OECD
# 65           ESP            Spain  High income: OECD
# 66           EST          Estonia  High income: OECD
# 69           FIN          Finland  High income: OECD
# 71           FRA           France  High income: OECD
# 75           GBR   United Kingdom  High income: OECD
# 83           GRC           Greece  High income: OECD
# 99           IRL          Ireland  High income: OECD
# 102          ISL          Iceland  High income: OECD
# ...

# %%
country2high.groupby(['Income Group']).count()[['Country Code']]
# Out:
#                    Country Code
# Income Group
# High income: OECD            31

# %%
high_inc_data = data['Data'].loc[data['Data']['Country Code'].isin(country2high['Country Code'])]

# %%
high_inc_available_count = get_df_avalaible_values(high_inc_data).sort_values(by='percent_available',ascending=False)
high_inc_available_count.reset_index(drop=True, inplace=True)
high_inc_available_count
# Out:
#                       Indicator Code  percent_available
# 0                  SP.SEC.TOTL.MA.IN              71.21
# 1                  SP.POP.TOTL.FE.IN              71.21
# 2                  SP.POP.0014.TO.ZS              71.21
# 3                     SP.SEC.TOTL.IN              71.21
# 4                  SP.SEC.TOTL.FE.IN              71.21
# 5                        SE.PRM.AGES              71.21
# 6                  SP.POP.TOTL.MA.ZS              71.21
# 7                        SE.SEC.AGES              71.21
# 8                     SP.PRE.TOTL.IN              71.21
# 9                  SP.POP.TOTL.FE.ZS              71.21
# 10                 SP.POP.0014.MA.IN              71.21
# 11                    SP.SEC.LTOT.IN              71.21
# 12                 SP.POP.TOTL.MA.IN              71.21
# 13                 SP.SEC.LTOT.FE.IN              71.21
# 14                 SP.SEC.UTOT.MA.IN              71.21
# 15                 SP.SEC.UTOT.FE.IN              71.21
# ...

# %%
high_inc_available_count.head(200)
# Out:
#            Indicator Code  percent_available
# 0       SP.SEC.TOTL.MA.IN              71.21
# 1       SP.POP.TOTL.FE.IN              71.21
# 2       SP.POP.0014.TO.ZS              71.21
# 3          SP.SEC.TOTL.IN              71.21
# 4       SP.SEC.TOTL.FE.IN              71.21
# 5             SE.PRM.AGES              71.21
# 6       SP.POP.TOTL.MA.ZS              71.21
# 7             SE.SEC.AGES              71.21
# 8          SP.PRE.TOTL.IN              71.21
# 9       SP.POP.TOTL.FE.ZS              71.21
# 10      SP.POP.0014.MA.IN              71.21
# 11         SP.SEC.LTOT.IN              71.21
# 12      SP.POP.TOTL.MA.IN              71.21
# 13      SP.SEC.LTOT.FE.IN              71.21
# 14      SP.SEC.UTOT.MA.IN              71.21
# 15      SP.SEC.UTOT.FE.IN              71.21
# 16      SP.SEC.LTOT.MA.IN              71.21
# 17         SP.SEC.UTOT.IN              71.21
# 18      SP.POP.0014.FE.IN              71.21
# 19            SP.POP.TOTL              71.21
# ...

# %%
plot_df_xy(high_inc_available_count.head(200), 'percent_available', 'Indicator Code', 35, 13)

# %%
high_inc_results_top = high_inc_available_count.loc[high_inc_available_count['percent_available'] > 45].sort_values(by='percent_available',ascending=False)
high_inc_results_top_col = [high_inc_results_top['Indicator Code'].unique()][0]

## obtenir data['Data'] avec uniquement indicateurs filtrés
high_inc_top_data = data['Data'].loc[data['Data']['Indicator Code'].isin(high_inc_results_top_col)]
high_inc_top_data_na = get_df_columns_na(high_inc_top_data)
plot_df_xy(high_inc_top_data_na, 'null %', 'columns', 12)

# %% [markdown]
# # Select / Cherrypick indicators

# %%
## list cherrypicked_indicators
cherrypicked_indicators = [
    'SP.POP.TOTL',
    'SP.POP.GROW',
    'SP.SEC.TOTL.IN',
    'SE.SEC.DURS',
    'SE.SEC.ENRL',
    'SE.SEC.ENRL.GC',
    'SP.TER.TOTL.IN',
    'NY.GDP.PCAP.CD',
    'NY.GDP.PCAP.KD',
    'NY.GNP.MKTP.CD'
    ]
## check descriptions of listed indicators
val_indic_desc.loc[val_indic_desc['Indicator Code'].isin(cherrypicked_indicators)]
# Out:
#     Indicator Code  percent_available  \
# 0      SP.POP.TOTL              98.07
# 1      SP.POP.GROW              98.02
# 19  SP.SEC.TOTL.IN              88.30
# 38  SP.TER.TOTL.IN              85.75
# 48     SE.SEC.DURS              83.18
# 51  NY.GDP.PCAP.CD              80.85
# 53  NY.GDP.PCAP.KD              78.07
# 54  NY.GNP.MKTP.CD              77.37
# 58  SE.SEC.ENRL.GC              70.55
# 67     SE.SEC.ENRL              65.10
#
#                                                                  Indicator Name
# 0                                                             Population, total
# 1                                                  Population growth (annual %)
# 19  Population of the official age for secondary education, both sexes (number)
# 38   Population of the official age for tertiary education, both sexes (number)
# 48                          Theoretical duration of secondary education (years)
# ...

# %% [markdown]
# # Reduce dataset

# %%
DF_merge.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978',
#        '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987',
#        '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017', '2020', '2025', '2030', '2035', '2040', '2045',
#        '2050', '2055', '2060', '2065', '2070', '2075', '2080', '2085', '2090',
#        '2095', '2100', 'Unnamed: 69', 'Short Name', 'Income Group', 'Region'],
#       dtype='object')

# %%
# https://stackoverflow.com/questions/27673231/why-should-i-make-a-copy-of-a-data-frame-in-pandas

# copy
data_redux = DF_merge.copy()
data_redux.shape
# Out:
# (886930, 73)

# %%
# reduce years

#cols_years_to_del = data['Data'].columns[44:-20].tolist()
cols_years_to_del = [f'{x}' for x in range(1970, 2010)]
cols_years_to_del_2 = ['2016', '2017', '2020', '2025', '2030', '2035', '2040', '2045',
       '2050', '2055', '2060', '2065', '2070', '2075', '2080', '2085', '2090',
       '2095', '2100', 'Unnamed: 69']
cols_years_to_del.extend(cols_years_to_del_2)

data_redux.drop(columns=cols_years_to_del, inplace=True)
data_redux.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '2010', '2011', '2012', '2013', '2014', '2015', 'Short Name',
#        'Income Group', 'Region'],
#       dtype='object')

# %%
data_redux.shape
# Out:
# (886930, 13)

# %%
# reduce indicators to cherrypicked ones

data_redux = data_redux[data_redux['Indicator Code'].isin(cherrypicked_indicators)]
data_redux.shape
# Out:
# (2420, 13)

# %%
data_redux.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '2010', '2011', '2012', '2013', '2014', '2015', 'Short Name',
#        'Income Group', 'Region'],
#       dtype='object')

# %%
# Recherche des codes pays des regroupements de pays
df_duplicate_countries = (
                            data_redux[~data_redux['Country Code']
                                    .isin(data['Country-Series']['CountryCode'])][['Country Name','Country Code']]
                                    .sort_values(by = 'Country Name')
                         )
df_duplicate_countries.drop_duplicates(inplace=True)

df_duplicate_countries
# Out:
#                                               Country Name Country Code
# 1191                                            Arab World          ARB
# 193566                              British Virgin Islands          VGB
# 277861                                             Curacao          CUW
# 4856                                   East Asia & Pacific          EAS
# 8521           East Asia & Pacific (excluding high income)          EAP
# 12192                                            Euro area          EMU
# 15857                                Europe & Central Asia          ECS
# 21311        Europe & Central Asia (excluding high income)          ECA
# 23187                                       European Union          EUU
# 26852               Heavily indebted poor countries (HIPC)          HPC
# 30570                                          High income          HIC
# 35518                            Latin America & Caribbean          LCN
# ...

# %%
df_duplicate_countries_todel = df_duplicate_countries['Country Code'].to_list()
data_redux = data_redux[~data_redux['Country Code'].isin(df_duplicate_countries_todel)]

data_redux.shape
# Out:
# (2110, 13)

# %% [markdown]
# # Clean Dataset

# %%
# remove countries with NaNs for all years

data_redux.dropna(how='any', subset=[ '2010', '2011', '2012', '2013', '2014', '2015'], inplace=True)

data_redux.shape
# Out:
# (1684, 13)

# %%
values_data_redux = get_df_avalaible_values(data_redux).sort_values(by='percent_available',ascending=False)
plot_df_xy(values_data_redux, 'percent_available', 'Indicator Code', 13)

# %%
values_data_redux
# Out:
#    Indicator Code  percent_available
# 0     SE.SEC.ENRL             100.00
# 1  SE.SEC.ENRL.GC             100.00
# 2  NY.GDP.PCAP.KD             100.00
# 3  NY.GDP.PCAP.CD             100.00
# 4  NY.GNP.MKTP.CD             100.00
# 6  SP.SEC.TOTL.IN             100.00
# 7  SP.TER.TOTL.IN             100.00
# 5     SP.POP.GROW              99.89
# 8     SP.POP.TOTL              99.89
# 9     SE.SEC.DURS              99.89

# %%
# check and drop last lines with NaNs
data_redux_NaN = data_redux[data_redux.isna().any(axis=1)]
data_redux_NaN
# Out:
#        Country Name Country Code  \
# 365142    Gibraltar          GIB
# 365368    Gibraltar          GIB
# 365821    Gibraltar          GIB
#
#                                              Indicator Name Indicator Code  \
# 365142                         Population growth (annual %)    SP.POP.GROW
# 365368                                    Population, total    SP.POP.TOTL
# 365821  Theoretical duration of secondary education (years)    SE.SEC.DURS
#
#                 2010          2011          2012          2013          2014  \
# 365142      0.704516      0.648709      0.650477      0.616719      0.610001
# 365368  33189.000000  33405.000000  33623.000000  33831.000000  34038.000000
# 365821      4.000000      4.000000      4.000000      4.000000      4.000000
#
#                 2015 Short Name Income Group Region
# 365142      0.556647  Gibraltar          NaN    NaN
# 365368  34228.000000  Gibraltar          NaN    NaN
# 365821      4.000000  Gibraltar          NaN    NaN

# %%
data_redux = data_redux.drop(data_redux_NaN.index, axis = 0)
data_redux.shape
# Out:
# (1681, 13)

# %%
values_data_redux_2 = get_df_avalaible_values(data_redux).sort_values(by='percent_available',ascending=False)
plot_df_xy(values_data_redux_2, 'percent_available', 'Indicator Code', 13)

# %%
values_data_redux_2
# Out:
#    Indicator Code  percent_available
# 0     SE.SEC.ENRL              100.0
# 1  SE.SEC.ENRL.GC              100.0
# 2  NY.GDP.PCAP.KD              100.0
# 3  NY.GDP.PCAP.CD              100.0
# 4  NY.GNP.MKTP.CD              100.0
# 5     SP.POP.GROW              100.0
# 6  SP.SEC.TOTL.IN              100.0
# 7  SP.TER.TOTL.IN              100.0
# 8     SP.POP.TOTL              100.0
# 9     SE.SEC.DURS              100.0

# %%
data_redux[data_redux.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Country Name, Country Code, Indicator Name, Indicator Code, 2010, 2011, 2012, 2013, 2014, 2015, Short Name, Income Group, Region]
# Index: []

# %%
data_redux['Country Name'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas, The', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'Brunei Darussalam', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon',
#        'Canada', 'Cayman Islands', 'Central African Republic', 'Chad',
#        'Channel Islands', 'Chile', 'China', 'Colombia', 'Comoros',
#        'Congo, Dem. Rep.', 'Congo, Rep.', 'Costa Rica', "Cote d'Ivoire",
#        'Croatia', 'Cuba', 'Cyprus', 'Czech Republic', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador',
#        'Egypt, Arab Rep.', 'El Salvador', 'Equatorial Guinea', 'Eritrea',
#        'Estonia', 'Ethiopia', 'Faroe Islands', 'Fiji', 'Finland',
# ...

# %%
all_years = ['1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978',
       '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987',
       '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
       '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
       '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
       '2015', '2016', '2017', '2020', '2025', '2030', '2035', '2040', '2045',
       '2050', '2055', '2060', '2065', '2070', '2075', '2080', '2085', '2090',
       '2095', '2100']
len(all_years)
# Out:
# 65

# %%
data_shape = data['Data'].shape
data_redux_shape = data_redux.shape

data_countries_count = data['Data']['Country Name'].nunique()
data_redux_countries_count = data_redux['Country Name'].nunique()

data_indicators_count = data['Data']['Indicator Code'].nunique()
data_redux_indicators_count = data_redux['Indicator Code'].nunique()


print(f'Le dataframe EdStatsData contient initialement {data_shape[0]} lignes et {data_shape[1]} colonnes, avec {data_indicators_count} indicateurs pour {data_countries_count} pays, {len(all_years)} années')
print(f'Le dataframe réduit contient {data_redux_shape[0]} lignes et {data_redux_shape[1]} colonnes, avec {data_redux_indicators_count} indicateurs pour {data_redux_countries_count} pays, 5 années')
# Out:
# Le dataframe EdStatsData contient initialement 886930 lignes et 70 colonnes, avec 3665 indicateurs pour 242 pays, 65 années
# Le dataframe réduit contient 1681 lignes et 13 colonnes, avec 10 indicateurs pour 210 pays, 5 années

# %% [markdown]
# # Reduce dataset to one year, pivot indicators and further clean

# %%
# reduce data_redux on 1 year
data_redux_1year = data_redux[['Country Name','Country Code','Indicator Name','Indicator Code', 'Region', 
                       'Income Group','2015']]

# %%
#data_redux_1year[data_redux_1year.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Country Name, Country Code, Indicator Name, Indicator Code, Region, Income Group, 2015]
# Index: []

# %%
#data_redux['Indicator Code'].loc[data_redux['Indicator Code'] == df_cats[0]]

# %%
redux_1y_indicators = data_redux_1year.pivot(index='Country Name', columns = 'Indicator Code', values = '2015')
redux_1y_indicators.head()
# Out:
# Indicator Code  NY.GDP.PCAP.CD  NY.GDP.PCAP.KD  NY.GNP.MKTP.CD  SE.SEC.DURS  \
# Country Name
# Afghanistan         569.577923      599.135196    1.938857e+10          6.0
# Albania            3934.895394     4524.990993    1.122583e+10          7.0
# Algeria            4160.220067     4759.595242    1.604671e+11          7.0
# American Samoa    11865.963232     9884.111866             NaN          NaN
# Andorra           36038.267604    41765.920353             NaN          6.0
#
# Indicator Code  SE.SEC.ENRL  SE.SEC.ENRL.GC  SP.POP.GROW  SP.POP.TOTL  \
# Country Name
# Afghanistan       2698816.0       2671830.0     2.943234   33736494.0
# Albania            315079.0        287812.0    -0.291206    2880703.0
# Algeria                 NaN       4131265.0     1.919959   39871528.0
# American Samoa          NaN             NaN     0.180222      55537.0
# Andorra              4395.0          4004.0    -1.537836      78014.0
#
# Indicator Code  SP.SEC.TOTL.IN  SP.TER.TOTL.IN
# ...

# %%
redux_1y_indicators[redux_1y_indicators.isna().any(axis=1)]
# Out:
# Indicator Code                  NY.GDP.PCAP.CD  NY.GDP.PCAP.KD  \
# Country Name
# Algeria                            4160.220067     4759.595242
# American Samoa                    11865.963232     9884.111866
# Andorra                           36038.267604    41765.920353
# Angola                             3695.793748     3730.169063
# Antigua and Barbuda               13659.147914    12771.767577
# Argentina                         13467.102357    10490.019568
# Armenia                            3617.935746     3935.288772
# Aruba                                      NaN             NaN
# Australia                         56554.038761    54941.911458
# Azerbaijan                         5500.310382     6117.030862
# Bahamas, The                      29056.090663    20184.735694
# Bangladesh                         1210.158769      971.641988
# Barbados                          16129.049283    15961.200154
# Benin                               783.947091      827.845967
# ...

# %%
redux_1y_indicators.isna().sum().sort_values(ascending=False)
# Out:
# Indicator Code
# SE.SEC.ENRL       121
# SE.SEC.ENRL.GC    108
# SP.TER.TOTL.IN     95
# NY.GNP.MKTP.CD     26
# SP.SEC.TOTL.IN     22
# NY.GDP.PCAP.KD     17
# NY.GDP.PCAP.CD     15
# SE.SEC.DURS        12
# SP.POP.GROW         2
# SP.POP.TOTL         1
# dtype: int64

# %%
redux_1y_indicators.shape
# Out:
# (210, 10)

# %% [markdown]
# => drop columns with 90+ values missing
#
# => remove countries (rows) with NaN left

# %%
redux_1y_ind_to_drop = ['SE.SEC.ENRL', 'SE.SEC.ENRL.GC', 'SP.TER.TOTL.IN']
redux_1y_indicators.drop(columns=redux_1y_ind_to_drop, inplace=True)
redux_1y_indicators.isna().sum().sort_values(ascending=False)
# Out:
# Indicator Code
# NY.GNP.MKTP.CD    26
# SP.SEC.TOTL.IN    22
# NY.GDP.PCAP.KD    17
# NY.GDP.PCAP.CD    15
# SE.SEC.DURS       12
# SP.POP.GROW        2
# SP.POP.TOTL        1
# dtype: int64

# %%
# check and drop last lines with NaNs
redux_1y_ind_NaN = redux_1y_indicators[redux_1y_indicators.isna().any(axis=1)]
redux_1y_ind_NaN

redux_1y_indicators = redux_1y_indicators.drop(redux_1y_ind_NaN.index, axis = 0)
redux_1y_indicators.shape
# Out:
# (173, 7)

# %%
redux_1y_indicators
# Out:
# Indicator Code                  NY.GDP.PCAP.CD  NY.GDP.PCAP.KD  \
# Country Name
# Afghanistan                         569.577923      599.135196
# Albania                            3934.895394     4524.990993
# Algeria                            4160.220067     4759.595242
# Angola                             3695.793748     3730.169063
# Antigua and Barbuda               13659.147914    12771.767577
# Argentina                         13467.102357    10490.019568
# Australia                         56554.038761    54941.911458
# Austria                           44255.583356    47834.787303
# Azerbaijan                         5500.310382     6117.030862
# Bahamas, The                      29056.090663    20184.735694
# Bahrain                           22688.878244    22436.207532
# Bangladesh                         1210.158769      971.641988
# Barbados                          16129.049283    15961.200154
# Belarus                            5949.106307     6398.689735
# ...

# %%
redux_1y_indicators.isna().sum().sum()
# Out:
# 0

# %%
redux_1y_indicators.shape
# Out:
# (173, 7)

# %% [markdown]
# # Univariate / multi-variate analysis

# %%
## Aggregate to obtain following shape / columns :
##
## country name | country code | indicator code | moyenne | mediane | nan count | nan % / standard deviation

# %%
def UVA_numeric(data, i):
  '''
  Univariate_Analysis_numeric
  takes a group of variables (INTEGER and FLOAT) and plot/print all the descriptives and properties along with KDE.

  Runs a loop: calculate all the descriptives of i(th) variable and plot/print it
  '''
  # calculating descriptives of variable
  mini = data[i].min()
  maxi = data[i].max()
  ran = data[i].max()-data[i].min()
  mean = data[i].mean()
  median = data[i].median()
  st_dev = data[i].std()
  skew = data[i].skew()
  kurt = data[i].kurtosis()

  # calculating points of standard deviation
  points = mean-st_dev, mean+st_dev

  #Plotting the variable with every information
  sns.kdeplot(data[i], shade=True)
  sns.lineplot(points, [0,0], color = 'black', label = "std_dev")
  sns.scatterplot([mini,maxi], [0,0], color = 'orange', label = "min/max")
  sns.scatterplot([mean], [0], color = 'red', label = "mean")
  sns.scatterplot([median], [0], color = 'blue', label = "median")
  plt.xlabel('{}'.format(i), fontsize = 20)
  plt.ylabel('density')
  plt.title('std_dev = {}; kurtosis = {};\nskew = {}; range = {}\nmean = {}; median = {}'.format((round(points[0],2),round(points[1],2)),
                                                                                                   round(kurt,2),
                                                                                                   round(skew,2),
                                                                                                   (round(mini,2),round(maxi,2),round(ran,2)),
                                                                                                   round(mean,2),
                                                                                                   round(median,2)))

# %%
# list data for every indicator in a separated dataframe

#def split_categories(df, category):
#    df_cats = df[category].to_list()
#    df_keys = [x.replace('.','_') for x in df_cats]
#
#    data_dict = {}
#    for k, c in zip(df_keys, df_cats):
#        data_dict[k] = df[df[category] == c]
#        
#    return data_dict

# %%
# afficher détail Boxplot / UVA_num pour chaque indicateur par ligne

def UVA_num_plus(df):
    indicators_list = df.columns.tolist()
    
    for i in indicators_list:
        plt.figure(figsize = (15, 20))
        df_indic = df[i]

        plt.subplot(5,2,1)
        sns.boxplot(y=df_indic)
        plt.xlabel(f'{i}', fontsize = 20)


        plt.subplot(5,2,2)
        UVA_numeric(df, i)

# %%
UVA_num_plus(redux_1y_indicators)
