# %%
# imports
# %matplotlib inline

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import scipy.stats as st
#from pandas_profiling import ProfileReport
#import missingno as msno

# %% [markdown]
# # extract and load data properly

# %% [markdown]
# ## build up fct elements

# %%
csv_path = './data/'

# %%
file_names = [x for x in os.listdir(csv_path) if ".csv" in x]
file_names
# Out:
# ['EdStatsData.csv',
#  'EdStatsCountry-Series.csv',
#  'EdStatsSeries.csv',
#  'EdStatsCountry.csv',
#  'EdStatsFootNote.csv']

# %%
file_names = [x.removesuffix('.csv') for x in file_names]
file_names = [x.removeprefix('EdStats') for x in file_names]
file_names
# Out:
# ['Data', 'Country-Series', 'Series', 'Country', 'FootNote']

# %%
# construct dict data

dataframe_list = [f'DataFrame{i}' for i, item in enumerate(file_names, start=1)]
dataframe_list
# Out:
# ['DataFrame1', 'DataFrame2', 'DataFrame3', 'DataFrame4', 'DataFrame5']

# %%
data = dict(zip(file_names, dataframe_list))
data
# Out:
# {'Data': 'DataFrame1',
#  'Country-Series': 'DataFrame2',
#  'Series': 'DataFrame3',
#  'Country': 'DataFrame4',
#  'FootNote': 'DataFrame5'}

# %% [markdown]
# ## summarize in a function

# %%
csv_path = './data/'

# %%
def get_data(csv_path):
    file_names = [x for x in os.listdir(csv_path) if ".csv" in x]
    # file_names_base = file_names
    key_names = [
        key_name.removesuffix('.csv').removeprefix('EdStats')
        for key_name in file_names
    ]

    data_dict = {}
    for k, f in zip(key_names, file_names):
        data_dict[k] = pd.read_csv(os.path.join(csv_path, f))

    return data_dict

# %%
data = get_data(csv_path)

# %% [markdown]
# # simple explo

# %% [markdown]
# ## check dataset

# %% [markdown]
# ### fct build

# %%
ls -lh ./data
# Out:
# total 353M
# -rw-r--r-- 1 mijka mijka 137K 22 janv.  2018 EdStatsCountry.csv
# -rw-r--r-- 1 mijka mijka  48K 22 janv.  2018 EdStatsCountry-Series.csv
# -rw-r--r-- 1 mijka mijka 312M 22 janv.  2018 EdStatsData.csv
# -rw-r--r-- 1 mijka mijka  38M 22 janv.  2018 EdStatsFootNote.csv
# -rw-r--r-- 1 mijka mijka 3,6M 22 janv.  2018 EdStatsSeries.csv

# %%
import enum
from os import listdir
from os.path import isfile, join

class SIZE_UNIT(enum.Enum):
   BYTES = 1
   KB = 2
   MB = 3
   GB = 4

def convert_unit(size_in_bytes, unit):
  # Convert the size from bytes to other units like KB, MB or GB
   if unit == SIZE_UNIT.KB:
       return size_in_bytes/1024
   elif unit == SIZE_UNIT.MB:
       return size_in_bytes/(1024*1024)
   elif unit == SIZE_UNIT.GB:
       return size_in_bytes/(1024*1024*1024)
   else:
       return size_in_bytes

def get_file_size(file_name, size_type = SIZE_UNIT.BYTES ):
   # Get file in size in given unit like KB, MB or GB
   size = os.path.getsize(file_name)
   return convert_unit(size, size_type)

def get_folder_files_size(folder_path):
    files_list = [f for f in listdir(folder_path) if isfile(join(folder_path, f))]
    for i in files_list:
        size = get_file_size(f'{folder_path + i}', SIZE_UNIT.MB)
        print(f'Size of {i}: ', round(size,2),'MB')

# %%
def get_shape(dict):
    for key in dict:
        print(key, dict[f'{key}'].shape)

# %% [markdown]
# ### Use explore fct

# %%
data.keys()
# Out:
# dict_keys(['Data', 'Country-Series', 'Series', 'Country', 'FootNote'])

# %%
data['Data'].nunique()
# Out:
# Country Name        242
# Country Code        242
# Indicator Name     3665
# Indicator Code     3665
# 1970              24595
#                   ...
# 2085               7335
# 2090               7150
# 2095               7044
# 2100               6914
# Unnamed: 69           0
# Length: 70, dtype: int64

# %%
get_folder_files_size(csv_path)
# Out:
# Size of EdStatsData.csv:  311.3 MB
# Size of EdStatsCountry-Series.csv:  0.05 MB
# Size of EdStatsSeries.csv:  3.54 MB
# Size of EdStatsCountry.csv:  0.13 MB
# Size of EdStatsFootNote.csv:  37.87 MB

# %%
get_shape(data)
# Out:
# Data (886930, 70)
# Country-Series (613, 4)
# Series (3665, 21)
# Country (241, 32)
# FootNote (643638, 5)

# %%
data['Country-Series']
# Out:
#     CountryCode         SeriesCode  \
# 0           ABW        SP.POP.TOTL
# 1           ABW        SP.POP.GROW
# 2           AFG        SP.POP.GROW
# 3           AFG  NY.GDP.PCAP.PP.CD
# 4           AFG        SP.POP.TOTL
# ..          ...                ...
# 608         ZAF        SP.POP.GROW
# 609         ZMB        SP.POP.GROW
# 610         ZMB        SP.POP.TOTL
# 611         ZWE        SP.POP.TOTL
# 612         ZWE        SP.POP.GROW
#
#                                            DESCRIPTION  Unnamed: 3
# 0    Data sources : United Nations World Population...         NaN
# 1    Data sources: United Nations World Population ...         NaN
# 2    Data sources: United Nations World Population ...         NaN
# 3                   Estimates are based on regression.         NaN
# 4    Data sources : United Nations World Population...         NaN
# ..                                                 ...         ...
# 608  Data sources : Statistics South Africa, United...         NaN
# 609  Data sources: United Nations World Population ...         NaN
# 610  Data sources : United Nations World Population...         NaN
# 611  Data sources : United Nations World Population...         NaN
# 612  Data sources: United Nations World Population ...         NaN
#
# [613 rows x 4 columns]

# %%
# taux de remplissage par champ

# %% [markdown]
# ## cardinality

# %%
country2 = data['Country'][['Country Code','Short Name','Income Group']]

# %%
# find distribution of different "Income Group"
country2.groupby(['Income Group']).count()
# Out:
#                       Country Code  Short Name
# Income Group
# High income: OECD               31          31
# High income: nonOECD            44          44
# Low income                      34          34
# Lower middle income             50          50
# Upper middle income             55          55

# %%
country2.head()
# Out:
#   Country Code   Short Name          Income Group
# 0          ABW        Aruba  High income: nonOECD
# 1          AFG  Afghanistan            Low income
# 2          AGO       Angola   Upper middle income
# 3          ALB      Albania   Upper middle income
# 4          AND      Andorra  High income: nonOECD

# %%
data['Data'].head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name  Indicator Code  \
# 0  Adjusted net enrolment rate, lower secondary, ...      UIS.NERA.2
# 1  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.F
# 2  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.GPI
# 3  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.M
# 4  Adjusted net enrolment rate, primary, both sex...     SE.PRM.TENR
#
#         1970       1971       1972       1973       1974      1975  ...  2060  \
# 0        NaN        NaN        NaN        NaN        NaN       NaN  ...   NaN
# 1        NaN        NaN        NaN        NaN        NaN       NaN  ...   NaN
# 2        NaN        NaN        NaN        NaN        NaN       NaN  ...   NaN
# 3        NaN        NaN        NaN        NaN        NaN       NaN  ...   NaN
# 4  54.822121  54.894138  56.209438  57.267109  57.991138  59.36554  ...   NaN
#
#    2065  2070  2075  2080  2085  2090  2095  2100  Unnamed: 69
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN          NaN
#
# [5 rows x 70 columns]

# %%
data['Data'].columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978',
#        '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987',
#        '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017', '2020', '2025', '2030', '2035', '2040', '2045',
#        '2050', '2055', '2060', '2065', '2070', '2075', '2080', '2085', '2090',
#        '2095', '2100', 'Unnamed: 69'],
#       dtype='object')

# %% [markdown]
# ### tests

# %%
maindata = data['Data'][['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code']]
maindata
# Out:
#        Country Name Country Code  \
# 0        Arab World          ARB
# 1        Arab World          ARB
# 2        Arab World          ARB
# 3        Arab World          ARB
# 4        Arab World          ARB
# ...             ...          ...
# 886925     Zimbabwe          ZWE
# 886926     Zimbabwe          ZWE
# 886927     Zimbabwe          ZWE
# 886928     Zimbabwe          ZWE
# 886929     Zimbabwe          ZWE
#
#                                            Indicator Name  \
# 0       Adjusted net enrolment rate, lower secondary, ...
# 1       Adjusted net enrolment rate, lower secondary, ...
# 2       Adjusted net enrolment rate, lower secondary, ...
# 3       Adjusted net enrolment rate, lower secondary, ...
# 4       Adjusted net enrolment rate, primary, both sex...
# ...                                                   ...
# 886925  Youth illiterate population, 15-24 years, male...
# 886926  Youth literacy rate, population 15-24 years, b...
# 886927  Youth literacy rate, population 15-24 years, f...
# 886928  Youth literacy rate, population 15-24 years, g...
# 886929  Youth literacy rate, population 15-24 years, m...
#
#               Indicator Code
# 0                 UIS.NERA.2
# 1               UIS.NERA.2.F
# 2             UIS.NERA.2.GPI
# 3               UIS.NERA.2.M
# 4                SE.PRM.TENR
# ...                      ...
# 886925      UIS.LP.AG15T24.M
# 886926     SE.ADT.1524.LT.ZS
# 886927  SE.ADT.1524.LT.FE.ZS
# 886928  SE.ADT.1524.LT.FM.ZS
# 886929  SE.ADT.1524.LT.MA.ZS
#
# [886930 rows x 4 columns]

# %%
maindata.iloc[1,:]
# Out:
# Country Name                                             Arab World
# Country Code                                                    ARB
# Indicator Name    Adjusted net enrolment rate, lower secondary, ...
# Indicator Code                                         UIS.NERA.2.F
# Name: 1, dtype: object

# %%
maindata.duplicated().sum()
# Out:
# 0

# %%
data['Data'].duplicated().sum()
# Out:
# 0

# %%
#data[list(data.keys())[0]]
data['Data']
# Out:
#        Country Name Country Code  \
# 0        Arab World          ARB
# 1        Arab World          ARB
# 2        Arab World          ARB
# 3        Arab World          ARB
# 4        Arab World          ARB
# ...             ...          ...
# 886925     Zimbabwe          ZWE
# 886926     Zimbabwe          ZWE
# 886927     Zimbabwe          ZWE
# 886928     Zimbabwe          ZWE
# 886929     Zimbabwe          ZWE
#
#                                            Indicator Name  \
# 0       Adjusted net enrolment rate, lower secondary, ...
# 1       Adjusted net enrolment rate, lower secondary, ...
# 2       Adjusted net enrolment rate, lower secondary, ...
# 3       Adjusted net enrolment rate, lower secondary, ...
# 4       Adjusted net enrolment rate, primary, both sex...
# ...                                                   ...
# 886925  Youth illiterate population, 15-24 years, male...
# 886926  Youth literacy rate, population 15-24 years, b...
# 886927  Youth literacy rate, population 15-24 years, f...
# 886928  Youth literacy rate, population 15-24 years, g...
# 886929  Youth literacy rate, population 15-24 years, m...
#
#               Indicator Code       1970       1971       1972       1973  \
# 0                 UIS.NERA.2        NaN        NaN        NaN        NaN
# 1               UIS.NERA.2.F        NaN        NaN        NaN        NaN
# 2             UIS.NERA.2.GPI        NaN        NaN        NaN        NaN
# 3               UIS.NERA.2.M        NaN        NaN        NaN        NaN
# 4                SE.PRM.TENR  54.822121  54.894138  56.209438  57.267109
# ...                      ...        ...        ...        ...        ...
# 886925      UIS.LP.AG15T24.M        NaN        NaN        NaN        NaN
# 886926     SE.ADT.1524.LT.ZS        NaN        NaN        NaN        NaN
# 886927  SE.ADT.1524.LT.FE.ZS        NaN        NaN        NaN        NaN
# 886928  SE.ADT.1524.LT.FM.ZS        NaN        NaN        NaN        NaN
# 886929  SE.ADT.1524.LT.MA.ZS        NaN        NaN        NaN        NaN
#
#              1974      1975  ...  2060  2065  2070  2075  2080  2085  2090  \
# 0             NaN       NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1             NaN       NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2             NaN       NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3             NaN       NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4       57.991138  59.36554  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...           ...       ...  ...   ...   ...   ...   ...   ...   ...   ...
# 886925        NaN       NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 886926        NaN       NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 886927        NaN       NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 886928        NaN       NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 886929        NaN       NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#         2095  2100  Unnamed: 69
# 0        NaN   NaN          NaN
# 1        NaN   NaN          NaN
# 2        NaN   NaN          NaN
# 3        NaN   NaN          NaN
# 4        NaN   NaN          NaN
# ...      ...   ...          ...
# 886925   NaN   NaN          NaN
# 886926   NaN   NaN          NaN
# 886927   NaN   NaN          NaN
# 886928   NaN   NaN          NaN
# 886929   NaN   NaN          NaN
#
# [886930 rows x 70 columns]

# %%
data['Data'].isnull().count()
# Out:
# Country Name      886930
# Country Code      886930
# Indicator Name    886930
# Indicator Code    886930
# 1970              886930
#                    ...
# 2085              886930
# 2090              886930
# 2095              886930
# 2100              886930
# Unnamed: 69       886930
# Length: 70, dtype: int64

# %%
data['Data'].count()
# Out:
# Country Name      886930
# Country Code      886930
# Indicator Name    886930
# Indicator Code    886930
# 1970               72288
#                    ...
# 2085               51436
# 2090               51436
# 2095               51436
# 2100               51436
# Unnamed: 69            0
# Length: 70, dtype: int64

# %%
minor = data['Data'][['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code', 
       '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978',
       '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987',
       '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
       '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
       '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
       '2015', '2016', '2017', '2020', '2025', '2030', '2035', '2040', '2045',
       '2050', '2055', '2060', '2065', '2070', '2075', '2080', '2085', '2090',
       '2095', '2100']]

# %%
preds = data['Data'][['Country Name', 'Country Code', 'Indicator Code','2020', '2025', '2030', '2035', '2040', '2045',
       '2050', '2055', '2060', '2065', '2070', '2075', '2080', '2085', '2090',
       '2095', '2100']]

# %%
preds
# Out:
#        Country Name Country Code        Indicator Code  2020  2025  2030  \
# 0        Arab World          ARB            UIS.NERA.2   NaN   NaN   NaN
# 1        Arab World          ARB          UIS.NERA.2.F   NaN   NaN   NaN
# 2        Arab World          ARB        UIS.NERA.2.GPI   NaN   NaN   NaN
# 3        Arab World          ARB          UIS.NERA.2.M   NaN   NaN   NaN
# 4        Arab World          ARB           SE.PRM.TENR   NaN   NaN   NaN
# ...             ...          ...                   ...   ...   ...   ...
# 886925     Zimbabwe          ZWE      UIS.LP.AG15T24.M   NaN   NaN   NaN
# 886926     Zimbabwe          ZWE     SE.ADT.1524.LT.ZS   NaN   NaN   NaN
# 886927     Zimbabwe          ZWE  SE.ADT.1524.LT.FE.ZS   NaN   NaN   NaN
# 886928     Zimbabwe          ZWE  SE.ADT.1524.LT.FM.ZS   NaN   NaN   NaN
# 886929     Zimbabwe          ZWE  SE.ADT.1524.LT.MA.ZS   NaN   NaN   NaN
#
#         2035  2040  2045  2050  2055  2060  2065  2070  2075  2080  2085  \
# 0        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...      ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 886925   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 886926   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 886927   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 886928   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 886929   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#         2090  2095  2100
# 0        NaN   NaN   NaN
# 1        NaN   NaN   NaN
# 2        NaN   NaN   NaN
# 3        NaN   NaN   NaN
# 4        NaN   NaN   NaN
# ...      ...   ...   ...
# 886925   NaN   NaN   NaN
# 886926   NaN   NaN   NaN
# 886927   NaN   NaN   NaN
# 886928   NaN   NaN   NaN
# 886929   NaN   NaN   NaN
#
# [886930 rows x 20 columns]

# %%
preds.dropna().count()
# Out:
# Country Name      51436
# Country Code      51436
# Indicator Code    51436
# 2020              51436
# 2025              51436
# 2030              51436
# 2035              51436
# 2040              51436
# 2045              51436
# 2050              51436
# 2055              51436
# 2060              51436
# 2065              51436
# 2070              51436
# 2075              51436
# 2080              51436
# 2085              51436
# 2090              51436
# 2095              51436
# 2100              51436
# dtype: int64

# %%
# variables ayant des valeurs manquantes
preds_na = preds.isnull().sum()
preds_na[preds_na>0]
# Out:
# 2020    835494
# 2025    835494
# 2030    835494
# 2035    835494
# 2040    835494
# 2045    835494
# 2050    835494
# 2055    835494
# 2060    835494
# 2065    835494
# 2070    835494
# 2075    835494
# 2080    835494
# 2085    835494
# 2090    835494
# 2095    835494
# 2100    835494
# dtype: int64

# %% [markdown]
# ## TODO : take 1 value per country per indicator

# %% [markdown]
# ## explo work

# %%
# select all rows with column 'Indicator Code' with value 'UIS.XGDP.56.FSGOV' 
#(Government expenditure on education as % of GDP (%))

XGDP_Data = data['Data'].loc[data['Data']['Indicator Code'] == 'UIS.XGDP.56.FSGOV']
XGDP_Data
# Out:
#                                        Country Name Country Code  \
# 1266                                     Arab World          ARB
# 4931                            East Asia & Pacific          EAS
# 8596    East Asia & Pacific (excluding high income)          EAP
# 12261                                     Euro area          EMU
# 15926                         Europe & Central Asia          ECS
# ...                                             ...          ...
# 869871                        Virgin Islands (U.S.)          VIR
# 873536                           West Bank and Gaza          PSE
# 877201                                  Yemen, Rep.          YEM
# 880866                                       Zambia          ZMB
# 884531                                     Zimbabwe          ZWE
#
#                                            Indicator Name     Indicator Code  \
# 1266    Government expenditure on tertiary education a...  UIS.XGDP.56.FSGOV
# 4931    Government expenditure on tertiary education a...  UIS.XGDP.56.FSGOV
# 8596    Government expenditure on tertiary education a...  UIS.XGDP.56.FSGOV
# 12261   Government expenditure on tertiary education a...  UIS.XGDP.56.FSGOV
# 15926   Government expenditure on tertiary education a...  UIS.XGDP.56.FSGOV
# ...                                                   ...                ...
# 869871  Government expenditure on tertiary education a...  UIS.XGDP.56.FSGOV
# 873536  Government expenditure on tertiary education a...  UIS.XGDP.56.FSGOV
# 877201  Government expenditure on tertiary education a...  UIS.XGDP.56.FSGOV
# 880866  Government expenditure on tertiary education a...  UIS.XGDP.56.FSGOV
# 884531  Government expenditure on tertiary education a...  UIS.XGDP.56.FSGOV
#
#         1970  1971  1972  1973  1974  1975  ...  2060  2065  2070  2075  2080  \
# 1266     NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 4931     NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 8596     NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 12261    NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 15926    NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# ...      ...   ...   ...   ...   ...   ...  ...   ...   ...   ...   ...   ...
# 869871   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 873536   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 877201   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 880866   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 884531   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
#
#         2085  2090  2095  2100  Unnamed: 69
# 1266     NaN   NaN   NaN   NaN          NaN
# 4931     NaN   NaN   NaN   NaN          NaN
# 8596     NaN   NaN   NaN   NaN          NaN
# 12261    NaN   NaN   NaN   NaN          NaN
# 15926    NaN   NaN   NaN   NaN          NaN
# ...      ...   ...   ...   ...          ...
# 869871   NaN   NaN   NaN   NaN          NaN
# 873536   NaN   NaN   NaN   NaN          NaN
# 877201   NaN   NaN   NaN   NaN          NaN
# 880866   NaN   NaN   NaN   NaN          NaN
# 884531   NaN   NaN   NaN   NaN          NaN
#
# [242 rows x 70 columns]

# %%
# check if all country codes are different

XGDP_Data['Country Code'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## fct build

# %%
## fonction de transformation

def select_column_val(df, col, val):
    df_select = df.loc[df[col] == val]
    return df_select

# %%
data_XGDP = select_column_val(data['Data'],'Indicator Code','UIS.XGDP.56.FSGOV')
data_XGDP
# Out:
#                                        Country Name Country Code  \
# 1266                                     Arab World          ARB
# 4931                            East Asia & Pacific          EAS
# 8596    East Asia & Pacific (excluding high income)          EAP
# 12261                                     Euro area          EMU
# 15926                         Europe & Central Asia          ECS
# ...                                             ...          ...
# 869871                        Virgin Islands (U.S.)          VIR
# 873536                           West Bank and Gaza          PSE
# 877201                                  Yemen, Rep.          YEM
# 880866                                       Zambia          ZMB
# 884531                                     Zimbabwe          ZWE
#
#                                            Indicator Name     Indicator Code  \
# 1266    Government expenditure on tertiary education a...  UIS.XGDP.56.FSGOV
# 4931    Government expenditure on tertiary education a...  UIS.XGDP.56.FSGOV
# 8596    Government expenditure on tertiary education a...  UIS.XGDP.56.FSGOV
# 12261   Government expenditure on tertiary education a...  UIS.XGDP.56.FSGOV
# 15926   Government expenditure on tertiary education a...  UIS.XGDP.56.FSGOV
# ...                                                   ...                ...
# 869871  Government expenditure on tertiary education a...  UIS.XGDP.56.FSGOV
# 873536  Government expenditure on tertiary education a...  UIS.XGDP.56.FSGOV
# 877201  Government expenditure on tertiary education a...  UIS.XGDP.56.FSGOV
# 880866  Government expenditure on tertiary education a...  UIS.XGDP.56.FSGOV
# 884531  Government expenditure on tertiary education a...  UIS.XGDP.56.FSGOV
#
#         1970  1971  1972  1973  1974  1975  ...  2060  2065  2070  2075  2080  \
# 1266     NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 4931     NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 8596     NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 12261    NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 15926    NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# ...      ...   ...   ...   ...   ...   ...  ...   ...   ...   ...   ...   ...
# 869871   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 873536   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 877201   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 880866   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 884531   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
#
#         2085  2090  2095  2100  Unnamed: 69
# 1266     NaN   NaN   NaN   NaN          NaN
# 4931     NaN   NaN   NaN   NaN          NaN
# 8596     NaN   NaN   NaN   NaN          NaN
# 12261    NaN   NaN   NaN   NaN          NaN
# 15926    NaN   NaN   NaN   NaN          NaN
# ...      ...   ...   ...   ...          ...
# 869871   NaN   NaN   NaN   NaN          NaN
# 873536   NaN   NaN   NaN   NaN          NaN
# 877201   NaN   NaN   NaN   NaN          NaN
# 880866   NaN   NaN   NaN   NaN          NaN
# 884531   NaN   NaN   NaN   NaN          NaN
#
# [242 rows x 70 columns]

# %%
# sur data_XGDP, compter le nombre de données présentes / absentes sans prendre en compte pays

# %%
#create df with only 'years' columns
data_XGDP_years = data_XGDP.loc[:, ~data_XGDP.columns.isin(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'])]
data_XGDP_years.shape
# Out:
# (242, 66)

# %%
#### calcule % of missing values within 'years' columns
percent_missing = data_XGDP_years.isnull().sum() * 100 / len(data_XGDP_years)

#create df listing df column names with missing values % 
missing_values_df = pd.DataFrame({'column_name':data_XGDP_years.columns,
                                  'percent_missing': percent_missing
                                 })
#
missing_values_df[missing_values_df.percent_missing !=100]
# Out:
#      column_name  percent_missing
# 1998        1998        76.033058
# 1999        1999        70.661157
# 2000        2000        71.074380
# 2001        2001        67.768595
# 2002        2002        63.223140
# 2003        2003        71.487603
# 2004        2004        61.570248
# 2005        2005        64.462810
# 2006        2006        63.636364
# 2007        2007        63.636364
# 2008        2008        60.330579
# 2009        2009        57.024793
# 2010        2010        53.305785
# 2011        2011        57.024793
# 2012        2012        62.809917
# 2013        2013        69.421488
# 2014        2014        85.123967
# 2015        2015        99.586777

# %%
data['Data'].describe()
# Out:
#                1970          1971          1972          1973          1974  \
# count  7.228800e+04  3.553700e+04  3.561900e+04  3.554500e+04  3.573000e+04
# mean   1.974772e+09  4.253638e+09  4.592365e+09  5.105006e+09  5.401493e+09
# std    1.211687e+11  1.804814e+11  1.914083e+11  2.059170e+11  2.112150e+11
# min   -1.435564e+00 -1.594625e+00 -3.056522e+00 -4.032582e+00 -4.213563e+00
# 25%    8.900000e-01  8.853210e+00  9.240920e+00  9.595200e+00  9.861595e+00
# 50%    6.317724e+00  6.316240e+01  6.655139e+01  6.969595e+01  7.087760e+01
# 75%    6.251250e+01  5.655200e+04  5.863650e+04  6.202900e+04  6.383675e+04
# max    1.903929e+13  1.986457e+13  2.100916e+13  2.238367e+13  2.282991e+13
#
#                1975          1976          1977          1978          1979  \
# count  8.730600e+04  3.748300e+04  3.757400e+04  3.757600e+04  3.680900e+04
# mean   2.314288e+09  5.731808e+09  6.124437e+09  6.671489e+09  7.436724e+09
# std    1.375059e+11  2.215546e+11  2.325489e+11  2.473986e+11  2.660957e+11
# min   -3.658569e+00 -2.950945e+00 -3.174870e+00 -3.558749e+00 -2.973612e+00
# 25%    1.400000e+00  9.312615e+00  9.519913e+00  1.000000e+01  1.000000e+01
# 50%    9.677420e+00  7.101590e+01  7.133326e+01  7.290512e+01  7.510173e+01
# 75%    7.854163e+01  5.682800e+04  5.739175e+04  5.940425e+04  6.411500e+04
# max    2.300634e+13  2.424128e+13  2.521383e+13  2.622101e+13  2.730873e+13
#
#        ...          2060          2065          2070          2075  \
# count  ...  5.143600e+04  5.143600e+04  5.143600e+04  5.143600e+04
# mean   ...  7.224868e+02  7.271290e+02  7.283779e+02  7.266484e+02
# std    ...  2.215845e+04  2.287990e+04  2.352338e+04  2.408149e+04
# min    ... -1.630000e+00 -1.440000e+00 -1.260000e+00 -1.090000e+00
# 25%    ...  3.000000e-02  3.000000e-02  2.000000e-02  2.000000e-02
# 50%    ...  2.300000e-01  2.300000e-01  2.300000e-01  2.300000e-01
# 75%    ...  7.505000e+00  7.500000e+00  7.300000e+00  7.100000e+00
# max    ...  2.951569e+06  3.070879e+06  3.169711e+06  3.246239e+06
#
#                2080          2085          2090          2095          2100  \
# count  5.143600e+04  5.143600e+04  5.143600e+04  5.143600e+04  5.143600e+04
# mean   7.228327e+02  7.176899e+02  7.113072e+02  7.034274e+02  6.940296e+02
# std    2.455897e+04  2.496587e+04  2.530183e+04  2.556069e+04  2.574189e+04
# min   -9.200000e-01 -7.800000e-01 -6.500000e-01 -5.500000e-01 -4.500000e-01
# 25%    1.000000e-02  1.000000e-02  1.000000e-02  1.000000e-02  1.000000e-02
# 50%    2.300000e-01  2.300000e-01  2.300000e-01  2.300000e-01  2.200000e-01
# 75%    6.722500e+00  6.080000e+00  5.462500e+00  4.680000e+00  4.032500e+00
# max    3.301586e+06  3.337871e+06  3.354746e+06  3.351887e+06  3.330484e+06
#
#        Unnamed: 69
# count          0.0
# mean           NaN
# std            NaN
# min            NaN
# 25%            NaN
# 50%            NaN
# 75%            NaN
# max            NaN
#
# [8 rows x 66 columns]

# %%
data['Data'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 886930 entries, 0 to 886929
# Data columns (total 70 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Country Name    886930 non-null  object
#  1   Country Code    886930 non-null  object
#  2   Indicator Name  886930 non-null  object
#  3   Indicator Code  886930 non-null  object
#  4   1970            72288 non-null   float64
#  5   1971            35537 non-null   float64
#  6   1972            35619 non-null   float64
#  7   1973            35545 non-null   float64
#  8   1974            35730 non-null   float64
#  9   1975            87306 non-null   float64
#  10  1976            37483 non-null   float64
#  11  1977            37574 non-null   float64
#  12  1978            37576 non-null   float64
#  13  1979            36809 non-null   float64
#  14  1980            89122 non-null   float64
#  15  1981            38777 non-null   float64
#  16  1982            37511 non-null   float64
#  17  1983            38460 non-null   float64
#  18  1984            38606 non-null   float64
#  19  1985            90296 non-null   float64
#  20  1986            39372 non-null   float64
#  21  1987            38641 non-null   float64
#  22  1988            38552 non-null   float64
#  23  1989            37540 non-null   float64
#  24  1990            124405 non-null  float64
#  25  1991            74437 non-null   float64
#  26  1992            75543 non-null   float64
#  27  1993            75793 non-null   float64
#  28  1994            77462 non-null   float64
#  29  1995            131361 non-null  float64
#  30  1996            76807 non-null   float64
#  31  1997            73453 non-null   float64
#  32  1998            84914 non-null   float64
#  33  1999            118839 non-null  float64
#  34  2000            176676 non-null  float64
#  35  2001            123509 non-null  float64
#  36  2002            124205 non-null  float64
#  37  2003            130363 non-null  float64
#  38  2004            128814 non-null  float64
#  39  2005            184108 non-null  float64
#  40  2006            140312 non-null  float64
#  41  2007            137272 non-null  float64
#  42  2008            134387 non-null  float64
#  43  2009            142108 non-null  float64
#  44  2010            242442 non-null  float64
#  45  2011            146012 non-null  float64
#  46  2012            147264 non-null  float64
#  47  2013            137509 non-null  float64
#  48  2014            113789 non-null  float64
#  49  2015            131058 non-null  float64
#  50  2016            16460 non-null   float64
#  51  2017            143 non-null     float64
#  52  2020            51436 non-null   float64
#  53  2025            51436 non-null   float64
#  54  2030            51436 non-null   float64
#  55  2035            51436 non-null   float64
#  56  2040            51436 non-null   float64
#  57  2045            51436 non-null   float64
#  58  2050            51436 non-null   float64
#  59  2055            51436 non-null   float64
#  60  2060            51436 non-null   float64
#  61  2065            51436 non-null   float64
#  62  2070            51436 non-null   float64
#  63  2075            51436 non-null   float64
#  64  2080            51436 non-null   float64
#  65  2085            51436 non-null   float64
#  66  2090            51436 non-null   float64
#  67  2095            51436 non-null   float64
#  68  2100            51436 non-null   float64
#  69  Unnamed: 69     0 non-null       float64
# dtypes: float64(66), object(4)
# memory usage: 473.7+ MB

# %% [markdown]
# ## Assess available / missing data in whole dataframe

# %% [markdown]
# ### create function

# %%
# list unique indicators
indicators_list = data['Data']['Indicator Code'].unique()
indicators_list
# Out:
# array(['UIS.NERA.2', 'UIS.NERA.2.F', 'UIS.NERA.2.GPI', ...,
#        'SE.ADT.1524.LT.FE.ZS', 'SE.ADT.1524.LT.FM.ZS',
#        'SE.ADT.1524.LT.MA.ZS'], dtype=object)

# %%
#create df with only 'years' columns from first indicator in the list
indicator_full_data = data['Data'].loc[data['Data']['Indicator Code'] == indicators_list[0]]
indicator_years_data = indicator_full_data.loc[:, ~indicator_full_data.columns.isin(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'])]

# %%
df_nan_count = indicator_years_data.isna().values.sum()
df_nan_count
# Out:
# 13567

# %%
df_non_nan_count = indicator_years_data.count().sum()
df_non_nan_count
# Out:
# 2405

# %%
# percent of non-nan values 
available_values_percent = round((df_non_nan_count / (df_non_nan_count + df_nan_count) * 100), 2)
available_values_percent
# Out:
# 15.06

# %%
for i in range(len(indicators_list)):
        print(indicators_list[i])
# Out:
# UIS.NERA.2
# UIS.NERA.2.F
# UIS.NERA.2.GPI
# UIS.NERA.2.M
# SE.PRM.TENR
# SE.PRM.TENR.FE
# UIS.NERA.1.GPI
# SE.PRM.TENR.MA
# UIS.NERA.3
# UIS.NERA.3.F
# UIS.NERA.3.GPI
# UIS.NERA.3.M
# UIS.NIRA.1
# UIS.NIRA.1.F
# UIS.NIRA.1.GPI
# UIS.NIRA.1.M
# UIS.LPP.AG15T99
# UIS.LP.AG15T99
# UIS.LP.AG15T99.F
# UIS.LP.AG15T99.M
# SE.ADT.LITR.ZS
# SE.ADT.LITR.FE.ZS
# UIS.LR.AG15T99.GPI
# SE.ADT.LITR.MA.ZS
# UIS.AFR.AGRADMG.1.PU
# UIS.AFR.PBR.1.G1.PU.MATH
# UIS.AFR.PBR.1.G2.PU.MATH
# UIS.AFR.PBR.1.G3.PU.MATH
# UIS.AFR.PBR.1.G4.PU.MATH
# UIS.AFR.PBR.1.G5.PU.MATH
# UIS.AFR.PBR.1.G6.PU.MATH
# UIS.AFR.PBR.1.G7.PU.MATH
# UIS.AFR.PBR.1.PU.MATH
# UIS.AFR.PBR.1.G1.PU.READ
# UIS.AFR.PBR.1.G2.PU.READ
# UIS.AFR.PBR.1.G3.PU.READ
# UIS.AFR.PBR.1.G4.PU.READ
# UIS.AFR.PBR.1.G5.PU.READ
# UIS.AFR.PBR.1.G6.PU.READ
# UIS.AFR.PBR.1.G7.PU.READ
# UIS.AFR.PBR.1.PU.READ
# UIS.AFR.CS.1.PU
# UIS.AFR.CS.MG.1.PU
# UIS.AFR.CS.SG.1.G1.PU
# UIS.AFR.CS.SG.1.G2.PU
# UIS.AFR.CS.SG.1.G3.PU
# UIS.AFR.CS.SG.1.G4.PU
# UIS.AFR.CS.SG.1.G5.PU
# UIS.AFR.CS.SG.1.G6.PU
# UIS.AFR.CS.SG.1.G7.PU
# UIS.AFR.CS.SG.1.PU
# UIS.AFR.GTC.2.T
# UIS.AFR.GTC.2.F
# UIS.AFR.GTC.1T3.T
# UIS.AFR.GTC.1T3.F
# UIS.AFR.GTC.1.T
# UIS.AFR.GTC.1.F
# UIS.AFR.GTC.UK.T
# UIS.AFR.GTC.UK.F
# UIS.AFR.GTC.3.T
# UIS.AFR.GTC.3.F
# UIS.AFR.TRNTP.2.PU.F
# UIS.AFR.TRNTP.1.PU.F
# UIS.AFR.TRNTP.3.PU.F
# UIS.AFR.NTP.2.PU.F
# UIS.AFR.NTP.1.PU.F
# UIS.AFR.NTP.3.PU.F
# UIS.AFR.SCHBSP.2.PU.WELEC
# UIS.AFR.SCHBSP.2.PU.WPOWAT
# UIS.AFR.SCHBSP.2.PU.MIXTOIL
# UIS.AFR.SCHBSP.2.PU.WNIELEC
# UIS.AFR.SCHBSP.2.PU.WNIPOWAT
# UIS.AFR.SCHBSP.2.PU.WNITOIL
# UIS.AFR.SCHBSP.2.PU.WSTOIL
# UIS.AFR.SCHBSP.2.PU.WTOIL
# UIS.AFR.SCHBSP.2.PU.WOELEC
# UIS.AFR.SCHBSP.2.PU.WOPOWAT
# UIS.AFR.SCHBSP.2.PU.WOTOIL
# UIS.AFR.TRNTP.2.PU.M
# UIS.AFR.TRNTP.1.PU.M
# UIS.AFR.TRNTP.3.PU.M
# UIS.AFR.NTP.2.PU.M
# UIS.AFR.NTP.1.PU.M
# UIS.AFR.NTP.3.PU.M
# UIS.AFR.FNTP.2
# UIS.AFR.TRNTP.2.PU.T
# UIS.AFR.FNTP.1
# UIS.AFR.TRNTP.1.PU.T
# UIS.AFR.FNTP.3
# UIS.AFR.TRNTP.3.PU.T
# UIS.AFR.ECP.MG.1.PU
# UIS.AFR.SCHBSP.1.PU.WELEC
# UIS.AFR.SCHBSP.1.PU.WPOWAT
# UIS.AFR.SCHBSP.1.PU.MIXTOIL
# UIS.AFR.SCHBSP.1.PU.WNIELEC
# UIS.AFR.SCHBSP.1.PU.WNIPOWAT
# UIS.AFR.SCHBSP.1.PU.WNITOIL
# UIS.AFR.SCHBSP.1.PU.WSTOIL
# UIS.AFR.SCHBSP.1.PU.WTOIL
# UIS.AFR.SCHBSP.1.PU.WOELEC
# UIS.AFR.SCHBSP.1.PU.WOPOWAT
# UIS.AFR.SCHBSP.1.PU.WOTOIL
# UIS.AFR.NTP.2.PU.T
# UIS.AFR.NTP.1.PU.T
# UIS.AFR.NTP.3.PU.T
# UIS.AFR.GTCTR.2.T
# UIS.AFR.GTCTR.2.F
# UIS.AFR.GTCTR.2.M
# UIS.AFR.GTCTR.1.T
# UIS.AFR.GTCTR.1.F
# UIS.AFR.GTCTR.1.M
# UIS.AFR.GTCTR.3.T
# UIS.AFR.GTCTR.3.F
# UIS.AFR.GTCTR.3.M
# UIS.AFR.SCHCENRESPR.1.PU
# UIS.AFR.SCHCENRESPR.23.PU
# UIS.AFR.TATTRR.2.PU.T
# UIS.AFR.TATTRR.2.Pu.F
# UIS.AFR.TATTRR.2.Pu.M
# UIS.AFR.TATTRR.1.PU.T
# UIS.AFR.TATTRR.1.PU.F
# UIS.AFR.TATTRR.1.PU.M
# UIS.AFR.TATTRR.3.Pu.T
# UIS.AFR.TATTRR.3.Pu.F
# UIS.AFR.TATTRR.3.Pu.M
# UIS.XSPENDP.2.FDPUB.FNS
# UIS.XSPENDP.4.FDPUB.FNS
# UIS.XSPENDP.0.FDPUB.FNS
# UIS.XSPENDP.1.FDPUB.FNS
# UIS.XSPENDP.FDPUB.FNS
# UIS.XSPENDP.23.FDPUB.FNS
# UIS.XSPENDP.56.FDPUB.FNS
# UIS.XSPENDP.3.FDPUB.FNS
# OECD.TSAL.2.E10
# OECD.TSAL.2.E15
# OECD.TSAL.2.E0
# OECD.TSAL.2.ETOP
# OECD.TSAL.0.E10
# OECD.TSAL.0.E15
# OECD.TSAL.0.E0
# OECD.TSAL.0.ETOP
# OECD.TSAL.1.E10
# OECD.TSAL.1.E15
# OECD.TSAL.1.E0
# OECD.TSAL.1.ETOP
# OECD.TSAL.3.E10
# OECD.TSAL.3.E15
# OECD.TSAL.3.E0
# OECD.TSAL.3.ETOP
# BAR.PRM.SCHL.15UP.FE
# BAR.PRM.SCHL.15UP
# BAR.PRM.SCHL.1519.FE
# BAR.PRM.SCHL.1519
# BAR.PRM.SCHL.2024.FE
# BAR.PRM.SCHL.2024
# BAR.PRM.SCHL.25UP.FE
# BAR.PRM.SCHL.25UP
# BAR.PRM.SCHL.2529.FE
# BAR.PRM.SCHL.2529
# BAR.PRM.SCHL.3034.FE
# BAR.PRM.SCHL.3034
# BAR.PRM.SCHL.3539.FE
# BAR.PRM.SCHL.3539
# BAR.PRM.SCHL.4044.FE
# BAR.PRM.SCHL.4044
# BAR.PRM.SCHL.4549.FE
# BAR.PRM.SCHL.4549
# BAR.PRM.SCHL.5054.FE
# BAR.PRM.SCHL.5054
# BAR.PRM.SCHL.5559.FE
# BAR.PRM.SCHL.5559
# BAR.PRM.SCHL.6064.FE
# BAR.PRM.SCHL.6064
# BAR.PRM.SCHL.6569.FE
# BAR.PRM.SCHL.6569
# BAR.PRM.SCHL.7074.FE
# BAR.PRM.SCHL.7074
# BAR.PRM.SCHL.75UP.FE
# BAR.PRM.SCHL.75UP
# BAR.SEC.SCHL.15UP.FE
# BAR.SEC.SCHL.15UP
# BAR.SEC.SCHL.1519.FE
# BAR.SEC.SCHL.1519
# BAR.SEC.SCHL.2024.FE
# BAR.SEC.SCHL.2024
# BAR.SEC.SCHL.25UP.FE
# BAR.SEC.SCHL.25UP
# BAR.SEC.SCHL.2529.FE
# BAR.SEC.SCHL.2529
# BAR.SEC.SCHL.3034.FE
# BAR.SEC.SCHL.3034
# BAR.SEC.SCHL.3539.FE
# BAR.SEC.SCHL.3539
# BAR.SEC.SCHL.4044.FE
# BAR.SEC.SCHL.4044
# BAR.SEC.SCHL.4549.FE
# BAR.SEC.SCHL.4549
# BAR.SEC.SCHL.5054.FE
# BAR.SEC.SCHL.5054
# BAR.SEC.SCHL.5559.FE
# BAR.SEC.SCHL.5559
# BAR.SEC.SCHL.6064.FE
# BAR.SEC.SCHL.6064
# BAR.SEC.SCHL.6569.FE
# BAR.SEC.SCHL.6569
# BAR.SEC.SCHL.7074.FE
# BAR.SEC.SCHL.7074
# BAR.SEC.SCHL.75UP.FE
# BAR.SEC.SCHL.75UP
# BAR.TER.SCHL.15UP.FE
# BAR.TER.SCHL.15UP
# BAR.TER.SCHL.1519.FE
# BAR.TER.SCHL.1519
# BAR.TER.SCHL.2024.FE
# BAR.TER.SCHL.2024
# BAR.TER.SCHL.25UP.FE
# BAR.TER.SCHL.25UP
# BAR.TER.SCHL.2529.FE
# BAR.TER.SCHL.2529
# BAR.TER.SCHL.3034.FE
# BAR.TER.SCHL.3034
# BAR.TER.SCHL.3539.FE
# BAR.TER.SCHL.3539
# BAR.TER.SCHL.4044.FE
# BAR.TER.SCHL.4044
# BAR.TER.SCHL.4549.FE
# BAR.TER.SCHL.4549
# BAR.TER.SCHL.5054.FE
# BAR.TER.SCHL.5054
# BAR.TER.SCHL.5559.FE
# BAR.TER.SCHL.5559
# BAR.TER.SCHL.6064.FE
# BAR.TER.SCHL.6064
# BAR.TER.SCHL.6569.FE
# BAR.TER.SCHL.6569
# BAR.TER.SCHL.7074.FE
# BAR.TER.SCHL.7074
# BAR.TER.SCHL.75UP.FE
# BAR.TER.SCHL.75UP
# BAR.SCHL.15UP.FE
# BAR.SCHL.15UP
# BAR.SCHL.1519.FE
# BAR.SCHL.1519
# BAR.SCHL.2024.FE
# BAR.SCHL.2024
# BAR.SCHL.25UP.FE
# BAR.SCHL.25UP
# BAR.SCHL.2529.FE
# BAR.SCHL.2529
# BAR.SCHL.3034.FE
# BAR.SCHL.3034
# BAR.SCHL.3539.FE
# BAR.SCHL.3539
# BAR.SCHL.4044.FE
# BAR.SCHL.4044
# BAR.SCHL.4549.FE
# BAR.SCHL.4549
# BAR.SCHL.5054.FE
# BAR.SCHL.5054
# BAR.SCHL.5559.FE
# BAR.SCHL.5559
# BAR.SCHL.6064.FE
# BAR.SCHL.6064
# BAR.SCHL.6569.FE
# BAR.SCHL.6569
# BAR.SCHL.7074.FE
# BAR.SCHL.7074
# BAR.SCHL.75UP.FE
# BAR.SCHL.75UP
# BAR.NOED.15UP.FE.ZS
# BAR.PRM.CMPT.15UP.FE.ZS
# BAR.PRM.ICMP.15UP.FE.ZS
# BAR.SEC.CMPT.15UP.FE.ZS
# BAR.SEC.ICMP.15UP.FE.ZS
# BAR.TER.CMPT.15UP.FE.ZS
# BAR.TER.ICMP.15UP.FE.ZS
# BAR.NOED.1519.FE.ZS
# BAR.PRM.CMPT.1519.FE.ZS
# BAR.PRM.ICMP.1519.FE.ZS
# BAR.SEC.CMPT.1519.FE.ZS
# BAR.SEC.ICMP.1519.FE.ZS
# BAR.TER.CMPT.1519.FE.ZS
# BAR.TER.ICMP.1519.FE.ZS
# BAR.NOED.2024.FE.ZS
# BAR.PRM.CMPT.2024.FE.ZS
# BAR.PRM.ICMP.2024.FE.ZS
# BAR.SEC.CMPT.2024.FE.ZS
# BAR.SEC.ICMP.2024.FE.ZS
# BAR.TER.CMPT.2024.FE.ZS
# BAR.TER.ICMP.2024.FE.ZS
# BAR.NOED.25UP.FE.ZS
# BAR.PRM.CMPT.25UP.FE.ZS
# BAR.PRM.ICMP.25UP.FE.ZS
# BAR.SEC.CMPT.25UP.FE.ZS
# BAR.SEC.ICMP.25UP.FE.ZS
# BAR.TER.CMPT.25UP.FE.ZS
# BAR.TER.ICMP.25UP.FE.ZS
# BAR.NOED.2529.FE.ZS
# BAR.PRM.CMPT.2529.FE.ZS
# BAR.PRM.ICMP.2529.FE.ZS
# BAR.SEC.CMPT.2529.FE.ZS
# BAR.SEC.ICMP.2529.FE.ZS
# BAR.TER.CMPT.2529.FE.ZS
# BAR.TER.ICMP.2529.FE.ZS
# BAR.NOED.3034.FE.ZS
# BAR.PRM.CMPT.3034.FE.ZS
# BAR.PRM.ICMP.3034.FE.ZS
# BAR.SEC.CMPT.3034.FE.ZS
# BAR.SEC.ICMP.3034.FE.ZS
# BAR.TER.CMPT.3034.FE.ZS
# BAR.TER.ICMP.3034.FE.ZS
# BAR.NOED.3539.FE.ZS
# BAR.PRM.CMPT.3539.FE.ZS
# BAR.PRM.ICMP.3539.FE.ZS
# BAR.SEC.CMPT.3539.FE.ZS
# BAR.SEC.ICMP.3539.FE.ZS
# BAR.TER.CMPT.3539.FE.ZS
# BAR.TER.ICMP.3539.FE.ZS
# BAR.NOED.4044.FE.ZS
# BAR.PRM.CMPT.4044.FE.ZS
# BAR.PRM.ICMP.4044.FE.ZS
# BAR.SEC.CMPT.4044.FE.ZS
# BAR.SEC.ICMP.4044.FE.ZS
# BAR.TER.CMPT.4044.FE.ZS
# BAR.TER.ICMP.4044.FE.ZS
# BAR.NOED.4549.FE.ZS
# BAR.PRM.CMPT.4549.FE.ZS
# BAR.PRM.ICMP.4549.FE.ZS
# BAR.SEC.CMPT.4549.FE.ZS
# BAR.SEC.ICMP.4549.FE.ZS
# BAR.TER.CMPT.4549.FE.ZS
# BAR.TER.ICMP.4549.FE.ZS
# BAR.NOED.5054.FE.ZS
# BAR.PRM.CMPT.5054.FE.ZS
# BAR.PRM.ICMP.5054.FE.ZS
# BAR.SEC.CMPT.5054.FE.ZS
# BAR.SEC.ICMP.5054.FE.ZS
# BAR.TER.CMPT.5054.FE.ZS
# BAR.TER.ICMP.5054.FE.ZS
# BAR.NOED.5559.FE.ZS
# BAR.PRM.CMPT.5559.FE.ZS
# BAR.PRM.ICMP.5559.FE.ZS
# BAR.SEC.CMPT.5559.FE.ZS
# BAR.SEC.ICMP.5559.FE.ZS
# BAR.TER.CMPT.5559.FE.ZS
# BAR.TER.ICMP.5559.FE.ZS
# BAR.NOED.6064.FE.ZS
# BAR.PRM.CMPT.6064.FE.ZS
# BAR.PRM.ICMP.6064.FE.ZS
# BAR.SEC.CMPT.6064.FE.ZS
# BAR.SEC.ICMP.6064.FE.ZS
# BAR.TER.CMPT.6064.FE.ZS
# BAR.TER.ICMP.6064.FE.ZS
# BAR.NOED.6569.FE.ZS
# BAR.PRM.CMPT.6569.FE.ZS
# BAR.PRM.ICMP.6569.FE.ZS
# BAR.SEC.CMPT.6569.FE.ZS
# BAR.SEC.ICMP.6569.FE.ZS
# BAR.TER.CMPT.6569.FE.ZS
# BAR.TER.ICMP.6569.FE.ZS
# BAR.NOED.7074.FE.ZS
# BAR.PRM.CMPT.7074.FE.ZS
# BAR.PRM.ICMP.7074.FE.ZS
# BAR.SEC.CMPT.7074.FE.ZS
# BAR.SEC.ICMP.7074.FE.ZS
# BAR.TER.CMPT.7074.FE.ZS
# BAR.TER.ICMP.7074.FE.ZS
# BAR.NOED.75UP.FE.ZS
# BAR.PRM.CMPT.75UP.FE.ZS
# BAR.PRM.ICMP.75UP.FE.ZS
# BAR.SEC.CMPT.75UP.FE.ZS
# BAR.SEC.ICMP.75UP.FE.ZS
# BAR.TER.CMPT.75UP.FE.ZS
# BAR.TER.ICMP.75UP.FE.ZS
# BAR.NOED.15UP.ZS
# BAR.PRM.CMPT.15UP.ZS
# BAR.PRM.ICMP.15UP.ZS
# BAR.SEC.CMPT.15UP.ZS
# BAR.SEC.ICMP.15UP.ZS
# BAR.TER.CMPT.15UP.ZS
# BAR.TER.ICMP.15UP.ZS
# BAR.NOED.1519.ZS
# BAR.PRM.CMPT.1519.ZS
# BAR.PRM.ICMP.1519.ZS
# BAR.SEC.CMPT.1519.ZS
# BAR.SEC.ICMP.1519.ZS
# BAR.TER.CMPT.1519.ZS
# BAR.TER.ICMP.1519.ZS
# BAR.NOED.2024.ZS
# BAR.PRM.CMPT.2024.ZS
# BAR.PRM.ICMP.2024.ZS
# BAR.SEC.CMPT.2024.ZS
# BAR.SEC.ICMP.2024.ZS
# BAR.TER.CMPT.2024.ZS
# BAR.TER.ICMP.2024.ZS
# BAR.NOED.25UP.ZS
# BAR.PRM.CMPT.25UP.ZS
# BAR.PRM.ICMP.25UP.ZS
# BAR.SEC.CMPT.25UP.ZS
# BAR.SEC.ICMP.25UP.ZS
# BAR.TER.CMPT.25UP.ZS
# BAR.TER.ICMP.25UP.ZS
# BAR.NOED.2529.ZS
# BAR.PRM.CMPT.2529.ZS
# BAR.PRM.ICMP.2529.ZS
# BAR.SEC.CMPT.2529.ZS
# BAR.SEC.ICMP.2529.ZS
# BAR.TER.CMPT.2529.ZS
# BAR.TER.ICMP.2529.ZS
# BAR.NOED.3034.ZS
# BAR.PRM.CMPT.3034.ZS
# BAR.PRM.ICMP.3034.ZS
# BAR.SEC.CMPT.3034.ZS
# BAR.SEC.ICMP.3034.ZS
# BAR.TER.CMPT.3034.ZS
# BAR.TER.ICMP.3034.ZS
# BAR.NOED.3539.ZS
# BAR.PRM.CMPT.3539.ZS
# BAR.PRM.ICMP.3539.ZS
# BAR.SEC.CMPT.3539.ZS
# BAR.SEC.ICMP.3539.ZS
# BAR.TER.CMPT.3539.ZS
# BAR.TER.ICMP.3539.ZS
# BAR.NOED.4044.ZS
# BAR.PRM.CMPT.4044.ZS
# BAR.PRM.ICMP.4044.ZS
# BAR.SEC.CMPT.4044.ZS
# BAR.SEC.ICMP.4044.ZS
# BAR.TER.CMPT.4044.ZS
# BAR.TER.ICMP.4044.ZS
# BAR.NOED.4549.ZS
# BAR.PRM.CMPT.4549.ZS
# BAR.PRM.ICMP.4549.ZS
# BAR.SEC.CMPT.4549.ZS
# BAR.SEC.ICMP.4549.ZS
# BAR.TER.CMPT.4549.ZS
# BAR.TER.ICMP.4549.ZS
# BAR.NOED.5054.ZS
# BAR.PRM.CMPT.5054.ZS
# BAR.PRM.ICMP.5054.ZS
# BAR.SEC.CMPT.5054.ZS
# BAR.SEC.ICMP.5054.ZS
# BAR.TER.CMPT.5054.ZS
# BAR.TER.ICMP.5054.ZS
# BAR.NOED.5559.ZS
# BAR.PRM.CMPT.5559.ZS
# BAR.PRM.ICMP.5559.ZS
# BAR.SEC.CMPT.5559.ZS
# BAR.SEC.ICMP.5559.ZS
# BAR.TER.CMPT.5559.ZS
# BAR.TER.ICMP.5559.ZS
# BAR.NOED.6064.ZS
# BAR.PRM.CMPT.6064.ZS
# BAR.PRM.ICMP.6064.ZS
# BAR.SEC.CMPT.6064.ZS
# BAR.SEC.ICMP.6064.ZS
# BAR.TER.CMPT.6064.ZS
# BAR.TER.ICMP.6064.ZS
# BAR.NOED.6569.ZS
# BAR.PRM.CMPT.6569.ZS
# BAR.PRM.ICMP.6569.ZS
# BAR.SEC.CMPT.6569.ZS
# BAR.SEC.ICMP.6569.ZS
# BAR.TER.CMPT.6569.ZS
# BAR.TER.ICMP.6569.ZS
# BAR.NOED.7074.ZS
# BAR.PRM.CMPT.7074.ZS
# BAR.PRM.ICMP.7074.ZS
# BAR.SEC.CMPT.7074.ZS
# BAR.SEC.ICMP.7074.ZS
# BAR.TER.CMPT.7074.ZS
# BAR.TER.ICMP.7074.ZS
# BAR.NOED.75UP.ZS
# BAR.PRM.CMPT.75UP.ZS
# BAR.PRM.ICMP.75UP.ZS
# BAR.SEC.CMPT.75UP.ZS
# BAR.SEC.ICMP.75UP.ZS
# BAR.TER.CMPT.75UP.ZS
# BAR.TER.ICMP.75UP.ZS
# BAR.POP.15UP.FE
# BAR.POP.15UP
# BAR.POP.1519.FE
# BAR.POP.1519
# BAR.POP.2024.FE
# BAR.POP.2024
# BAR.POP.25UP.FE
# BAR.POP.25UP
# BAR.POP.2529.FE
# BAR.POP.2529
# BAR.POP.3034.FE
# BAR.POP.3034
# BAR.POP.3539.FE
# BAR.POP.3539
# BAR.POP.4044.FE
# BAR.POP.4044
# BAR.POP.4549.FE
# BAR.POP.4549
# BAR.POP.5054.FE
# BAR.POP.5054
# BAR.POP.5559.FE
# BAR.POP.5559
# BAR.POP.6064.FE
# BAR.POP.6064
# BAR.POP.6569.FE
# BAR.POP.6569
# BAR.POP.7074.FE
# BAR.POP.7074
# BAR.POP.75UP.FE
# BAR.POP.75UP
# UIS.XSPENDP.2.FDPUB.FNCAP
# UIS.XSPENDP.4.FDPUB.FNCAP
# UIS.XSPENDP.0.FDPUB.FNCAP
# UIS.XSPENDP.1.FDPUB.FNCAP
# UIS.XSPENDP.FDPUB.FNCAP
# UIS.XSPENDP.23.FDPUB.FNCAP
# UIS.XSPENDP.56.FDPUB.FNCAP
# UIS.XSPENDP.3.FDPUB.FNCAP
# UIS.DR.2.GPV.T
# UIS.DR.2.GPV.F
# UIS.DR.2.GPV.M
# SE.PRM.DROP.ZS
# SE.PRM.DROP.FE.ZS
# SE.PRM.DROP.MA.ZS
# UIS.XSPENDP.2.FDPUB.FNCUR
# UIS.XSPENDP.4.FDPUB.FNCUR
# UIS.XSPENDP.0.FDPUB.FNCUR
# UIS.XSPENDP.1.FDPUB.FNCUR
# SE.XPD.CUR.TOTL.ZS
# UIS.XSPENDP.23.FDPUB.FNCUR
# UIS.XSPENDP.56.FDPUB.FNCUR
# UIS.XSPENDP.3.FDPUB.FNCUR
# UIS.XSPENDP.2.FDPUB.FNNONS
# UIS.XSPENDP.4.FDPUB.FNNONS
# UIS.XSPENDP.0.FDPUB.FNNONS
# UIS.XSPENDP.1.FDPUB.FNNONS
# UIS.XSPENDP.FDPUB.FNNONS
# UIS.XSPENDP.23.FDPUB.FNNONS
# UIS.XSPENDP.56.FDPUB.FNNONS
# UIS.XSPENDP.3.FDPUB.FNNONS
# HH.DHS.YRS.1519
# HH.DHS.YRS.1519.F
# HH.DHS.YRS.1519.M
# HH.DHS.YRS.1519.Q1
# HH.DHS.YRS.1519.Q2
# HH.DHS.YRS.1519.Q3
# HH.DHS.YRS.1519.Q4
# HH.DHS.YRS.1519.Q5
# HH.DHS.YRS.1519.R
# HH.DHS.YRS.1519.U
# HH.DHS.YRS.15UP.GIN
# HH.DHS.YRS.15UP.GIN.F
# HH.DHS.YRS.15UP.GIN.M
# HH.DHS.YRS.15UP.GIN.Q1
# HH.DHS.YRS.15UP.GIN.Q2
# HH.DHS.YRS.15UP.GIN.Q3
# HH.DHS.YRS.15UP.GIN.Q4
# HH.DHS.YRS.15UP.GIN.Q5
# HH.DHS.YRS.15UP.GIN.R
# HH.DHS.YRS.15UP.GIN.U
# HH.DHS.GAR.456
# HH.DHS.GAR.456.F
# HH.DHS.GAR.456.M
# HH.DHS.GAR.456.Q1
# HH.DHS.GAR.456.Q2
# HH.DHS.GAR.456.Q3
# HH.DHS.GAR.456.Q4
# HH.DHS.GAR.456.Q5
# HH.DHS.GAR.456.R
# HH.DHS.GAR.456.U
# HH.DHS.NAR.1
# HH.DHS.NAR.1.F
# HH.DHS.NAR.1.M
# HH.DHS.NAR.1.Q1
# HH.DHS.NAR.1.Q2
# HH.DHS.NAR.1.Q3
# HH.DHS.NAR.1.Q4
# HH.DHS.NAR.1.Q5
# HH.DHS.NAR.1.R
# HH.DHS.NAR.1.U
# HH.DHS.NAR.23
# HH.DHS.NAR.23.F
# HH.DHS.NAR.23.M
# HH.DHS.NAR.23.Q1
# HH.DHS.NAR.23.Q2
# HH.DHS.NAR.23.Q3
# HH.DHS.NAR.23.Q4
# HH.DHS.NAR.23.Q5
# HH.DHS.NAR.23.R
# HH.DHS.NAR.23.U
# HH.DHS.NIR.1
# HH.DHS.NIR.1.F
# HH.DHS.NIR.1.M
# HH.DHS.NIR.1.Q1
# HH.DHS.NIR.1.Q2
# HH.DHS.NIR.1.Q3
# HH.DHS.NIR.1.Q4
# HH.DHS.NIR.1.Q5
# HH.DHS.NIR.1.R
# HH.DHS.NIR.1.U
# HH.DHS.PCR
# HH.DHS.PCR.F
# HH.DHS.PCR.M
# HH.DHS.PCR.Q1
# HH.DHS.PCR.Q2
# HH.DHS.PCR.Q3
# HH.DHS.PCR.Q4
# HH.DHS.PCR.Q5
# HH.DHS.PCR.R
# HH.DHS.PCR.U
# HH.DHS.OOS.1
# HH.DHS.OOS.1.F
# HH.DHS.OOS.1.M
# HH.DHS.OOS.1.Q1
# HH.DHS.OOS.1.Q2
# HH.DHS.OOS.1.Q3
# HH.DHS.OOS.1.Q4
# HH.DHS.OOS.1.Q5
# HH.DHS.OOS.1.R
# HH.DHS.OOS.1.U
# HH.DHS.SCR
# HH.DHS.SCR.F
# HH.DHS.SCR.M
# HH.DHS.SCR.Q1
# HH.DHS.SCR.Q2
# HH.DHS.SCR.Q3
# HH.DHS.SCR.Q4
# HH.DHS.SCR.Q5
# HH.DHS.SCR.R
# HH.DHS.SCR.U
# HH.DHS.TR.12
# HH.DHS.TR.12.F
# HH.DHS.TR.12.M
# HH.DHS.TR.12.Q1
# HH.DHS.TR.12.Q2
# HH.DHS.TR.12.Q3
# HH.DHS.TR.12.Q4
# HH.DHS.TR.12.Q5
# HH.DHS.TR.12.R
# HH.DHS.TR.12.U
# HH.DHS.OOST.DO
# HH.DHS.OOST.DO.F
# HH.DHS.OOST.DO.M
# HH.DHS.OOST.DO.Q1
# HH.DHS.OOST.DO.Q2
# HH.DHS.OOST.DO.Q3
# HH.DHS.OOST.DO.Q4
# HH.DHS.OOST.DO.Q5
# HH.DHS.OOST.DO.R
# HH.DHS.OOST.DO.U
# HH.DHS.OOST.L
# HH.DHS.OOST.L.F
# HH.DHS.OOST.L.M
# HH.DHS.OOST.L.Q1
# HH.DHS.OOST.L.Q2
# HH.DHS.OOST.L.Q3
# HH.DHS.OOST.L.Q4
# HH.DHS.OOST.L.Q5
# HH.DHS.OOST.L.R
# HH.DHS.OOST.L.U
# HH.DHS.OOST.X
# HH.DHS.OOST.X.F
# HH.DHS.OOST.X.M
# HH.DHS.OOST.X.Q1
# HH.DHS.OOST.X.Q2
# HH.DHS.OOST.X.Q3
# HH.DHS.OOST.X.Q4
# HH.DHS.OOST.X.Q5
# HH.DHS.OOST.X.R
# HH.DHS.OOST.X.U
# UIS.DR.2.GPV.G1.T
# UIS.DR.2.GPV.G1.F
# UIS.DR.2.GPV.G1.M
# UIS.DR.1.G1
# UIS.DR.1.G1.F
# UIS.DR.1.G1.M
# UIS.DR.2.GPV.G2.T
# UIS.DR.2.GPV.G2.F
# UIS.DR.2.GPV.G2.M
# UIS.DR.1.G2
# UIS.DR.1.G2.F
# UIS.DR.1.G2.M
# UIS.DR.2.GPV.G3.T
# UIS.DR.2.GPV.G3.F
# UIS.DR.2.GPV.G3.M
# UIS.DR.1.G3
# UIS.DR.1.G3.F
# UIS.DR.1.G3.M
# UIS.DR.2.GPV.G4.T
# UIS.DR.2.GPV.G4.F
# UIS.DR.2.GPV.G4.M
# UIS.DR.1.G4
# UIS.DR.1.G4.F
# UIS.DR.1.G4.M
# UIS.DR.2.GPV.G5.T
# UIS.DR.2.GPV.G5.F
# UIS.DR.2.GPV.G5.M
# UIS.DR.1.G5
# UIS.DR.1.G5.F
# UIS.DR.1.G5.M
# UIS.DR.1.G6
# UIS.DR.1.G6.F
# UIS.DR.1.G6.M
# SE.COM.DURS
# UIS.ESL.1.T
# UIS.ESL.1.F
# UIS.ESL.1.M
# SE.SEC.PROG.ZS
# SE.SEC.PROG.FE.ZS
# UIS.TRANRA.23.GPV.GPI
# SE.SEC.PROG.MA.ZS
# LO.EGRA.CWPM.AFA.2GRD
# LO.EGRA.CWPM.AFA.3GRD
# LO.EGRA.CWPM.AMH.2GRD
# LO.EGRA.CWPM.AMH.3GRD
# LO.EGRA.CWPM.ARB.2GRD
# LO.EGRA.CWPM.BMN.2GRD
# LO.EGRA.CWPM.BOM.2GRD
# LO.EGRA.CWPM.CHC.2GRD
# LO.EGRA.CWPM.CHC.4GRD
# LO.EGRA.CWPM.ENG.2GRD
# LO.EGRA.CWPM.ENG.3GRD
# LO.EGRA.CWPM.ENG.4GRD
# LO.EGRA.CWPM.ENG.6GRD
# LO.EGRA.CWPM.FLP.3GRD
# LO.EGRA.CWPM.FLF.2GRD
# LO.EGRA.CWPM.HAR.2GRD
# LO.EGRA.CWPM.HAR.3GRD
# LO.EGRA.CWPM.KNY.4GRD
# LO.EGRA.CWPM.KNY.6GRD
# LO.EGRA.CWPM.KIS.2GRD
# LO.EGRA.CWPM.SID.2GRD
# LO.EGRA.CWPM.SID.3GRD
# LO.EGRA.CWPM.SOM.2GRD
# LO.EGRA.CWPM.SOM.3GRD
# LO.EGRA.CWPM.SNG.2GRD
# LO.EGRA.CWPM.SPN.2GRD
# LO.EGRA.CWPM.SPN.3GRD
# LO.EGRA.CWPM.SPN.4GRD
# LO.EGRA.CWPM.TIG.2GRD
# LO.EGRA.CWPM.TIG.3GRD
# LO.EGRA.CLPM.AFA.2GRD
# LO.EGRA.CLPM.AFA.3GRD
# LO.EGRA.CLPM.AMH.2GRD
# LO.EGRA.CLPM.AMH.3GRD
# LO.EGRA.CLPM.BMN.2GRD
# LO.EGRA.CLPM.BOM.2GRD
# LO.EGRA.CLPM.CHC.2GRD
# LO.EGRA.CLPM.CHC.4GRD
# LO.EGRA.CLPM.ENG.2GRD
# LO.EGRA.CLPM.ENG.3GRD
# LO.EGRA.CLPM.ENG.4GRD
# LO.EGRA.CLPM.FRN.3GRD
# LO.EGRA.CLPM.FLF.2GRD
# LO.EGRA.CLPM.HAR.2GRD
# LO.EGRA.CLPM.HAR.3GRD
# LO.EGRA.CLPM.SID.2GRD
# LO.EGRA.CLPM.SID.3GRD
# LO.EGRA.CLPM.SOM.2GRD
# LO.EGRA.CLPM.SOM.3GRD
# LO.EGRA.CLPM.SNG.2GRD
# LO.EGRA.CLPM.SPN.2GRD
# LO.EGRA.CLPM.SPN.3GRD
# LO.EGRA.CLPM.SPN.4GRD
# LO.EGRA.CLPM.TIG.2GRD
# LO.EGRA.CLPM.TIG.3GRD
# LO.EGRA.CLSPM.AKU.2GRD
# LO.EGRA.CLSPM.ARB.2GRD
# LO.EGRA.CLSPM.ARB.3GRD
# LO.EGRA.CLSPM.AST.2GRD
# LO.EGRA.CLSPM.CHI.2GRD
# LO.EGRA.CLSPM.CIN.2GRD
# LO.EGRA.CLSPM.DAG.2GRD
# LO.EGRA.CLSPM.DAGB.2GRD
# LO.EGRA.CLSPM.DAN.2GRD
# LO.EGRA.CLSPM.ENG.2GRD
# LO.EGRA.CLSPM.ENG.3GRD
# LO.EGRA.CLSPM.ENG.4GRD
# LO.EGRA.CLSPM.ENG.6GRD
# LO.EGRA.CLSPM.EWE.2GRD
# LO.EGRA.CLSPM.FAN.2GRD
# LO.EGRA.CLSPM.FLP.3GRD
# LO.EGRA.CLSPM.GA.2GRD
# LO.EGRA.CLSPM.GON.2GRD
# LO.EGRA.CLSPM.ICI.2GRD
# LO.EGRA.CLSPM.IND.2GRD
# LO.EGRA.CLSPM.KAS.2GRD
# LO.EGRA.CLSPM.KII.2GRD
# LO.EGRA.CLSPM.KNY.4GRD
# LO.EGRA.CLSPM.KNY.6GRD
# LO.EGRA.CLSPM.LUN.2GRD
# LO.EGRA.CLSPM.LUV.2GRD
# LO.EGRA.CLSPM.NZE.2GRD
# LO.EGRA.CLSPM.SIL.2GRD
# LO.EGRA.NCWPM.AFA.2GRD
# LO.EGRA.NCWPM.AFA.3GRD
# LO.EGRA.NCWPM.AKU.2GRD
# LO.EGRA.NCWPM.AMH.2GRD
# LO.EGRA.NCWPM.AMH.3GRD
# LO.EGRA.NCWPM.ARB.2GRD
# LO.EGRA.NCWPM.ARB.3GRD
# LO.EGRA.NCWPM.AST.2GRD
# LO.EGRA.NCWPM.BMN.2GRD
# LO.EGRA.NCWPM.BOM.2GRD
# LO.EGRA.NCWPM.CHC.2GRD
# LO.EGRA.NCWPM.CHC.4GRD
# LO.EGRA.NCWPM.CHI.2GRD
# LO.EGRA.NCWPM.CIN.2GRD
# LO.EGRA.NCWPM.DAG.2GRD
# LO.EGRA.NCWPM.DAGB.2GRD
# LO.EGRA.NCWPM.DAN.2GRD
# LO.EGRA.NCWPM.ENG.2GRD
# LO.EGRA.NCWPM.ENG.3GRD
# LO.EGRA.NCWPM.ENG.4GRD
# LO.EGRA.NCWPM.ENG.6GRD
# LO.EGRA.NCWPM.EWE.2GRD
# LO.EGRA.NCWPM.FAN.2GRD
# LO.EGRA.NCWPM.FLP.3GRD
# LO.EGRA.NCWPM.FRN.3GRD
# LO.EGRA.NCWPM.FLF.2GRD
# LO.EGRA.NCWPM.GA.2GRD
# LO.EGRA.NCWPM.GON.2GRD
# LO.EGRA.NCWPM.HAR.2GRD
# LO.EGRA.NCWPM.HAR.3GRD
# LO.EGRA.NCWPM.ICI.2GRD
# LO.EGRA.NCWPM.IND.2GRD
# LO.EGRA.NCWPM.KAS.2GRD
# LO.EGRA.NCWPM.KII.2GRD
# LO.EGRA.NCWPM.KNY.4GRD
# LO.EGRA.NCWPM.KNY.6GRD
# LO.EGRA.NCWPM.KIS.2GRD
# LO.EGRA.NCWPM.LUN.2GRD
# LO.EGRA.NCWPM.LUV.2GRD
# LO.EGRA.NCWPM.NZE.2GRD
# LO.EGRA.NCWPM.SID.2GRD
# LO.EGRA.NCWPM.SID.3GRD
# LO.EGRA.NCWPM.SIL.2GRD
# LO.EGRA.NCWPM.SOM.2GRD
# LO.EGRA.NCWPM.SOM.3GRD
# LO.EGRA.NCWPM.SNG.2GRD
# LO.EGRA.NCWPM.SPN.2GRD
# LO.EGRA.NCWPM.SPN.3GRD
# LO.EGRA.NCWPM.SPN.4GRD
# LO.EGRA.NCWPM.TIG.2GRD
# LO.EGRA.NCWPM.TIG.3GRD
# LO.EGRA.INIT.0.BMN.2GRD
# LO.EGRA.INIT.0.BOM.2GRD
# LO.EGRA.INIT.0.CHC.2GRD
# LO.EGRA.INIT.0.CHC.4GRD
# LO.EGRA.INIT.0.ENG.2GRD
# LO.EGRA.INIT.0.ENG.3GRD
# LO.EGRA.INIT.0.ENG.4GRD
# LO.EGRA.INIT.0.ENG.6GRD
# LO.EGRA.INIT.0.FLF.2GRD
# LO.EGRA.INIT.0.KNY.4GRD
# LO.EGRA.INIT.0.KNY.6GRD
# LO.EGRA.INIT.0.SNG.2GRD
# LO.EGRA.INIT.0.SPN.2GRD
# LO.EGRA.INIT.0.SPN.3GRD
# LO.EGRA.INIT.0.SPN.4GRD
# LO.EGRA.LSTN.0.AFA.2GRD
# LO.EGRA.LSTN.0.AFA.3GRD
# LO.EGRA.LSTN.0.AKU.2GRD
# LO.EGRA.LSTN.0.AMH.2GRD
# LO.EGRA.LSTN.0.AMH.3GRD
# LO.EGRA.LSTN.0.ARB.2GRD
# LO.EGRA.LSTN.0.ARB.3GRD
# LO.EGRA.LSTN.0.AST.2GRD
# LO.EGRA.LSTN.0.BMN.2GRD
# LO.EGRA.LSTN.0.BOM.2GRD
# LO.EGRA.LSTN.0.CHC.2GRD
# LO.EGRA.LSTN.0.CHC.4GRD
# LO.EGRA.LSTN.0.CHI.2GRD
# LO.EGRA.LSTN.0.CIN.2GRD
# LO.EGRA.LSTN.0.DAG.2GRD
# LO.EGRA.LSTN.0.DAGB.2GRD
# LO.EGRA.LSTN.0.DAN.2GRD
# LO.EGRA.LSTN.0.ENG.2GRD
# LO.EGRA.LSTN.0.ENG.3GRD
# LO.EGRA.LSTN.0.ENG.4GRD
# LO.EGRA.LSTN.0.ENG.6GRD
# LO.EGRA.LSTN.0.EWE.2GRD
# LO.EGRA.LSTN.0.FAN.2GRD
# LO.EGRA.LSTN.0.FLP.3GRD
# LO.EGRA.LSTN.0.FLF.2GRD
# LO.EGRA.LSTN.0.GA.2GRD
# LO.EGRA.LSTN.0.GON.2GRD
# LO.EGRA.LSTN.0.HAR.2GRD
# LO.EGRA.LSTN.0.HAR.3GRD
# LO.EGRA.LSTN.0.ICI.2GRD
# LO.EGRA.LSTN.0.IND.2GRD
# LO.EGRA.LSTN.0.KAS.2GRD
# LO.EGRA.LSTN.0.KII.2GRD
# LO.EGRA.LSTN.0.KNY.4GRD
# LO.EGRA.LSTN.0.KNY.6GRD
# LO.EGRA.LSTN.0.KIS.2GRD
# LO.EGRA.LSTN.0.LUN.2GRD
# LO.EGRA.LSTN.0.LUV.2GRD
# LO.EGRA.LSTN.0.NZE.2GRD
# LO.EGRA.LSTN.0.SID.2GRD
# LO.EGRA.LSTN.0.SID.3GRD
# LO.EGRA.LSTN.0.SIL.2GRD
# LO.EGRA.LSTN.0.SOM.2GRD
# LO.EGRA.LSTN.0.SOM.3GRD
# LO.EGRA.LSTN.0.SNG.2GRD
# LO.EGRA.LSTN.0.SPN.2GRD
# LO.EGRA.LSTN.0.SPN.3GRD
# LO.EGRA.LSTN.0.SPN.4GRD
# LO.EGRA.LSTN.0.TIG.2GRD
# LO.EGRA.LSTN.0.TIG.3GRD
# LO.EGRA.ORF.AFA.2GRD
# LO.EGRA.ORF.AFA.3GRD
# LO.EGRA.ORF.AKU.2GRD
# LO.EGRA.ORF.AMH.2GRD
# LO.EGRA.ORF.AMH.3GRD
# LO.EGRA.ORF.ARB.2GRD
# LO.EGRA.ORF.ARB.3GRD
# LO.EGRA.ORF.AST.2GRD
# LO.EGRA.ORF.BMN.2GRD
# LO.EGRA.ORF.BOM.2GRD
# LO.EGRA.ORF.CHC.2GRD
# LO.EGRA.ORF.CHC.4GRD
# LO.EGRA.ORF.CHI.2GRD
# LO.EGRA.ORF.CIN.2GRD
# LO.EGRA.ORF.DAG.2GRD
# LO.EGRA.ORF.DAGB.2GRD
# LO.EGRA.ORF.DAN.2GRD
# LO.EGRA.ORF.ENG.2GRD
# LO.EGRA.ORF.ENG.3GRD
# LO.EGRA.ORF.ENG.4GRD
# LO.EGRA.ORF.ENG.6GRD
# LO.EGRA.ORF.EWE.2GRD
# LO.EGRA.ORF.FAN.2GRD
# LO.EGRA.ORF.FLP.3GRD
# LO.EGRA.ORF.FRN.3GRD
# LO.EGRA.ORF.FLF.2GRD
# LO.EGRA.ORF.GA.2GRD
# LO.EGRA.ORF.GON.2GRD
# LO.EGRA.ORF.HAR.2GRD
# LO.EGRA.ORF.HAR.3GRD
# LO.EGRA.ORF.ICI.2GRD
# LO.EGRA.ORF.IND.2GRD
# LO.EGRA.ORF.KAS.2GRD
# LO.EGRA.ORF.KII.2GRD
# LO.EGRA.ORF.KNY.4GRD
# LO.EGRA.ORF.KNY.6GRD
# LO.EGRA.ORF.KIS.2GRD
# LO.EGRA.ORF.LUN.2GRD
# LO.EGRA.ORF.LUV.2GRD
# LO.EGRA.ORF.NZE.2GRD
# LO.EGRA.ORF.SID.2GRD
# LO.EGRA.ORF.SID.3GRD
# LO.EGRA.ORF.SIL.2GRD
# LO.EGRA.ORF.SOM.2GRD
# LO.EGRA.ORF.SOM.3GRD
# LO.EGRA.ORF.SNG.2GRD
# LO.EGRA.ORF.SPN.2GRD
# LO.EGRA.ORF.SPN.3GRD
# LO.EGRA.ORF.SPN.4GRD
# LO.EGRA.ORF.TIG.2GRD
# LO.EGRA.ORF.TIG.3GRD
# LO.EGRA.CWPM.ZERO.AFA.2GRD
# LO.EGRA.CWPM.ZERO.AFA.3GRD
# LO.EGRA.CWPM.ZERO.AKU.2GRD
# LO.EGRA.CWPM.ZERO.AMH.2GRD
# LO.EGRA.CWPM.ZERO.AMH.3GRD
# LO.EGRA.CWPM.ZERO.ARB.2GRD
# LO.EGRA.CWPM.ZERO.ARB.3GRD
# LO.EGRA.CWPM.ZERO.AST.2GRD
# LO.EGRA.CWPM.ZERO.BMN.2GRD
# LO.EGRA.CWPM.ZERO.BOM.2GRD
# LO.EGRA.CWPM.ZERO.CHC.2GRD
# LO.EGRA.CWPM.ZERO.CHC.4GRD
# LO.EGRA.CWPM.ZERO.CHI.2GRD
# LO.EGRA.CWPM.ZERO.CIN.2GRD
# LO.EGRA.CWPM.ZERO.DAG.2GRD
# LO.EGRA.CWPM.ZERO.DAGB.2GRD
# LO.EGRA.CWPM.ZERO.DAN.2GRD
# LO.EGRA.CWPM.ZERO.ENG.2GRD
# LO.EGRA.CWPM.ZERO.ENG.3GRD
# LO.EGRA.CWPM.ZERO.ENG.4GRD
# LO.EGRA.CWPM.ZERO.ENG.6GRD
# LO.EGRA.CWPM.ZERO.EWE.2GRD
# LO.EGRA.CWPM.ZERO.FAN.2GRD
# LO.EGRA.CWPM.ZERO.FLP.3GRD
# LO.EGRA.CWPM.ZERO.FRN.3GRD
# LO.EGRA.CWPM.ZERO.FLF.2GRD
# LO.EGRA.CWPM.ZERO.GA.2GRD
# LO.EGRA.CWPM.ZERO.GON.2GRD
# LO.EGRA.CWPM.ZERO.HAR.2GRD
# LO.EGRA.CWPM.ZERO.HAR.3GRD
# LO.EGRA.CWPM.ZERO.ICI.2GRD
# LO.EGRA.CWPM.ZERO.IND.2GRD
# LO.EGRA.CWPM.ZERO.KAS.2GRD
# LO.EGRA.CWPM.ZERO.KII.2GRD
# LO.EGRA.CWPM.ZERO.KNY.4GRD
# LO.EGRA.CWPM.ZERO.KNY.6GRD
# LO.EGRA.CWPM.ZERO.KIS.2GRD
# LO.EGRA.CWPM.ZERO.LUN.2GRD
# LO.EGRA.CWPM.ZERO.LUV.2GRD
# LO.EGRA.CWPM.ZERO.NZE.2GRD
# LO.EGRA.CWPM.ZERO.SID.2GRD
# LO.EGRA.CWPM.ZERO.SID.3GRD
# LO.EGRA.CWPM.ZERO.SIL.2GRD
# LO.EGRA.CWPM.ZERO.SOM.2GRD
# LO.EGRA.CWPM.ZERO.SOM.3GRD
# LO.EGRA.CWPM.ZERO.SNG.2GRD
# LO.EGRA.CWPM.ZERO.SPN.2GRD
# LO.EGRA.CWPM.ZERO.SPN.3GRD
# LO.EGRA.CWPM.ZERO.SPN.4GRD
# LO.EGRA.CWPM.ZERO.TIG.2GRD
# LO.EGRA.CWPM.ZERO.TIG.3GRD
# LO.EGRA.READ.AFA.ADV.2GRD
# LO.EGRA.READ.AFA.ADV.3GRD
# LO.EGRA.READ.AKU.ADV.2GRD
# LO.EGRA.READ.AMH.ADV.2GRD
# LO.EGRA.READ.AMH.ADV.3GRD
# LO.EGRA.READ.ARB.ADV.2GRD
# LO.EGRA.READ.ARB.ADV.3GRD
# LO.EGRA.READ.AST.ADV.2GRD
# LO.EGRA.READ.BMN.ADV.2GRD
# LO.EGRA.READ.BOM.ADV.2GRD
# LO.EGRA.READ.CHC.ADV.2GRD
# LO.EGRA.READ.CHC.ADV.4GRD
# LO.EGRA.READ.CHI.ADV.2GRD
# LO.EGRA.READ.CIN.ADV.2GRD
# LO.EGRA.READ.DAG.ADV.2GRD
# LO.EGRA.READ.DAGB.ADV.2GRD
# LO.EGRA.READ.DAN.ADV.2GRD
# LO.EGRA.READ.ENG.ADV.2GRD
# LO.EGRA.READ.ENG.ADV.3GRD
# LO.EGRA.READ.ENG.ADV.4GRD
# LO.EGRA.READ.ENG.ADV.6GRD
# LO.EGRA.READ.EWE.ADV.2GRD
# LO.EGRA.READ.FAN.ADV.2GRD
# LO.EGRA.READ.FLP.ADV.3GRD
# LO.EGRA.READ.FRN.ADV.3GRD
# LO.EGRA.READ.FLF.ADV.2GRD
# LO.EGRA.READ.GA.ADV.2GRD
# LO.EGRA.READ.GON.ADV.2GRD
# LO.EGRA.READ.HAR.ADV.2GRD
# LO.EGRA.READ.HAR.ADV.3GRD
# LO.EGRA.READ.ICI.ADV.2GRD
# LO.EGRA.READ.IND.ADV.3GRD
# LO.EGRA.READ.KAS.ADV.2GRD
# LO.EGRA.READ.KII.ADV.2GRD
# LO.EGRA.READ.KNY.ADV.4GRD
# LO.EGRA.READ.KNY.ADV.6GRD
# LO.EGRA.READ.KIS.ADV.2GRD
# LO.EGRA.READ.LUN.ADV.2GRD
# LO.EGRA.READ.LUV.ADV.2GRD
# LO.EGRA.READ.NZE.ADV.2GRD
# LO.EGRA.READ.SID.ADV.2GRD
# LO.EGRA.READ.SID.ADV.3GRD
# LO.EGRA.READ.SIL.ADV.2GRD
# LO.EGRA.READ.SOM.ADV.2GRD
# LO.EGRA.READ.SOM.ADV.3GRD
# LO.EGRA.READ.SNG.ADV.2GRD
# LO.EGRA.READ.SPN.ADV.2GRD
# LO.EGRA.READ.SPN.ADV.3GRD
# LO.EGRA.READ.SPN.ADV.4GRD
# LO.EGRA.READ.TIG.ADV.2GRD
# LO.EGRA.READ.TIG.ADV.3GRD
# LO.EGRA.READ.0.AFA.2GRD
# LO.EGRA.READ.0.AFA.3GRD
# LO.EGRA.READ.0.AKU.2GRD
# LO.EGRA.READ.0.AMH.2GRD
# LO.EGRA.READ.0.AMH.3GRD
# LO.EGRA.READ.0.ARB.2GRD
# LO.EGRA.READ.0.ARB.3GRD
# LO.EGRA.READ.0.AST.2GRD
# LO.EGRA.READ.0.BMN.2GRD
# LO.EGRA.READ.0.BOM.2GRD
# LO.EGRA.READ.0.CHC.2GRD
# LO.EGRA.READ.0.CHC.4GRD
# LO.EGRA.READ.0.CHI.2GRD
# LO.EGRA.READ.0.CIN.2GRD
# LO.EGRA.READ.0.DAG.2GRD
# LO.EGRA.READ.0.DAGB.2GRD
# LO.EGRA.READ.0.DAN.2GRD
# LO.EGRA.READ.0.ENG.2GRD
# LO.EGRA.READ.0.ENG.3GRD
# LO.EGRA.READ.0.ENG.4GRD
# LO.EGRA.READ.0.ENG.6GRD
# LO.EGRA.READ.0.EWE.2GRD
# LO.EGRA.READ.0.FAN.2GRD
# LO.EGRA.READ.0.FLP.3GRD
# LO.EGRA.READ.0.FRN.3GRD
# LO.EGRA.READ.0.FLF.2GRD
# LO.EGRA.READ.0.GA.2GRD
# LO.EGRA.READ.0.GON.2GRD
# LO.EGRA.READ.0.HAR.2GRD
# LO.EGRA.READ.0.HAR.3GRD
# LO.EGRA.READ.0.ICI.2GRD
# LO.EGRA.READ.0.IND.2GRD
# LO.EGRA.READ.0.KAS.2GRD
# LO.EGRA.READ.0.KII.2GRD
# LO.EGRA.READ.0.KNY.4GRD
# LO.EGRA.READ.0.KNY.6GRD
# LO.EGRA.READ.0.KIS.2GRD
# LO.EGRA.READ.0.LUN.2GRD
# LO.EGRA.READ.0.LUV.2GRD
# LO.EGRA.READ.0.NZE.2GRD
# LO.EGRA.READ.0.SID.2GRD
# LO.EGRA.READ.0.SID.3GRD
# LO.EGRA.READ.0.SIL.2GRD
# LO.EGRA.READ.0.SOM.2GRD
# LO.EGRA.READ.0.SOM.3GRD
# LO.EGRA.READ.0.SNG.2GRD
# LO.EGRA.READ.0.SPN.2GRD
# LO.EGRA.READ.0.SPN.3GRD
# LO.EGRA.READ.0.SPN.4GRD
# LO.EGRA.READ.0.TIG.2GRD
# LO.EGRA.READ.0.TIG.3GRD
# UIS.LPP.AG65
# UIS.LP.AG65
# UIS.LP.AG65.F
# UIS.LP.AG65.M
# UIS.LR.AG65
# UIS.LR.AG65.F
# UIS.LR.AG65.GPI
# UIS.LR.AG65.M
# UIS.E.0.T
# UIS.E.0.F
# UIS.E.0.PR.T
# UIS.E.0.PR.F
# UIS.E.0.PU.T
# UIS.E.0.PU.F
# UIS.E.01.T
# UIS.E.01.F
# UIS.E.01.PR.T
# UIS.E.01.PR.F
# UIS.E.01.PU.T
# UIS.E.01.PU.F
# UIS.E.2.GPV.G1.T
# UIS.E.2.GPV.G1.F
# UIS.E.1.G1
# UIS.E.1.G1.F
# UIS.E.2.GPV.G2.T
# UIS.E.2.GPV.G2.F
# UIS.E.1.G2
# UIS.E.1.G2.F
# UIS.E.2.GPV.G3.T
# UIS.E.2.GPV.G3.F
# UIS.E.1.G3
# UIS.E.1.G3.F
# UIS.E.2.GPV.G4.T
# UIS.E.2.GPV.G4.F
# UIS.E.1.G4
# UIS.E.1.G4.F
# UIS.E.2.GPV.G5.T
# UIS.E.2.GPV.G5.F
# UIS.E.1.G5
# UIS.E.1.G5.F
# UIS.E.2.GPV.G6.T
# UIS.E.2.GPV.G6.F
# UIS.E.1.G6
# UIS.E.1.G6.F
# UIS.E.1.G7
# UIS.E.1.G7.F
# UIS.E.2
# UIS.E.2.F
# UIS.E.2.PR
# UIS.E.2.PR.F
# UIS.E.2.PU
# UIS.E.2.PU.F
# UIS.E.2.GPV.GUK.T
# UIS.E.2.GPV.GUK.F
# UIS.E.2.GPV
# UIS.E.2.GPV.F
# UIS.E.2.V
# UIS.E.2.V.F
# UIS.E.4
# UIS.E.4.F
# UIS.E.4.PR
# UIS.E.4.PR.F
# UIS.E.4.PU
# UIS.E.4.PU.F
# SE.PRE.ENRL
# SE.PRE.ENRL.FE
# UIS.E.02.PR
# UIS.E.02.PR.F
# UIS.E.02.PU
# UIS.E.02.PU.F
# SE.PRM.ENRL
# SE.PRM.ENRL.FE
# UIS.E.1.GUK
# UIS.E.1.GUK.F
# UIS.E.1.PR
# UIS.E.1.PR.F
# UIS.E.1.PU
# UIS.E.1.PU.F
# SE.SEC.ENRL
# SE.SEC.ENRL.FE
# UIS.E.23.PR
# UIS.E.23.PR.F
# UIS.E.23.PU
# UIS.E.23.PU.F
# SE.SEC.ENRL.GC
# SE.SEC.ENRL.GC.FE
# SE.SEC.ENRL.VO
# SE.SEC.ENRL.VO.FE
# UIS.TE_100000.56
# UIS.TE_100000.56.F
# UIS.TE_100000.56.M
# SE.TER.ENRL
# SE.TER.ENRL.FE
# UIS.E.5.B
# UIS.E.5.B.F
# UIS.E.6
# UIS.E.6.F
# UIS.E.7
# UIS.E.7.F
# UIS.E.8
# UIS.E.8.F
# UIS.E.3
# UIS.E.3.F
# UIS.E.3.PR
# UIS.E.3.PR.F
# UIS.E.3.PU
# UIS.E.3.PU.F
# UIS.E.3.GPV
# UIS.E.3.GPV.F
# UIS.E.3.V
# UIS.E.3.V.F
# SE.XPD.TOTL.GB.ZS
# UIS.XPUBP.UK
# UIS.XPUBP.2
# UIS.XGOVEXP.IMF.2
# UIS.XPUBP.4
# UIS.XGOVEXP.IMF.4
# UIS.XPUBP.0
# UIS.XGOVEXP.IMF.0
# SE.XPD.PRIM.ZS
# UIS.XGOVEXP.IMF.1
# UIS.XPUBP.2T4.V
# UIS.XGOVEXP.IMF.2T4.V
# SE.XPD.SECO.ZS
# UIS.XGOVEXP.IMF.23
# SE.XPD.TERT.ZS
# UIS.XGOVEXP.IMF.56
# UIS.XPUBP.3
# UIS.XGOVEXP.IMF.3
# NY.GDP.MKTP.KD
# NY.GDP.MKTP.CD
# NY.GDP.PCAP.KD
# NY.GDP.PCAP.CD
# NY.GDP.PCAP.PP.KD
# NY.GDP.PCAP.PP.CD
# NY.GDP.MKTP.PP.KD
# NY.GDP.MKTP.PP.CD
# NY.GNP.MKTP.CD
# NY.GNP.PCAP.CD
# NY.GNP.PCAP.PP.CD
# NY.GNP.MKTP.PP.CD
# UIS.XGDP.FSGOV.FDINSTADM.FFD
# UIS.XGDP.4.FSGOV.FDINSTADM.FFD
# UIS.XGDP.0.FSGOV.FDINSTADM.FFD
# UIS.XGDP.1.FSGOV.FDINSTADM.FFD
# XGDP.23.FSGOV.FDINSTADM.FFD
# XGDP.56.FSGOV.FDINSTADM.FFD
# SE.XPD.TOTL.GD.ZS
# UIS.XGDP.4.FSGOV
# UIS.XGDP.0.FSGOV
# UIS.XGDP.1.FSGOV
# UIS.XGDP.2T4.V.FSGOV
# UIS.XGDP.23.FSGOV
# UIS.XGDP.56.FSGOV
# UIS.XUNIT.PPPCONST.2.FSGOV
# UIS.XUNIT.USCONST.2.FSGOV
# UIS.XUNIT.PPP.2.FSGOV
# UIS.XUNIT.US.2.FSGOV
# UIS.XUNIT.GDPCAP.2.FSGOV
# UIS.XUNIT.PPPCONST.4.FSGOV
# UIS.XUNIT.USCONST.4.FSGOV
# UIS.XUNIT.PPP.4.FSGOV
# UIS.XUNIT.US.4.FSGOV
# UIS.XUNIT.GDPCAP.4.FSGOV
# UIS.XUNIT.PPPCONST.1.FSGOV
# UIS.XUNIT.USCONST.1.FSGOV
# UIS.XUNIT.PPP.1.FSGOV
# UIS.XUNIT.US.1.FSGOV
# SE.XPD.PRIM.PC.ZS
# UIS.XUNIT.PPPCONST.23.FSGOV
# UIS.XUNIT.USCONST.23.FSGOV
# UIS.XUNIT.PPP.23.FSGOV
# UIS.XUNIT.US.23.FSGOV
# SE.XPD.SECO.PC.ZS
# UIS.XUNIT.PPPCONST.56.FSGOV
# UIS.XUNIT.USCONST.56.FSGOV
# UIS.XUNIT.PPP.56.FSGOV
# UIS.XUNIT.US.56.FSGOV
# SE.XPD.TERT.PC.ZS
# UIS.XUNIT.PPPCONST.3.FSGOV
# UIS.XUNIT.USCONST.3.FSGOV
# UIS.XUNIT.PPP.3.FSGOV
# UIS.XUNIT.US.3.FSGOV
# UIS.XUNIT.GDPCAP.3.FSGOV
# UIS.G.5.B.T
# UIS.G.5.B.F
# UIS.G.6.T
# UIS.G.6.F
# UIS.G.7.T
# UIS.G.7.F
# UIS.G.8.T
# UIS.G.8.F
# SE.TER.GRAD
# SE.TER.GRAD.FE
# SE.SEC.ENRR.LO
# SE.SEC.ENRR.LO.FE
# UIS.GER.2.GPI
# SE.SEC.ENRR.LO.MA
# UIS.GER.4
# UIS.GER.4.F
# UIS.GER.4.GPI
# UIS.GER.4.M
# SE.PRE.ENRR
# SE.PRE.ENRR.FE
# UIS.GER.0.GPI
# SE.PRE.ENRR.MA
# UIS.GER.12
# UIS.GER.12.F
# UIS.GER.12.GPI
# UIS.GER.12.M
# UIS.GER.123
# UIS.GER.123.F
# SE.ENR.PRSC.FM.ZS
# UIS.GER.123.M
# SE.TOT.ENRR
# UIS.GER.1T6.F
# UIS.GER.1T6.GPI
# UIS.GER.1T6.M
# SE.PRM.ENRR
# SE.PRM.ENRR.FE
# SE.ENR.PRIM.FM.ZS
# SE.PRM.ENRR.MA
# SE.SEC.ENRR
# SE.SEC.ENRR.FE
# SE.ENR.SECO.FM.ZS
# SE.SEC.ENRR.MA
# SE.TER.ENRR
# SE.TER.ENRR.FE
# SE.ENR.TERT.FM.ZS
# SE.TER.ENRR.MA
# SE.SEC.ENRR.UP
# SE.SEC.ENRR.UP.FE
# UIS.GER.3.GPI
# SE.SEC.ENRR.UP.MA
# SE.TER.CMPL.ZS
# SE.TER.CMPL.FE.ZS
# UIS.GGR.5.A.GPI
# SE.TER.CMPL.MA.ZS
# UIS.GGR.2
# UIS.GGR.2.F
# UIS.GGR.2.GPI
# UIS.GGR.2.M
# SE.PRM.CMPL.ZS
# SE.PRM.CMPL.FE.ZS
# UIS.GGR.1.GPI
# SE.PRM.CMPL.MA.ZS
# UIS.AIR.2.GPV
# UIS.AIR.2.GPV.F
# UIS.AIR.2.GPV.GPI
# UIS.AIR.2.GPV.M
# SE.PRM.GINT.ZS
# SE.PRM.GINT.FE.ZS
# UIS.AIR.1.GPI
# SE.PRM.GINT.MA.ZS
# UIS.GOER.56
# UIS.ILLPOPF.AG25T64
# UIS.ILLPOP.AG25T64
# UIS.ILLPOP.AG25T64.F
# UIS.ILLPOP.AG25T64.M
# UIS.MSEP.56
# UIS.MSEP.56.F
# UIS.MSEP.56.M
# IT.NET.USER.P2
# SL.TLF.ADVN.ZS
# SL.TLF.ADVN.FE.ZS
# SL.TLF.ADVN.MA.ZS
# SL.TLF.BASC.ZS
# SL.TLF.BASC.FE.ZS
# SL.TLF.BASC.MA.ZS
# SL.TLF.INTM.ZS
# SL.TLF.INTM.FE.ZS
# SL.TLF.INTM.MA.ZS
# SL.TLF.TOTL.FE.ZS
# SL.TLF.TOTL.IN
# UIS.LR.AG25T64
# UIS.LR.AG25T64.F
# UIS.LR.AG25T64.GPI
# UIS.LR.AG25T64.M
# LO.LLECE.MAT3.0
# LO.LLECE.MAT3.1
# LO.LLECE.MAT3.2
# LO.LLECE.MAT3.3
# LO.LLECE.MAT3.4
# LO.LLECE.REA3.0
# LO.LLECE.REA3.1
# LO.LLECE.REA3.2
# LO.LLECE.REA3.3
# LO.LLECE.REA3.4
# LO.LLECE.MAT6.0
# LO.LLECE.MAT6.1
# LO.LLECE.MAT6.2
# LO.LLECE.MAT6.3
# LO.LLECE.MAT6.4
# LO.LLECE.REA6.0
# LO.LLECE.REA6.1
# LO.LLECE.REA6.2
# LO.LLECE.REA6.3
# LO.LLECE.REA6.4
# LO.LLECE.SCI6.0
# LO.LLECE.SCI6.1
# LO.LLECE.SCI6.2
# LO.LLECE.SCI6.3
# LO.LLECE.SCI6.4
# LO.LLECE.MAT3.P10
# LO.LLECE.MAT3.P25
# LO.LLECE.MAT3.P50
# LO.LLECE.MAT3.P75
# LO.LLECE.MAT3.P90
# LO.LLECE.REA3.P10
# LO.LLECE.REA3.P25
# LO.LLECE.REA3.P50
# LO.LLECE.REA3.P75
# LO.LLECE.REA3.P90
# LO.LLECE.MAT4.P10
# LO.LLECE.MAT4.P25
# LO.LLECE.MAT4.P50
# LO.LLECE.MAT4.P75
# LO.LLECE.MAT4.P90
# LO.LLECE.REA4.P10
# LO.LLECE.REA4.P25
# LO.LLECE.REA4.P50
# LO.LLECE.REA4.P75
# LO.LLECE.REA4.P90
# LO.LLECE.MAT6.P10
# LO.LLECE.MAT6.P25
# LO.LLECE.MAT6.P50
# LO.LLECE.MAT6.P75
# LO.LLECE.MAT6.P90
# LO.LLECE.REA6.P10
# LO.LLECE.REA6.P25
# LO.LLECE.REA6.P50
# LO.LLECE.REA6.P75
# LO.LLECE.REA6.P90
# LO.LLECE.SCI6.P10
# LO.LLECE.SCI6.P25
# LO.LLECE.SCI6.P50
# LO.LLECE.SCI6.P75
# LO.LLECE.SCI6.P90
# LO.LLECE.MAT3.0.FE
# LO.LLECE.MAT3.1.FE
# LO.LLECE.MAT3.2.FE
# LO.LLECE.MAT3.3.FE
# LO.LLECE.MAT3.4.FE
# LO.LLECE.REA3.0.FE
# LO.LLECE.REA3.1.FE
# LO.LLECE.REA3.2.FE
# LO.LLECE.REA3.3.FE
# LO.LLECE.REA3.4.FE
# LO.LLECE.MAT6.0.FE
# LO.LLECE.MAT6.1.FE
# LO.LLECE.MAT6.2.FE
# LO.LLECE.MAT6.3.FE
# LO.LLECE.MAT6.4.FE
# LO.LLECE.REA6.0.FE
# LO.LLECE.REA6.1.FE
# LO.LLECE.REA6.2.FE
# LO.LLECE.REA6.3.FE
# LO.LLECE.REA6.4.FE
# LO.LLECE.SCI6.0.FE
# LO.LLECE.SCI6.1.FE
# LO.LLECE.SCI6.2.FE
# LO.LLECE.SCI6.3.FE
# LO.LLECE.SCI6.4.FE
# LO.LLECE.MAT3.0.MA
# LO.LLECE.MAT3.1.MA
# LO.LLECE.MAT3.2.MA
# LO.LLECE.MAT3.3.MA
# LO.LLECE.MAT3.4.MA
# LO.LLECE.REA3.0.MA
# LO.LLECE.REA3.1.MA
# LO.LLECE.REA3.2.MA
# LO.LLECE.REA3.3.MA
# LO.LLECE.REA3.4.MA
# LO.LLECE.MAT6.0.MA
# LO.LLECE.MAT6.1.MA
# LO.LLECE.MAT6.2.MA
# LO.LLECE.MAT6.3.MA
# LO.LLECE.MAT6.4.MA
# LO.LLECE.REA6.0.MA
# LO.LLECE.REA6.1.MA
# LO.LLECE.REA6.2.MA
# LO.LLECE.REA6.3.MA
# LO.LLECE.REA6.4.MA
# LO.LLECE.SCI6.0.MA
# LO.LLECE.SCI6.1.MA
# LO.LLECE.SCI6.2.MA
# LO.LLECE.SCI6.3.MA
# LO.LLECE.SCI6.4.MA
# LO.LLECE.MAT3.FE
# LO.LLECE.MAT3.MA
# LO.LLECE.MAT3
# LO.LLECE.MAT4
# LO.LLECE.MAT6.FE
# LO.LLECE.MAT6.MA
# LO.LLECE.MAT6
# LO.LLECE.REA3.FE
# LO.LLECE.REA3.MA
# LO.LLECE.REA3
# LO.LLECE.REA4
# LO.LLECE.REA6.FE
# LO.LLECE.REA6.MA
# LO.LLECE.REA6
# LO.LLECE.SCI6.FE
# LO.LLECE.SCI6.MA
# LO.LLECE.SCI6
# SE.SEC.CMPT.LO.ZS
# SE.SEC.CMPT.LO.FE.ZS
# UIS.AIR.2.GPV.GLAST.GPI
# SE.SEC.CMPT.LO.MA.ZS
# HH.MICS.YRS.1519
# HH.MICS.YRS.1519.F
# HH.MICS.YRS.1519.M
# HH.MICS.YRS.1519.Q1
# HH.MICS.YRS.1519.Q2
# HH.MICS.YRS.1519.Q3
# HH.MICS.YRS.1519.Q4
# HH.MICS.YRS.1519.Q5
# HH.MICS.YRS.1519.R
# HH.MICS.YRS.1519.U
# HH.MICS.YRS.15UP.GIN
# HH.MICS.YRS.15UP.GIN.F
# HH.MICS.YRS.15UP.GIN.M
# HH.MICS.YRS.15UP.GIN.Q1
# HH.MICS.YRS.15UP.GIN.Q2
# HH.MICS.YRS.15UP.GIN.Q3
# HH.MICS.YRS.15UP.GIN.Q4
# HH.MICS.YRS.15UP.GIN.Q5
# HH.MICS.YRS.15UP.GIN.R
# HH.MICS.YRS.15UP.GIN.U
# HH.MICS.GAR.456
# HH.MICS.GAR.456.F
# HH.MICS.GAR.456.M
# HH.MICS.GAR.456.Q1
# HH.MICS.GAR.456.Q2
# HH.MICS.GAR.456.Q3
# HH.MICS.GAR.456.Q4
# HH.MICS.GAR.456.Q5
# HH.MICS.GAR.456.R
# HH.MICS.GAR.456.U
# HH.MICS.NAR.1
# HH.MICS.NAR.1.F
# HH.MICS.NAR.1.M
# HH.MICS.NAR.1.Q1
# HH.MICS.NAR.1.Q2
# HH.MICS.NAR.1.Q3
# HH.MICS.NAR.1.Q4
# HH.MICS.NAR.1.Q5
# HH.MICS.NAR.1.R
# HH.MICS.NAR.1.U
# HH.MICS.NAR.23
# HH.MICS.NAR.23.F
# HH.MICS.NAR.23.M
# HH.MICS.NAR.23.Q1
# HH.MICS.NAR.23.Q2
# HH.MICS.NAR.23.Q3
# HH.MICS.NAR.23.Q4
# HH.MICS.NAR.23.Q5
# HH.MICS.NAR.23.R
# HH.MICS.NAR.23.U
# HH.MICS.PCR
# HH.MICS.PCR.F
# HH.MICS.PCR.M
# HH.MICS.PCR.Q1
# HH.MICS.PCR.Q2
# HH.MICS.PCR.Q3
# HH.MICS.PCR.Q4
# HH.MICS.PCR.Q5
# HH.MICS.PCR.R
# HH.MICS.PCR.U
# HH.MICS.OOS.1
# HH.MICS.OOS.1.F
# HH.MICS.OOS.1.M
# HH.MICS.OOS.1.Q1
# HH.MICS.OOS.1.Q2
# HH.MICS.OOS.1.Q3
# HH.MICS.OOS.1.Q4
# HH.MICS.OOS.1.Q5
# HH.MICS.OOS.1.R
# HH.MICS.OOS.1.U
# HH.MICS.SCR
# HH.MICS.SCR.F
# HH.MICS.SCR.M
# HH.MICS.SCR.Q1
# HH.MICS.SCR.Q2
# HH.MICS.SCR.Q3
# HH.MICS.SCR.Q4
# HH.MICS.SCR.Q5
# HH.MICS.SCR.R
# HH.MICS.SCR.U
# HH.MICS.TR.12
# HH.MICS.TR.12.F
# HH.MICS.TR.12.M
# HH.MICS.TR.12.Q1
# HH.MICS.TR.12.Q2
# HH.MICS.TR.12.Q3
# HH.MICS.TR.12.Q4
# HH.MICS.TR.12.Q5
# HH.MICS.TR.12.R
# HH.MICS.TR.12.U
# HH.MICS.OOST.DO
# HH.MICS.OOST.DO.F
# HH.MICS.OOST.DO.M
# HH.MICS.OOST.DO.Q1
# HH.MICS.OOST.DO.Q2
# HH.MICS.OOST.DO.Q3
# HH.MICS.OOST.DO.Q4
# HH.MICS.OOST.DO.Q5
# HH.MICS.OOST.DO.R
# HH.MICS.OOST.DO.U
# HH.MICS.OOST.L
# HH.MICS.OOST.L.F
# HH.MICS.OOST.L.M
# HH.MICS.OOST.L.Q1
# HH.MICS.OOST.L.Q2
# HH.MICS.OOST.L.Q3
# HH.MICS.OOST.L.Q4
# HH.MICS.OOST.L.Q5
# HH.MICS.OOST.L.R
# HH.MICS.OOST.L.U
# HH.MICS.OOST.X
# HH.MICS.OOST.X.F
# HH.MICS.OOST.X.M
# HH.MICS.OOST.X.Q1
# HH.MICS.OOST.X.Q2
# HH.MICS.OOST.X.Q3
# HH.MICS.OOST.X.Q4
# HH.MICS.OOST.X.Q5
# HH.MICS.OOST.X.R
# HH.MICS.OOST.X.U
# SH.DYN.MORT
# UIS.NER.2
# UIS.NER.2.F
# UIS.NER.2.M
# SE.PRE.NENR
# SE.PRE.NENR.FE
# UIS.NER.0.GPI
# SE.PRE.NENR.MA
# SE.PRM.NENR
# SE.PRM.NENR.FE
# UIS.NER.1.GPI
# SE.PRM.NENR.MA
# SE.SEC.NENR
# SE.SEC.NENR.FE
# UIS.NER.23.GPI
# SE.SEC.NENR.MA
# UIS.NER.3
# UIS.NER.3.F
# UIS.NER.3.M
# UIS.MENF.56
# UIS.MENFR.56
# UIS.NIR.1.AGP1
# UIS.NIR.1.AGP1.F
# UIS.NIR.1.AGP1.GPI
# UIS.NIR.1.AGP1.M
# UIS.NIR.1.AGM1
# UIS.NIR.1.AGM1.F
# UIS.NIR.1.AGM1.GPI
# UIS.NIR.1.AGM1.M
# SE.PRM.NINT.ZS
# SE.PRM.NINT.FE.ZS
# UIS.NIR.1.GPI
# SE.PRM.NINT.MA.ZS
# UIS.NE.1.ECD
# UIS.NE.1.ECD.F
# UIS.NE.1.G1
# UIS.NE.1.G1.F
# UIS.FNP.1
# UIS.CEAGE.1
# SE.SEC.AGES
# UIS.THAGE.4.A.GPV
# UIS.THAGE.0
# SE.PRM.AGES
# UIS.THAGE.3.A.GPV
# UIS.OMR.56
# UIS.OFST.2
# UIS.OFST.2.F
# UIS.OFST.2.M
# UIS.FOFSTP.2
# UIS.OFSPPT.1
# UIS.OFSPPT.1.F
# UIS.OFSPPT.1.M
# SE.PRM.UNER
# SE.PRM.UNER.FE
# SE.PRM.UNER.MA
# UIS.FOFSTP.1
# UIS.OFST.3.CP
# UIS.OFST.3.F.CP
# UIS.OFST.3.M.CP
# UIS.FOFSTP.3
# UIS.OAPP.1
# UIS.OAPP.1.F
# UIS.OAPP.1.M
# LO.PASEC.REA.2.L0
# LO.PASEC.REA.2.L1
# LO.PASEC.REA.2.L2
# LO.PASEC.REA.2.L3
# LO.PASEC.REA.2.L4
# LO.PASEC.MAT.2.L0
# LO.PASEC.MAT.2.L1
# LO.PASEC.MAT.2.L2
# LO.PASEC.MAT.2.L3
# LO.PASEC.FRE5.HIG.FE
# LO.PASEC.FRE5.HIG.MA
# LO.PASEC.FRE5.HIG
# LO.PASEC.MAT5.HIG.FE
# LO.PASEC.MAT5.HIG.MA
# LO.PASEC.MAT5.HIG
# LO.PASEC.FRE5.LO.FE
# LO.PASEC.FRE5.LO.MA
# LO.PASEC.FRE5.LO
# LO.PASEC.MAT5.LO.FE
# LO.PASEC.MAT5.LO.MA
# LO.PASEC.MAT5.LO
# LO.PASEC.MAT.6.L0
# LO.PASEC.MAT.6.L1
# LO.PASEC.MAT.6.L2
# LO.PASEC.MAT.6.L3
# LO.PASEC.REA.6.L0
# LO.PASEC.REA.6.L1
# LO.PASEC.REA.6.L2
# LO.PASEC.REA.6.L3
# LO.PASEC.REA.6.L4
# LO.PASEC.REA.2.MG.GAP
# LO.PASEC.MAT.2.MG.GAP
# LO.PASEC.REA.2.PRI.GAP
# LO.PASEC.MAT.2.PRI.GAP
# LO.PASEC.REA.2.RU.GAP
# LO.PASEC.MAT.2.RU.GAP
# LO.PASEC.REA.2.PP.GAP
# LO.PASEC.MAT.2.PP.GAP
# LO.PASEC.MAT.6.MG.GAP
# LO.PASEC.REA.6.MG.GAP
# LO.PASEC.MAT.6.PRI.GAP
# LO.PASEC.REA.6.PRI.GAP
# LO.PASEC.MAT.6.RU.GAP
# LO.PASEC.REA.6.RU.GAP
# LO.PASEC.MAT.6.PP.GAP
# LO.PASEC.REA.6.PP.GAP
# LO.PASEC.REA.2.P10
# LO.PASEC.REA.2.P1
# LO.PASEC.REA.2.P25
# LO.PASEC.REA.2.P50
# LO.PASEC.REA.2.P05
# LO.PASEC.REA.2.P75
# LO.PASEC.REA.2.P90
# LO.PASEC.REA.2.P95
# LO.PASEC.REA.2.P99
# LO.PASEC.MAT.2.P10
# LO.PASEC.MAT.2.P1
# LO.PASEC.MAT.2.P25
# LO.PASEC.MAT.2.P50
# LO.PASEC.MAT.2.P05
# LO.PASEC.MAT.2.P75
# LO.PASEC.MAT.2.P90
# LO.PASEC.MAT.2.P95
# LO.PASEC.MAT.2.P99
# LO.PASEC.REA.2.LTR.0T5
# LO.PASEC.REA.2.LTR.11T20
# LO.PASEC.REA.2.LTR.20UP
# LO.PASEC.REA.2.LTR.6T10
# LO.PASEC.REA.2.WRD.0
# LO.PASEC.REA.2.WRD.1T5
# LO.PASEC.REA.2.WRD.11T20
# LO.PASEC.REA.2.WRD.20UP
# LO.PASEC.REA.2.WRD.6T10
# LO.PASEC.MAT.2.CNT.0T60
# LO.PASEC.MAT.2.CNT.61T80
# LO.PASEC.MAT.2.CNT.80UP
# LO.PASEC.FRE.P10
# LO.PASEC.FRE.P25
# LO.PASEC.FRE.P50
# LO.PASEC.FRE.P05
# LO.PASEC.FRE.P75
# LO.PASEC.FRE.P90
# LO.PASEC.FRE.P95
# LO.PASEC.MAT.P10
# LO.PASEC.MAT.P25
# LO.PASEC.MAT.P50
# LO.PASEC.MAT.P05
# LO.PASEC.MAT.P75
# LO.PASEC.MAT.P90
# LO.PASEC.MAT.P95
# LO.PASEC.MAT.6.P10
# LO.PASEC.MAT.6.P1
# LO.PASEC.MAT.6.P25
# LO.PASEC.MAT.6.P50
# LO.PASEC.MAT.6.P05
# LO.PASEC.MAT.6.P75
# LO.PASEC.MAT.6.P90
# LO.PASEC.MAT.6.P95
# LO.PASEC.MAT.6.P99
# LO.PASEC.REA.6.P10
# LO.PASEC.REA.6.P1
# LO.PASEC.REA.6.P25
# LO.PASEC.REA.6.P50
# LO.PASEC.REA.6.P05
# LO.PASEC.REA.6.P75
# LO.PASEC.REA.6.P90
# LO.PASEC.REA.6.P95
# LO.PASEC.REA.6.P99
# LO.PASEC.FRE5.FE
# LO.PASEC.FRE5.MA
# LO.PASEC.FRE5
# LO.PASEC.REA.2.PP
# LO.PASEC.REA.2.NPP
# LO.PASEC.REA.2.FE
# LO.PASEC.REA.2.MA
# LO.PASEC.REA.2
# LO.PASEC.MAT5.FE
# LO.PASEC.MAT5.MA
# LO.PASEC.MAT5
# LO.PASEC.MAT.2.PP
# LO.PASEC.MAT.2.NPP
# LO.PASEC.MAT.2.FE
# LO.PASEC.MAT.2.MA
# LO.PASEC.MAT.2
# LO.PASEC.MAT.6.PP
# LO.PASEC.MAT.6.NPP
# LO.PASEC.MAT.6.FE
# LO.PASEC.MAT.6.MA
# LO.PASEC.MAT.6
# LO.PASEC.REA.6.PP
# LO.PASEC.REA.6.NPP
# LO.PASEC.REA.6.FE
# LO.PASEC.REA.6.MA
# LO.PASEC.REA.6
# LO.PASEC.MAT.2.ADD2
# LO.PASEC.MAT.2.ADD3
# LO.PASEC.MAT.2.ADD1
# LO.PASEC.MAT.2.SUB1
# LO.PASEC.MAT.2.SUB2
# LO.PASEC.MAT.2.SUB3
# UIS.FEP.56.FOREIGN
# UIS.TEP.5.B
# UIS.TEP.6
# UIS.TEP.7
# UIS.TEP.8
# UIS.PRP.0
# UIS.PRP.01
# UIS.PRP.2
# UIS.PRP.4
# SE.PRE.PRIV.ZS
# SE.PRM.PRIV.ZS
# SE.SEC.PRIV.ZS
# SE.TER.PRIV.ZS
# UIS.PRP.3
# SE.TER.GRAD.AG.FE.ZS
# SE.TER.GRAD.ED.FE.ZS
# SE.TER.GRAD.EN.FE.ZS
# SE.TER.GRAD.HL.FE.ZS
# SE.TER.GRAD.HU.FE.ZS
# SE.TER.GRAD.OT.FE.ZS
# SE.TER.GRAD.SC.FE.ZS
# SE.TER.GRAD.SV.FE.ZS
# SE.TER.GRAD.SS.FE.ZS
# UIS.OAEP.1.F
# UIS.UAEP.1.F
# UIS.GTVP.2.GPV.F
# UIS.GTVP.2.V.F
# UIS.GTVP.4.GPV.F
# UIS.GTVP.4.V.F
# UIS.GTVP.23.GPV.F
# SE.SEC.ENRL.FE.VO.ZS
# UIS.FOSEP.56.F600.F
# UIS.FOSEP.56.F140.F
# UIS.FOSEP.56.F500.F
# UIS.FOSEP.56.F700.F
# UIS.FOSEP.56.F200.F
# UIS.TEP.5.B.F
# UIS.TEP.6.F
# UIS.TEP.7.F
# UIS.TEP.8.F
# UIS.FOSEP.56.FUK.F
# UIS.FOSEP.56.F400.F
# UIS.FOSEP.56.F800.F
# UIS.FOSEP.56.F300.F
# UIS.GTVP.3.GPV.F
# UIS.GTVP.3.V.F
# UIS.TRTP.2.F
# UIS.TRTP.4.F
# UIS.TRTP.0.F
# SE.PRM.TCAQ.FE.ZS
# SE.SEC.TCAQ.FE.ZS
# UIS.TRTP.3.F
# SE.TER.GRAD.FE.AG.ZS
# SE.TER.GRAD.FE.ED.ZS
# SE.TER.GRAD.FE.EN.ZS
# SE.TER.GRAD.FE.HL.ZS
# SE.TER.GRAD.FE.HU.ZS
# UIS.FGP.56.FNON400500
# SE.TER.GRAD.FE.OT.ZS
# UIS.FGP.56.F400500
# SE.TER.GRAD.FE.SC.ZS
# SE.TER.GRAD.FE.SV.ZS
# SE.TER.GRAD.FE.SS.ZS
# SE.TER.GRAD.AG.ZS
# SE.TER.GRAD.ED.ZS
# SE.TER.GRAD.EN.ZS
# SE.TER.GRAD.HL.ZS
# SE.TER.GRAD.HU.ZS
# SE.TER.GRAD.OT.ZS
# SE.TER.GRAD.SC.ZS
# SE.TER.GRAD.SV.ZS
# SE.TER.GRAD.SS.ZS
# SE.TER.GRAD.FE.ZS
# UIS.FGP.5.B
# UIS.FGP.6
# UIS.FGP.7
# UIS.FGP.8
# UIS.FOSGP.56.F600.M
# UIS.FOSGP.56.F140.M
# UIS.FOSGP.56.F500.M
# UIS.FOSGP.56.F700.M
# UIS.FOSGP.56.F200.M
# UIS.FOSGP.56.FUK.M
# UIS.FOSGP.56.F400.M
# UIS.FOSGP.56.F800.M
# UIS.FOSGP.56.F300.M
# UIS.OAEP.1.M
# UIS.UAEP.1.M
# UIS.GTVP.2.GPV.M
# UIS.GTVP.2.V.M
# UIS.GTVP.4.GPV.M
# UIS.GTVP.4.V.M
# UIS.GTVP.23.GPV.M
# SE.SEC.ENRL.MA.VO.ZS
# UIS.FOSEP.56.F600.M
# UIS.FOSEP.56.F140.M
# UIS.FOSEP.56.F500.M
# UIS.FOSEP.56.F700.M
# UIS.FOSEP.56.F200.M
# UIS.TEP.5.B.M
# UIS.TEP.6.M
# UIS.TEP.7.M
# UIS.TEP.8.M
# UIS.FOSEP.56.FUK.M
# UIS.FOSEP.56.F400.M
# UIS.FOSEP.56.F800.M
# UIS.FOSEP.56.F300.M
# UIS.GTVP.3.GPV.M
# UIS.GTVP.3.V.M
# UIS.TRTP.2.M
# UIS.TRTP.4.M
# UIS.TRTP.0.M
# SE.PRM.TCAQ.MA.ZS
# SE.SEC.TCAQ.MA.ZS
# UIS.TRTP.3.M
# UIS.ECDP.1
# UIS.ECDP.1.F
# UIS.ECDP.1.GPI
# UIS.ECDP.1.M
# UIS.REPP.2.GPV.G1
# UIS.REPP.2.GPV.G1.F
# UIS.REPP.2.GPV.G1.M
# UIS.REPP.1.G1
# UIS.REPP.1.G1.F
# UIS.REPP.1.G1.M
# UIS.REPP.2.GPV.G2
# UIS.REPP.2.GPV.G2.F
# UIS.REPP.2.GPV.G2.M
# UIS.REPP.1.G2
# UIS.REPP.1.G2.F
# UIS.REPP.1.G2.M
# UIS.REPP.2.GPV.G3
# UIS.REPP.2.GPV.G3.F
# UIS.REPP.2.GPV.G3.M
# UIS.REPP.1.G3
# UIS.REPP.1.G3.F
# UIS.REPP.1.G3.M
# UIS.REPP.2.GPV.G4
# UIS.REPP.2.GPV.G4.F
# UIS.REPP.2.GPV.G4.M
# UIS.REPP.1.G4
# UIS.REPP.1.G4.F
# UIS.REPP.1.G4.M
# UIS.REPP.2.GPV.G5
# UIS.REPP.2.GPV.G5.F
# UIS.REPP.2.GPV.G5.M
# UIS.REPP.1.G5
# UIS.REPP.1.G5.F
# UIS.REPP.1.G5.M
# UIS.REPP.2.GPV.G6
# UIS.REPP.2.GPV.G6.F
# UIS.REPP.2.GPV.G6.M
# UIS.REPP.1.G6
# UIS.REPP.1.G6.F
# UIS.REPP.1.G6.M
# UIS.REPP.1.G7
# UIS.REPP.1.G7.F
# UIS.REPP.1.G7.M
# UIS.REPP.2.GPV.GPI
# UIS.REPP.2.GPV
# UIS.REPP.2.GPV.F
# UIS.REPP.2.GPV.M
# SE.PRM.REPT.ZS
# SE.PRM.REPT.FE.ZS
# UIS.REPP.1.GPI
# SE.PRM.REPT.MA.ZS
# UIS.FEP.56.F600
# UIS.FEP.56.F140
# UIS.FEP.56.F500
# UIS.FEP.56.F700
# UIS.FEP.56.F200
# UIS.OAEP.1
# UIS.UAEP.1
# UIS.FEP.56.FUK
# UIS.FEP.56.F400
# UIS.FEP.56.F800
# UIS.FEP.56.F300
# UIS.FEP.0
# UIS.FEP.01
# UIS.GTVP.2.GPV
# UIS.GTVP.2.V
# UIS.FEP.2
# UIS.FEP.2.GPV
# UIS.FEP.2.V
# UIS.GTVP.4.GPV
# UIS.GTVP.4.V
# UIS.FEP.4
# UIS.FEP.4.GPV
# UIS.FEP.4.V
# SE.PRE.ENRL.FE.ZS
# SE.PRM.ENRL.FE.ZS
# UIS.GTVP.23.GPV
# SE.SEC.ENRL.VO.ZS
# SE.SEC.ENRL.FE.ZS
# SE.SEC.ENRL.GC.FE.ZS
# SE.SEC.ENRL.VO.FE.ZS
# UIS.FOSEP.56.F600
# UIS.FOSEP.56.F140
# UIS.FOSEP.56.F500
# UIS.FOSEP.56.F700
# UIS.FOSEP.56.F200
# UIS.FOSEP.56.FUK
# UIS.FOSEP.56.F400
# UIS.FOSEP.56.F800
# UIS.FOSEP.56.F300
# SE.TER.ENRL.FE.ZS
# UIS.FEP.5.B
# UIS.FEP.6
# UIS.FEP.7
# UIS.FEP.8
# UIS.GTVP.3.GPV
# UIS.GTVP.3.V
# UIS.FEP.3
# UIS.FEP.3.GPV
# UIS.FEP.3.V
# UIS.FTP.2
# UIS.QUTP.2
# UIS.TRTP.2
# UIS.TRTP.2.GPI
# UIS.FTP.4
# UIS.TRTP.4
# UIS.TRTP.4.GPI
# SE.PRE.TCHR.FE.ZS
# UIS.QUTP.02
# UIS.TRTP.0
# UIS.TRTP.0.GPI
# SE.PRM.TCHR.FE.ZS
# UIS.QUTP.1
# SE.PRM.TCAQ.ZS
# UIS.TRTP.1.GPI
# SE.SEC.TCHR.FE.ZS
# UIS.QUTP.2T3
# SE.SEC.TCAQ.ZS
# UIS.TRTP.23.GPI
# SE.TER.TCHR.FE.ZS
# UIS.FTP.3
# UIS.QUTP.3
# UIS.TRTP.3
# UIS.TRTP.3.GPI
# IT.CMP.PCMP.P2
# LO.PIAAC.LIT.BE
# LO.PIAAC.LIT.1
# LO.PIAAC.LIT.2
# LO.PIAAC.LIT.3
# LO.PIAAC.LIT.4
# LO.PIAAC.LIT.5
# LO.PIAAC.NUM.BE
# LO.PIAAC.NUM.1
# LO.PIAAC.NUM.2
# LO.PIAAC.NUM.3
# LO.PIAAC.NUM.4
# LO.PIAAC.NUM.5
# LO.PIAAC.TEC.BE
# LO.PIAAC.TEC.FAIL
# LO.PIAAC.TEC.1
# LO.PIAAC.TEC.2
# LO.PIAAC.TEC.3
# LO.PIAAC.TEC.NO
# LO.PIAAC.TEC.OPT
# LO.PIAAC.LIT.P10
# LO.PIAAC.LIT.P25
# LO.PIAAC.LIT.P50
# LO.PIAAC.LIT.P05
# LO.PIAAC.LIT.P75
# LO.PIAAC.LIT.P90
# LO.PIAAC.LIT.P95
# LO.PIAAC.NUM.P10
# LO.PIAAC.NUM.P25
# LO.PIAAC.NUM.P50
# LO.PIAAC.NUM.P05
# LO.PIAAC.NUM.P75
# LO.PIAAC.NUM.P90
# LO.PIAAC.NUM.P95
# LO.PIAAC.TEC.P10
# LO.PIAAC.TEC.P25
# LO.PIAAC.TEC.P50
# LO.PIAAC.TEC.P05
# LO.PIAAC.TEC.P75
# LO.PIAAC.TEC.P90
# LO.PIAAC.TEC.P95
# LO.PIAAC.LIT.FE.BE
# LO.PIAAC.LIT.FE.1
# LO.PIAAC.LIT.FE.2
# LO.PIAAC.LIT.FE.3
# LO.PIAAC.LIT.FE.45
# LO.PIAAC.NUM.FE.BE
# LO.PIAAC.NUM.FE.1
# LO.PIAAC.NUM.FE.2
# LO.PIAAC.NUM.FE.3
# LO.PIAAC.NUM.FE.45
# LO.PIAAC.TEC.FE.BE
# LO.PIAAC.TEC.FE.1
# LO.PIAAC.TEC.FE.2
# LO.PIAAC.TEC.FE.3
# LO.PIAAC.TEC.FE.FAILNO
# LO.PIAAC.LIT.MA.BE
# LO.PIAAC.LIT.MA.1
# LO.PIAAC.LIT.MA.2
# LO.PIAAC.LIT.MA.3
# LO.PIAAC.LIT.MA.45
# LO.PIAAC.NUM.MA.BE
# LO.PIAAC.NUM.MA.1
# LO.PIAAC.NUM.MA.2
# LO.PIAAC.NUM.MA.3
# LO.PIAAC.NUM.MA.45
# LO.PIAAC.TEC.MA.BE
# LO.PIAAC.TEC.MA.1
# LO.PIAAC.TEC.MA.2
# LO.PIAAC.TEC.MA.3
# LO.PIAAC.TEC.MA.FAILNO
# LO.PIAAC.LIT.FE
# LO.PIAAC.LIT.MA
# LO.PIAAC.LIT
# LO.PIAAC.NUM.FE
# LO.PIAAC.NUM.MA
# LO.PIAAC.NUM
# LO.PIAAC.LIT.YOU.FE
# LO.PIAAC.LIT.YOU.MA
# LO.PIAAC.LIT.YOU
# LO.PIAAC.NUM.YOU.FE
# LO.PIAAC.NUM.YOU.MA
# LO.PIAAC.NUM.YOU
# LO.PIAAC.LIT.YOU.BE
# LO.PIAAC.LIT.YOU.1
# LO.PIAAC.LIT.YOU.2
# LO.PIAAC.LIT.YOU.3
# LO.PIAAC.LIT.YOU.45
# LO.PIAAC.NUM.YOU.BE
# LO.PIAAC.NUM.YOU.1
# LO.PIAAC.NUM.YOU.2
# LO.PIAAC.NUM.YOU.3
# LO.PIAAC.NUM.YOU.45
# LO.PIAAC.TEC.YOU.BE
# LO.PIAAC.TEC.YOU.1
# LO.PIAAC.TEC.YOU.2
# LO.PIAAC.TEC.YOU.3
# LO.PIAAC.TEC.YOU.FAILNO
# LO.PIAAC.TEC.YOU.OPT
# LO.PIRLS.REA.P10
# LO.PIRLS.REA.P25
# LO.PIRLS.REA.P50
# LO.PIRLS.REA.P05
# LO.PIRLS.REA.P75
# LO.PIRLS.REA.P90
# LO.PIRLS.REA.P95
# LO.PIRLS.REA.ADV.FE
# LO.PIRLS.REA.HI.FE
# LO.PIRLS.REA.INT.FE
# LO.PIRLS.REA.LOW.FE
# LO.PIRLS.REA.BL.FE
# LO.PIRLS.REA.ADV
# LO.PIRLS.REA.HI
# LO.PIRLS.REA.INT
# LO.PIRLS.REA.LOW
# LO.PIRLS.REA.BL
# LO.PIRLS.REA.ADV.MA
# LO.PIRLS.REA.HI.MA
# LO.PIRLS.REA.INT.MA
# LO.PIRLS.REA.LOW.MA
# LO.PIRLS.REA.BL.MA
# LO.PIRLS.REA.FE
# LO.PIRLS.REA.MA
# LO.PIRLS.REA
# LO.PISA.MAT.0
# LO.PISA.MAT.1
# LO.PISA.MAT.2
# LO.PISA.MAT.3
# LO.PISA.MAT.4
# LO.PISA.MAT.5
# LO.PISA.MAT.6
# LO.PISA.REA.0
# LO.PISA.REA.1A
# LO.PISA.REA.1B
# LO.PISA.REA.2
# LO.PISA.REA.3
# LO.PISA.REA.4
# LO.PISA.REA.5
# LO.PISA.REA.6
# LO.PISA.SCI.0
# LO.PISA.SCI.1A
# LO.PISA.SCI.1B
# LO.PISA.SCI.2
# LO.PISA.SCI.3
# LO.PISA.SCI.4
# LO.PISA.SCI.5
# LO.PISA.SCI.6
# LO.PISA.MAT.P10
# LO.PISA.MAT.P25
# LO.PISA.MAT.P50
# LO.PISA.MAT.P05
# LO.PISA.MAT.P75
# LO.PISA.MAT.P90
# LO.PISA.MAT.P95
# LO.PISA.REA.P10
# LO.PISA.REA.P25
# LO.PISA.REA.P50
# LO.PISA.REA.P05
# LO.PISA.REA.P75
# LO.PISA.REA.P90
# LO.PISA.REA.P95
# LO.PISA.SCI.P10
# LO.PISA.SCI.P25
# LO.PISA.SCI.P50
# LO.PISA.SCI.P05
# LO.PISA.SCI.P75
# LO.PISA.SCI.P90
# LO.PISA.SCI.P95
# LO.PISA.MAT.0.FE
# LO.PISA.MAT.1.FE
# LO.PISA.MAT.2.FE
# LO.PISA.MAT.3.FE
# LO.PISA.MAT.4.FE
# LO.PISA.MAT.5.FE
# LO.PISA.MAT.6.FE
# LO.PISA.REA.0.FE
# LO.PISA.REA.1A.FE
# LO.PISA.REA.1B.FE
# LO.PISA.REA.2.FE
# LO.PISA.REA.3.FE
# LO.PISA.REA.4.FE
# LO.PISA.REA.5.FE
# LO.PISA.REA.6.FE
# LO.PISA.SCI.0.FE
# LO.PISA.SCI.1A.FE
# LO.PISA.SCI.1B.FE
# LO.PISA.SCI.2.FE
# LO.PISA.SCI.3.FE
# LO.PISA.SCI.4.FE
# LO.PISA.SCI.5.FE
# LO.PISA.SCI.6.FE
# LO.PISA.MAT.0.MA
# LO.PISA.MAT.1.MA
# LO.PISA.MAT.2.MA
# LO.PISA.MAT.3.MA
# LO.PISA.MAT.4.MA
# LO.PISA.MAT.5.MA
# LO.PISA.MAT.6.MA
# LO.PISA.REA.0.MA
# LO.PISA.REA.1A.MA
# LO.PISA.REA.1B.MA
# LO.PISA.REA.2.MA
# LO.PISA.REA.3.MA
# LO.PISA.REA.4.MA
# LO.PISA.REA.5.MA
# LO.PISA.REA.6.MA
# LO.PISA.SCI.0.MA
# LO.PISA.SCI.1A.MA
# LO.PISA.SCI.1B.MA
# LO.PISA.SCI.2.MA
# LO.PISA.SCI.3.MA
# LO.PISA.SCI.4.MA
# LO.PISA.SCI.5.MA
# LO.PISA.SCI.6.MA
# LO.PISA.MAT
# LO.PISA.MAT.FE
# LO.PISA.MAT.MA
# LO.PISA.REA
# LO.PISA.REA.FE
# LO.PISA.REA.MA
# LO.PISA.SCI
# LO.PISA.SCI.FE
# LO.PISA.SCI.MA
# SP.POP.GROW
# UIS.SAP.CE
# UIS.SAP.CE.F
# UIS.SAP.CE.M
# SP.SEC.LTOT.IN
# SP.SEC.LTOT.FE.IN
# SP.SEC.LTOT.MA.IN
# UIS.SAP.4
# UIS.SAP.4.F
# UIS.SAP.4.M
# SP.PRE.TOTL.IN
# SP.PRE.TOTL.FE.IN
# SP.PRE.TOTL.MA.IN
# SP.PRM.TOTL.IN
# SP.PRM.TOTL.FE.IN
# SP.PRM.TOTL.MA.IN
# SP.SEC.TOTL.IN
# SP.SEC.TOTL.FE.IN
# SP.SEC.TOTL.MA.IN
# SP.TER.TOTL.IN
# SP.TER.TOTL.FE.IN
# SP.TER.TOTL.MA.IN
# SP.PRM.GRAD.TO
# SP.PRM.GRAD.FE
# SP.PRM.GRAD.MA
# SP.SEC.UTOT.IN
# SP.SEC.UTOT.FE.IN
# SP.SEC.UTOT.MA.IN
# UIS.SAP.1.G1
# UIS.SAP.1.G1.F
# UIS.SAP.1.G1.M
# UIS.SAP.23.GPV.G1
# UIS.SAP.23.GPV.G1.F
# UIS.SAP.23.GPV.G1.M
# SP.POP.AG00.FE.UN
# SP.POP.AG00.MA.UN
# SP.POP.AG00.TO.UN
# SP.POP.AG01.FE.UN
# SP.POP.AG01.MA.UN
# SP.POP.AG01.TO.UN
# SP.POP.AG10.FE.UN
# SP.POP.AG10.MA.UN
# SP.POP.AG10.TO.UN
# SP.POP.AG11.FE.UN
# SP.POP.AG11.MA.UN
# SP.POP.AG11.TO.UN
# SP.POP.AG12.FE.UN
# SP.POP.AG12.MA.UN
# SP.POP.AG12.TO.UN
# SP.POP.AG13.FE.UN
# SP.POP.AG13.MA.UN
# SP.POP.AG13.TO.UN
# SP.POP.AG14.FE.UN
# SP.POP.AG14.MA.UN
# SP.POP.AG14.TO.UN
# SP.POP.AG15.FE.UN
# SP.POP.AG15.MA.UN
# SP.POP.AG15.TO.UN
# SP.POP.AG16.FE.UN
# SP.POP.AG16.MA.UN
# SP.POP.AG16.TO.UN
# SP.POP.AG17.FE.UN
# SP.POP.AG17.MA.UN
# SP.POP.AG17.TO.UN
# SP.POP.AG18.FE.UN
# SP.POP.AG18.MA.UN
# SP.POP.AG18.TO.UN
# SP.POP.AG19.FE.UN
# SP.POP.AG19.MA.UN
# SP.POP.AG19.TO.UN
# SP.POP.AG02.FE.UN
# SP.POP.AG02.MA.UN
# SP.POP.AG02.TO.UN
# SP.POP.AG20.FE.UN
# SP.POP.AG20.MA.UN
# SP.POP.AG20.TO.UN
# SP.POP.AG21.FE.UN
# SP.POP.AG21.MA.UN
# SP.POP.AG21.TO.UN
# SP.POP.AG22.FE.UN
# SP.POP.AG22.MA.UN
# SP.POP.AG22.TO.UN
# SP.POP.AG23.FE.UN
# SP.POP.AG23.MA.UN
# SP.POP.AG23.TO.UN
# SP.POP.AG24.FE.UN
# SP.POP.AG24.MA.UN
# SP.POP.AG24.TO.UN
# SP.POP.AG25.FE.UN
# SP.POP.AG25.MA.UN
# SP.POP.AG25.TO.UN
# SP.POP.AG03.FE.UN
# SP.POP.AG03.MA.UN
# SP.POP.AG03.TO.UN
# SP.POP.AG04.FE.UN
# SP.POP.AG04.MA.UN
# SP.POP.AG04.TO.UN
# SP.POP.AG05.FE.UN
# SP.POP.AG05.MA.UN
# SP.POP.AG05.TO.UN
# SP.POP.AG06.FE.UN
# SP.POP.AG06.MA.UN
# SP.POP.AG06.TO.UN
# SP.POP.AG07.FE.UN
# SP.POP.AG07.MA.UN
# SP.POP.AG07.TO.UN
# SP.POP.AG08.FE.UN
# SP.POP.AG08.MA.UN
# SP.POP.AG08.TO.UN
# SP.POP.AG09.FE.UN
# SP.POP.AG09.MA.UN
# SP.POP.AG09.TO.UN
# SP.POP.0014.TO.ZS
# SP.POP.0014.FE.IN
# SP.POP.0014.MA.IN
# SP.POP.0014.TO
# SP.POP.1014.FE.UN
# SP.POP.1014.MA.UN
# SP.POP.1014.TO.UN
# SP.POP.1015.FE.UN
# SP.POP.1015.MA.UN
# SP.POP.1015.TO.UN
# SP.POP.1016.FE.UN
# SP.POP.1016.MA.UN
# SP.POP.1016.TO.UN
# SP.POP.1017.FE.UN
# SP.POP.1017.MA.UN
# SP.POP.1017.TO.UN
# SP.POP.1018.FE.UN
# SP.POP.1018.MA.UN
# SP.POP.1018.TO.UN
# SP.POP.1115.FE.UN
# SP.POP.1115.MA.UN
# SP.POP.1115.TO.UN
# SP.POP.1116.FE.UN
# SP.POP.1116.MA.UN
# SP.POP.1116.TO.UN
# SP.POP.1117.FE.UN
# SP.POP.1117.MA.UN
# SP.POP.1117.TO.UN
# SP.POP.1118.FE.UN
# SP.POP.1118.MA.UN
# SP.POP.1118.TO.UN
# SP.POP.1215.FE.UN
# SP.POP.1215.MA.UN
# SP.POP.1215.TO.UN
# SP.POP.1216.FE.UN
# SP.POP.1216.MA.UN
# SP.POP.1216.TO.UN
# SP.POP.1217.FE.UN
# SP.POP.1217.MA.UN
# SP.POP.1217.TO.UN
# SP.POP.1218.FE.UN
# SP.POP.1218.MA.UN
# SP.POP.1218.TO.UN
# SP.POP.1316.FE.UN
# SP.POP.1316.MA.UN
# SP.POP.1316.TO.UN
# SP.POP.1317.FE.UN
# SP.POP.1317.MA.UN
# SP.POP.1317.TO.UN
# SP.POP.1318.FE.UN
# SP.POP.1318.MA.UN
# SP.POP.1318.TO.UN
# SP.POP.1319.FE.UN
# SP.POP.1319.MA.UN
# SP.POP.1319.TO.UN
# SP.POP.1418.FE.UN
# SP.POP.1418.MA.UN
# SP.POP.1418.TO.UN
# SP.POP.1419.FE.UN
# SP.POP.1419.MA.UN
# SP.POP.1419.TO.UN
# SP.POP.1524.FE.UN
# SP.POP.1524.MA.UN
# SP.POP.1524.TO.UN
# SP.POP.1564.TO.ZS
# SP.POP.1564.FE.IN
# SP.POP.1564.MA.IN
# SP.POP.1564.TO
# SP.POP.0305.FE.UN
# SP.POP.0305.MA.UN
# SP.POP.0305.TO.UN
# SP.POP.0406.FE.UN
# SP.POP.0406.MA.UN
# SP.POP.0406.TO.UN
# SP.POP.0510.FE.UN
# SP.POP.0510.MA.UN
# SP.POP.0510.TO.UN
# SP.POP.0511.FE.UN
# SP.POP.0511.MA.UN
# SP.POP.0511.TO.UN
# SP.POP.0509.FE.UN
# SP.POP.0509.MA.UN
# SP.POP.0509.TO.UN
# SP.POP.0610.FE.UN
# SP.POP.0610.MA.UN
# SP.POP.0610.TO.UN
# SP.POP.0611.FE.UN
# SP.POP.0611.MA.UN
# SP.POP.0611.TO.UN
# SP.POP.0612.FE.UN
# SP.POP.0612.MA.UN
# SP.POP.0612.TO.UN
# SP.POP.0609.FE.UN
# SP.POP.0609.MA.UN
# SP.POP.0609.TO.UN
# SP.POP.0710.FE.UN
# SP.POP.0710.MA.UN
# SP.POP.0710.TO.UN
# SP.POP.0711.FE.UN
# SP.POP.0711.MA.UN
# SP.POP.0711.TO.UN
# SP.POP.0712.FE.UN
# SP.POP.0712.MA.UN
# SP.POP.0712.TO.UN
# SP.POP.0713.FE.UN
# SP.POP.0713.MA.UN
# SP.POP.0713.TO.UN
# SP.POP.0709.FE.UN
# SP.POP.0709.MA.UN
# SP.POP.0709.TO.UN
# SP.POP.TOTL.FE.IN
# SP.POP.TOTL.FE.ZS
# SP.POP.TOTL.MA.IN
# SP.POP.TOTL.MA.ZS
# SP.POP.TOTL
# SH.DYN.AIDS.ZS
# SE.PRM.CMPT.ZS
# SE.PRM.CMPT.FE.ZS
# UIS.AIR.1.GLAST.GPI
# SE.PRM.CMPT.MA.ZS
# UIS.PTRHC.2.QUALIFIED
# UIS.PTRHC.02.QUALIFIED
# UIS.PTRHC.1.QUALIFIED
# UIS.PTRHC.2T3.QUALIFIED
# UIS.PTRHC.3.QUALIFIED
# UIS.PTRHC.2.TRAINED
# UIS.PTRHC.02.TRAINED
# UIS.PTRHC.1.TRAINED
# UIS.PTRHC.2T3.TRAINED
# UIS.PTRHC.3.TRAINED
# UIS.PTRHC.2
# SE.PRE.ENRL.TC.ZS
# SE.PRM.ENRL.TC.ZS
# SE.SEC.ENRL.TC.ZS
# UIS.PTRHC.56
# UIS.PTRHC.3
# UIS.ROFST.2
# UIS.ROFST.2.F
# UIS.ROFST.2.M
# UIS.ROFSPPT.1
# UIS.ROFSPPT.1.F
# UIS.ROFSPPT.1.M
# UIS.ROFST.1
# UIS.ROFST.1.F
# UIS.ROFST.1.M
# UIS.ROFST.3.CP
# UIS.ROFST.3.F.CP
# UIS.ROFST.3.M.CP
# UIS.R.2.GPV.G1
# UIS.R.2.GPV.G1.F
# UIS.R.1.G1
# UIS.R.1.G1.F
# UIS.R.2.GPV.G2
# UIS.R.2.GPV.G2.F
# UIS.R.1.G2
# UIS.R.1.G2.F
# UIS.R.2.GPV.G3
# ...
# SABER.SCH.FNNC.GOAL4.LVL2
# SABER.SCH.FNNC.GOAL4
# SABER.SCH.FNNC.GOAL5.LVL1
# SABER.SCH.FNNC.GOAL5.LVL2
# SABER.SCH.FNNC.GOAL5
# SABER.SCH.FNNC.GOAL6.LVL1
# SABER.SCH.FNNC.GOAL6.LVL2
# SABER.SCH.FNNC.GOAL6
# SABER.HLTH.GOAL1
# SABER.HLTH.GOAL2
# SABER.HLTH.GOAL3
# SABER.HLTH.GOAL4
# SABER.HLTH.GOAL5
# SABER.HLTH.GOAL6
# SABER.HLTH.GOAL7
# SABER.HLTH.GOAL8
# SABER.HLTH.GOAL9
# SABER.STD.ASS.GOAL1.LVL1
# SABER.STD.ASS.GOAL1.LVL2
# SABER.STD.ASS.GOAL1
# SABER.STD.ASS.GOAL2.LVL1
# SABER.STD.ASS.GOAL2.LVL2
# SABER.STD.ASS.GOAL2.LVL3
# SABER.STD.ASS.GOAL2
# SABER.STD.ASS.GOAL3.LVL1
# SABER.STD.ASS.GOAL3.LVL2
# SABER.STD.ASS.GOAL3.LVL3
# SABER.STD.ASS.GOAL3
# SABER.STD.ASS.GOAL4.LVL1
# SABER.STD.ASS.GOAL4.LVL2
# SABER.STD.ASS.GOAL4.LVL3
# SABER.STD.ASS.GOAL4
# SABER.TECH.GOAL1.LVL1
# SABER.TECH.GOAL1.LVL2
# SABER.TECH.GOAL1
# SABER.TECH.GOAL2.LVL1
# SABER.TECH.GOAL2.LVL2
# SABER.TECH.GOAL2.LVL3
# SABER.TECH.GOAL2.LVL4
# SABER.TECH.GOAL2
# SABER.TECH.GOAL3.LVL1
# SABER.TECH.GOAL3.LVL2
# SABER.TECH.GOAL3
# SABER.TECH.GOAL4.LVL1
# SABER.TECH.GOAL4.LVL2
# SABER.TECH.GOAL4
# SABER.TECH.GOAL5.LVL1
# SABER.TECH.GOAL5.LVL2
# SABER.TECH.GOAL5
# SABER.TECH.GOAL6.LVL1
# SABER.TECH.GOAL6.LVL2
# SABER.TECH.GOAL6.LVL3
# SABER.TECH.GOAL6
# SABER.TECH.GOAL7.LVL1
# SABER.TECH.GOAL7.LVL2
# SABER.TECH.GOAL7.LVL3
# SABER.TECH.GOAL7
# SABER.TECH.GOAL8.LVL1
# SABER.TECH.GOAL8.LVL2
# SABER.TECH.GOAL8.LVL3
# SABER.TECH.GOAL8
# SABER.TER.GOAL1.LVL1
# SABER.TER.GOAL1
# SABER.TER.GOAL2.LVL1
# SABER.TER.GOAL2
# SABER.TER.GOAL3.LVL1
# SABER.TER.GOAL3.LVL2
# SABER.TER.GOAL3
# SABER.TER.GOAL4.LVL1
# SABER.TER.GOAL4.LVL2
# SABER.TER.GOAL4.LVL3
# SABER.TER.GOAL4
# SABER.TER.GOAL5.LVL1
# SABER.TER.GOAL5
# SABER.TER.GOAL6.LVL1
# SABER.TER.GOAL6.LVL2
# SABER.TER.GOAL6.LVL3
# SABER.TER.GOAL6
# SABER.WORK.GOAL1.LVL1
# SABER.WORK.GOAL1.LVL2
# SABER.WORK.GOAL1.LVL3
# SABER.WORK.GOAL1
# SABER.WORK.GOAL2.LVL1
# SABER.WORK.GOAL2.LVL2
# SABER.WORK.GOAL2.LVL3
# SABER.WORK.GOAL2
# SABER.WORK.GOAL3.LVL1
# SABER.WORK.GOAL3.LVL2
# SABER.WORK.GOAL3.LVL3
# SABER.WORK.GOAL3
# LO.SACMEQ.MAT.L1
# LO.SACMEQ.MAT.L2
# LO.SACMEQ.MAT.L3
# LO.SACMEQ.MAT.L4
# LO.SACMEQ.MAT.L5
# LO.SACMEQ.MAT.L6
# LO.SACMEQ.MAT.L7
# LO.SACMEQ.MAT.L8
# LO.SACMEQ.REA.L1
# LO.SACMEQ.REA.L2
# LO.SACMEQ.REA.L3
# LO.SACMEQ.REA.L4
# LO.SACMEQ.REA.L5
# LO.SACMEQ.REA.L6
# LO.SACMEQ.REA.L7
# LO.SACMEQ.REA.L8
# LO.SACMEQ.MAT.L1.FE
# LO.SACMEQ.MAT.L2.FE
# LO.SACMEQ.MAT.L3.FE
# LO.SACMEQ.MAT.L4.FE
# LO.SACMEQ.MAT.L5.FE
# LO.SACMEQ.MAT.L6.FE
# LO.SACMEQ.MAT.L7.FE
# LO.SACMEQ.MAT.L8.FE
# LO.SACMEQ.REA.L1.FE
# LO.SACMEQ.REA.L2.FE
# LO.SACMEQ.REA.L3.FE
# LO.SACMEQ.REA.L4.FE
# LO.SACMEQ.REA.L5.FE
# LO.SACMEQ.REA.L6.FE
# LO.SACMEQ.REA.L7.FE
# LO.SACMEQ.REA.L8.FE
# LO.SACMEQ.MAT.L1.MA
# LO.SACMEQ.MAT.L2.MA
# LO.SACMEQ.MAT.L3.MA
# LO.SACMEQ.MAT.L4.MA
# LO.SACMEQ.MAT.L5.MA
# LO.SACMEQ.MAT.L6.MA
# LO.SACMEQ.MAT.L7.MA
# LO.SACMEQ.MAT.L8.MA
# LO.SACMEQ.REA.L1.MA
# LO.SACMEQ.REA.L2.MA
# LO.SACMEQ.REA.L3.MA
# LO.SACMEQ.REA.L4.MA
# LO.SACMEQ.REA.L5.MA
# LO.SACMEQ.REA.L6.MA
# LO.SACMEQ.REA.L7.MA
# LO.SACMEQ.REA.L8.MA
# LO.SACMEQ.MAT
# LO.SACMEQ.MAT.FE
# LO.SACMEQ.MAT.MA
# LO.SACMEQ.REA.FE
# LO.SACMEQ.REA.MA
# LO.SACMEQ.REA
# UIS.SLE.4
# UIS.SLE.4.F
# UIS.SLE.4.GPI
# UIS.SLE.4.M
# UIS.SLE.0
# UIS.SLE.0.F
# UIS.SLE.0.GPI
# UIS.SLE.0.M
# UIS.SLEN.12.T
# UIS.SLEN.12.F
# UIS.SLEN.12.GPI
# UIS.SLEN.12.M
# UIS.SLE.12
# UIS.SLE.12.F
# UIS.SLE.12.M
# UIS.SLE.123
# UIS.SLE.123.F
# UIS.SLE.123.GPI
# UIS.SLE.123.M
# SE.SCH.LIFE
# SE.SCH.LIFE.FE
# UIS.SLE.1T6.GPI
# SE.SCH.LIFE.MA
# UIS.SLE.1
# UIS.SLE.1.F
# UIS.SLE.1.GPI
# UIS.SLE.1.M
# UIS.SLE.23
# UIS.SLE.23.F
# UIS.SLE.23.GPI
# UIS.SLE.23.M
# UIS.SLE.56
# UIS.SLE.56.F
# UIS.SLE.56.GPI
# UIS.SLE.56.M
# SL.UEM.NEET.FE.ZS
# SL.UEM.NEET.MA.ZS
# SL.UEM.NEET.ZS
# UIS.SR.1.G4
# UIS.SR.1.G4.F
# UIS.SR.1.G4.GPI
# UIS.SR.1.G4.M
# SE.PRM.PRS5.ZS
# SE.PRM.PRS5.FE.ZS
# UIS.SR.1.G5.GPI
# SE.PRM.PRS5.MA.ZS
# UIS.SR.2.GPV.GLAST.CP.T
# UIS.SR.2.GPV.GLAST.CP.F
# UIS.SR.2.GPV.GLAST.GPI
# UIS.SR.2.GPV.GLAST.CP.M
# SE.PRM.PRSL.ZS
# SE.PRM.PRSL.FE.ZS
# UIS.SR.1.GLAST.GPI
# SE.PRM.PRSL.MA.ZS
# UIS.T.2
# UIS.T.2.F
# UIS.T.4
# UIS.T.4.F
# SE.PRE.TCHR
# SE.PRE.TCHR.FE
# SE.PRM.TCHR
# SE.PRM.TCHR.FE
# SE.SEC.TCHR
# SE.SEC.TCHR.FE
# UIS.T.23.GPV
# UIS.T.23.GPV.F
# UIS.T.23.V
# UIS.T.23.V.F
# UIS.T.5.B
# UIS.T.5.B.F
# SE.TER.TCHR
# SE.TER.TCHR.FE
# UIS.T.3
# UIS.T.3.F
# SE.SEC.DURS.LO
# UIS.THDUR.4.A.GPV
# UIS.THDUR.0
# SE.PRM.DURS
# SE.SEC.DURS
# SE.SEC.DURS.UP
# LO.TIMSS.MAT4.P10
# LO.TIMSS.MAT4.P25
# LO.TIMSS.MAT4.P50
# LO.TIMSS.MAT4.P05
# LO.TIMSS.MAT4.P75
# LO.TIMSS.MAT4.P90
# LO.TIMSS.MAT4.P95
# LO.TIMSS.SCI4.P10
# LO.TIMSS.SCI4.P25
# LO.TIMSS.SCI4.P50
# LO.TIMSS.SCI4.P05
# LO.TIMSS.SCI4.P75
# LO.TIMSS.SCI4.P90
# LO.TIMSS.SCI4.P95
# LO.TIMSS.MAT8.P10
# LO.TIMSS.MAT8.P25
# LO.TIMSS.MAT8.P50
# LO.TIMSS.MAT8.P05
# LO.TIMSS.MAT8.P75
# LO.TIMSS.MAT8.P90
# LO.TIMSS.MAT8.P95
# LO.TIMSS.SCI8.P10
# LO.TIMSS.SCI8.P25
# LO.TIMSS.SCI8.P50
# LO.TIMSS.SCI8.P05
# LO.TIMSS.SCI8.P75
# LO.TIMSS.SCI8.P90
# LO.TIMSS.SCI8.P95
# LO.TIMSS.MAT8.ADV
# LO.TIMSS.SCI8.ADV
# LO.TIMSS.MAT8.HI
# LO.TIMSS.SCI8.HI
# LO.TIMSS.MAT8.INT
# LO.TIMSS.SCI8.INT
# LO.TIMSS.MAT8.LOW
# LO.TIMSS.SCI8.LOW
# LO.TIMSS.MAT8.BL
# LO.TIMSS.SCI8.BL
# LO.TIMSS.MAT4.ADV.FE
# LO.TIMSS.SCI4.ADV.FE
# LO.TIMSS.MAT4.HI.FE
# LO.TIMSS.SCI4.HI.FE
# LO.TIMSS.MAT4.INT.FE
# LO.TIMSS.SCI4.INT.FE
# LO.TIMSS.MAT4.LOW.FE
# LO.TIMSS.SCI4.LOW.FE
# LO.TIMSS.MAT4.BL.FE
# LO.TIMSS.SCI4.BL.FE
# LO.TIMSS.MAT8.ADV.FE
# LO.TIMSS.SCI8.ADV.FE
# LO.TIMSS.MAT8.HI.FE
# LO.TIMSS.SCI8.HI.FE
# LO.TIMSS.MAT8.INT.FE
# LO.TIMSS.SCI8.INT.FE
# LO.TIMSS.MAT8.LOW.FE
# LO.TIMSS.SCI8.LOW.FE
# LO.TIMSS.MAT8.BL.FE
# LO.TIMSS.SCI8.BL.FE
# LO.TIMSS.MAT4.ADV
# LO.TIMSS.SCI4.ADV
# LO.TIMSS.MAT4.HI
# LO.TIMSS.SCI4.HI
# LO.TIMSS.MAT4.INT
# LO.TIMSS.SCI4.INT
# LO.TIMSS.MAT4.LOW
# LO.TIMSS.SCI4.LOW
# LO.TIMSS.MAT4.BL
# LO.TIMSS.SCI4.BL
# LO.TIMSS.MAT4.ADV.MA
# LO.TIMSS.SCI4.ADV.MA
# LO.TIMSS.MAT4.HI.MA
# LO.TIMSS.SCI4.HI.MA
# LO.TIMSS.MAT4.INT.MA
# LO.TIMSS.SCI4.INT.MA
# LO.TIMSS.MAT4.LOW.MA
# LO.TIMSS.SCI4.LOW.MA
# LO.TIMSS.MAT4.BL.MA
# LO.TIMSS.SCI4.BL.MA
# LO.TIMSS.MAT8.ADV.MA
# LO.TIMSS.SCI8.ADV.MA
# LO.TIMSS.MAT8.HI.MA
# LO.TIMSS.SCI8.HI.MA
# LO.TIMSS.MAT8.INT.MA
# LO.TIMSS.SCI8.INT.MA
# LO.TIMSS.MAT8.LOW.MA
# LO.TIMSS.SCI8.LOW.MA
# LO.TIMSS.MAT8.BL.MA
# LO.TIMSS.SCI8.BL.MA
# LO.TIMSS.MAT8.FE
# LO.TIMSS.MAT8.MA
# LO.TIMSS.MAT8
# LO.TIMSS.MAT4.FE
# LO.TIMSS.MAT4.MA
# LO.TIMSS.MAT4
# LO.TIMSS.SCI8.FE
# LO.TIMSS.SCI8.MA
# LO.TIMSS.SCI8
# LO.TIMSS.SCI4.FE
# LO.TIMSS.SCI4.MA
# LO.TIMSS.SCI4
# UIS.MS.56.T
# UIS.MS.56.F
# UIS.NERT.2
# UIS.NERT.2.F
# UIS.NERT.2.GPI
# UIS.NERT.2.M
# UIS.NERT.1
# UIS.NERT.1.F
# UIS.NERT.1.GPI
# UIS.NERT.1.M
# UIS.OE.56.40510
# UIS.NARA.1
# UIS.NARA.1.F
# UIS.NARA.1.Q4
# UIS.NARA.1.Q4.F
# UIS.NARA.1.Q4.GPI
# UIS.NARA.1.Q4.M
# UIS.NARA.1.GPI
# UIS.NARA.1.M
# UIS.NARA.1.Q3
# UIS.NARA.1.Q3.F
# UIS.NARA.1.Q3.GPI
# UIS.NARA.1.Q3.M
# UIS.NARA.1.Q1
# UIS.NARA.1.Q1.F
# UIS.NARA.1.Q1.GPI
# UIS.NARA.1.Q1.M
# UIS.NARA.1.Q5
# UIS.NARA.1.Q5.F
# UIS.NARA.1.Q5.GPI
# UIS.NARA.1.Q5.M
# UIS.NARA.1.RUR
# UIS.NARA.1.RUR.F
# UIS.NARA.1.RUR.GPI
# UIS.NARA.1.RUR.M
# UIS.NARA.1.Q2
# UIS.NARA.1.Q2.F
# UIS.NARA.1.Q2.GPI
# UIS.NARA.1.Q2.M
# UIS.NARA.1.URB
# UIS.NARA.1.URB.F
# UIS.NARA.1.URB.GPI
# UIS.NARA.1.URB.M
# UIS.EA.MEAN.1T6.AG25T99.F
# UIS.EA.MEAN.1T6.AG25T99.M
# UIS.EA.MEAN.1T6.AG25T99
# UIS.NAR.2
# UIS.NAR.2.F
# UIS.NAR.2.Q4
# UIS.NAR.2.Q4.F
# UIS.NAR.2.Q4.GPI
# UIS.NAR.2.Q4.M
# UIS.NAR.2.GPI
# UIS.NAR.2.M
# UIS.NAR.2.Q3
# UIS.NAR.2.Q3.F
# UIS.NAR.2.Q3.GPI
# UIS.NAR.2.Q3.M
# UIS.NAR.2.Q1
# UIS.NAR.2.Q1.F
# UIS.NAR.2.Q1.GPI
# UIS.NAR.2.Q1.M
# UIS.NAR.2.Q5
# UIS.NAR.2.Q5.F
# UIS.NAR.2.Q5.GPI
# UIS.NAR.2.Q5.M
# UIS.NAR.2.RUR
# UIS.NAR.2.RUR.F
# UIS.NAR.2.RUR.GPI
# UIS.NAR.2.RUR.M
# UIS.NAR.2.Q2
# UIS.NAR.2.Q2.F
# UIS.NAR.2.Q2.GPI
# UIS.NAR.2.Q2.M
# UIS.NAR.2.URB
# UIS.NAR.2.URB.F
# UIS.NAR.2.URB.GPI
# UIS.NAR.2.URB.M
# UIS.NAR.1
# UIS.NAR.1.F
# UIS.NAR.1.Q4
# UIS.NAR.1.Q4.F
# UIS.NAR.1.Q4.GPI
# UIS.NAR.1.Q4.M
# UIS.NAR.1.GPI
# UIS.NAR.1.M
# UIS.NAR.1.Q3
# UIS.NAR.1.Q3.F
# UIS.NAR.1.Q3.GPI
# UIS.NAR.1.Q3.M
# UIS.NAR.1.Q1
# UIS.NAR.1.Q1.F
# UIS.NAR.1.Q1.GPI
# UIS.NAR.1.Q1.M
# UIS.NAR.1.Q5
# UIS.NAR.1.Q5.F
# UIS.NAR.1.Q5.GPI
# UIS.NAR.1.Q5.M
# UIS.NAR.1.RUR
# UIS.NAR.1.RUR.F
# UIS.NAR.1.RUR.GPI
# UIS.NAR.1.RUR.M
# UIS.NAR.1.Q2
# UIS.NAR.1.Q2.F
# UIS.NAR.1.Q2.GPI
# UIS.NAR.1.Q2.M
# UIS.NAR.1.URB
# UIS.NAR.1.URB.F
# UIS.NAR.1.URB.GPI
# UIS.NAR.1.URB.M
# UIS.EA.6.AG25T99.F
# UIS.EA.6.AG25T99.M
# UIS.EA.6.AG25T99
# UIS.EA.7.AG25T99.F
# UIS.EA.7.AG25T99.M
# UIS.EA.7.AG25T99
# UIS.EA.5.AG25T99.F
# UIS.EA.5.AG25T99.M
# UIS.EA.5.AG25T99
# UIS.EA.8.AG25T99.F
# UIS.EA.8.AG25T99.GPI
# UIS.EA.8.AG25T99.M
# UIS.EA.8.AG25T99
# UIS.EA.6T8.AG25T99.F
# UIS.EA.6T8.AG25T99.GPI
# UIS.EA.6T8.AG25T99.M
# UIS.EA.6T8.AG25T99
# UIS.EA.7T8.AG25T99.F
# UIS.EA.7T8.AG25T99.GPI
# UIS.EA.7T8.AG25T99.M
# UIS.EA.7T8.AG25T99
# UIS.EA.5T8.AG25T99.F
# UIS.EA.5T8.AG25T99.GPI
# UIS.EA.5T8.AG25T99.M
# UIS.EA.5T8.AG25T99
# UIS.EA.2T6.AG25T99.F
# UIS.EA.2T6.AG25T99.GPI
# UIS.EA.2T6.AG25T99.M
# UIS.EA.2T6.AG25T99
# UIS.EA.4T6.AG25T99.F
# UIS.EA.4T6.AG25T99.GPI
# UIS.EA.4T6.AG25T99.M
# UIS.EA.4T6.AG25T99
# UIS.EA.1T6.AG25T99.F
# UIS.EA.1T6.AG25T99.GPI
# UIS.EA.1T6.AG25T99.M
# UIS.EA.1T6.AG25T99
# UIS.EA.3T6.AG25T99.F
# UIS.EA.3T6.AG25T99.GPI
# UIS.EA.3T6.AG25T99.M
# UIS.EA.3T6.AG25T99
# UIS.EA.2.AG25T99.F
# UIS.EA.2.AG25T99.M
# UIS.EA.2.AG25T99
# UIS.EA.4.AG25T99.F
# UIS.EA.4.AG25T99.M
# UIS.EA.4.AG25T99
# UIS.EA.1.AG25T99.F
# UIS.EA.1.AG25T99.M
# UIS.EA.1.AG25T99
# UIS.EA.3.AG25T99.F
# UIS.EA.3.AG25T99.M
# UIS.EA.3.AG25T99
# UIS.EA.NS.AG25T99.F
# UIS.EA.NS.AG25T99.M
# UIS.EA.NS.AG25T99
# UIS.EA.S1.AG25T99.F
# UIS.EA.S1.AG25T99.M
# UIS.EA.S1.AG25T99
# UIS.EA.UK.AG25T99.F
# UIS.EA.UK.AG25T99.M
# UIS.EA.UK.AG25T99
# UIS.ROFST.H.2
# UIS.ROFST.H.2.F
# UIS.ROFST.H.2.Q4
# UIS.ROFST.H.2.Q4.F
# UIS.ROFST.H.2.Q4.M
# UIS.ROFST.H.2.M
# UIS.ROFST.H.2.Q3
# UIS.ROFST.H.2.Q3.F
# UIS.ROFST.H.2.Q3.M
# UIS.ROFST.H.2.Q1
# UIS.ROFST.H.2.Q1.F
# UIS.ROFST.H.2.Q1.M
# UIS.ROFST.H.2.Q5
# UIS.ROFST.H.2.Q5.F
# UIS.ROFST.H.2.Q5.M
# UIS.ROFST.H.2.RUR
# UIS.ROFST.H.2.RUR.F
# UIS.ROFST.H.2.RUR.M
# UIS.ROFST.H.2.Q2
# UIS.ROFST.H.2.Q2.F
# UIS.ROFST.H.2.Q2.M
# UIS.ROFST.H.2.URB
# UIS.ROFST.H.2.URB.F
# UIS.ROFST.H.2.URB.M
# UIS.ROFST.H.1
# UIS.ROFST.H.1.F
# UIS.ROFST.H.1.Q4
# UIS.ROFST.H.1.Q4.F
# UIS.ROFST.H.1.Q4.M
# UIS.ROFST.H.1.M
# UIS.ROFST.H.1.Q3
# UIS.ROFST.H.1.Q3.F
# UIS.ROFST.H.1.Q3.M
# UIS.ROFST.H.1.Q1
# UIS.ROFST.H.1.Q1.F
# UIS.ROFST.H.1.Q1.M
# UIS.ROFST.H.1.Q5
# UIS.ROFST.H.1.Q5.F
# UIS.ROFST.H.1.Q5.M
# UIS.ROFST.H.1.RUR
# UIS.ROFST.H.1.RUR.F
# UIS.ROFST.H.1.RUR.M
# UIS.ROFST.H.1.Q2
# UIS.ROFST.H.1.Q2.F
# UIS.ROFST.H.1.Q2.M
# UIS.ROFST.H.1.URB
# UIS.ROFST.H.1.URB.F
# UIS.ROFST.H.1.URB.M
# UIS.NART.2
# UIS.NART.2.F
# UIS.NART.2.Q4
# UIS.NART.2.Q4.F
# UIS.NART.2.Q4.GPI
# UIS.NART.2.Q4.M
# UIS.NART.2.GPI
# UIS.NART.2.M
# UIS.NART.2.Q3
# UIS.NART.2.Q3.F
# UIS.NART.2.Q3.GPI
# UIS.NART.2.Q3.M
# UIS.NART.2.Q1
# UIS.NART.2.Q1.F
# UIS.NART.2.Q1.GPI
# UIS.NART.2.Q1.M
# UIS.NART.2.Q5
# UIS.NART.2.Q5.F
# UIS.NART.2.Q5.GPI
# UIS.NART.2.Q5.M
# UIS.NART.2.RUR
# UIS.NART.2.RUR.F
# UIS.NART.2.RUR.GPI
# UIS.NART.2.RUR.M
# UIS.NART.2.Q2
# UIS.NART.2.Q2.F
# UIS.NART.2.Q2.GPI
# UIS.NART.2.Q2.M
# UIS.NART.2.URB
# UIS.NART.2.URB.F
# UIS.NART.2.URB.GPI
# UIS.NART.2.URB.M
# UIS.UAPP.1
# UIS.UAPP.1.F
# UIS.UAPP.1.M
# UIS.UAPP.23
# UIS.UAPP.23.F
# UIS.UAPP.23.M
# SL.UEM.TOTL.FE.ZS
# SL.UEM.TOTL.MA.ZS
# SL.UEM.TOTL.ZS
# PRJ.MYS.0T19.FE
# PRJ.MYS.0T19.MA
# PRJ.MYS.0T19.MF
# PRJ.MYS.15UP.FE
# PRJ.MYS.15UP.GPI
# PRJ.MYS.15UP.MA
# PRJ.MYS.15UP.MF
# PRJ.MYS.1519.FE
# PRJ.MYS.1519.MA
# PRJ.MYS.1519.MF
# PRJ.MYS.2024.FE
# PRJ.MYS.2024.MA
# PRJ.MYS.2024.MF
# PRJ.MYS.2039.FE
# PRJ.MYS.2039.MA
# PRJ.MYS.2039.MF
# PRJ.MYS.2064.FE
# PRJ.MYS.2064.MA
# PRJ.MYS.2064.MF
# PRJ.MYS.25UP.FE
# PRJ.MYS.25UP.GPI
# PRJ.MYS.25UP.MA
# PRJ.MYS.25UP.MF
# PRJ.MYS.2529.FE
# PRJ.MYS.2529.MA
# PRJ.MYS.2529.MF
# PRJ.MYS.4064.FE
# PRJ.MYS.4064.MA
# PRJ.MYS.4064.MF
# PRJ.MYS.60UP.FE
# PRJ.MYS.60UP.MA
# PRJ.MYS.60UP.MF
# PRJ.MYS.65UP.FE
# PRJ.MYS.65UP.MA
# PRJ.MYS.65UP.MF
# PRJ.MYS.80UP.FE
# PRJ.MYS.80UP.MA
# PRJ.MYS.80UP.MF
# PRJ.ATT.15UP.S1.FE
# PRJ.ATT.15UP.S1.MA
# PRJ.ATT.15UP.S1.MF
# PRJ.ATT.15UP.2.FE
# PRJ.ATT.15UP.2.MA
# PRJ.ATT.15UP.2.MF
# PRJ.ATT.15UP.NED.FE
# PRJ.ATT.15UP.NED.MA
# PRJ.ATT.15UP.NED.MF
# PRJ.ATT.15UP.4.FE
# PRJ.ATT.15UP.4.MA
# PRJ.ATT.15UP.4.MF
# PRJ.ATT.15UP.1.FE
# PRJ.ATT.15UP.1.MA
# PRJ.ATT.15UP.1.MF
# PRJ.ATT.15UP.3.FE
# PRJ.ATT.15UP.3.MA
# PRJ.ATT.15UP.3.MF
# PRJ.ATT.1519.S1.FE
# PRJ.ATT.1519.S1.MA
# PRJ.ATT.1519.S1.MF
# PRJ.ATT.1519.2.FE
# PRJ.ATT.1519.2.MA
# PRJ.ATT.1519.2.MF
# PRJ.ATT.1519.NED.FE
# PRJ.ATT.1519.NED.MA
# PRJ.ATT.1519.NED.MF
# PRJ.ATT.1519.4.FE
# PRJ.ATT.1519.4.MA
# PRJ.ATT.1519.4.MF
# PRJ.ATT.1519.1.FE
# PRJ.ATT.1519.1.MA
# PRJ.ATT.1519.1.MF
# PRJ.ATT.1519.3.FE
# PRJ.ATT.1519.3.MA
# PRJ.ATT.1519.3.MF
# PRJ.ATT.2024.S1.FE
# PRJ.ATT.2024.S1.MA
# PRJ.ATT.2024.S1.MF
# PRJ.ATT.2024.2.FE
# PRJ.ATT.2024.2.MA
# PRJ.ATT.2024.2.MF
# PRJ.ATT.2024.NED.FE
# PRJ.ATT.2024.NED.MA
# PRJ.ATT.2024.NED.MF
# PRJ.ATT.2024.4.FE
# PRJ.ATT.2024.4.MA
# PRJ.ATT.2024.4.MF
# PRJ.ATT.2024.1.FE
# PRJ.ATT.2024.1.MA
# PRJ.ATT.2024.1.MF
# PRJ.ATT.2024.3.FE
# PRJ.ATT.2024.3.MA
# PRJ.ATT.2024.3.MF
# PRJ.ATT.2039.S1.FE
# PRJ.ATT.2039.S1.MA
# PRJ.ATT.2039.S1.MF
# PRJ.ATT.2039.2.FE
# PRJ.ATT.2039.2.MA
# PRJ.ATT.2039.2.MF
# PRJ.ATT.2039.NED.FE
# PRJ.ATT.2039.NED.MA
# PRJ.ATT.2039.NED.MF
# PRJ.ATT.2039.4.FE
# PRJ.ATT.2039.4.MA
# PRJ.ATT.2039.4.MF
# PRJ.ATT.2039.1.FE
# PRJ.ATT.2039.1.MA
# PRJ.ATT.2039.1.MF
# PRJ.ATT.2039.3.FE
# PRJ.ATT.2039.3.MA
# PRJ.ATT.2039.3.MF
# PRJ.ATT.2064.S1.FE
# PRJ.ATT.2064.S1.MA
# PRJ.ATT.2064.S1.MF
# PRJ.ATT.2064.2.FE
# PRJ.ATT.2064.2.MA
# PRJ.ATT.2064.2.MF
# PRJ.ATT.2064.NED.FE
# PRJ.ATT.2064.NED.MA
# PRJ.ATT.2064.NED.MF
# PRJ.ATT.2064.4.FE
# PRJ.ATT.2064.4.MA
# PRJ.ATT.2064.4.MF
# PRJ.ATT.2064.1.FE
# PRJ.ATT.2064.1.MA
# PRJ.ATT.2064.1.MF
# PRJ.ATT.2064.3.FE
# PRJ.ATT.2064.3.MA
# PRJ.ATT.2064.3.MF
# PRJ.ATT.25UP.S1.FE
# PRJ.ATT.25UP.S1.MA
# PRJ.ATT.25UP.S1.MF
# PRJ.ATT.25UP.2.FE
# PRJ.ATT.25UP.2.MA
# PRJ.ATT.25UP.2.MF
# PRJ.ATT.25UP.NED.FE
# PRJ.ATT.25UP.NED.MA
# PRJ.ATT.25UP.NED.MF
# PRJ.ATT.25UP.4.FE
# PRJ.ATT.25UP.4.MA
# PRJ.ATT.25UP.4.MF
# PRJ.ATT.25UP.1.FE
# PRJ.ATT.25UP.1.MA
# PRJ.ATT.25UP.1.MF
# PRJ.ATT.25UP.3.FE
# PRJ.ATT.25UP.3.MA
# PRJ.ATT.25UP.3.MF
# PRJ.ATT.2529.S1.FE
# PRJ.ATT.2529.S1.MA
# PRJ.ATT.2529.S1.MF
# PRJ.ATT.2529.2.FE
# PRJ.ATT.2529.2.MA
# PRJ.ATT.2529.2.MF
# PRJ.ATT.2529.NED.FE
# PRJ.ATT.2529.NED.MA
# PRJ.ATT.2529.NED.MF
# PRJ.ATT.2529.4.FE
# PRJ.ATT.2529.4.MA
# PRJ.ATT.2529.4.MF
# PRJ.ATT.2529.1.FE
# PRJ.ATT.2529.1.MA
# PRJ.ATT.2529.1.MF
# PRJ.ATT.2529.3.FE
# PRJ.ATT.2529.3.MA
# PRJ.ATT.2529.3.MF
# PRJ.ATT.4064.S1.FE
# PRJ.ATT.4064.S1.MA
# PRJ.ATT.4064.S1.MF
# PRJ.ATT.4064.2.FE
# PRJ.ATT.4064.2.MA
# PRJ.ATT.4064.2.MF
# PRJ.ATT.4064.NED.FE
# PRJ.ATT.4064.NED.MA
# PRJ.ATT.4064.NED.MF
# PRJ.ATT.4064.4.FE
# PRJ.ATT.4064.4.MA
# PRJ.ATT.4064.4.MF
# PRJ.ATT.4064.1.FE
# PRJ.ATT.4064.1.MA
# PRJ.ATT.4064.1.MF
# PRJ.ATT.4064.3.FE
# PRJ.ATT.4064.3.MA
# PRJ.ATT.4064.3.MF
# PRJ.ATT.60UP.S1.FE
# PRJ.ATT.60UP.S1.MA
# PRJ.ATT.60UP.S1.MF
# PRJ.ATT.60UP.2.FE
# PRJ.ATT.60UP.2.MA
# PRJ.ATT.60UP.2.MF
# PRJ.ATT.60UP.NED.FE
# PRJ.ATT.60UP.NED.MA
# PRJ.ATT.60UP.NED.MF
# PRJ.ATT.60UP.4.FE
# PRJ.ATT.60UP.4.MA
# PRJ.ATT.60UP.4.MF
# PRJ.ATT.60UP.1.FE
# PRJ.ATT.60UP.1.MA
# PRJ.ATT.60UP.1.MF
# PRJ.ATT.60UP.3.FE
# PRJ.ATT.60UP.3.MA
# PRJ.ATT.60UP.3.MF
# PRJ.ATT.80UP.S1.FE
# PRJ.ATT.80UP.S1.MA
# PRJ.ATT.80UP.S1.MF
# PRJ.ATT.80UP.2.FE
# PRJ.ATT.80UP.2.MA
# PRJ.ATT.80UP.2.MF
# PRJ.ATT.80UP.NED.FE
# PRJ.ATT.80UP.NED.MA
# PRJ.ATT.80UP.NED.MF
# PRJ.ATT.80UP.4.FE
# PRJ.ATT.80UP.4.MA
# PRJ.ATT.80UP.4.MF
# PRJ.ATT.80UP.1.FE
# PRJ.ATT.80UP.1.MA
# PRJ.ATT.80UP.1.MF
# PRJ.ATT.80UP.3.FE
# PRJ.ATT.80UP.3.MA
# PRJ.ATT.80UP.3.MF
# PRJ.ATT.ALL.S1.FE
# PRJ.ATT.ALL.S1.MA
# PRJ.ATT.ALL.S1.MF
# PRJ.ATT.ALL.2.FE
# PRJ.ATT.ALL.2.MA
# PRJ.ATT.ALL.2.MF
# PRJ.ATT.ALL.NED.FE
# PRJ.ATT.ALL.NED.MA
# PRJ.ATT.ALL.NED.MF
# PRJ.ATT.ALL.4.FE
# PRJ.ATT.ALL.4.MA
# PRJ.ATT.ALL.4.MF
# PRJ.ATT.ALL.1.FE
# PRJ.ATT.ALL.1.MA
# PRJ.ATT.ALL.1.MF
# PRJ.ATT.ALL.3.FE
# PRJ.ATT.ALL.3.MA
# PRJ.ATT.ALL.3.MF
# PRJ.POP.1519.S1.FE
# PRJ.POP.1519.S1.MA
# PRJ.POP.1519.S1.MF
# PRJ.POP.1519.2.FE
# PRJ.POP.1519.2.MA
# PRJ.POP.1519.2.MF
# PRJ.POP.1519.NED.FE
# PRJ.POP.1519.NED.MA
# PRJ.POP.1519.NED.MF
# PRJ.POP.1519.4.FE
# PRJ.POP.1519.4.MA
# PRJ.POP.1519.4.MF
# PRJ.POP.1519.1.FE
# PRJ.POP.1519.1.MA
# PRJ.POP.1519.1.MF
# PRJ.POP.1519.3.FE
# PRJ.POP.1519.3.MA
# PRJ.POP.1519.3.MF
# PRJ.POP.2024.S1.FE
# PRJ.POP.2024.S1.MA
# PRJ.POP.2024.S1.MF
# PRJ.POP.2024.2.FE
# PRJ.POP.2024.2.MA
# PRJ.POP.2024.2.MF
# PRJ.POP.2024.NED.FE
# PRJ.POP.2024.NED.MA
# PRJ.POP.2024.NED.MF
# PRJ.POP.2024.4.FE
# PRJ.POP.2024.4.MA
# PRJ.POP.2024.4.MF
# PRJ.POP.2024.1.FE
# PRJ.POP.2024.1.MA
# PRJ.POP.2024.1.MF
# PRJ.POP.2024.3.FE
# PRJ.POP.2024.3.MA
# PRJ.POP.2024.3.MF
# PRJ.POP.2529.S1.FE
# PRJ.POP.2529.S1.MA
# PRJ.POP.2529.S1.MF
# PRJ.POP.2529.2.FE
# PRJ.POP.2529.2.MA
# PRJ.POP.2529.2.MF
# PRJ.POP.2529.NED.FE
# PRJ.POP.2529.NED.MA
# PRJ.POP.2529.NED.MF
# PRJ.POP.2529.4.FE
# PRJ.POP.2529.4.MA
# PRJ.POP.2529.4.MF
# PRJ.POP.2529.1.FE
# PRJ.POP.2529.1.MA
# PRJ.POP.2529.1.MF
# PRJ.POP.2529.3.FE
# PRJ.POP.2529.3.MA
# PRJ.POP.2529.3.MF
# PRJ.POP.ALL.S1.FE
# PRJ.POP.ALL.S1.MA
# PRJ.POP.ALL.S1.MF
# PRJ.POP.ALL.2.FE
# PRJ.POP.ALL.2.MA
# PRJ.POP.ALL.2.MF
# PRJ.POP.ALL.NED.FE
# PRJ.POP.ALL.NED.MA
# PRJ.POP.ALL.NED.MF
# PRJ.POP.ALL.4.FE
# PRJ.POP.ALL.4.MA
# PRJ.POP.ALL.4.MF
# PRJ.POP.ALL.1.FE
# PRJ.POP.ALL.1.MA
# PRJ.POP.ALL.1.MF
# PRJ.POP.ALL.3.FE
# PRJ.POP.ALL.3.MA
# PRJ.POP.ALL.3.MF
# UIS.LPP.AG15T24
# UIS.LP.AG15T24
# UIS.LP.AG15T24.F
# UIS.LP.AG15T24.M
# SE.ADT.1524.LT.ZS
# SE.ADT.1524.LT.FE.ZS
# SE.ADT.1524.LT.FM.ZS
# SE.ADT.1524.LT.MA.ZS

# %%
# Python program to print list
# using for loop
a = [1, 2, 3, 4, 5]
  
# printing the list using loop
for x in range(len(a)):
    print(a[x])
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# refactor in a function to assess from whole dataframe

def get_df_avalaible_values(df):
    indicators_list = df['Indicator Code'].unique()
    available_values_list = []
    
    for i in range(len(indicators_list)):
        indicator_full_data = df.loc[df['Indicator Code'] == indicators_list[i]]
        indicator_years_data = indicator_full_data.loc[:, ~indicator_full_data.columns.isin(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'])]
        df_nan_count = indicator_years_data.isna().values.sum()
        df_non_nan_count = indicator_years_data.count().sum()
        available_values_percent = round((df_non_nan_count / (df_non_nan_count + df_nan_count) * 100), 2)
        available_values_list.append(available_values_percent)
        
    
    available_values_df = pd.DataFrame({'Indicator Code':indicators_list,
                                  'percent_available': available_values_list
                                 })   
    return available_values_df

# %% [markdown]
# ### get results

# %%
result = get_df_avalaible_values(data['Data'])
result
# Out:
#             Indicator Code  percent_available
# 0               UIS.NERA.2              15.06
# 1             UIS.NERA.2.F              14.15
# 2           UIS.NERA.2.GPI              14.07
# 3             UIS.NERA.2.M              14.07
# 4              SE.PRM.TENR              20.14
# ...                    ...                ...
# 3660      UIS.LP.AG15T24.M               6.66
# 3661     SE.ADT.1524.LT.ZS               8.13
# 3662  SE.ADT.1524.LT.FE.ZS               8.12
# 3663  SE.ADT.1524.LT.FM.ZS               8.12
# 3664  SE.ADT.1524.LT.MA.ZS               8.12
#
# [3665 rows x 2 columns]

# %% [markdown]
# ### plotting results

# %%
ax = sns.displot(result['percent_available'])

# %%
sns.histplot(data=result, y="percent_available")
# Out:
# <AxesSubplot:xlabel='Count', ylabel='percent_available'>

# %%
result.head()
# Out:
#    Indicator Code  percent_available
# 0      UIS.NERA.2              15.06
# 1    UIS.NERA.2.F              14.15
# 2  UIS.NERA.2.GPI              14.07
# 3    UIS.NERA.2.M              14.07
# 4     SE.PRM.TENR              20.14

# %%
sns.catplot(data=result.head(), x="Indicator Code", y="percent_available", kind="bar")
plt.xticks(rotation=70)
plt.tight_layout()

# %%
sns.catplot(data=result, x="Indicator Code", y="percent_available", kind="bar")
plt.xticks(rotation=70)
plt.tight_layout()

# %%
# take top 200 results from dataframe and plot them
