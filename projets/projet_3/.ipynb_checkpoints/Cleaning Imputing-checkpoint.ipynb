# %%
# imports

import os
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
pd.options.mode.chained_assignment = None  # default='warn

pd.set_option('display.max_rows', 750)
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_colwidth', None)

# %%
path = './data/'
csv_path = path + 'to_input_openfoodfacts.csv'
sm_df = pd.read_csv(csv_path, low_memory=False)

# %%
import numpy as np
from sklearn.impute import SimpleImputer

# %%
sm_df.head()
# Out:
#                 product_name pnns_groups_1 pnns_groups_2  \
# 0             jeunes pousses       unknown       unknown
# 1                    L.casei       unknown       unknown
# 2                      Cacao       unknown       unknown
# 3  Filetes de pollo empanado       unknown       unknown
# 4          Burger Meat Pollo       unknown       unknown
#
#                    code  energy-kcal_100g  fat_100g  saturated-fat_100g  \
# 0     00000000000000225               NaN       NaN                 NaN
# 1  00000000000003429145               NaN       1.4                 0.9
# 2         0000000000031               NaN       NaN                 NaN
# 3    000000000003327986             163.9       1.9                 1.0
# 4    000000000004128579             194.0      11.0                 3.9
#
#    carbohydrates_100g  sugars_100g  proteins_100g  salt_100g  sodium_100g
# 0                 NaN          NaN            NaN        NaN          NaN
# 1                 9.8         9.80            2.7        0.1         0.04
# 2                 NaN          NaN            NaN        NaN          NaN
# 3                 NaN          NaN           15.3        1.1         0.44
# 4                 5.7         0.05           18.0        NaN          NaN

# %%
main_cats = sm_df['pnns_groups_1'].unique()
main_cats
# Out:
# array(['unknown', 'Fat and sauces', 'Composite foods', 'Sugary snacks',
#        'Fruits and vegetables', 'Fish Meat Eggs', 'Beverages',
#        'Milk and dairy products', 'Cereals and potatoes', 'Salty snacks',
#        'Alcoholic beverages', nan, 'sugary-snacks'], dtype=object)

# %%
sm_df['pnns_groups_1'].value_counts()
# Out:
# unknown                    1166781
# Fish Meat Eggs              114618
# Milk and dairy products     100917
# Cereals and potatoes         78293
# Beverages                    70328
# Fat and sauces               63673
# Composite foods              58221
# Fruits and vegetables        55942
# Sugary snacks                47312
# Salty snacks                 28204
# Alcoholic beverages          20093
# sugary-snacks                    2
# Name: pnns_groups_1, dtype: int64

# %%
sm_df['pnns_groups_1'].value_counts()
# Out:
# unknown                    1166781
# Fish Meat Eggs              114618
# Milk and dairy products     100917
# Cereals and potatoes         78293
# Beverages                    70328
# Fat and sauces               63673
# Composite foods              58221
# Fruits and vegetables        55942
# Sugary snacks                47312
# Salty snacks                 28204
# Alcoholic beverages          20093
# sugary-snacks                    2
# Name: pnns_groups_1, dtype: int64

# %%
all_cols = sm_df['pnns_groups_1'].unique().tolist()
all_cols
# Out:
# ['unknown',
#  'Fat and sauces',
#  'Composite foods',
#  'Sugary snacks',
#  'Fruits and vegetables',
#  'Fish Meat Eggs',
#  'Beverages',
#  'Milk and dairy products',
#  'Cereals and potatoes',
#  'Salty snacks',
#  'Alcoholic beverages',
#  nan,
#  'sugary-snacks']

# %%
sm_df.columns
# Out:
# Index(['product_name', 'pnns_groups_1', 'pnns_groups_2', 'code',
#        'energy-kcal_100g', 'fat_100g', 'saturated-fat_100g',
#        'carbohydrates_100g', 'sugars_100g', 'proteins_100g', 'salt_100g',
#        'sodium_100g'],
#       dtype='object')

# %%
main_cats = ['fat_100g', 'salt_100g']
complementary_cats = ['saturated-fat_100g','sodium_100g']

# %%
final_cats = [c for c in all_cols if c not in main_cats+complementary_cats]
final_cats
# Out:
# ['unknown',
#  'Fat and sauces',
#  'Composite foods',
#  'Sugary snacks',
#  'Fruits and vegetables',
#  'Fish Meat Eggs',
#  'Beverages',
#  'Milk and dairy products',
#  'Cereals and potatoes',
#  'Salty snacks',
#  'Alcoholic beverages',
#  nan,
#  'sugary-snacks']

# %%
#groupby pnns_groups_1, mean, remplir avec mean / categorie
#list1 = ["fat_100g", "salt_100g"]
main_cats
# Out:
# ['fat_100g', 'salt_100g']

# %%
main_cats_grp = main_cats.append('pnns_group_1')
main_cats_grp

# %%
main_cats_grp = ['fat_100g', 'salt_100g', 'pnns_group_1']
main_cats_grp
# Out:
# ['fat_100g', 'salt_100g', 'pnns_group_1']

# %%
# sm_df[[c for c in df.columns if c in main_cats]].head()

# %%
sm_df.filter(main_cats).head()
# Out:
#    fat_100g  salt_100g
# 0       NaN        NaN
# 1       1.4        0.1
# 2       NaN        NaN
# 3       1.9        1.1
# 4      11.0        NaN

# %%
sm_df_groupby = sm_df.groupby(by='pnns_groups_1')

# %%
sm_df_groupby.mean()
# Out:
#                          energy-kcal_100g   fat_100g  saturated-fat_100g  \
# pnns_groups_1
# Alcoholic beverages             66.821537   1.324277            0.269855
# Beverages                       48.412707   0.821225            0.428708
# Cereals and potatoes           294.315671   4.692302            1.023522
# Composite foods                177.363104   7.561558            2.496990
# Fat and sauces                 229.007425  16.518870            4.782780
# Fish Meat Eggs                 207.294995  12.759877            4.190822
# Fruits and vegetables           72.043071   1.494367            0.333472
# Milk and dairy products        223.190792  15.607347           10.115245
# Salty snacks                   380.132543  29.338509            6.319236
# Sugary snacks                  275.076945   7.891178            3.244172
# sugary-snacks                         NaN        NaN                 NaN
# unknown                        201.843270   9.480352            3.254674
#
#                          carbohydrates_100g  sugars_100g  proteins_100g  \
# pnns_groups_1
# Alcoholic beverages                7.832151     3.613592       1.420671
# Beverages                          8.324501     7.093757       0.952815
# Cereals and potatoes              50.997691     3.000721      10.045625
# Composite foods                   18.210216     2.571389       7.666515
# Fat and sauces                    10.548242     7.185771       1.966969
# Fish Meat Eggs                     2.694070     0.897322      18.915734
# Fruits and vegetables             11.227790     6.714644       2.066187
# Milk and dairy products            7.704649     5.976818      12.266726
# Salty snacks                      18.658572     1.900867       8.431316
# Sugary snacks                     42.347374    19.393121       3.912719
# sugary-snacks                           NaN          NaN            NaN
# unknown                           18.181003     4.868732       9.364569
#
#                          salt_100g  sodium_100g
# pnns_groups_1
# Alcoholic beverages       0.490174     0.223693
# Beverages                 0.208003     0.094003
# Cereals and potatoes      0.683726     0.275108
# Composite foods           1.178701     0.472504
# Fat and sauces            2.018059     0.812265
# Fish Meat Eggs            1.935001     0.776855
# Fruits and vegetables     0.517703     0.209516
# Milk and dairy products   0.872055     0.363077
# Salty snacks              1.658129     0.666026
# Sugary snacks             0.487017     0.199135
# sugary-snacks                  NaN          NaN
# unknown                   1.385344     0.588469

# %%
## faire fonction et apply par ligne ou boucler sur données uniques

# %%
## utiliser index (str) de sm_df_groupby

# %%
#sm_df.filter(main_cats_grp).head()

# %%
### appliquer imputer différentes strategies (check distribution) avec un groupby categories
### iterative imputer / estimation du choix d'imputer selon la distribution (mean/median/most frequent...)

# %%
imp_med = SimpleImputer(missing_values=np.nan, strategy='median')
imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')

# %%
# IterativeImputer avec estimator=LinearRegression()
#list2 = ["saturated-fat_100g", "sodium_100g"] 
complementary_cats

# %%
sm_df.filter(complementary_cats).head()

# %%
#Reste des variables contenant des valeurs vides (sans list1, list2,  pnns_groups_1, pnns_groups_2) : 
# remplir soit avec la moyenne soit avec la mediane, en fonction de la distribution 
#- remplir avec la valeur la plus fréquente
