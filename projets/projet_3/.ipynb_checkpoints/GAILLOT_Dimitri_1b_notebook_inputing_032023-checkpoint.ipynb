# %% [markdown]
# # imports

# %%
# imports

import os
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.preprocessing import PowerTransformer

# %matplotlib inline
pd.options.mode.chained_assignment = None  # default='warn

pd.set_option('display.max_rows', 750)
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_colwidth', None)

# %%
#imp_med = SimpleImputer(missing_values=np.nan, strategy='median')
#imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')

# %%
path = './data/'
csv_path = path + 'to_input_openfoodfacts.csv'
#csv_path = path + 'en.openfoodfacts.org.products.csv'
sm_df = pd.read_csv(csv_path, low_memory=False)

# %% [markdown]
# # Dataframe info

# %% [markdown]
# ## functions

# %%
def get_df_columns_na(df):
    nan_values = df.isnull().sum()
    nan_percent = nan_values /df.shape[0]*100
    nan_info = pd.concat([nan_values,nan_percent],axis=1)
    nan_info.columns = ['count', 'null_percent']
    nan_info = nan_info.sort_values(by='null_percent',ascending=True)
    return nan_info

# %%
def plot_df_xy(df, x_val, y_val, height_val = 20, width_val = 13):
    sns.catplot(data=df, x= x_val, y= y_val, kind="bar", height=height_val, aspect=width_val/height_val)
    sns.set(rc={'figure.figsize':(width_val,height_val)})
    plt.xticks(rotation=70)
    plt.tight_layout()

# %%
def show_nulls(df, display=False):
    df_nulls = get_df_columns_na(df).sort_values(by='null_percent',ascending=False)
    print(df_nulls)
    if display == True:
        plot_df_xy(df_nulls.reset_index(), 'null_percent', 'index', 7)

# %%
def boxplot_nums_old(df, num_cols, energy_cols, scores_cols):
    sns.set(rc={'figure.figsize':(11.7,8.27)})
    fig, ax  = plt.subplots(1,3, gridspec_kw={'width_ratios': [8, 1, 1]})
    sns.boxplot(data=df[num_cols], ax=ax[0])
    sns.boxplot(data=df[energy_cols], ax=ax[1])
    sns.boxplot(data=df[scores_cols], ax=ax[2])
    ax[0].set_xticklabels(ax[0].get_xticklabels(),rotation=55)
    ax[1].set_xticklabels(ax[1].get_xticklabels(),rotation=55)
    ax[2].set_xticklabels(ax[2].get_xticklabels(),rotation=55)
    plt.show()

# %%
def boxplot_nums(df, cols_lists):
    sns.set(rc={'figure.figsize':(11.7,8.27)})
    
    col_lists_len = len(cols_lists)
    all_lists_len = []
    iter = 0
    for i in cols_lists:
        all_lists_len.append(len(i))
    
    fig, ax  = plt.subplots(1,col_lists_len, gridspec_kw={'width_ratios': all_lists_len})
    
    for i in cols_lists:
        sns.boxplot(data=df[i], ax=ax[iter])
        ax[iter].set_xticklabels(ax[iter].get_xticklabels(),rotation=55)
        iter+=1
    
    plt.show()

# %%
def UVA_numeric2(data, i):
  '''
  Univariate_Analysis_numeric
  takes a group of variables (INTEGER and FLOAT) and plot/print all the descriptives and properties along with KDE.

  Runs a loop: calculate all the descriptives of i(th) variable and plot/print it
  '''
  # calculating descriptives of variable
  mini = data[i].min()
  maxi = data[i].max()
  ran = data[i].max()-data[i].min()
  mean = data[i].mean()
  median = data[i].median()
  st_dev = data[i].std()
  skew = data[i].skew()
  kurt = data[i].kurtosis()

  # calculating points of standard deviation
  points = mean-st_dev, mean+st_dev
    

  #fig, ax = plt.subplots()
  sns.kdeplot(data[i]
                  #, shade=True
                  , fill=True
                )
    
  max_ax = (sns.kdeplot(data[i]).lines[0].get_xydata())[:, 1].max()
  y_line = [max_ax/100, max_ax/100]
  y_point = [max_ax/100]
    
  sns.lineplot(x = points, y=y_line, color = 'black', label = "marg_err")
  sns.scatterplot(x=[mini,maxi], y=y_line, color = 'orange', label = "min/max")
  sns.scatterplot(x=[mean], y=y_point, color = 'red', label = "mean")
  sns.scatterplot(x=[median], y=y_point, color = 'blue', label = "median")
  plt.xlabel('{}'.format(i), fontsize = 20)
  plt.ylabel('density')
  plt.title('margin_error = {}; kurtosis = {};\nskew = {}; range = {}\nmean = {}; median = {}'.format((round(points[0],2),round(points[1],2)),
                                                                                                   round(kurt,2),
                                                                                                   round(skew,2),
                                                                                                   (round(mini,2),round(maxi,2),round(ran,2)),
                                                                                                   round(mean,2),
                                                                                                   round(median,2)))

# %%
# afficher détail Boxplot / UVA_num pour chaque indicateur par ligne

def UVA_num_plus(df, indicators_list):
  
    for i in indicators_list:
        plt.figure(figsize = (15, 20))
        df_indic = df[i]

        plt.subplot(5,2,1)
        sns.boxplot(y=df_indic, showmeans=True)
        plt.xlabel(f'{i}', fontsize = 20)


        plt.subplot(5,2,2)
        UVA_numeric2(df, i)

# %% [markdown]
# ## General distribution / NaNs

# %%
sm_df.shape
# Out:
# (46254, 15)

# %%
sm_df.head()
# Out:
#        code nutrition_grade_fr  nutrition-score-fr_100g  proteins_100g  \
# 0  10187319                  d                     14.0            0.6
# 1  10207260                  d                     14.0            9.5
# 2  40608754                  e                     13.0            0.0
# 3  69161025                  d                     15.0            7.5
# 4  87177756                  e                     13.0            0.0
#
#    energy_100g  salt_100g  sodium_100g  sugars_100g  saturated-fat_100g  \
# 0       1753.0     0.0100     0.003937         87.7                 0.8
# 1       2406.0     0.0030     0.001181         50.3                 2.9
# 2        177.0     0.0254     0.010000         10.4                 0.0
# 3       1079.0     0.8000     0.314961          1.0                11.0
# 4        177.0     0.1000     0.039370         10.4                 0.0
#
#                  product_name  fiber_100g  fat_100g  carbohydrates_100g  \
# 0              Mini Confettis         0.9       NaN                 NaN
# 1  Praliné Amande Et Noisette         3.9       NaN                 NaN
# 2       Pepsi, Nouveau goût !         0.0       0.0                10.4
# 3   Tarte Poireaux Et Lardons         1.4       NaN                 NaN
# 4                         7Up         NaN       0.0                10.4
#
#          pnns_groups_2 pnns_groups_1
# 0                  NaN           NaN
# 1                  NaN           NaN
# 2  Sweetened beverages     Beverages
# 3                  NaN           NaN
# 4  Sweetened beverages     Beverages

# %%
sm_df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46254 entries, 0 to 46253
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   code                     46254 non-null  int64
#  1   nutrition_grade_fr       46254 non-null  object
#  2   nutrition-score-fr_100g  36796 non-null  float64
#  3   proteins_100g            46187 non-null  float64
#  4   energy_100g              46015 non-null  float64
#  5   salt_100g                46186 non-null  float64
#  6   sodium_100g              46187 non-null  float64
#  7   sugars_100g              46184 non-null  float64
#  8   saturated-fat_100g       46186 non-null  float64
#  9   product_name             46254 non-null  object
#  10  fiber_100g               34517 non-null  float64
#  11  fat_100g                 29410 non-null  float64
#  12  carbohydrates_100g       29364 non-null  float64
#  13  pnns_groups_2            27834 non-null  object
#  14  pnns_groups_1            27746 non-null  object
# dtypes: float64(10), int64(1), object(4)
# memory usage: 5.3+ MB

# %%
sm_df.describe()
# Out:
#                code  nutrition-score-fr_100g  proteins_100g   energy_100g  \
# count  4.625400e+04             36796.000000   46187.000000  46015.000000
# mean   3.819760e+12                 9.375068       8.002255    902.814028
# std    4.428525e+12                 7.276457       8.175554    666.120119
# min    1.756000e+03                 0.000000       0.000000      0.000000
# 25%    3.248830e+12                 3.000000       1.500000    345.500000
# 50%    3.329770e+12                 9.000000       5.800000    751.000000
# 75%    3.608581e+12                15.000000      12.000000   1403.000000
# max    3.661112e+14                36.000000      90.000000   3761.000000
#
#           salt_100g   sodium_100g   sugars_100g  saturated-fat_100g  \
# count  46186.000000  46187.000000  46184.000000        46186.000000
# mean       1.030939      0.406938      8.410142            4.265709
# std        2.220297      0.903142     14.188582            7.076040
# min        0.000000      0.000000      0.000000            0.000000
# 25%        0.080000      0.031496      0.800000            0.200000
# 50%        0.650000      0.255906      2.900000            1.400000
# 75%        1.300000      0.511811     10.000000            5.000000
# max       68.200000     49.212598    100.000000          100.000000
#
#          fiber_100g      fat_100g  carbohydrates_100g
# count  34517.000000  29410.000000        29364.000000
# mean       2.082982      9.407097           16.340414
# std        4.110923     12.654028           20.163020
# min        0.000000      0.000000            0.000000
# 25%        0.000000      1.000000            2.500000
# 50%        1.000000      4.200000            9.400000
# 75%        2.600000     12.900000           20.400000
# max      100.000000     92.000000          100.000000

# %%
sm_df.columns.to_list()
# Out:
# ['code',
#  'nutrition_grade_fr',
#  'nutrition-score-fr_100g',
#  'proteins_100g',
#  'energy_100g',
#  'salt_100g',
#  'sodium_100g',
#  'sugars_100g',
#  'saturated-fat_100g',
#  'product_name',
#  'fiber_100g',
#  'fat_100g',
#  'carbohydrates_100g',
#  'pnns_groups_2',
#  'pnns_groups_1']

# %%
sm_num_cols = ['fat_100g', 'saturated-fat_100g',
               'carbohydrates_100g', 'sugars_100g', 'proteins_100g', 
               'salt_100g','sodium_100g',
               'fiber_100g']
energy_cols = ['energy_100g']
scores_cols = ['nutrition-score-fr_100g'
               #'ecoscore_grade'
              ]
macro_nutrients = ['fat_100g', 'saturated-fat_100g',
       'carbohydrates_100g', 'sugars_100g', 'proteins_100g']
salt = ['salt_100g', 'sodium_100g']

# %%
boxplot_nums(sm_df, [macro_nutrients, salt, energy_cols, scores_cols])

# %%
UVA_num_plus(sm_df, num_cols)

# %%
## initial (2 282 517, 186)

sm_df.shape

# %%
#sm_df.isna().sum()

# %%
show_nulls(sm_df)

# %% [markdown]
# ### Distribution avec retrait d'outliers

# %%
df.columns[df.dtypes == 'float64']

# %%
num_cols = ['nutrition-score-fr_100g', 'proteins_100g', 'energy_100g', 'salt_100g',
       'sodium_100g', 'sugars_100g', 'saturated-fat_100g', 'fiber_100g',
       'fat_100g', 'carbohydrates_100g']
energy_cols = ['energy_100g']
scores_cols = ['nutrition-score-fr_100g']


##

macro_nutrients = ['fat_100g', 'saturated-fat_100g',
       'carbohydrates_100g', 'sugars_100g', 'proteins_100g']
salt = ['salt_100g', 'sodium_100g']

# %%
skewed_num_cols = macro_nutrients + salt + energy_cols
skewed_num_cols

# %%
df.shape

# %%
q1 = df[skewed_num_cols].quantile(0.25)
q3 = df[skewed_num_cols].quantile(0.75)
iqr = q3 - q1

# %%
treshold = 1.5
out_low = q1 - treshold * iqr
out_high = q3 + treshold * iqr

# %%
# identify outliers at low and high range : 
np.sum((df.loc[:, skewed_num_cols] > out_high) | (df.loc[:, skewed_num_cols] < out_low))

# %%
outliers = ((df.loc[:, skewed_num_cols] > out_high) | (df.loc[:, skewed_num_cols] < out_low)).any(axis=1)

df_no_outliers = df.loc[~outliers, :]
df_no_outliers.shape

# %%
boxplot_nums(df_no_outliers, [macro_nutrients, salt, energy_cols, scores_cols])

# %%
# distribution sans outliers
UVA_num_plus(df_no_outliers, num_cols)

# %%
# compare means by categories for sugar_100g
df_no_outliers

# %% [markdown]
# ## Categories / "unknown"

# %%
main_cats = sm_df['pnns_groups_1'].unique()
main_cats
# Out:
# array([nan, 'Beverages', 'Fruits and vegetables', 'Salty snacks',
#        'Composite foods', 'Fat and sauces', 'Sugary snacks',
#        'Milk and dairy products', 'Cereals and potatoes',
#        'Fish Meat Eggs'], dtype=object)

# %%
sm_df['pnns_groups_1'].value_counts()
# Out:
# pnns_groups_1
# Composite foods            4763
# Milk and dairy products    4725
# Fish Meat Eggs             4444
# Beverages                  3789
# Cereals and potatoes       3465
# Fruits and vegetables      2741
# Fat and sauces             2007
# Sugary snacks              1231
# Salty snacks                581
# Name: count, dtype: int64

# %%
all_cats = sm_df['pnns_groups_1'].unique().tolist()
all_cats
# Out:
# [nan,
#  'Beverages',
#  'Fruits and vegetables',
#  'Salty snacks',
#  'Composite foods',
#  'Fat and sauces',
#  'Sugary snacks',
#  'Milk and dairy products',
#  'Cereals and potatoes',
#  'Fish Meat Eggs']

# %%
all_cols = sm_df.columns
all_cols
# Out:
# Index(['code', 'nutrition_grade_fr', 'nutrition-score-fr_100g',
#        'proteins_100g', 'energy_100g', 'salt_100g', 'sodium_100g',
#        'sugars_100g', 'saturated-fat_100g', 'product_name', 'fiber_100g',
#        'fat_100g', 'carbohydrates_100g', 'pnns_groups_2', 'pnns_groups_1'],
#       dtype='object')

# %%
main_cats = ['fat_100g', 'salt_100g']
complementary_cats = ['saturated-fat_100g','sodium_100g']

# %%
final_cats = [c for c in all_cols if c not in main_cats+complementary_cats]
final_cats
# Out:
# ['code',
#  'nutrition_grade_fr',
#  'nutrition-score-fr_100g',
#  'proteins_100g',
#  'energy_100g',
#  'sugars_100g',
#  'product_name',
#  'fiber_100g',
#  'carbohydrates_100g',
#  'pnns_groups_2',
#  'pnns_groups_1']

# %%
all_cols
# Out:
# Index(['code', 'nutrition_grade_fr', 'nutrition-score-fr_100g',
#        'proteins_100g', 'energy_100g', 'salt_100g', 'sodium_100g',
#        'sugars_100g', 'saturated-fat_100g', 'product_name', 'fiber_100g',
#        'fat_100g', 'carbohydrates_100g', 'pnns_groups_2', 'pnns_groups_1'],
#       dtype='object')

# %%
num_cols = sm_df.columns[sm_df.dtypes == 'float64']
num_cols
# Out:
# Index(['nutrition-score-fr_100g', 'proteins_100g', 'energy_100g', 'salt_100g',
#        'sodium_100g', 'sugars_100g', 'saturated-fat_100g', 'fiber_100g',
#        'fat_100g', 'carbohydrates_100g'],
#       dtype='object')

# %% [markdown]
# # Inputing

# %% [markdown]
# ## categories : most frequent

# %%
sm_df['pnns_groups_1'].value_counts()
# Out:
# pnns_groups_1
# Composite foods            4763
# Milk and dairy products    4725
# Fish Meat Eggs             4444
# Beverages                  3789
# Cereals and potatoes       3465
# Fruits and vegetables      2741
# Fat and sauces             2007
# Sugary snacks              1231
# Salty snacks                581
# Name: count, dtype: int64

# %%
sm_df.shape
# Out:
# (46254, 15)

# %%
## categorical pnn1 

## inputing valeur vides avec valeur plus fréQUENTE / SIMPLE IMPUTER _ strategy most _frequent
# SimpleImputer(strategy="most_frequent")

# %%
from sklearn.impute import SimpleImputer

# %%
imp_fre = SimpleImputer(missing_values=np.nan, strategy= 'most_frequent')

# %%
imp_pnns = imp_fre.fit_transform(sm_df[['pnns_groups_1', 'pnns_groups_2']])
imp_pnns
# Out:
# array([['Composite foods', 'One-dish meals'],
#        ['Composite foods', 'One-dish meals'],
#        ['Beverages', 'Sweetened beverages'],
#        ...,
#        ['Composite foods', 'One-dish meals'],
#        ['Composite foods', 'One-dish meals'],
#        ['Beverages', 'Non-sugared beverages']], dtype=object)

# %%
sm_df[['pnns_groups_1', 'pnns_groups_2']] = imp_pnns

# %%
show_nulls(sm_df)
# Out:
#                          count  null_percent
# carbohydrates_100g       16890     36.515761
# fat_100g                 16844     36.416310
# fiber_100g               11737     25.375103
# nutrition-score-fr_100g   9458     20.447961
# energy_100g                239      0.516712
# sugars_100g                 70      0.151338
# salt_100g                   68      0.147014
# saturated-fat_100g          68      0.147014
# proteins_100g               67      0.144852
# sodium_100g                 67      0.144852
# code                         0      0.000000
# nutrition_grade_fr           0      0.000000
# product_name                 0      0.000000
# pnns_groups_2                0      0.000000
# pnns_groups_1                0      0.000000

# %%
sm_df[['pnns_groups_1', 'pnns_groups_2']].head()
# Out:
#      pnns_groups_1        pnns_groups_2
# 0  Composite foods       One-dish meals
# 1  Composite foods       One-dish meals
# 2        Beverages  Sweetened beverages
# 3  Composite foods       One-dish meals
# 4        Beverages  Sweetened beverages

# %%
sm_df[['pnns_groups_1', 'pnns_groups_2']].value_counts()
# Out:
# pnns_groups_1            pnns_groups_2
# Composite foods          One-dish meals                      22299
# Cereals and potatoes     Cereals                              2219
# Fish Meat Eggs           Processed meat                       2080
# Milk and dairy products  Cheese                               2056
# Fat and sauces           Dressings and sauces                 1744
# Milk and dairy products  Milk and yogurt                      1626
# Fish Meat Eggs           Fish and seafood                     1494
# Beverages                Fruit juices                         1245
#                          Non-sugared beverages                1122
# Fruits and vegetables    Vegetables                           1082
# Beverages                Sweetened beverages                  1019
# Fruits and vegetables    Fruits                                827
# Fish Meat Eggs           Meat                                  770
# Cereals and potatoes     Bread                                 706
# Milk and dairy products  Dairy desserts                        616
# Sugary snacks            Sweets                                594
# Composite foods          Sandwich                              513
# Salty snacks             Appetizers                            473
# Milk and dairy products  Ice cream                             427
# Fruits and vegetables    vegetables                            390
# Cereals and potatoes     Legumes                               377
# Composite foods          Pizza pies and quiche                 371
# Fruits and vegetables    Soups                                 348
# Fat and sauces           Fats                                  263
# Sugary snacks            Biscuits and cakes                    262
# Beverages                Fruit nectars                         249
# Sugary snacks            pastries                              248
# Beverages                Artificially sweetened beverages      154
# Sugary snacks            Chocolate products                    127
# Cereals and potatoes     Breakfast cereals                     127
# Salty snacks             Nuts                                  101
# Fish Meat Eggs           Eggs                                  100
# Fruits and vegetables    Dried fruits                           77
# Composite foods          Tripe dishes                           47
#                          Alcoholic beverages                    41
# Cereals and potatoes     Potatoes                               35
# Fruits and vegetables    fruits                                 17
# Salty snacks             Salty and fatty products                7
# Cereals and potatoes     cereals                                 1
# Name: count, dtype: int64

# %% [markdown]
# ## numerical values

# %%
### appliquer imputer différentes strategies (check distribution) avec un groupby categories
### iterative imputer / estimation du choix d'imputer selon la distribution (mean/median/most frequent...)

# %%
# Use mean imputation if variables are normally distributed and median imputation otherwise. 
# Mean and median imputation may distort 
# the distribution of the original variables if there is a high percentage of missing data.

# %%
sm_num_cols
# Out:
# ['fat_100g',
#  'saturated-fat_100g',
#  'carbohydrates_100g',
#  'sugars_100g',
#  'proteins_100g',
#  'salt_100g',
#  'sodium_100g',
#  'fiber_100g']

# %%
boxplot_nums(sm_df, [sm_num_cols, energy_cols, scores_cols])

# %%
energy_cols
# Out:
# ['energy_100g']

# %% [markdown]
# ### sm_num_cols : fat / salt => median input

# %%
#imp_med = SimpleImputer(missing_values=np.nan, strategy='median')

###sm_df[all_num_cols] = imp_med.fit_transform(sm_df[all_num_cols])

# %%
# sm_df[[c for c in df.columns if c in main_cats]].head()

# %%
sm_df.filter(sm_num_cols).head()
# Out:
#    fat_100g  saturated-fat_100g  carbohydrates_100g  sugars_100g  \
# 0       NaN                 0.8                 NaN         87.7
# 1       NaN                 2.9                 NaN         50.3
# 2       0.0                 0.0                10.4         10.4
# 3       NaN                11.0                 NaN          1.0
# 4       0.0                 0.0                10.4         10.4
#
#    proteins_100g  salt_100g  sodium_100g  fiber_100g
# 0            0.6     0.0100     0.003937         0.9
# 1            9.5     0.0030     0.001181         3.9
# 2            0.0     0.0254     0.010000         0.0
# 3            7.5     0.8000     0.314961         1.4
# 4            0.0     0.1000     0.039370         NaN

# %%
sm_df_groupby = sm_df.groupby(by='pnns_groups_1')

# %%
sm_df.columns
# Out:
# Index(['code', 'nutrition_grade_fr', 'nutrition-score-fr_100g',
#        'proteins_100g', 'energy_100g', 'salt_100g', 'sodium_100g',
#        'sugars_100g', 'saturated-fat_100g', 'product_name', 'fiber_100g',
#        'fat_100g', 'carbohydrates_100g', 'pnns_groups_2', 'pnns_groups_1'],
#       dtype='object')

# %%
sm_df_groupby[sm_num_cols].median()
# Out:
#                          fat_100g  saturated-fat_100g  carbohydrates_100g  \
# pnns_groups_1
# Beverages                     0.0                0.00                9.70
# Cereals and potatoes          2.0                0.40               59.00
# Composite foods               6.7                1.90               12.41
# Fat and sauces               12.0                2.00                6.10
# Fish Meat Eggs               10.6                2.60                0.90
# Fruits and vegetables         0.4                0.10                6.07
# Milk and dairy products       9.7                6.50                4.80
# Salty snacks                 26.3                2.90               49.50
# Sugary snacks                 2.1                1.35               46.05
#
#                          sugars_100g  proteins_100g  salt_100g  sodium_100g  \
# pnns_groups_1
# Beverages                        9.0            0.3     0.0100     0.003937
# Cereals and potatoes             2.5            9.8     0.2000     0.078740
# Composite foods                  2.9            6.2     0.7500     0.295276
# Fat and sauces                   3.6            1.4     1.5000     0.590551
# Fish Meat Eggs                   0.6           19.5     1.8000     0.708661
# Fruits and vegetables            3.1            1.1     0.2159     0.085000
# Milk and dairy products          4.6            4.5     0.1524     0.060000
# Salty snacks                     2.0            6.4     1.3000     0.511811
# Sugary snacks                   19.1            3.6     0.1300     0.051181
#
#                          fiber_100g
# pnns_groups_1
# Beverages                     0.100
# Cereals and potatoes          3.500
# Composite foods               1.000
# Fat and sauces                1.000
# Fish Meat Eggs                0.001
# Fruits and vegetables         2.000
# Milk and dairy products       0.000
# Salty snacks                  4.000
# Sugary snacks                 1.300

# %%
sm_df_groupby[sm_num_cols].count()
# Out:
#                          fat_100g  saturated-fat_100g  carbohydrates_100g  \
# pnns_groups_1
# Beverages                    3119                3771                3131
# Cereals and potatoes         3208                3463                3220
# Composite foods              8644               23241                8625
# Fat and sauces               1816                2004                1815
# Fish Meat Eggs               4241                4441                4231
# Fruits and vegetables        2547                2739                2555
# Milk and dairy products      4487                4720                4439
# Salty snacks                  503                 579                 502
# Sugary snacks                 845                1228                 846
#
#                          sugars_100g  proteins_100g  salt_100g  sodium_100g  \
# pnns_groups_1
# Beverages                       3771           3771       3771         3771
# Cereals and potatoes            3463           3463       3463         3463
# Composite foods                23239          23241      23240        23241
# Fat and sauces                  2004           2004       2004         2004
# Fish Meat Eggs                  4441           4441       4441         4441
# Fruits and vegetables           2739           2739       2739         2739
# Milk and dairy products         4719           4720       4720         4720
# Salty snacks                     580            580        580          580
# Sugary snacks                   1228           1228       1228         1228
#
#                          fiber_100g
# pnns_groups_1
# Beverages                      2520
# Cereals and potatoes           2870
# Composite foods               20264
# Fat and sauces                 1136
# Fish Meat Eggs                 1898
# Fruits and vegetables          2346
# Milk and dairy products        2249
# Salty snacks                    316
# Sugary snacks                   918

# %%
# https://pandas.pydata.org/docs/user_guide/groupby.html

sm_df[sm_num_cols] = sm_df_groupby[sm_num_cols].transform(lambda x: x.fillna(x.median()))

# %%
sm_df.isna().sum()
# Out:
# code                          0
# nutrition_grade_fr            0
# nutrition-score-fr_100g    9458
# proteins_100g                 0
# energy_100g                 239
# salt_100g                     0
# sodium_100g                   0
# sugars_100g                   0
# saturated-fat_100g            0
# product_name                  0
# fiber_100g                    0
# fat_100g                      0
# carbohydrates_100g            0
# pnns_groups_2                 0
# pnns_groups_1                 0
# dtype: int64

# %%
show_nulls(sm_df)
# Out:
#                          count  null_percent
# nutrition-score-fr_100g   9458     20.447961
# energy_100g                239      0.516712
# code                         0      0.000000
# nutrition_grade_fr           0      0.000000
# proteins_100g                0      0.000000
# salt_100g                    0      0.000000
# sodium_100g                  0      0.000000
# sugars_100g                  0      0.000000
# saturated-fat_100g           0      0.000000
# product_name                 0      0.000000
# fiber_100g                   0      0.000000
# fat_100g                     0      0.000000
# carbohydrates_100g           0      0.000000
# pnns_groups_2                0      0.000000
# pnns_groups_1                0      0.000000

# %%
boxplot_nums(sm_df, [sm_num_cols, energy_cols, scores_cols])

# %%
#sm_df_gr_transf = sm_df_groupby[main_cats].transform(lambda x: x.fillna(x.mean()))
#sm_df_gr_transf

# %%
#grouped.transform(lambda x: x.fillna(inplace=False))

# %% [markdown]
# ## energy_100 / nutrition_score: mean inputing

# %%
sm_df_groupby[energy_cols+scores_cols].mean()
# Out:
#                          energy_100g  nutrition-score-fr_100g
# pnns_groups_1
# Beverages                 188.797017                 7.639745
# Cereals and potatoes     1223.079691                 4.076985
# Composite foods          1007.189627                 9.649005
# Fat and sauces           1137.965872                11.537906
# Fish Meat Eggs            852.493770                10.738947
# Fruits and vegetables     274.016969                 1.988728
# Milk and dairy products   836.730676                 9.211802
# Salty snacks             1894.692573                11.606947
# Sugary snacks            1217.795020                11.039496

# %%
sm_df[energy_cols+scores_cols] = sm_df_groupby[energy_cols+scores_cols].transform(lambda x: x.fillna(x.mean()))

# %% [markdown]
# # Check nulls

# %%
sm_df.shape
# Out:
# (46254, 15)

# %%
show_nulls(sm_df)
# Out:
#                          count  null_percent
# code                         0           0.0
# nutrition_grade_fr           0           0.0
# nutrition-score-fr_100g      0           0.0
# proteins_100g                0           0.0
# energy_100g                  0           0.0
# salt_100g                    0           0.0
# sodium_100g                  0           0.0
# sugars_100g                  0           0.0
# saturated-fat_100g           0           0.0
# product_name                 0           0.0
# fiber_100g                   0           0.0
# fat_100g                     0           0.0
# carbohydrates_100g           0           0.0
# pnns_groups_2                0           0.0
# pnns_groups_1                0           0.0

# %%
boxplot_nums(sm_df, [sm_num_cols, energy_cols, scores_cols])

# %%
np.log(sm_df[num_cols])
# Out:
# C:\Users\dgaillot\AppData\Local\anaconda3\envs\base_env\lib\site-packages\pandas\core\internals\blocks.py:329: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
#        nutrition-score-fr_100g  proteins_100g  energy_100g  salt_100g  \
# 0                     2.639057      -0.510826     7.469084  -4.605170
# 1                     2.639057       2.251292     7.785721  -5.809143
# 2                     2.564949           -inf     5.176150  -3.673006
# 3                     2.708050       2.014903     6.983790  -0.223144
# 4                     2.564949           -inf     5.176150  -2.302585
# ...                        ...            ...          ...        ...
# 46249                 0.693147      -5.521461     6.938284  -6.907755
# 46250                 2.772589       2.163323     6.988413  -1.237874
# 46251                     -inf       2.302585     1.386294   2.302585
# 46252                     -inf       3.054944     7.785721  -2.302585
# 46253                 0.693147      -0.693147     3.044522  -3.673006
#
#        sodium_100g  sugars_100g  saturated-fat_100g  fiber_100g  fat_100g  \
# 0        -5.537334     4.473922           -0.223144   -0.105361  1.902108
# 1        -6.741307     3.918005            1.064711    1.360977  1.902108
# 2        -4.605170     2.341806                -inf        -inf      -inf
# 3        -1.155308     0.000000            2.397895    0.336472  1.902108
# 4        -3.234749     2.341806                -inf   -2.302585      -inf
# ...            ...          ...                 ...         ...       ...
# 46249    -7.839919    -2.302585            0.246860    0.385262  0.262364
# 46250    -2.170038     2.351375            2.484907        -inf  1.902108
# 46251     1.370421     0.000000            0.000000    2.302585  1.902108
# 46252    -3.234749     1.358409            1.316408    2.501436  1.902108
# 46253    -4.605170    -0.693147           -1.609438   -1.609438 -1.609438
#
#        carbohydrates_100g
# 0                2.518503
# 1                2.518503
# 2                2.341806
# 3                2.518503
# 4                2.341806
# ...                   ...
# 46249            4.557135
# 46250            2.518503
# 46251            2.518503
# 46252            2.518503
# 46253           -0.693147
#
# [46254 rows x 10 columns]

# %%
UVA_num_plus(sm_df, num_cols)

# %%
log_score = np.log(sm_df['nutrition-score-fr_100g'], where=result > 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 log_score = np.log(sm_df['nutrition-score-fr_100g'], where=result > 0)
#
# NameError: name 'result' is not defined

# %%
sm_df['nutrition-score-fr_100g']
# Out:
# 0        14.0
# 1        14.0
# 2        13.0
# 3        15.0
# 4        13.0
#          ...
# 46249     2.0
# 46250    16.0
# 46251     0.0
# 46252     0.0
# 46253     2.0
# Name: nutrition-score-fr_100g, Length: 46254, dtype: float64

# %%
log_score
# Out:
# 0        2.639057
# 1        2.639057
# 2        2.564949
# 3        2.708050
# 4        2.564949
#            ...
# 46249    0.693147
# 46250    2.772589
# 46251        -inf
# 46252        -inf
# 46253    0.693147
# Name: nutrition-score-fr_100g, Length: 46254, dtype: float64

# %% [markdown]
# # export to csv

# %%
#sm_df.reset_index()

sm_df.to_csv(path + 'clean_openfoodfacts_3.csv', index=False)
print('export finished !')
# Out:
# export finished !

# %%
ls -lh ./data
# Out:
# total 8,9G
# -rw-r--r-- 1 mijka mijka 6,0M  6 mars  09:25 clean_openfoodfacts_3.csv
# -rw-r--r-- 1 mijka mijka 8,1G  1 déc.  17:49 en.openfoodfacts.org.products.csv
# -rw-r--r-- 1 mijka mijka 809M 21 avril  2017 fr.openfoodfacts.org.products.csv
# -rw-r--r-- 1 mijka mijka 5,2M  6 mars  09:25 to_input_openfoodfacts.csv
