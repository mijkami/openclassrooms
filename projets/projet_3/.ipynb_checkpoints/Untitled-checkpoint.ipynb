# %%
# imports

import os
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer

# %matplotlib inline
pd.options.mode.chained_assignment = None  # default='warn

pd.set_option('display.max_rows', 750)
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_colwidth', None)

# %%
imp_med = SimpleImputer(missing_values=np.nan, strategy='median')
imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')

# %%
path = './data/'
csv_path = path + 'fr.openfoodfacts.org.products.csv'
df = pd.read_csv(csv_path, low_memory=False, sep='\t')

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 320772 entries, 0 to 320771
# Data columns (total 162 columns):
#  #    Column                                      Dtype
# ---   ------                                      -----
#  0    code                                        object
#  1    url                                         object
#  2    creator                                     object
#  3    created_t                                   object
#  4    created_datetime                            object
#  5    last_modified_t                             object
#  6    last_modified_datetime                      object
#  7    product_name                                object
#  8    generic_name                                object
#  9    quantity                                    object
#  10   packaging                                   object
#  11   packaging_tags                              object
# ...

# %%
df.describe()
# Out:
#        no_nutriments    additives_n  ingredients_from_palm_oil_n  \
# count            0.0  248939.000000                248939.000000
# mean             NaN       1.936024                     0.019659
# std              NaN       2.502019                     0.140524
# min              NaN       0.000000                     0.000000
# 25%              NaN       0.000000                     0.000000
# 50%              NaN       1.000000                     0.000000
# 75%              NaN       3.000000                     0.000000
# max              NaN      31.000000                     2.000000
#
#        ingredients_from_palm_oil  ingredients_that_may_be_from_palm_oil_n  \
# count                        0.0                            248939.000000
# mean                         NaN                                 0.055246
# std                          NaN                                 0.269207
# min                          NaN                                 0.000000
# ...

# %%
df.head()
# Out:
#             code  \
# 0  0000000003087
# 1  0000000004530
# 2  0000000004559
# 3  0000000016087
# 4  0000000016094
#
#                                                                                           url  \
# 0  http://world-fr.openfoodfacts.org/produit/0000000003087/farine-de-ble-noir-ferme-t-y-r-nao
# 1        http://world-fr.openfoodfacts.org/produit/0000000004530/banana-chips-sweetened-whole
# 2                http://world-fr.openfoodfacts.org/produit/0000000004559/peanuts-torn-glasser
# 3    http://world-fr.openfoodfacts.org/produit/0000000016087/organic-salted-nut-mix-grizzlies
# 4      http://world-fr.openfoodfacts.org/produit/0000000016094/organic-polenta-bob-s-red-mill
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# ...

# %%
df.shape
# Out:
# (320772, 162)

# %%
#df.groupby(['Courses'])['Courses'].count()

# %%
# count distinct values
df.countries.nunique()
# Out:
# 1434

# %%
# show values
df.countries.unique().tolist()
# Out:
# ['en:FR',
#  'US',
#  'France',
#  'en:GB',
#  'France, US',
#  'Canada',
#  'United Kingdom',
#  'en:CH',
#  'en:ES',
#  'Deutschland',
#  'en:SI',
#  'en:DE',
#  'en:IT',
#  'en:RO',
#  'España',
#  'en:AU',
#  'en:PT',
#  'United States',
#  'Germany',
#  'Usa',
#  'France,Royaume-Uni',
#  'UK,France',
#  'France,Belgique,Pays-Bas,Royaume-Uni',
#  'France,United Kingdom',
#  'en:GP',
#  'France,UK',
#  'États-Unis',
#  'Royaume-Uni,France',
#  'en:CA',
#  nan,
#  'en:US,United Kingdom',
#  'Switzerland',
#  'en:US',
#  'en:CA, US',
#  'Nederland',
#  'en:AU, en:france',
#  'Australia',
#  'France,Suisse,États-Unis,Canada',
#  'États-Unis, en:france, US',
#  'Ireland',
#  'United Kingdom, US',
#  'en:RE, en:france',
#  'United States, en:france',
#  'en:TW',
#  'en:AU, Suisse',
#  'Deutschland, en:france',
#  'Suisse',
#  'en:BR',
#  'Belgique,France',
#  'en:DO',
#  'en:FR, US',
#  'Belgique,France,Pays-Bas,Royaume-Uni',
#  'France,United States',
#  'Australie, US',
#  'USA',
# ...

# %%
countries_fr_count = df['countries'].loc[df['countries'].str.contains('be', na=False)].value_counts()
countries_fr_count
# Out:
# France, en:belgium                                                                                                                                                                                                                                                                                                                          80
# France, en:switzerland, en:belgium                                                                                                                                                                                                                                                                                                          23
# ...

# %%
countries_fr_count.head(25)
# Out:
# France, en:belgium                                                                                                                                                                                                                                                                                                                          80
# France, en:switzerland, en:belgium                                                                                                                                                                                                                                                                                                          23
# ...

# %%
# df_be = df.loc[df['countries'].isin(top_fr)]

# %%
beverages = ['Alcoholic beverages', 'Beverages']

# %%
product_count = df.loc[df['pnns_groups_1'].isin(beverages)]
product_count
# Out:
#                  code  \
# 188     0000010090206
# 226     0000040608754
# 240     0000087177756
# 415     0000886100252
# 664          00071543
# ...               ...
# 320666  9569185896477
# 320668  9577283844672
# 320708     9661975680
# 320752    98709870987
# 320763       99111250
#
#                                                                                                                url  \
# 188     http://world-fr.openfoodfacts.org/produit/0000010090206/the-de-noel-aromatise-orange-cannelle-alice-delice
# 226                                     http://world-fr.openfoodfacts.org/produit/0000040608754/pepsi-nouveau-gout
# 240                                                    http://world-fr.openfoodfacts.org/produit/0000087177756/7up
# 415                                                  http://world-fr.openfoodfacts.org/produit/0000886100252/pepsi
# 664                             http://world-fr.openfoodfacts.org/produit/00071543/aloe-vera-grape-apple-juice-m-s
# ...

# %%
df.loc[df['pnns_groups_1'].str.contains('Alcoholic beverages', na=False)]

# %%
product_count = df.loc[df['product_name'].str.contains('bière', na=False)]
product_count
# Out:
#                  code  \
# 29062   0033984004009
# 177149       20015893
# 177497       20045166
# 188988  3033210007511
# 192512  3080210002732
# 192534  3080216033013
# 192550  3080216041254
# 192556  3080216043814
# 194794  3119780262458
# 197442  3175681159969
# 199878  3222471124161
# 202355  3229820027005
# 202391  3229820144160
# 203376  3244851001459
# 214291  3261570000136
# 214297  3261570001546
# 218015  3266191019024
# 220571  3272460122364
# 220582  3272460123125
# 220876  3273190575062
# 222723  3286010019998
# 223066  3288842013175
# 223532  3292590555368
# 224751  3324020003757
# 226551  3340040000446
# 226747  3347430848541
# 226788  3347431961331
# 229731  3380380070266
# 232520  3428881125600
# 232737  3434221543263
# 235254  3485853568513
# 235404  3492270104026
# 236348  3514123102918
# 243731  3564709053974
# 243842  3565700000486
# 244498  3585260418002
# 248290  3629103000327
# 248670  3660989128590
# 249467  3700029430013
# 250296  3700311864670
# ...

# %%
product_count

# %%
countries_count = product_count['countries'].value_counts()
countries_count
# Out:
# France                                                         44
# en:FR                                                          13
# Suisse                                                          4
# en:BE                                                           2
# France, Suisse                                                  1
# Canada,France,Grèce,Pays-Bas,Espagne,Royaume-Uni,États-Unis     1
# Côte d'Ivoire                                                   1
# United Kingdom                                                  1
# Italia                                                          1
# Name: countries, dtype: int64

# %%
### minima 4-5k éléments.

df['countries'].value_counts()
# Out:
# US                                            169928
# France                                         77292
# en:FR                                          16979
# Suisse                                         12314
# Deutschland                                     6161
#                                                ...
# Tschechien,Dänemark,Frankreich,Deutschland         1
# Danemark,Allemagne,France                          1
# Dänemark,Frankreich,Deutschland,Indien             1
# Dänemark                                           1
# Hong Kong,China                                    1
# Name: countries, Length: 1434, dtype: int64

# %%
df.shape
# Out:
# (320772, 162)

# %%
## uniquement france : déjà fait
## check contributeur : virer les moins complets

# %%
## check éq .info() group by sous catégories (pays, pnn_groups...) pour trouver cats les plus "propre"
## opérer grande maille => petite maille

# %%
# exemple : catégoriser pour différents régimes les aliments (diabète, sportif, etc..)

# %%
# favoriser méthodes au lieu d'anova : whitney
