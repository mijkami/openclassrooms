# %% [markdown]
# # imports

# %%
# imports

import os
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer, KNNImputer

# %matplotlib inline
pd.options.mode.chained_assignment = None  # default='warn

pd.set_option('display.max_rows', 750)
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_colwidth', None)

# %%
imp_med = SimpleImputer(missing_values=np.nan, strategy='median')
imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')

# %%
path = './data/'
csv_path = path + 'to_input_openfoodfacts.csv'
sm_df = pd.read_csv(csv_path, low_memory=False)

# %% [markdown]
# # Dataframe info

# %% [markdown]
# ## functions

# %%
def get_df_columns_na(df):
    counts = df.isna().sum()
    percentages = round(df.isna().mean() * 100, 1)
    null_values = pd.concat([counts, percentages], axis = 1, keys = ["count", "null_percent"])
    null_values['columns'] = null_values.index
    null_values = null_values[['columns', 'count', 'null_percent']]
    return null_values

# %%
def plot_df_xy(df, x_val, y_val, height_val = 20, width_val = 13):
    sns.catplot(data=df, x= x_val, y= y_val, kind="bar", height=height_val, aspect=width_val/height_val)
    sns.set(rc={'figure.figsize':(width_val,height_val)})
    plt.xticks(rotation=70)
    plt.tight_layout()

# %%
def show_nulls(df):
    top_sm_df_sort = get_df_columns_na(df).sort_values(by='null_percent',ascending=False)
    print(top_sm_df_sort)
    return plot_df_xy(top_sm_df_sort.reset_index(), 'null_percent', 'columns', 8)

# %% [markdown]
# ## General distribution / NaNs

# %%
sm_df.head()
# Out:
#                    product_name   pnns_groups_1         pnns_groups_2  \
# 0                       L.casei         unknown               unknown
# 1     Filetes de pollo empanado         unknown               unknown
# 2             Burger Meat Pollo         unknown               unknown
# 3  Hamburguesas de ternera 100%         unknown               unknown
# 4   moutarde au moût de raisin   Fat and sauces  Dressings and sauces
#
#                    code  energy-kcal_100g  fat_100g  saturated-fat_100g  \
# 0  00000000000003429145               NaN       1.4                 0.9
# 1    000000000003327986             163.9       1.9                 1.0
# 2    000000000004128579             194.0      11.0                 3.9
# 3    000000000004622327             874.9      15.1                 6.1
# 4         0000000000100               NaN       8.2                 2.2
#
#    carbohydrates_100g  sugars_100g  proteins_100g  salt_100g  sodium_100g
# 0                 9.8         9.80            2.7        0.1         0.04
# 1                 NaN          NaN           15.3        1.1         0.44
# 2                 5.7         0.05           18.0        NaN          NaN
# 3                 2.6         1.00           15.7        2.1         0.84
# 4                29.0        22.00            5.1        4.6         1.84

# %%
sm_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1361912 entries, 0 to 1361911
# Data columns (total 12 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   product_name        1361912 non-null  object
#  1   pnns_groups_1       1361912 non-null  object
#  2   pnns_groups_2       1361912 non-null  object
#  3   code                1361912 non-null  object
#  4   energy-kcal_100g    1273181 non-null  float64
#  5   fat_100g            1301039 non-null  float64
#  6   saturated-fat_100g  1276510 non-null  float64
#  7   carbohydrates_100g  1301962 non-null  float64
#  8   sugars_100g         1291669 non-null  float64
#  9   proteins_100g       1312137 non-null  float64
#  10  salt_100g           1204825 non-null  float64
#  11  sodium_100g         1205415 non-null  float64
# dtypes: float64(8), object(4)
# memory usage: 124.7+ MB

# %%
sm_df.describe()
# Out:
#        energy-kcal_100g      fat_100g  saturated-fat_100g  carbohydrates_100g  \
# count      1.273181e+06  1.301039e+06        1.276510e+06        1.301962e+06
# mean       2.017106e+02  9.733119e+00        3.567546e+00        1.746357e+01
# std        1.573178e+02  1.302372e+01        5.959421e+00        2.139302e+01
# min        0.000000e+00  0.000000e+00        0.000000e+00        0.000000e+00
# 25%        6.700000e+01  5.000000e-01        1.000000e-02        1.900000e+00
# 50%        1.730000e+02  4.100000e+00        1.000000e+00        8.750000e+00
# 75%        3.180000e+02  1.400000e+01        4.200000e+00        2.450000e+01
# max        8.995633e+02  9.999000e+01        9.990000e+01        9.996000e+01
#
#         sugars_100g  proteins_100g     salt_100g   sodium_100g
# count  1.291669e+06   1.312137e+06  1.204825e+06  1.205415e+06
# mean   4.966224e+00   9.132162e+00  1.265053e+00  5.278156e-01
# std    8.085940e+00   1.050464e+01  2.779495e+00  1.498138e+00
# min    0.000000e+00   0.000000e+00  0.000000e+00  0.000000e+00
# 25%    4.500000e-01   1.000000e+00  9.000000e-02  3.600000e-02
# 50%    1.900000e+00   5.952381e+00  7.225000e-01  2.900000e-01
# 75%    5.900000e+00   1.400000e+01  1.500000e+00  6.000000e-01
# max    9.990000e+01   9.990000e+01  7.142750e+01  9.398000e+01

# %%
#sm_df.isna().sum()

# %%
show_nulls(sm_df)
# Out:
#                                columns   count  null_percent
# salt_100g                    salt_100g  157087          11.5
# sodium_100g                sodium_100g  156497          11.5
# energy-kcal_100g      energy-kcal_100g   88731           6.5
# saturated-fat_100g  saturated-fat_100g   85402           6.3
# sugars_100g                sugars_100g   70243           5.2
# fat_100g                      fat_100g   60873           4.5
# carbohydrates_100g  carbohydrates_100g   59950           4.4
# proteins_100g            proteins_100g   49775           3.7
# product_name              product_name       0           0.0
# pnns_groups_1            pnns_groups_1       0           0.0
# pnns_groups_2            pnns_groups_2       0           0.0
# code                              code       0           0.0

# %% [markdown]
# ## Categories / "unknown"

# %%
main_cats = sm_df['pnns_groups_1'].unique()
main_cats
# Out:
# array(['unknown', 'Fat and sauces', 'Composite foods', 'Sugary snacks',
#        'Fruits and vegetables', 'Milk and dairy products',
#        'Fish Meat Eggs', 'Cereals and potatoes', 'Salty snacks',
#        'Beverages', 'Alcoholic beverages'], dtype=object)

# %%
sm_df['pnns_groups_1'].value_counts()
# Out:
# unknown                    818399
# Fish Meat Eggs              98519
# Milk and dairy products     92960
# Cereals and potatoes        70910
# Beverages                   63429
# Fat and sauces              57575
# Composite foods             54347
# Fruits and vegetables       44640
# Sugary snacks               31421
# Salty snacks                24831
# Alcoholic beverages          4881
# Name: pnns_groups_1, dtype: int64

# %%
all_cats = sm_df['pnns_groups_1'].unique().tolist()
all_cats
# Out:
# ['unknown',
#  'Fat and sauces',
#  'Composite foods',
#  'Sugary snacks',
#  'Fruits and vegetables',
#  'Milk and dairy products',
#  'Fish Meat Eggs',
#  'Cereals and potatoes',
#  'Salty snacks',
#  'Beverages',
#  'Alcoholic beverages']

# %%
all_cols = sm_df.columns
all_cols
# Out:
# Index(['product_name', 'pnns_groups_1', 'pnns_groups_2', 'code',
#        'energy-kcal_100g', 'fat_100g', 'saturated-fat_100g',
#        'carbohydrates_100g', 'sugars_100g', 'proteins_100g', 'salt_100g',
#        'sodium_100g'],
#       dtype='object')

# %%
main_cats = ['fat_100g', 'salt_100g']
complementary_cats = ['saturated-fat_100g','sodium_100g']

# %%
final_cats = [c for c in all_cols if c not in main_cats+complementary_cats]
final_cats
# Out:
# ['product_name',
#  'pnns_groups_1',
#  'pnns_groups_2',
#  'code',
#  'energy-kcal_100g',
#  'carbohydrates_100g',
#  'sugars_100g',
#  'proteins_100g']

# %%
all_cols
# Out:
# Index(['product_name', 'pnns_groups_1', 'pnns_groups_2', 'code',
#        'energy-kcal_100g', 'fat_100g', 'saturated-fat_100g',
#        'carbohydrates_100g', 'sugars_100g', 'proteins_100g', 'salt_100g',
#        'sodium_100g'],
#       dtype='object')

# %%
num_cols = sm_df.columns[sm_df.dtypes == 'float64']
num_cols
# Out:
# Index(['energy-kcal_100g', 'fat_100g', 'saturated-fat_100g',
#        'carbohydrates_100g', 'sugars_100g', 'proteins_100g', 'salt_100g',
#        'sodium_100g'],
#       dtype='object')

# %% [markdown]
# # Inputing

# %% [markdown]
# ## categories : knn_inputing

# %% [markdown]
# ### label encode categories

# %%
sm_df.shape
# Out:
# (1361912, 12)

# %%
sm_df.loc[sm_df[num_cols].isna().any(1) == False]
# Out:
# /tmp/ipykernel_9940/1149045631.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.any and Series.any will be keyword-only.
#   sm_df.loc[sm_df[num_cols].isna().any(1) == False]
#                          product_name    pnns_groups_1   pnns_groups_2  \
# 3        Hamburguesas de ternera 100%          unknown         unknown
# 5               Sauce Sweety chili 0%          unknown         unknown
# 6                           Mini coco          unknown         unknown
# 8                    Pur jus de pomme          unknown         unknown
# 10          Salade de carottes râpées  Composite foods  One-dish meals
# ...                               ...              ...             ...
# 1361904                   Steak haché          unknown         unknown
# 1361907                Minis beignets          unknown         unknown
# 1361909                    Faux filet   Fish Meat Eggs            Meat
# 1361910                           Scs          unknown         unknown
# 1361911                          Fati          unknown         unknown
#
#                        code  energy-kcal_100g  fat_100g  saturated-fat_100g  \
# 3        000000000004622327             874.9      15.1                 6.1
# 5             0000000000123              21.0       0.0                 0.0
# 6             0000000000178              60.0       3.0                 1.0
# 8              000000000080              63.0       0.0                 0.0
# 10            0000000000949              32.0       0.3                 0.1
# ...                     ...               ...       ...                 ...
# 1361904       9999992756112             196.0      14.0                 6.2
# 1361907       9999999004360             333.0      20.2                 6.0
# 1361909            99999995             131.0       5.0                 2.3
# 1361910          9999999901             100.0      12.0                 1.0
# 1361911       9999999990397              24.0       0.3                 0.0
#
#          carbohydrates_100g  sugars_100g  proteins_100g  salt_100g  \
# 3                       2.6          1.0           15.7       2.10
# 5                       4.8          0.4            0.2       2.04
# 6                      10.0          3.0            2.0       1.15
# 8                      15.5         15.5            0.2       0.00
# 10                      5.3          3.9            0.9       0.42
# ...                     ...          ...            ...        ...
# 1361904                 0.0          0.0           19.0       0.19
# 1361907                30.9         10.4            7.4       1.10
# 1361909                 0.0          0.0           21.5       0.18
# 1361910                 2.0          1.0            1.0       1.00
# 1361911                 2.4          0.6            1.6       0.64
#
#          sodium_100g
# 3              0.840
# 5              0.816
# 6              0.460
# 8              0.000
# 10             0.168
# ...              ...
# 1361904        0.076
# 1361907        0.440
# 1361909        0.072
# 1361910        0.400
# 1361911        0.256
#
# [1087717 rows x 12 columns]

# %%
sm_df[num_cols].isna().any(1).sum()
# Out:
# /tmp/ipykernel_9940/3583621291.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.any and Series.any will be keyword-only.
#   sm_df[num_cols].isna().any(1).sum()
# 274195

# %%
#df_clean_num = sm_df.loc[~sm_df[num_cols].isna().any(1)]
#show_nulls(df_clean_num)

# %%
num_cols
# Out:
# Index(['energy-kcal_100g', 'fat_100g', 'saturated-fat_100g',
#        'carbohydrates_100g', 'sugars_100g', 'proteins_100g', 'salt_100g',
#        'sodium_100g'],
#       dtype='object')

# %%
sm_df.shape
# Out:
# (1361912, 12)

# %%
sm_df.loc[sm_df[num_cols].isna().any(1) == False].shape
# Out:
# /tmp/ipykernel_9940/3973607031.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.any and Series.any will be keyword-only.
#   sm_df.loc[sm_df[num_cols].isna().any(1) == False].shape
# (1087717, 12)

# %%
show_nulls(sm_df.loc[sm_df[num_cols].isna().any(1) == False])
# Out:
# /tmp/ipykernel_9940/1973947013.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.any and Series.any will be keyword-only.
#   show_nulls(sm_df.loc[sm_df[num_cols].isna().any(1) == False])
#                                columns  count  null_percent
# product_name              product_name      0           0.0
# pnns_groups_1            pnns_groups_1      0           0.0
# pnns_groups_2            pnns_groups_2      0           0.0
# code                              code      0           0.0
# energy-kcal_100g      energy-kcal_100g      0           0.0
# fat_100g                      fat_100g      0           0.0
# saturated-fat_100g  saturated-fat_100g      0           0.0
# carbohydrates_100g  carbohydrates_100g      0           0.0
# sugars_100g                sugars_100g      0           0.0
# proteins_100g            proteins_100g      0           0.0
# salt_100g                    salt_100g      0           0.0
# sodium_100g                sodium_100g      0           0.0

# %%
# https://pbpython.com/categorical-encoding.html
# https://stackoverflow.com/questions/52059309/convert-categorical-codes-to-categorical-values

# %%
sm_df['pnns_groups_1'] = sm_df['pnns_groups_1'].astype('category')
sm_df.dtypes
# Out:
# product_name            object
# pnns_groups_1         category
# pnns_groups_2           object
# code                    object
# energy-kcal_100g       float64
# fat_100g               float64
# saturated-fat_100g     float64
# carbohydrates_100g     float64
# sugars_100g            float64
# proteins_100g          float64
# salt_100g              float64
# sodium_100g            float64
# dtype: object

# %%
sm_df['pnns_groups_1_cat'] = sm_df['pnns_groups_1'].cat.codes
sm_df.head()
# Out:
#                    product_name   pnns_groups_1         pnns_groups_2  \
# 0                       L.casei         unknown               unknown
# 1     Filetes de pollo empanado         unknown               unknown
# 2             Burger Meat Pollo         unknown               unknown
# 3  Hamburguesas de ternera 100%         unknown               unknown
# 4   moutarde au moût de raisin   Fat and sauces  Dressings and sauces
#
#                    code  energy-kcal_100g  fat_100g  saturated-fat_100g  \
# 0  00000000000003429145               NaN       1.4                 0.9
# 1    000000000003327986             163.9       1.9                 1.0
# 2    000000000004128579             194.0      11.0                 3.9
# 3    000000000004622327             874.9      15.1                 6.1
# 4         0000000000100               NaN       8.2                 2.2
#
#    carbohydrates_100g  sugars_100g  proteins_100g  salt_100g  sodium_100g  \
# 0                 9.8         9.80            2.7        0.1         0.04
# 1                 NaN          NaN           15.3        1.1         0.44
# 2                 5.7         0.05           18.0        NaN          NaN
# 3                 2.6         1.00           15.7        2.1         0.84
# 4                29.0        22.00            5.1        4.6         1.84
#
#    pnns_groups_1_cat
# 0                 10
# 1                 10
# 2                 10
# 3                 10
# 4                  4

# %%
sm_df['pnns_groups_1_cat'].replace(10, np.nan, inplace=True)
sm_df.head()
# Out:
#                    product_name   pnns_groups_1         pnns_groups_2  \
# 0                       L.casei         unknown               unknown
# 1     Filetes de pollo empanado         unknown               unknown
# 2             Burger Meat Pollo         unknown               unknown
# 3  Hamburguesas de ternera 100%         unknown               unknown
# 4   moutarde au moût de raisin   Fat and sauces  Dressings and sauces
#
#                    code  energy-kcal_100g  fat_100g  saturated-fat_100g  \
# 0  00000000000003429145               NaN       1.4                 0.9
# 1    000000000003327986             163.9       1.9                 1.0
# 2    000000000004128579             194.0      11.0                 3.9
# 3    000000000004622327             874.9      15.1                 6.1
# 4         0000000000100               NaN       8.2                 2.2
#
#    carbohydrates_100g  sugars_100g  proteins_100g  salt_100g  sodium_100g  \
# 0                 9.8         9.80            2.7        0.1         0.04
# 1                 NaN          NaN           15.3        1.1         0.44
# 2                 5.7         0.05           18.0        NaN          NaN
# 3                 2.6         1.00           15.7        2.1         0.84
# 4                29.0        22.00            5.1        4.6         1.84
#
#    pnns_groups_1_cat
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                4.0

# %%
pnns1_dict = dict(enumerate(sm_df['pnns_groups_1'].cat.categories))
pnns1_dict
# Out:
# {0: 'Alcoholic beverages',
#  1: 'Beverages',
#  2: 'Cereals and potatoes',
#  3: 'Composite foods',
#  4: 'Fat and sauces',
#  5: 'Fish Meat Eggs',
#  6: 'Fruits and vegetables',
#  7: 'Milk and dairy products',
#  8: 'Salty snacks',
#  9: 'Sugary snacks',
#  10: 'unknown'}

# %%
sm_df['pnns_groups_2'] = sm_df['pnns_groups_2'].astype('category')
sm_df['pnns_groups_2_cat'] = sm_df['pnns_groups_2'].cat.codes
sm_df['pnns_groups_2_cat'].replace(39, np.nan, inplace=True)
sm_df.head()
# Out:
#                    product_name   pnns_groups_1         pnns_groups_2  \
# 0                       L.casei         unknown               unknown
# 1     Filetes de pollo empanado         unknown               unknown
# 2             Burger Meat Pollo         unknown               unknown
# 3  Hamburguesas de ternera 100%         unknown               unknown
# 4   moutarde au moût de raisin   Fat and sauces  Dressings and sauces
#
#                    code  energy-kcal_100g  fat_100g  saturated-fat_100g  \
# 0  00000000000003429145               NaN       1.4                 0.9
# 1    000000000003327986             163.9       1.9                 1.0
# 2    000000000004128579             194.0      11.0                 3.9
# 3    000000000004622327             874.9      15.1                 6.1
# 4         0000000000100               NaN       8.2                 2.2
#
#    carbohydrates_100g  sugars_100g  proteins_100g  salt_100g  sodium_100g  \
# 0                 9.8         9.80            2.7        0.1         0.04
# 1                 NaN          NaN           15.3        1.1         0.44
# 2                 5.7         0.05           18.0        NaN          NaN
# 3                 2.6         1.00           15.7        2.1         0.84
# 4                29.0        22.00            5.1        4.6         1.84
#
#    pnns_groups_1_cat  pnns_groups_2_cat
# 0                NaN                NaN
# 1                NaN                NaN
# 2                NaN                NaN
# 3                NaN                NaN
# 4                4.0               10.0

# %%
pnns2_dict = dict(enumerate(sm_df['pnns_groups_2'].cat.categories))
pnns2_dict
# Out:
# {0: 'Alcoholic beverages',
#  1: 'Appetizers',
#  2: 'Artificially sweetened beverages',
#  3: 'Biscuits and cakes',
#  4: 'Bread',
#  5: 'Breakfast cereals',
#  6: 'Cereals',
#  7: 'Cheese',
#  8: 'Chocolate products',
#  9: 'Dairy desserts',
#  10: 'Dressings and sauces',
#  11: 'Dried fruits',
#  12: 'Eggs',
#  13: 'Fats',
#  14: 'Fish and seafood',
#  15: 'Fruit juices',
#  16: 'Fruit nectars',
#  17: 'Fruits',
#  18: 'Ice cream',
#  19: 'Legumes',
#  20: 'Meat',
#  21: 'Milk and yogurt',
#  22: 'Nuts',
#  23: 'Offals',
#  24: 'One-dish meals',
#  25: 'Pastries',
#  26: 'Pizza pies and quiches',
#  27: 'Plant-based milk substitutes',
#  28: 'Potatoes',
#  29: 'Processed meat',
#  30: 'Salty and fatty products',
#  31: 'Sandwiches',
#  32: 'Soups',
#  33: 'Sweetened beverages',
#  34: 'Sweets',
#  35: 'Teas and herbal teas and coffees',
#  36: 'Unsweetened beverages',
#  37: 'Vegetables',
#  38: 'Waters and flavored waters',
#  39: 'unknown'}

# %% [markdown]
# ### knn inputing

# %%
sm_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1361912 entries, 0 to 1361911
# Data columns (total 14 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   product_name        1361912 non-null  object
#  1   pnns_groups_1       1361912 non-null  category
#  2   pnns_groups_2       1361912 non-null  category
#  3   code                1361912 non-null  object
#  4   energy-kcal_100g    1273181 non-null  float64
#  5   fat_100g            1301039 non-null  float64
#  6   saturated-fat_100g  1276510 non-null  float64
#  7   carbohydrates_100g  1301962 non-null  float64
#  8   sugars_100g         1291669 non-null  float64
#  9   proteins_100g       1312137 non-null  float64
#  10  salt_100g           1204825 non-null  float64
#  11  sodium_100g         1205415 non-null  float64
#  12  pnns_groups_1_cat   543513 non-null   float64
#  13  pnns_groups_2_cat   543513 non-null   float64
# dtypes: category(2), float64(10), object(2)
# memory usage: 127.3+ MB

# %%
num_cols_plus_cats = sm_df.columns[sm_df.dtypes == 'float64']
num_cols_plus_cats
# Out:
# Index(['energy-kcal_100g', 'fat_100g', 'saturated-fat_100g',
#        'carbohydrates_100g', 'sugars_100g', 'proteins_100g', 'salt_100g',
#        'sodium_100g', 'pnns_groups_1_cat', 'pnns_groups_2_cat'],
#       dtype='object')

# %%
sm_df[num_cols_plus_cats].loc[sm_df[num_cols].isna().any(1) == False]
# Out:
# /tmp/ipykernel_9940/890951202.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.any and Series.any will be keyword-only.
#   sm_df[num_cols_plus_cats].loc[sm_df[num_cols].isna().any(1) == False]
#          energy-kcal_100g  fat_100g  saturated-fat_100g  carbohydrates_100g  \
# 3                   874.9      15.1                 6.1                 2.6
# 5                    21.0       0.0                 0.0                 4.8
# 6                    60.0       3.0                 1.0                10.0
# 8                    63.0       0.0                 0.0                15.5
# 10                   32.0       0.3                 0.1                 5.3
# ...                   ...       ...                 ...                 ...
# 1361904             196.0      14.0                 6.2                 0.0
# 1361907             333.0      20.2                 6.0                30.9
# 1361909             131.0       5.0                 2.3                 0.0
# 1361910             100.0      12.0                 1.0                 2.0
# 1361911              24.0       0.3                 0.0                 2.4
#
#          sugars_100g  proteins_100g  salt_100g  sodium_100g  \
# 3                1.0           15.7       2.10        0.840
# 5                0.4            0.2       2.04        0.816
# 6                3.0            2.0       1.15        0.460
# 8               15.5            0.2       0.00        0.000
# 10               3.9            0.9       0.42        0.168
# ...              ...            ...        ...          ...
# 1361904          0.0           19.0       0.19        0.076
# 1361907         10.4            7.4       1.10        0.440
# 1361909          0.0           21.5       0.18        0.072
# 1361910          1.0            1.0       1.00        0.400
# 1361911          0.6            1.6       0.64        0.256
#
#          pnns_groups_1_cat  pnns_groups_2_cat
# 3                      NaN                NaN
# 5                      NaN                NaN
# 6                      NaN                NaN
# 8                      NaN                NaN
# 10                     3.0               24.0
# ...                    ...                ...
# 1361904                NaN                NaN
# 1361907                NaN                NaN
# 1361909                5.0               20.0
# 1361910                NaN                NaN
# 1361911                NaN                NaN
#
# [1087717 rows x 10 columns]

# %%
imputer = KNNImputer(n_neighbors=2)

# %%
imputer.fit_transform(sm_df[num_cols_plus_cats].loc[sm_df[num_cols].isna().any(1) == False])
# Out:
# /tmp/ipykernel_9940/55618228.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.any and Series.any will be keyword-only.
#   imputer.fit_transform(sm_df[num_cols_plus_cats].loc[sm_df[num_cols].isna().any(1) == False])

# %%
#imputer.fit_transform(sm_df[num_cols])

# %%
sm_df.head()

# %%
show_nulls(sm_df)

# %% [markdown]
# ### Mapping back cat values

# %%
sm_df['pnns_groups_1'] = sm_df['pnns_groups_1_cat'].map(pnns1_dict)
sm_df['pnns_groups_2'] = sm_df['pnns_groups_2_cat'].map(pnns2_dict)
sm_df.drop(columns=['pnns_groups_1_cat', 'pnns_groups_2_cat'], inplace=True)
sm_df.head()
# Out:
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4          Fat and sauces
#                 ...
# 1361907               NaN
# 1361908     Sugary snacks
# 1361909    Fish Meat Eggs
# 1361910               NaN
# 1361911               NaN
# Name: pnns_groups_1_cat, Length: 1361912, dtype: object

# %%
# drop cat numerical cols

# %% [markdown]
# ## numerical values

# %%
### appliquer imputer différentes strategies (check distribution) avec un groupby categories
### iterative imputer / estimation du choix d'imputer selon la distribution (mean/median/most frequent...)

# %% [markdown]
# ### main_cats : fat / salt => mean input

# %%
#groupby pnns_groups_1, mean, remplir avec mean / categorie
#list1 = ["fat_100g", "salt_100g"]
main_cats
# Out:
# ['fat_100g', 'salt_100g']

# %%
#main_cats_grp = main_cats.append('pnns_group_1')
#main_cats_grp

# %%
#main_cats_grp = ['fat_100g', 'salt_100g', 'pnns_group_1']
#main_cats_grp

# %%
# sm_df[[c for c in df.columns if c in main_cats]].head()

# %%
sm_df.filter(main_cats).head()
# Out:
#    fat_100g  salt_100g
# 0       NaN        NaN
# 1       1.4        0.1
# 2       NaN        NaN
# 3       1.9        1.1
# 4      11.0        NaN

# %%
sm_df_groupby = sm_df.groupby(by='pnns_groups_1')

# %%
sm_df_groupby.mean()
# Out:
#                          energy-kcal_100g   fat_100g  saturated-fat_100g  \
# pnns_groups_1
# Alcoholic beverages             66.619878   1.290206            0.267635
# Beverages                       48.412283   0.820464            0.429246
# Cereals and potatoes           294.311534   4.684030            1.020387
# Composite foods                177.046995   7.539578            2.491210
# Fat and sauces                 228.787619  16.480630            4.785741
# Fish Meat Eggs                 207.257507  12.748846            4.186412
# Fruits and vegetables           71.978922   1.486411            0.331087
# Milk and dairy products        223.447365  15.633708           10.129301
# Salty snacks                   379.848515  29.337939            6.329597
# Sugary snacks                  274.965828   7.797832            3.198125
# sugary-snacks                         NaN        NaN                 NaN
# unknown                        201.681150   9.471510            3.250305
#
#                          carbohydrates_100g  sugars_100g  proteins_100g  \
# pnns_groups_1
# Alcoholic beverages                7.864081     3.626928       1.400195
# Beverages                          8.329317     7.094946       0.954389
# Cereals and potatoes              51.001032     3.002433      10.050230
# Composite foods                   18.182893     2.565496       7.652201
# Fat and sauces                    10.546215     7.180036       1.967222
# Fish Meat Eggs                     2.691659     0.896183      18.925177
# Fruits and vegetables             11.226577     6.711564       2.065463
# Milk and dairy products            7.687872     5.959879      12.292904
# Salty snacks                      18.591729     1.903797       8.434855
# Sugary snacks                     42.446313    19.491716       3.891545
# sugary-snacks                           NaN          NaN            NaN
# unknown                           18.148168     4.863237       9.365741
#
#                          salt_100g  sodium_100g
# pnns_groups_1
# Alcoholic beverages       0.469999     0.215946
# Beverages                 0.206885     0.092242
# Cereals and potatoes      0.682527     0.274646
# Composite foods           1.180105     0.473079
# Fat and sauces            2.017257     0.811976
# Fish Meat Eggs            1.933769     0.776386
# Fruits and vegetables     0.515616     0.208700
# Milk and dairy products   0.873741     0.363899
# Salty snacks              1.660792     0.667126
# Sugary snacks             0.483837     0.197936
# sugary-snacks                  NaN          NaN
# unknown                   1.386422     0.588584

# %%
sm_df.columns
# Out:
# Index(['product_name', 'pnns_groups_1', 'pnns_groups_2', 'code',
#        'energy-kcal_100g', 'fat_100g', 'saturated-fat_100g',
#        'carbohydrates_100g', 'sugars_100g', 'proteins_100g', 'salt_100g',
#        'sodium_100g'],
#       dtype='object')

# %%
sm_df_groupby[main_cats].mean()
# Out:
#                           fat_100g  salt_100g
# pnns_groups_1
# Alcoholic beverages       1.290206   0.469999
# Beverages                 0.820464   0.206885
# Cereals and potatoes      4.684030   0.682527
# Composite foods           7.539578   1.180105
# Fat and sauces           16.480630   2.017257
# Fish Meat Eggs           12.748846   1.933769
# Fruits and vegetables     1.486411   0.515616
# Milk and dairy products  15.633708   0.873741
# Salty snacks             29.337939   1.660792
# Sugary snacks             7.797832   0.483837
# sugary-snacks                  NaN        NaN
# unknown                   9.471510   1.386422

# %%
sm_df_groupby[main_cats].count()
# Out:
#                          fat_100g  salt_100g
# pnns_groups_1
# Alcoholic beverages          2135       2870
# Beverages                   61924      60627
# Cereals and potatoes        70277      66612
# Composite foods             54068      53594
# Fat and sauces              50769      56050
# Fish Meat Eggs              97356      96129
# Fruits and vegetables       43813      42598
# Milk and dairy products     92412      89970
# Salty snacks                24609      24241
# Sugary snacks               29261      28303
# sugary-snacks                   0          0
# unknown                    774415     683831

# %%
# https://pandas.pydata.org/docs/user_guide/groupby.html

sm_df[main_cats] = sm_df_groupby[main_cats].transform(lambda x: x.fillna(x.mean()))

# %%
sm_df.isna().sum()
# Out:
# product_name               0
# pnns_groups_1              3
# pnns_groups_2              1
# code                       0
# energy-kcal_100g      434849
# fat_100g                   5
# saturated-fat_100g    431520
# carbohydrates_100g    406068
# sugars_100g           416361
# proteins_100g         395893
# salt_100g                  5
# sodium_100g           502615
# dtype: int64

# %%
sm_df_gr_transf = sm_df_groupby[main_cats].transform(lambda x: x.fillna(x.mean()))
sm_df_gr_transf
# Out:
#          fat_100g  salt_100g
# 0         9.47151   1.386422
# 1         1.40000   0.100000
# 2         9.47151   1.386422
# 3         1.90000   1.100000
# 4        11.00000   1.386422
# ...           ...        ...
# 1708025  12.00000   1.000000
# 1708026   9.47151   1.386422
# 1708027   9.47151   1.386422
# 1708028   0.30000   0.640000
# 1708029   9.47151   1.386422
#
# [1708027 rows x 2 columns]

# %%
grouped.transform(lambda x: x.fillna(inplace=False))

# %%
sm_df.isna().sum()
# Out:
# product_name               0
# pnns_groups_1              3
# pnns_groups_2              1
# code                       0
# energy-kcal_100g      434849
# fat_100g              406991
# saturated-fat_100g    431520
# carbohydrates_100g    406068
# sugars_100g           416361
# proteins_100g         395893
# salt_100g             503205
# sodium_100g           502615
# dtype: int64

# %%
sm_df_groupby[main_cats]

# %%
## faire fonction et apply par ligne ou boucler sur données uniques

# %%
sm_df_main_mean = sm_df_groupby[main_cats].mean()
sm_df_main_mean
# Out:
#                           fat_100g  salt_100g
# pnns_groups_1
# Alcoholic beverages       1.290206   0.469999
# Beverages                 0.820464   0.206885
# Cereals and potatoes      4.684030   0.682527
# Composite foods           7.539578   1.180105
# Fat and sauces           16.480630   2.017257
# Fish Meat Eggs           12.748846   1.933769
# Fruits and vegetables     1.486411   0.515616
# Milk and dairy products  15.633708   0.873741
# Salty snacks             29.337939   1.660792
# Sugary snacks             7.797832   0.483837
# sugary-snacks                  NaN        NaN
# unknown                   9.471510   1.386422

# %%
sm_df.head()
# Out:
#                 product_name pnns_groups_1 pnns_groups_2  \
# 0             jeunes pousses       unknown       unknown
# 1                    L.casei       unknown       unknown
# 2                      Cacao       unknown       unknown
# 3  Filetes de pollo empanado       unknown       unknown
# 4          Burger Meat Pollo       unknown       unknown
#
#                    code  energy-kcal_100g  fat_100g  saturated-fat_100g  \
# 0     00000000000000225               NaN       NaN                 NaN
# 1  00000000000003429145               NaN       1.4                 0.9
# 2         0000000000031               NaN       NaN                 NaN
# 3    000000000003327986             163.9       1.9                 1.0
# 4    000000000004128579             194.0      11.0                 3.9
#
#    carbohydrates_100g  sugars_100g  proteins_100g  salt_100g  sodium_100g
# 0                 NaN          NaN            NaN        NaN          NaN
# 1                 9.8         9.80            2.7        0.1         0.04
# 2                 NaN          NaN            NaN        NaN          NaN
# 3                 NaN          NaN           15.3        1.1         0.44
# 4                 5.7         0.05           18.0        NaN          NaN

# %%
sm_df_main_mean['fat_100g']
# Out:
# pnns_groups_1
# Alcoholic beverages         1.290206
# Beverages                   0.820464
# Cereals and potatoes        4.684030
# Composite foods             7.539578
# Fat and sauces             16.480630
# Fish Meat Eggs             12.748846
# Fruits and vegetables       1.486411
# Milk and dairy products    15.633708
# Salty snacks               29.337939
# Sugary snacks               7.797832
# sugary-snacks                    NaN
# unknown                     9.471510
# Name: fat_100g, dtype: float64

# %%
import math

def fill_grp_fat(row):
    if math.isnan(row['fat_100g']):
        cat = row['pnns_groups_1']
        print(cat)
        return sm_df_main_mean['fat_100g'][cat]
    else:
        return row['fat_100g']

# %%
#sm_df['pnns_groups_1'].value_counts()

# %%
sm_df['fat_100g'] = sm_df.apply(lambda x : fill_grp_fat(x), axis=1)
# Out:
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fish Meat Eggs
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# Milk and dairy products
# Sugary snacks
# unknown
# unknown
# Fish Meat Eggs
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# unknown
# unknown
# Milk and dairy products
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# Fruits and vegetables
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# Sugary snacks
# unknown
# Salty snacks
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# Alcoholic beverages
# unknown
# unknown
# unknown
# Sugary snacks
# Cereals and potatoes
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# Beverages
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# Fruits and vegetables
# Fruits and vegetables
# unknown
# Fruits and vegetables
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fish Meat Eggs
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# Fish Meat Eggs
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# Milk and dairy products
# Sugary snacks
# Sugary snacks
# Sugary snacks
# unknown
# unknown
# Cereals and potatoes
# Sugary snacks
# unknown
# Fish Meat Eggs
# unknown
# unknown
# unknown
# Milk and dairy products
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# Fish Meat Eggs
# unknown
# Milk and dairy products
# Sugary snacks
# unknown
# Fish Meat Eggs
# unknown
# Sugary snacks
# unknown
# Fish Meat Eggs
# Sugary snacks
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# Fish Meat Eggs
# unknown
# unknown
# Sugary snacks
# unknown
# Sugary snacks
# unknown
# Milk and dairy products
# unknown
# unknown
# unknown
# unknown
# Composite foods
# Cereals and potatoes
# unknown
# unknown
# Sugary snacks
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# Cereals and potatoes
# Cereals and potatoes
# unknown
# Fish Meat Eggs
# Cereals and potatoes
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# Cereals and potatoes
# unknown
# Cereals and potatoes
# unknown
# Sugary snacks
# Sugary snacks
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# Fruits and vegetables
# Beverages
# unknown
# unknown
# Salty snacks
# unknown
# unknown
# unknown
# unknown
# Fish Meat Eggs
# unknown
# Fish Meat Eggs
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Salty snacks
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# Cereals and potatoes
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# Fruits and vegetables
# unknown
# Fish Meat Eggs
# Salty snacks
# unknown
# Fish Meat Eggs
# unknown
# unknown
# Fish Meat Eggs
# unknown
# Salty snacks
# Fish Meat Eggs
# Fish Meat Eggs
# unknown
# unknown
# Salty snacks
# unknown
# unknown
# Salty snacks
# unknown
# Salty snacks
# Salty snacks
# unknown
# unknown
# unknown
# Fish Meat Eggs
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# unknown
# Milk and dairy products
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# Milk and dairy products
# unknown
# unknown
# unknown
# Cereals and potatoes
# Milk and dairy products
# unknown
# unknown
# unknown
# Fish Meat Eggs
# unknown
# unknown
# Cereals and potatoes
# unknown
# unknown
# Composite foods
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# Cereals and potatoes
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# Composite foods
# unknown
# unknown
# unknown
# unknown
# unknown
# Milk and dairy products
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# Milk and dairy products
# unknown
# Fish Meat Eggs
# Cereals and potatoes
# unknown
# unknown
# unknown
# Fish Meat Eggs
# unknown
# Cereals and potatoes
# unknown
# unknown
# unknown
# Fish Meat Eggs
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Alcoholic beverages
# unknown
# Fish Meat Eggs
# unknown
# unknown
# unknown
# unknown
# Fish Meat Eggs
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# unknown
# Sugary snacks
# unknown
# Alcoholic beverages
# unknown
# Alcoholic beverages
# unknown
# Alcoholic beverages
# Alcoholic beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# Milk and dairy products
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# Cereals and potatoes
# unknown
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# Fish Meat Eggs
# unknown
# unknown
# Cereals and potatoes
# unknown
# unknown
# unknown
# unknown
# Alcoholic beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# Fat and sauces
# Fish Meat Eggs
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Alcoholic beverages
# Fish Meat Eggs
# unknown
# Sugary snacks
# unknown
# Cereals and potatoes
# unknown
# Alcoholic beverages
# Alcoholic beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# Composite foods
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# Fish Meat Eggs
# Sugary snacks
# unknown
# Cereals and potatoes
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# Fish Meat Eggs
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# Fat and sauces
# Sugary snacks
# unknown
# Cereals and potatoes
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# Composite foods
# Composite foods
# Composite foods
# Composite foods
# Composite foods
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Composite foods
# unknown
# Cereals and potatoes
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# Composite foods
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# Cereals and potatoes
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Alcoholic beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# unknown
# Beverages
# unknown
# unknown
# Alcoholic beverages
# Fish Meat Eggs
# Fish Meat Eggs
# Fish Meat Eggs
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Milk and dairy products
# unknown
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Salty snacks
# unknown
# unknown
# Fish Meat Eggs
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Milk and dairy products
# unknown
# Composite foods
# unknown
# unknown
# Milk and dairy products
# unknown
# Composite foods
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# Sugary snacks
# unknown
# Composite foods
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# unknown
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# unknown
# unknown
# unknown
# Cereals and potatoes
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# Fish Meat Eggs
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# Fruits and vegetables
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fish Meat Eggs
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# Fat and sauces
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# Fish Meat Eggs
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Milk and dairy products
# unknown
# Milk and dairy products
# Milk and dairy products
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Milk and dairy products
# unknown
# unknown
# Milk and dairy products
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fish Meat Eggs
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# unknown
# Fat and sauces
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# Cereals and potatoes
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# Fat and sauces
# unknown
# unknown
# unknown
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Cereals and potatoes
# unknown
# Fish Meat Eggs
# unknown
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# Fat and sauces
# Fat and sauces
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# Sugary snacks
# unknown
# unknown
# Beverages
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fish Meat Eggs
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# unknown
# Fat and sauces
# unknown
# Fat and sauces
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# Fat and sauces
# unknown
# Fat and sauces
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# Fat and sauces
# unknown
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# Fat and sauces
# Fat and sauces
# unknown
# Milk and dairy products
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# unknown
# Fat and sauces
# unknown
# Beverages
# unknown
# Fat and sauces
# unknown
# Fat and sauces
# unknown
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# unknown
# unknown
# unknown
# Milk and dairy products
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Salty snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# unknown
# Sugary snacks
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fish Meat Eggs
# unknown
# Sugary snacks
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Milk and dairy products
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# Beverages
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# Fat and sauces
# unknown
# unknown
# unknown
# Milk and dairy products
# unknown
# Fat and sauces
# unknown
# Fish Meat Eggs
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fish Meat Eggs
# unknown
# unknown
# unknown
# Alcoholic beverages
# Alcoholic beverages
# Alcoholic beverages
# unknown
# Alcoholic beverages
# Alcoholic beverages
# Fish Meat Eggs
# unknown
# unknown
# unknown
# unknown
# unknown
# Milk and dairy products
# unknown
# unknown
# unknown
# unknown
# unknown
# Fish Meat Eggs
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# Alcoholic beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fish Meat Eggs
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# Fat and sauces
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# Fat and sauces
# unknown
# Cereals and potatoes
# Cereals and potatoes
# Cereals and potatoes
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# Alcoholic beverages
# unknown
# unknown
# Sugary snacks
# unknown
# Fat and sauces
# unknown
# Fat and sauces
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# Fruits and vegetables
# Fish Meat Eggs
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Alcoholic beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fish Meat Eggs
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Alcoholic beverages
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Salty snacks
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# Fat and sauces
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# unknown
# Sugary snacks
# Beverages
# unknown
# Alcoholic beverages
# unknown
# unknown
# Sugary snacks
# Sugary snacks
# unknown
# unknown
# Salty snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# unknown
# unknown
# unknown
# Salty snacks
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Milk and dairy products
# unknown
# unknown
# Fish Meat Eggs
# unknown
# unknown
# unknown
# unknown
# Fish Meat Eggs
# Milk and dairy products
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# Cereals and potatoes
# Cereals and potatoes
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fish Meat Eggs
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# Cereals and potatoes
# unknown
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# unknown
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# unknown
# Beverages
# unknown
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# unknown
# Fat and sauces
# unknown
# unknown
# Fat and sauces
# Fat and sauces
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Alcoholic beverages
# unknown
# Milk and dairy products
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Milk and dairy products
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Salty snacks
# unknown
# unknown
# Composite foods
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Composite foods
# unknown
# unknown
# Cereals and potatoes
# unknown
# unknown
# unknown
# Fat and sauces
# unknown
# Milk and dairy products
# Fish Meat Eggs
# unknown
# Sugary snacks
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# unknown
# unknown
# Cereals and potatoes
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# Cereals and potatoes
# Cereals and potatoes
# unknown
# unknown
# Sugary snacks
# Cereals and potatoes
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# Cereals and potatoes
# Cereals and potatoes
# Cereals and potatoes
# Cereals and potatoes
# Cereals and potatoes
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# Milk and dairy products
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Salty snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Composite foods
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Milk and dairy products
# unknown
# Milk and dairy products
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fish Meat Eggs
# unknown
# Beverages
# Fruits and vegetables
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Milk and dairy products
# unknown
# Milk and dairy products
# unknown
# unknown
# unknown
# unknown
# unknown
# Milk and dairy products
# unknown
# unknown
# unknown
# Milk and dairy products
# unknown
# Milk and dairy products
# unknown
# Milk and dairy products
# Milk and dairy products
# Milk and dairy products
# Milk and dairy products
# Milk and dairy products
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Milk and dairy products
# unknown
# unknown
# Milk and dairy products
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# Milk and dairy products
# unknown
# Milk and dairy products
# unknown
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# Milk and dairy products
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Alcoholic beverages
# unknown
# unknown
# Alcoholic beverages
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# Fat and sauces
# Cereals and potatoes
# Alcoholic beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fish Meat Eggs
# unknown
# Composite foods
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# Fish Meat Eggs
# Sugary snacks
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Alcoholic beverages
# Alcoholic beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Alcoholic beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Alcoholic beverages
# unknown
# Alcoholic beverages
# unknown
# unknown
# unknown
# Alcoholic beverages
# unknown
# unknown
# Alcoholic beverages
# Alcoholic beverages
# Alcoholic beverages
# unknown
# Beverages
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# Fish Meat Eggs
# Cereals and potatoes
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# Fat and sauces
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# Fish Meat Eggs
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Composite foods
# unknown
# Fish Meat Eggs
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fish Meat Eggs
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# Fat and sauces
# Fat and sauces
# Fat and sauces
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# Fat and sauces
# Alcoholic beverages
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# unknown
# unknown
# unknown
# Fat and sauces
# unknown
# Fish Meat Eggs
# Fish Meat Eggs
# unknown
# Fish Meat Eggs
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# Alcoholic beverages
# Alcoholic beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# Cereals and potatoes
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# Fat and sauces
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Alcoholic beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# Fat and sauces
# unknown
# Sugary snacks
# Sugary snacks
# Sugary snacks
# Sugary snacks
# Sugary snacks
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fish Meat Eggs
# Fish Meat Eggs
# unknown
# unknown
# Fish Meat Eggs
# unknown
# Fish Meat Eggs
# unknown
# unknown
# Cereals and potatoes
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# Fat and sauces
# Composite foods
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# Composite foods
# unknown
# unknown
# Salty snacks
# unknown
# unknown
# unknown
# unknown
# Fish Meat Eggs
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# Fat and sauces
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fish Meat Eggs
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# unknown
# unknown
# Milk and dairy products
# unknown
# Milk and dairy products
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# unknown
# Fat and sauces
# unknown
# Fish Meat Eggs
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# unknown
# unknown
# unknown
# Composite foods
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# Cereals and potatoes
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# unknown
# unknown
# Fish Meat Eggs
# unknown
# Beverages
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# Fat and sauces
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# Alcoholic beverages
# unknown
# Cereals and potatoes
# unknown
# Milk and dairy products
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# Fruits and vegetables
# Fruits and vegetables
# unknown
# Fruits and vegetables
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# Beverages
# Composite foods
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# unknown
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fish Meat Eggs
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# Fish Meat Eggs
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Milk and dairy products
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# Fat and sauces
# unknown
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# unknown
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# Fat and sauces
# unknown
# Fat and sauces
# Fat and sauces
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# Fat and sauces
# unknown
# unknown
# unknown
# Salty snacks
# unknown
# unknown
# Beverages
# unknown
# unknown
# Beverages
# unknown
# Beverages
# Beverages
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fish Meat Eggs
# unknown
# unknown
# Cereals and potatoes
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Composite foods
# unknown
# unknown
# unknown
# Cereals and potatoes
# unknown
# Alcoholic beverages
# Alcoholic beverages
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Alcoholic beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# Alcoholic beverages
# unknown
# unknown
# unknown
# Beverages
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# Fish Meat Eggs
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# Beverages
# unknown
# Cereals and potatoes
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# unknown
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# Fat and sauces
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# unknown
# Fat and sauces
# Sugary snacks
# unknown
# Composite foods
# unknown
# Alcoholic beverages
# Composite foods
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# Fruits and vegetables
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# unknown
# unknown
# unknown
# unknown
# Fish Meat Eggs
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# Milk and dairy products
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# Alcoholic beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Composite foods
# unknown
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# Composite foods
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# unknown
# unknown
# unknown
# Fish Meat Eggs
# unknown
# unknown
# Alcoholic beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# Beverages
# Beverages
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Milk and dairy products
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# unknown
# unknown
# unknown
# unknown
# Alcoholic beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Composite foods
# unknown
# unknown
# unknown
# unknown
# Fish Meat Eggs
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# unknown
# unknown
# Alcoholic beverages
# Alcoholic beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Alcoholic beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# Cereals and potatoes
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# Fat and sauces
# Fat and sauces
# unknown
# unknown
# unknown
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# unknown
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# unknown
# unknown
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# unknown
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# unknown
# unknown
# unknown
# Fish Meat Eggs
# unknown
# unknown
# unknown
# Fish Meat Eggs
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Salty snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Alcoholic beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Alcoholic beverages
# unknown
# unknown
# Fish Meat Eggs
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# Salty snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# Cereals and potatoes
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Milk and dairy products
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# Sugary snacks
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Salty snacks
# Salty snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Salty snacks
# unknown
# Salty snacks
# unknown
# unknown
# unknown
# unknown
# Salty snacks
# Salty snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Salty snacks
# Salty snacks
# unknown
# Salty snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# unknown
# unknown
# Salty snacks
# Salty snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# Salty snacks
# Salty snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# ...
# unknown
# unknown
# unknown
# Cereals and potatoes
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# unknown
# Milk and dairy products
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# Fat and sauces
# unknown
# unknown
# Fat and sauces
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# Fruits and vegetables
# Beverages
# unknown
# Sugary snacks
# Composite foods
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Composite foods
# unknown
# unknown
# unknown
# Fat and sauces
# unknown
# Salty snacks
# unknown
# Fish Meat Eggs
# unknown
# unknown
# Milk and dairy products
# Milk and dairy products
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# Beverages
# Beverages
# unknown
# unknown
# unknown
# Beverages
# unknown
# Beverages
# Beverages
# Beverages
# Beverages
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# Cereals and potatoes
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fish Meat Eggs
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# unknown
# Fruits and vegetables
# unknown
# unknown
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fish Meat Eggs
# unknown
# Fish Meat Eggs
# Fish Meat Eggs
# Cereals and potatoes
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# Fish Meat Eggs
# unknown
# unknown
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# Fish Meat Eggs
# Fish Meat Eggs
# Fish Meat Eggs
# unknown
# unknown
# unknown
# unknown
# unknown
# Fish Meat Eggs
# Fish Meat Eggs
# Fish Meat Eggs
# Fish Meat Eggs
# unknown
# Fish Meat Eggs
# Fish Meat Eggs
# Fish Meat Eggs
# Fish Meat Eggs
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# Milk and dairy products
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# Fruits and vegetables
# unknown
# unknown
# unknown
# Composite foods
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Composite foods
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# Fat and sauces
# unknown
# Fruits and vegetables
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# Beverages
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Composite foods
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fish Meat Eggs
# unknown
# Fat and sauces
# unknown
# Composite foods
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# Fish Meat Eggs
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fish Meat Eggs
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# Fat and sauces
# Alcoholic beverages
# Alcoholic beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Alcoholic beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Composite foods
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# Milk and dairy products
# Composite foods
# unknown
# unknown
# unknown
# Composite foods
# unknown
# unknown
# Composite foods
# unknown
# unknown
# unknown
# Salty snacks
# unknown
# unknown
# unknown
# unknown
# Salty snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Salty snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Composite foods
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# unknown
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Beverages
# Beverages
# Beverages
# unknown
# Beverages
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Salty snacks
# unknown
# unknown
# Cereals and potatoes
# unknown
# Cereals and potatoes
# unknown
# unknown
# unknown
# unknown
# Fish Meat Eggs
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Milk and dairy products
# unknown
# Milk and dairy products
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# Fat and sauces
# Cereals and potatoes
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# Fat and sauces
# unknown
# Fat and sauces
# Fat and sauces
# unknown
# unknown
# unknown
# Cereals and potatoes
# unknown
# Beverages
# Beverages
# Beverages
# unknown
# unknown
# Beverages
# unknown
# Beverages
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# Sugary snacks
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# Alcoholic beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fruits and vegetables
# unknown
# unknown
# Beverages
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Fat and sauces
# Sugary snacks
# Fat and sauces
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Cereals and potatoes
# Fat and sauces
# Fat and sauces
# Fat and sauces
# Cereals and potatoes
# unknown
# Fruits and vegetables
# unknown
# unknown
# unknown
# unknown
# Composite foods
# Composite foods
# Composite foods
# unknown
# unknown
# unknown
# unknown
# unknown
# unknown
# Sugary snacks
# unknown
# unknown
# unknown
# nan
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: nan
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [79], in <module>
# ----> 1 sm_df['fat_100g'] = sm_df.apply(lambda x : fill_grp_fat(x), axis=1)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:8833, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8822 from pandas.core.apply import frame_apply
#    8824 op = frame_apply(
#    8825     self,
#    8826     func=func,
#    (...)
#    8831     kwargs=kwargs,
#    8832 )
# -> 8833 return op.apply().__finalize__(self, method="apply")
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/apply.py:727, in FrameApply.apply(self)
#     724 elif self.raw:
#     725     return self.apply_raw()
# --> 727 return self.apply_standard()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/apply.py:851, in FrameApply.apply_standard(self)
#     850 def apply_standard(self):
# --> 851     results, res_index = self.apply_series_generator()
#     853     # wrap results
#     854     return self.wrap_results(results, res_index)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/apply.py:867, in FrameApply.apply_series_generator(self)
#     864 with option_context("mode.chained_assignment", None):
#     865     for i, v in enumerate(series_gen):
#     866         # ignore SettingWithCopy here in case the user mutates
# --> 867         results[i] = self.f(v)
#     868         if isinstance(results[i], ABCSeries):
#     869             # If we have a view on v, we need to make a copy because
#     870             #  series_generator will swap out the underlying data
#     871             results[i] = results[i].copy(deep=False)
#
# Input In [79], in <lambda>(x)
# ----> 1 sm_df['fat_100g'] = sm_df.apply(lambda x : fill_grp_fat(x), axis=1)
#
# Input In [78], in fill_grp_fat(row)
#       5     cat = row['pnns_groups_1']
#       6     print(cat)
# ----> 7     return sm_df_main_mean['fat_100g'][cat]
#       8 else:
#       9     return row['fat_100g']
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:958, in Series.__getitem__(self, key)
#     955     return self._values[key]
#     957 elif key_is_scalar:
# --> 958     return self._get_value(key)
#     960 if is_hashable(key):
#     961     # Otherwise index.get_value will raise InvalidIndexError
#     962     try:
#     963         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:1069, in Series._get_value(self, label, takeable)
#    1066     return self._values[label]
#    1068 # Similar to Index.get_value, but we do not fall back to positional
# -> 1069 loc = self.index.get_loc(label)
#    1070 return self.index._get_values_for_loc(self, loc, label)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: nan

# %%
## utiliser index (str) de sm_df_groupby

# %%
#sm_df.filter(main_cats_grp).head()

# %% [markdown]
# ### compl_cats : sat_fat / sodium => linearRegression

# %%
# IterativeImputer avec estimator=LinearRegression()
#list2 = ["saturated-fat_100g", "sodium_100g"] 
complementary_cats
# Out:
# ['saturated-fat_100g', 'sodium_100g']

# %%
sm_df.filter(complementary_cats).head()
# Out:
#    saturated-fat_100g  sodium_100g
# 0                 NaN          NaN
# 1                 0.9         0.04
# 2                 NaN          NaN
# 3                 1.0         0.44
# 4                 3.9          NaN

# %%
#sm_df_groupby.median().columns

# %%
#sm_df_groupby.median()

# %%
sm_df_groupby[complementary_cats].median()
# Out:
#                          saturated-fat_100g  sodium_100g
# pnns_groups_1
# Alcoholic beverages                    0.00     0.000000
# Beverages                              0.00     0.004000
# Cereals and potatoes                   0.40     0.180000
# Composite foods                        1.79     0.390000
# Fat and sauces                         1.10     0.520000
# Fish Meat Eggs                         2.68     0.640000
# Fruits and vegetables                  0.00     0.066040
# Milk and dairy products                8.47     0.140000
# Salty snacks                           3.50     0.520000
# Sugary snacks                          0.90     0.050000
# sugary-snacks                           NaN          NaN
# unknown                                1.00     0.286512

# %% [markdown]
# ### final_cats =>

# %%
final_cats
# Out:
# ['product_name',
#  'pnns_groups_1',
#  'pnns_groups_2',
#  'code',
#  'energy-kcal_100g',
#  'carbohydrates_100g',
#  'sugars_100g',
#  'proteins_100g']

# %%
#Reste des variables contenant des valeurs vides (sans list1, list2,  pnns_groups_1, pnns_groups_2) : 
# remplir soit avec la moyenne soit avec la mediane, en fonction de la distribution 
#- remplir avec la valeur la plus fréquente

# %%
#imp_med = SimpleImputer(missing_values=np.nan, strategy='median')

###sm_df[all_num_cols] = imp_med.fit_transform(sm_df[all_num_cols])
