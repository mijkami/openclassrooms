# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
# Out:
# /home/mijka/.pyenv/versions/3.9.7/envs/oclass4/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.25.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df = pd.read_csv('data/olist_rfm.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                customer_unique_id  recency  frequency  monetary
# 0           0  7c396fd4830fd04220f754e42b4e5bff      380          2     65.38
# 1           1  af07308b275d755c9edb36a90c618231       85          1    118.70
# 2           2  3a653a41f6f9fc3d2a113cf8398680e8       70          1    159.90
# 3           3  7c142cf63193a1473d2e66489a9ae977      333          1     45.00
# 4           4  72632f0f9dd73dfee390c9b22eb56dd6      246          1     19.90

# %%
df.shape
# Out:
# (96096, 5)

# %%
# remove customer_unique_id

# %%
# K-Means

# %%
# DBscan
