# %% [markdown]
# Data source : https://www.kaggle.com/c/home-credit-default-risk/data

# %% [markdown]
# But notebook : Feature Engineering / Reduction
#
# - utiliser les donnes agrégées précédemment
# - réduire le dataframe (optimisation de futurs temps de calcul / temps de modélisation) tout en ayant le moins de données manquantes dans les features restantes
#    - verification des types et choix de types plus avantageux en poids si possible
#    - entrainement sur différents modèles et extraction des features notables via SHAPE ou autre (knn most important features)
#    - éviter de "créer" des informations ex-nihilo avec de l'inputing : favoriser la sélection / suppression en préservant au mieux l'intégrité des données

# %% [markdown]
# # Imports

# %% [markdown]
# ## libraries

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os

import numpy as np
import pandas as pd
import inspect

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import utils from parent directory
import sys
from pathlib import Path
parent_dir = str(Path().resolve().parents[1])
sys.path.insert(0, parent_dir)

import utils.UVA as UVA
import utils.MVA as MVA
import utils.PCA as PCA

# %%
import gc
import time
from contextlib import contextmanager
import re

# %%
# https://numpy.org/doc/stable/release/2.0.0-notes.html#representation-of-numpy-scalars-changed
np.set_printoptions(legacy='1.21')

# %%
import mlflow
import mlflow.lightgbm
import mlflow.xgboost
from mlflow import MlflowClient
from mlflow.models.signature import infer_signature
from pprint import pprint

# %%
from sklearn.impute import KNNImputer
from sklearn.impute import SimpleImputer

import lightgbm as lgb
from lightgbm import LGBMClassifier
from sklearn import model_selection
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score, roc_curve, accuracy_score,fbeta_score, make_scorer

from sklearn.ensemble import RandomForestClassifier

# %%
import xgboost as xgb
import shap

# %% [markdown]
# ## data

# %%
csv_path_output = '../data/output/'
file_name = 'homecredit_agg.csv'

df = pd.read_csv(f'{csv_path_output + file_name}', encoding='ISO-8859-1')

# %%
df.shape
# Out:
# (356251, 798)

# %%
df.head()
# Out:
#    index  SK_ID_CURR  TARGET  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  \
# 0      0      100002     1.0            0             0                0
# 1      1      100003     0.0            1             0                1
# 2      2      100004     0.0            0             1                0
# 3      3      100006     0.0            1             0                0
# 4      4      100007     0.0            0             0                0
#
#    CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  ...  \
# 0             0          202500.0    406597.5      24700.5  ...
# 1             0          270000.0   1293502.5      35698.5  ...
# 2             0           67500.0    135000.0       6750.0  ...
# 3             0          135000.0    312682.5      29686.5  ...
# 4             0          121500.0    513000.0      21865.5  ...
#
#    CC_NAME_CONTRACT_STATUS_Signed_MAX  CC_NAME_CONTRACT_STATUS_Signed_MEAN  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
# 3                                 0.0                                  0.0
# 4                                 NaN                                  NaN
#
#    CC_NAME_CONTRACT_STATUS_Signed_SUM  CC_NAME_CONTRACT_STATUS_Signed_VAR  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 0.0                                 0.0
# 4                                 NaN                                 NaN
#
#    CC_NAME_CONTRACT_STATUS_nan_MIN  CC_NAME_CONTRACT_STATUS_nan_MAX  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              0.0                              0.0
# 4                              NaN                              NaN
#
#    CC_NAME_CONTRACT_STATUS_nan_MEAN  CC_NAME_CONTRACT_STATUS_nan_SUM  \
# 0                               NaN                              NaN
# 1                               NaN                              NaN
# 2                               NaN                              NaN
# 3                               0.0                              0.0
# 4                               NaN                              NaN
#
#    CC_NAME_CONTRACT_STATUS_nan_VAR  CC_COUNT
# 0                              NaN       NaN
# 1                              NaN       NaN
# 2                              NaN       NaN
# 3                              0.0       6.0
# 4                              NaN       NaN
#
# [5 rows x 798 columns]

# %% [markdown]
# # Explo

# %% [markdown]
# ## Valeurs manquantes

# %%
# https://medium.com/@kavyasree42/how-to-handle-missing-data-in-python-simple-to-advanced-techniques-machine-learning-brain-ffae3c1a694f

# %%
@contextmanager
def timer(title):
    t0 = time.time()
    yield
    print("{} - done in {:.0f}s".format(title, time.time() - t0))
    
# Function to calculate missing values by column
def missing_values_table(df):
    # Taux de valeurs manquantes :
    print("Taux de valeurs manquantes dans le df avant imputation :" , round(df.isna().mean().mean(),4))
    # Total missing values
    mis_val = df.isnull().sum()
    
    # Percentage of missing values
    mis_val_percent = 100 * df.isnull().sum() / len(df)
    
    # Make a table with the results
    mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
    
    # Rename the columns
    mis_val_table_ren_columns = mis_val_table.rename(columns = {0 : 'Missing Values', 1 : '% of Total Values'})
    
    # Sort the table by percentage of missing descending
    mis_val_table_ren_columns = mis_val_table_ren_columns[
        mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
    
    # Print some summary information
    print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"
           "There are " + str(mis_val_table_ren_columns.shape[0]) +
           " columns that have missing values.")
    
    # Return the dataframe with missing information
    return mis_val_table_ren_columns

# %%
with timer ("Imputation des valeurs manquantes") :
     #  Statistiques sur les valeurs manquantes :
    missing_values = missing_values_table(df)
    df.replace([np.inf, -np.inf], np.nan, inplace=True)
    
    # Séparation du jeu de données en jeu de  training/validation et jeu de test
    train_df = df[df['TARGET'].notnull()] # partie du jeu de données qui contient une target
    test_df = df[df['TARGET'].isnull()] # partie du jeu de données qui n'a pas de target
    print(train_df.shape, test_df.shape)
    train_df["TARGET"].value_counts()/train_df.shape[0]
    
    # Taux de valeurs manquantes :
    print("Taux de valeurs manquantes dans jeu de train avant imputation :" , round(train_df.isna().mean().mean(),4))
    print("Taux de valeurs manquantes dans jeu de test avant imputation :" , round(test_df.isna().mean().mean(),4))
# Out:
# Taux de valeurs manquantes dans le df avant imputation : 0.2536
# Your selected dataframe has 798 columns.
# There are 617 columns that have missing values.
# (307507, 798) (48744, 798)
# Taux de valeurs manquantes dans jeu de train avant imputation : 0.2589
# Taux de valeurs manquantes dans jeu de test avant imputation : 0.22
# Imputation des valeurs manquantes - done in 3s

# %% [markdown]
# # Typage

# %%
df.head()
# Out:
#    index  SK_ID_CURR  TARGET  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  \
# 0      0      100002     1.0            0             0                0
# 1      1      100003     0.0            1             0                1
# 2      2      100004     0.0            0             1                0
# 3      3      100006     0.0            1             0                0
# 4      4      100007     0.0            0             0                0
#
#    CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  ...  \
# 0             0          202500.0    406597.5      24700.5  ...
# 1             0          270000.0   1293502.5      35698.5  ...
# 2             0           67500.0    135000.0       6750.0  ...
# 3             0          135000.0    312682.5      29686.5  ...
# 4             0          121500.0    513000.0      21865.5  ...
#
#    CC_NAME_CONTRACT_STATUS_Signed_MAX  CC_NAME_CONTRACT_STATUS_Signed_MEAN  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
# 3                                 0.0                                  0.0
# 4                                 NaN                                  NaN
#
#    CC_NAME_CONTRACT_STATUS_Signed_SUM  CC_NAME_CONTRACT_STATUS_Signed_VAR  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 0.0                                 0.0
# 4                                 NaN                                 NaN
#
#    CC_NAME_CONTRACT_STATUS_nan_MIN  CC_NAME_CONTRACT_STATUS_nan_MAX  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              0.0                              0.0
# 4                              NaN                              NaN
#
#    CC_NAME_CONTRACT_STATUS_nan_MEAN  CC_NAME_CONTRACT_STATUS_nan_SUM  \
# 0                               NaN                              NaN
# 1                               NaN                              NaN
# 2                               NaN                              NaN
# 3                               0.0                              0.0
# 4                               NaN                              NaN
#
#    CC_NAME_CONTRACT_STATUS_nan_VAR  CC_COUNT
# 0                              NaN       NaN
# 1                              NaN       NaN
# 2                              NaN       NaN
# 3                              0.0       6.0
# 4                              NaN       NaN
#
# [5 rows x 798 columns]

# %%
df.dtypes
# Out:
# index                                 int64
# SK_ID_CURR                            int64
# TARGET                              float64
# CODE_GENDER                           int64
# FLAG_OWN_CAR                          int64
#                                      ...
# CC_NAME_CONTRACT_STATUS_nan_MAX     float64
# CC_NAME_CONTRACT_STATUS_nan_MEAN    float64
# CC_NAME_CONTRACT_STATUS_nan_SUM     float64
# CC_NAME_CONTRACT_STATUS_nan_VAR     float64
# CC_COUNT                            float64
# Length: 798, dtype: object

# %%
# Vérification des dtypes actuels
print("Dtypes initiaux :")
print(df.dtypes.value_counts())
print("\nInfos avant conversion :")
print(df.info())

# Analyse de la distribution des données
for column in df.columns:
    if df[column].dtype == 'int64':
        min_val, max_val = df[column].min(), df[column].max()
        if min_val >= np.iinfo(np.int8).min and max_val <= np.iinfo(np.int8).max:
            df[column] = df[column].astype(np.int8)
        elif min_val >= np.iinfo(np.int16).min and max_val <= np.iinfo(np.int16).max:
            df[column] = df[column].astype(np.int16)
        elif min_val >= np.iinfo(np.int32).min and max_val <= np.iinfo(np.int32).max:
            df[column] = df[column].astype(np.int32)
    elif df[column].dtype == 'float64':
        df[column] = df[column].astype(np.float32)

# Vérification des dtypes après conversion
print("\nDtypes après conversion :")
print(df.dtypes.value_counts())
print("\nInfos sur le DataFrame :")
print(df.info())
# Out:
# Dtypes initiaux :
# float64    622
# int64      176
# dtype: int64
#
# Infos avant conversion :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 356251 entries, 0 to 356250
# Columns: 798 entries, index to CC_COUNT
# dtypes: float64(622), int64(176)
# memory usage: 2.1 GB
# None
#
# Dtypes après conversion :
# float32    622
# int8       172
# int32        2
# int16        2
# dtype: int64
#
# Infos sur le DataFrame :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 356251 entries, 0 to 356250
# Columns: 798 entries, index to CC_COUNT
# dtypes: float32(622), int16(2), int32(2), int8(172)
# memory usage: 907.8 MB
# None

# %%
df['TARGET'].value_counts(dropna=False)
# Out:
# 0.0    282682
# NaN     48744
# 1.0     24825
# Name: TARGET, dtype: int64

# %%
fig,ax=plt.subplots(figsize=(7,6))
plt.title("Distribution de la cible)", fontsize=15)
sns.countplot(x='TARGET', data=df)
for container in ax.containers:
    ax.bar_label(container,size=12,fmt='%.0f')
plt.show()

# %%
# Séparer les données en X_train et X_test
X_train = df[df['TARGET'].notna()]
X_test = df[df['TARGET'].isna()]

print("Dimensions de X_train :", X_train.shape)
print("Dimensions de X_test :", X_test.shape)
# Out:
# Dimensions de X_train : (307507, 798)
# Dimensions de X_test : (48744, 798)

# %%
X_train['TARGET'].value_counts(dropna=False)
# Out:
# 0    282682
# 1     24825
# Name: TARGET, dtype: int64

# %%
# Compter le nombre d'éléments ayant TARGET à 1
count_target_1 = df['TARGET'].value_counts()[1]

# Sélectionner aléatoirement un nombre similaire d'éléments ayant TARGET à 0
df_target_0 = df[df['TARGET'] == 0]
df_target_0_sampled = df_target_0.sample(n=count_target_1, random_state=42)

# Sélectionner tous les éléments ayant TARGET à 1
df_target_1 = df[df['TARGET'] == 1]

# Combiner les deux ensembles pour former le nouvel ensemble X_train
X_train = pd.concat([df_target_0_sampled, df_target_1])

# Afficher les dimensions du nouvel ensemble X_train
print("Dimensions de X_train :", X_train.shape)
print("Décompte des valeurs de TARGET dans X_train :")
print(X_train['TARGET'].value_counts(dropna=False))
# Out:
# Dimensions de X_train : (49650, 798)
# Décompte des valeurs de TARGET dans X_train :
# 0.0    24825
# 1.0    24825
# Name: TARGET, dtype: int64

# %%
# Vérifier les valeurs manquantes dans X_train
missing_values = X_train.isna().sum()

# Afficher les valeurs manquantes par colonne
print("Valeurs manquantes dans X_train :")
print(missing_values.sum())
# Out:
# Valeurs manquantes dans X_train :
# 10203744

# %%
# Calculer le pourcentage de valeurs manquantes par colonne
missing_percentages = X_train.isna().mean() * 100

# Créer un DataFrame pour afficher les résultats
missing_table = pd.DataFrame({
    'Feature': missing_percentages.index,
    'Missing Percentage': missing_percentages.values
}).sort_values(by='Missing Percentage', ascending=False)

# Ajouter une ligne pour le total
total_missing_percentage = missing_percentages.mean()
missing_table = pd.concat([missing_table, pd.DataFrame({
    'Feature': ['Total'],
    'Missing Percentage': [total_missing_percentage]
})], ignore_index=True)

# Afficher le tableau
pd.set_option('display.max_rows', None)
print("Pourcentage de valeurs manquantes par feature :")
print(missing_table)
# Out:
# Pourcentage de valeurs manquantes par feature :
#                                                Feature  Missing Percentage
# 0                        REFUSED_RATE_DOWN_PAYMENT_MIN           84.080564
# 1                         REFUSED_AMT_DOWN_PAYMENT_MAX           84.080564
# 2                       REFUSED_RATE_DOWN_PAYMENT_MEAN           84.080564
# 3                         REFUSED_AMT_DOWN_PAYMENT_MIN           84.080564
# 4                        REFUSED_RATE_DOWN_PAYMENT_MAX           84.080564
# 5                        REFUSED_AMT_DOWN_PAYMENT_MEAN           84.080564
# 6                          REFUSED_APP_CREDIT_PERC_VAR           81.079557
# 7                              ACTIVE_AMT_ANNUITY_MEAN           79.401813
# 8                               ACTIVE_AMT_ANNUITY_MAX           79.401813
# 9                              CLOSED_AMT_ANNUITY_MEAN           79.033233
# 10                              CLOSED_AMT_ANNUITY_MAX           79.033233
# 11                          CC_AMT_PAYMENT_CURRENT_VAR           78.249748
# 12                     CC_AMT_DRAWINGS_POS_CURRENT_VAR           78.191339
# 13                     CC_CNT_DRAWINGS_ATM_CURRENT_VAR           78.191339
# 14                     CC_AMT_DRAWINGS_ATM_CURRENT_VAR           78.191339
# 15                   CC_AMT_DRAWINGS_OTHER_CURRENT_VAR           78.191339
# 16                   CC_CNT_DRAWINGS_OTHER_CURRENT_VAR           78.191339
# 17                     CC_CNT_DRAWINGS_POS_CURRENT_VAR           78.191339
# 18                          CC_AMT_PAYMENT_CURRENT_MIN           78.068479
# 19                          CC_AMT_PAYMENT_CURRENT_MAX           78.068479
# 20                         CC_AMT_PAYMENT_CURRENT_MEAN           78.068479
# 21                  CC_AMT_DRAWINGS_OTHER_CURRENT_MEAN           77.983887
# 22                     CC_CNT_DRAWINGS_POS_CURRENT_MAX           77.983887
# 23                    CC_AMT_DRAWINGS_POS_CURRENT_MEAN           77.983887
# 24                     CC_AMT_DRAWINGS_POS_CURRENT_MAX           77.983887
# 25                    CC_CNT_DRAWINGS_POS_CURRENT_MEAN           77.983887
# 26                     CC_AMT_DRAWINGS_POS_CURRENT_MIN           77.983887
# 27                   CC_AMT_DRAWINGS_OTHER_CURRENT_MAX           77.983887
# 28                  CC_CNT_DRAWINGS_OTHER_CURRENT_MEAN           77.983887
# 29                     CC_AMT_DRAWINGS_ATM_CURRENT_MIN           77.983887
# 30                    CC_AMT_DRAWINGS_ATM_CURRENT_MEAN           77.983887
# 31                   CC_CNT_DRAWINGS_OTHER_CURRENT_MIN           77.983887
# 32                    CC_CNT_DRAWINGS_ATM_CURRENT_MEAN           77.983887
# 33                     CC_CNT_DRAWINGS_ATM_CURRENT_MAX           77.983887
# 34                   CC_CNT_DRAWINGS_OTHER_CURRENT_MAX           77.983887
# 35                     CC_CNT_DRAWINGS_ATM_CURRENT_MIN           77.983887
# 36                     CC_AMT_DRAWINGS_ATM_CURRENT_MAX           77.983887
# 37                     CC_CNT_DRAWINGS_POS_CURRENT_MIN           77.983887
# 38                   CC_AMT_DRAWINGS_OTHER_CURRENT_MIN           77.983887
# 39                       ACTIVE_MONTHS_BALANCE_MAX_MAX           74.644512
# 40                       ACTIVE_MONTHS_BALANCE_MIN_MIN           74.644512
# 41                     ACTIVE_MONTHS_BALANCE_SIZE_MEAN           74.644512
# 42                       CLOSED_MONTHS_BALANCE_MIN_MIN           74.483384
# 43                     CLOSED_MONTHS_BALANCE_SIZE_MEAN           74.483384
# 44                       CLOSED_MONTHS_BALANCE_MAX_MAX           74.483384
# 45                                BURO_AMT_ANNUITY_MAX           73.897281
# 46                               BURO_AMT_ANNUITY_MEAN           73.897281
# 47                                      COMMONAREA_AVG           71.852971
# 48                                     COMMONAREA_MEDI           71.852971
# 49                                     COMMONAREA_MODE           71.852971
# 50                            NONLIVINGAPARTMENTS_MODE           71.442095
# 51                             NONLIVINGAPARTMENTS_AVG           71.442095
# 52                            NONLIVINGAPARTMENTS_MEDI           71.442095
# 53                         CC_CNT_DRAWINGS_CURRENT_VAR           71.146022
# 54                                CC_AMT_RECIVABLE_VAR           71.146022
# 55                     CC_AMT_RECEIVABLE_PRINCIPAL_VAR           71.146022
# 56                         CC_AMT_TOTAL_RECEIVABLE_VAR           71.146022
# 57                               CC_MONTHS_BALANCE_VAR           71.146022
# 58                                   CC_SK_DPD_DEF_VAR           71.146022
# 59                  CC_NAME_CONTRACT_STATUS_Active_VAR           71.146022
# 60                    CC_AMT_PAYMENT_TOTAL_CURRENT_VAR           71.146022
# 61                CC_NAME_CONTRACT_STATUS_Approved_VAR           71.146022
# 62                    CC_CNT_INSTALMENT_MATURE_CUM_VAR           71.146022
# 63                                       CC_SK_DPD_VAR           71.146022
# 64            CC_NAME_CONTRACT_STATUS_Sentproposal_VAR           71.146022
# 65                  CC_NAME_CONTRACT_STATUS_Signed_VAR           71.146022
# 66                 CC_NAME_CONTRACT_STATUS_Refused_VAR           71.146022
# 67                  CC_NAME_CONTRACT_STATUS_Demand_VAR           71.146022
# 68               CC_NAME_CONTRACT_STATUS_Completed_VAR           71.146022
# 69                      CC_AMT_CREDIT_LIMIT_ACTUAL_VAR           71.146022
# 70                         CC_AMT_DRAWINGS_CURRENT_VAR           71.146022
# 71                     CC_NAME_CONTRACT_STATUS_nan_VAR           71.146022
# 72                                  CC_AMT_BALANCE_VAR           71.146022
# 73                      CC_AMT_INST_MIN_REGULARITY_VAR           71.146022
# 74                      CC_AMT_CREDIT_LIMIT_ACTUAL_MAX           70.904330
# 75                         CC_CNT_DRAWINGS_CURRENT_MAX           70.904330
# 76                         CC_AMT_DRAWINGS_CURRENT_MAX           70.904330
# 77                     CC_CNT_DRAWINGS_ATM_CURRENT_SUM           70.904330
# 78                         CC_AMT_DRAWINGS_CURRENT_MIN           70.904330
# 79                                  CC_AMT_BALANCE_SUM           70.904330
# 80                         CC_CNT_DRAWINGS_CURRENT_MIN           70.904330
# 81                     CC_AMT_DRAWINGS_ATM_CURRENT_SUM           70.904330
# 82                        CC_CNT_DRAWINGS_CURRENT_MEAN           70.904330
# 83                         CC_CNT_DRAWINGS_CURRENT_SUM           70.904330
# 84                        CC_AMT_DRAWINGS_CURRENT_MEAN           70.904330
# 85                      CC_AMT_CREDIT_LIMIT_ACTUAL_MIN           70.904330
# 86                      CC_AMT_CREDIT_LIMIT_ACTUAL_SUM           70.904330
# 87                     CC_AMT_CREDIT_LIMIT_ACTUAL_MEAN           70.904330
# 88                   CC_CNT_DRAWINGS_OTHER_CURRENT_SUM           70.904330
# 89                     CC_AMT_RECEIVABLE_PRINCIPAL_MIN           70.904330
# 90                         CC_AMT_TOTAL_RECEIVABLE_SUM           70.904330
# 91                         CC_AMT_DRAWINGS_CURRENT_SUM           70.904330
# 92                    CC_AMT_PAYMENT_TOTAL_CURRENT_SUM           70.904330
# 93                   CC_AMT_PAYMENT_TOTAL_CURRENT_MEAN           70.904330
# 94                     CC_AMT_RECEIVABLE_PRINCIPAL_MAX           70.904330
# 95                    CC_AMT_PAYMENT_TOTAL_CURRENT_MAX           70.904330
# 96                    CC_AMT_PAYMENT_TOTAL_CURRENT_MIN           70.904330
# 97                      CC_AMT_INST_MIN_REGULARITY_SUM           70.904330
# 98                    CC_AMT_RECEIVABLE_PRINCIPAL_MEAN           70.904330
# 99                     CC_AMT_INST_MIN_REGULARITY_MEAN           70.904330
# 100                    CC_AMT_RECEIVABLE_PRINCIPAL_SUM           70.904330
# 101                     CC_AMT_INST_MIN_REGULARITY_MAX           70.904330
# 102                     CC_AMT_INST_MIN_REGULARITY_MIN           70.904330
# 103                    CC_AMT_DRAWINGS_POS_CURRENT_SUM           70.904330
# 104                               CC_AMT_RECIVABLE_MIN           70.904330
# 105                               CC_AMT_RECIVABLE_MAX           70.904330
# 106                              CC_AMT_RECIVABLE_MEAN           70.904330
# 107                               CC_AMT_RECIVABLE_SUM           70.904330
# 108                  CC_AMT_DRAWINGS_OTHER_CURRENT_SUM           70.904330
# 109                        CC_AMT_TOTAL_RECEIVABLE_MIN           70.904330
# 110                        CC_AMT_TOTAL_RECEIVABLE_MAX           70.904330
# 111                       CC_AMT_TOTAL_RECEIVABLE_MEAN           70.904330
# 112                         CC_AMT_PAYMENT_CURRENT_SUM           70.904330
# 113                                           CC_COUNT           70.904330
# 114                    CC_CNT_DRAWINGS_POS_CURRENT_SUM           70.904330
# 115                                 CC_AMT_BALANCE_MIN           70.904330
# 116              CC_NAME_CONTRACT_STATUS_Completed_MAX           70.904330
# 117             CC_NAME_CONTRACT_STATUS_Completed_MEAN           70.904330
# 118              CC_NAME_CONTRACT_STATUS_Completed_SUM           70.904330
# 119                 CC_NAME_CONTRACT_STATUS_Demand_MIN           70.904330
# 120                 CC_NAME_CONTRACT_STATUS_Demand_MAX           70.904330
# 121                CC_NAME_CONTRACT_STATUS_Demand_MEAN           70.904330
# 122                 CC_NAME_CONTRACT_STATUS_Demand_SUM           70.904330
# 123                CC_NAME_CONTRACT_STATUS_Refused_MIN           70.904330
# 124                CC_NAME_CONTRACT_STATUS_Refused_MAX           70.904330
# 125               CC_NAME_CONTRACT_STATUS_Refused_MEAN           70.904330
# 126                CC_NAME_CONTRACT_STATUS_Refused_SUM           70.904330
# 127           CC_NAME_CONTRACT_STATUS_Sentproposal_MIN           70.904330
# 128           CC_NAME_CONTRACT_STATUS_Sentproposal_MAX           70.904330
# 129          CC_NAME_CONTRACT_STATUS_Sentproposal_MEAN           70.904330
# 130           CC_NAME_CONTRACT_STATUS_Sentproposal_SUM           70.904330
# 131                 CC_NAME_CONTRACT_STATUS_Signed_MIN           70.904330
# 132                 CC_NAME_CONTRACT_STATUS_Signed_MAX           70.904330
# 133                CC_NAME_CONTRACT_STATUS_Signed_MEAN           70.904330
# 134                 CC_NAME_CONTRACT_STATUS_Signed_SUM           70.904330
# 135                    CC_NAME_CONTRACT_STATUS_nan_MIN           70.904330
# 136                    CC_NAME_CONTRACT_STATUS_nan_MAX           70.904330
# 137                   CC_NAME_CONTRACT_STATUS_nan_MEAN           70.904330
# 138                    CC_NAME_CONTRACT_STATUS_nan_SUM           70.904330
# 139              CC_NAME_CONTRACT_STATUS_Completed_MIN           70.904330
# 140                                CC_AMT_BALANCE_MEAN           70.904330
# 141              CC_NAME_CONTRACT_STATUS_Approved_MEAN           70.904330
# 142                                 CC_AMT_BALANCE_MAX           70.904330
# 143                 CC_NAME_CONTRACT_STATUS_Active_SUM           70.904330
# 144               CC_NAME_CONTRACT_STATUS_Approved_SUM           70.904330
# 145                              CC_MONTHS_BALANCE_MAX           70.904330
# 146                CC_NAME_CONTRACT_STATUS_Active_MEAN           70.904330
# 147                 CC_NAME_CONTRACT_STATUS_Active_MAX           70.904330
# 148                 CC_NAME_CONTRACT_STATUS_Active_MIN           70.904330
# 149                                  CC_SK_DPD_DEF_SUM           70.904330
# 150                                 CC_SK_DPD_DEF_MEAN           70.904330
# 151                                  CC_SK_DPD_DEF_MAX           70.904330
# 152                                  CC_SK_DPD_DEF_MIN           70.904330
# 153                                      CC_SK_DPD_SUM           70.904330
# 154               CC_NAME_CONTRACT_STATUS_Approved_MIN           70.904330
# 155                                     CC_SK_DPD_MEAN           70.904330
# 156                              CC_MONTHS_BALANCE_MIN           70.904330
# 157                                      CC_SK_DPD_MAX           70.904330
# 158                                      CC_SK_DPD_MIN           70.904330
# 159                   CC_CNT_INSTALMENT_MATURE_CUM_SUM           70.904330
# 160                  CC_CNT_INSTALMENT_MATURE_CUM_MEAN           70.904330
# 161                   CC_CNT_INSTALMENT_MATURE_CUM_MAX           70.904330
# 162                   CC_CNT_INSTALMENT_MATURE_CUM_MIN           70.904330
# 163                             CC_MONTHS_BALANCE_MEAN           70.904330
# 164                              CC_MONTHS_BALANCE_SUM           70.904330
# 165               CC_NAME_CONTRACT_STATUS_Approved_MAX           70.904330
# 166                              LIVINGAPARTMENTS_MEDI           70.426989
# 167                               LIVINGAPARTMENTS_AVG           70.426989
# 168                              LIVINGAPARTMENTS_MODE           70.426989
# 169                            BURO_STATUS_2_MEAN_MEAN           70.082578
# 170                            BURO_STATUS_0_MEAN_MEAN           70.082578
# 171                        BURO_MONTHS_BALANCE_MIN_MIN           70.082578
# 172                          BURO_STATUS_nan_MEAN_MEAN           70.082578
# 173                            BURO_STATUS_X_MEAN_MEAN           70.082578
# 174                            BURO_STATUS_C_MEAN_MEAN           70.082578
# 175                            BURO_STATUS_5_MEAN_MEAN           70.082578
# 176                            BURO_STATUS_4_MEAN_MEAN           70.082578
# 177                        BURO_MONTHS_BALANCE_MAX_MAX           70.082578
# 178                      BURO_MONTHS_BALANCE_SIZE_MEAN           70.082578
# 179                            BURO_STATUS_3_MEAN_MEAN           70.082578
# 180                            BURO_STATUS_1_MEAN_MEAN           70.082578
# 181                                     FLOORSMIN_MEDI           70.034240
# 182                                     FLOORSMIN_MODE           70.034240
# 183                                      FLOORSMIN_AVG           70.034240
# 184                                    YEARS_BUILD_AVG           68.765358
# 185                                   YEARS_BUILD_MEDI           68.765358
# 186                                   YEARS_BUILD_MODE           68.765358
# 187                                        OWN_CAR_AGE           67.458207
# 188                           REFUSED_CNT_PAYMENT_MEAN           66.684794
# 189                            REFUSED_AMT_ANNUITY_MIN           66.684794
# 190                            REFUSED_AMT_ANNUITY_MAX           66.684794
# 191                           REFUSED_AMT_ANNUITY_MEAN           66.684794
# 192                       REFUSED_AMT_GOODS_PRICE_MEAN           66.145015
# 193                        REFUSED_AMT_GOODS_PRICE_MIN           66.145015
# 194                        REFUSED_AMT_GOODS_PRICE_MAX           66.145015
# 195                        REFUSED_APP_CREDIT_PERC_MAX           65.438066
# 196                       REFUSED_APP_CREDIT_PERC_MEAN           65.438066
# 197                        REFUSED_APP_CREDIT_PERC_MIN           65.438066
# 198                        REFUSED_AMT_APPLICATION_MIN           63.438066
# 199                       REFUSED_AMT_APPLICATION_MEAN           63.438066
# 200                             REFUSED_AMT_CREDIT_MIN           63.438066
# 201                REFUSED_HOUR_APPR_PROCESS_START_MIN           63.438066
# 202                REFUSED_HOUR_APPR_PROCESS_START_MAX           63.438066
# 203               REFUSED_HOUR_APPR_PROCESS_START_MEAN           63.438066
# 204                             REFUSED_AMT_CREDIT_MAX           63.438066
# 205                            REFUSED_AMT_CREDIT_MEAN           63.438066
# 206                            REFUSED_CNT_PAYMENT_SUM           63.438066
# 207                          REFUSED_DAYS_DECISION_MIN           63.438066
# 208                          REFUSED_DAYS_DECISION_MAX           63.438066
# 209                         REFUSED_DAYS_DECISION_MEAN           63.438066
# 210                        REFUSED_AMT_APPLICATION_MAX           63.438066
# 211                                      LANDAREA_MODE           61.796576
# 212                                      LANDAREA_MEDI           61.796576
# 213                                       LANDAREA_AVG           61.796576
# 214                                  BASEMENTAREA_MODE           61.133938
# 215                                  BASEMENTAREA_MEDI           61.133938
# 216                                   BASEMENTAREA_AVG           61.133938
# 217                 ACTIVE_AMT_CREDIT_MAX_OVERDUE_MEAN           60.253776
# 218                                 NONLIVINGAREA_MODE           58.140987
# 219                                 NONLIVINGAREA_MEDI           58.140987
# 220                                  NONLIVINGAREA_AVG           58.140987
# 221                                       EXT_SOURCE_1           57.752266
# 222                                     ELEVATORS_MODE           56.294058
# 223                                     ELEVATORS_MEDI           56.294058
# 224                                      ELEVATORS_AVG           56.294058
# 225                 CLOSED_AMT_CREDIT_MAX_OVERDUE_MEAN           55.139980
# 226                                    APARTMENTS_MEDI           53.760322
# 227                                    APARTMENTS_MODE           53.760322
# 228                                     APARTMENTS_AVG           53.760322
# 229                                      ENTRANCES_AVG           53.383686
# 230                                     ENTRANCES_MEDI           53.383686
# 231                                     ENTRANCES_MODE           53.383686
# 232                                    LIVINGAREA_MEDI           53.139980
# 233                                    LIVINGAREA_MODE           53.139980
# 234                                     LIVINGAREA_AVG           53.139980
# 235                                     FLOORSMAX_MODE           52.797583
# 236                                      FLOORSMAX_AVG           52.797583
# 237                                     FLOORSMAX_MEDI           52.797583
# 238                             ACTIVE_DAYS_CREDIT_VAR           51.867069
# 239                       YEARS_BEGINEXPLUATATION_MEDI           51.806647
# 240                       YEARS_BEGINEXPLUATATION_MODE           51.806647
# 241                        YEARS_BEGINEXPLUATATION_AVG           51.806647
# 242                                     TOTALAREA_MODE           51.343404
# 243                             CLOSED_DAYS_CREDIT_VAR           46.497482
# 244                   BURO_AMT_CREDIT_MAX_OVERDUE_MEAN           41.059416
# 245                   CLOSED_AMT_CREDIT_SUM_LIMIT_MEAN           38.799597
# 246                   ACTIVE_AMT_CREDIT_SUM_LIMIT_MEAN           37.987915
# 247                    CLOSED_AMT_CREDIT_SUM_DEBT_MEAN           32.418933
# 248                     CLOSED_AMT_CREDIT_SUM_DEBT_MAX           32.418933
# 249                     ACTIVE_AMT_CREDIT_SUM_DEBT_MAX           32.330312
# 250                    ACTIVE_AMT_CREDIT_SUM_DEBT_MEAN           32.330312
# 251                       APPROVED_APP_CREDIT_PERC_VAR           32.004028
# 252                    ACTIVE_DAYS_CREDIT_ENDDATE_MEAN           31.903323
# 253                     ACTIVE_DAYS_CREDIT_ENDDATE_MIN           31.903323
# 254                     ACTIVE_DAYS_CREDIT_ENDDATE_MAX           31.903323
# 255                    CLOSED_DAYS_CREDIT_ENDDATE_MEAN           29.284995
# 256                     CLOSED_DAYS_CREDIT_ENDDATE_MAX           29.284995
# 257                     CLOSED_DAYS_CREDIT_ENDDATE_MIN           29.284995
# 258                             ACTIVE_DAYS_CREDIT_MAX           29.071501
# 259                            ACTIVE_DAYS_CREDIT_MEAN           29.071501
# 260                             ACTIVE_DAYS_CREDIT_MIN           29.071501
# 261                     ACTIVE_AMT_CREDIT_SUM_DEBT_SUM           29.071501
# 262                     ACTIVE_DAYS_CREDIT_UPDATE_MEAN           29.071501
# 263                      ACTIVE_CREDIT_DAY_OVERDUE_MAX           29.071501
# 264                     ACTIVE_CREDIT_DAY_OVERDUE_MEAN           29.071501
# 265                          ACTIVE_AMT_CREDIT_SUM_MAX           29.071501
# 266                         ACTIVE_AMT_CREDIT_SUM_MEAN           29.071501
# 267                          ACTIVE_AMT_CREDIT_SUM_SUM           29.071501
# 268                     ACTIVE_MONTHS_BALANCE_SIZE_SUM           29.071501
# 269                    ACTIVE_AMT_CREDIT_SUM_LIMIT_SUM           29.071501
# 270                      ACTIVE_CNT_CREDIT_PROLONG_SUM           29.071501
# 271                 ACTIVE_AMT_CREDIT_SUM_OVERDUE_MEAN           29.071501
# 272                          CLOSED_AMT_CREDIT_SUM_SUM           28.729104
# 273                     CLOSED_AMT_CREDIT_SUM_DEBT_SUM           28.729104
# 274                         CLOSED_AMT_CREDIT_SUM_MEAN           28.729104
# 275                             CLOSED_DAYS_CREDIT_MIN           28.729104
# 276                             CLOSED_DAYS_CREDIT_MAX           28.729104
# 277                            CLOSED_DAYS_CREDIT_MEAN           28.729104
# 278                     CLOSED_DAYS_CREDIT_UPDATE_MEAN           28.729104
# 279                    CLOSED_AMT_CREDIT_SUM_LIMIT_SUM           28.729104
# 280                     CLOSED_CREDIT_DAY_OVERDUE_MEAN           28.729104
# 281                          CLOSED_AMT_CREDIT_SUM_MAX           28.729104
# 282                      CLOSED_CREDIT_DAY_OVERDUE_MAX           28.729104
# 283                 CLOSED_AMT_CREDIT_SUM_OVERDUE_MEAN           28.729104
# 284                     CLOSED_MONTHS_BALANCE_SIZE_SUM           28.729104
# 285                      CLOSED_CNT_CREDIT_PROLONG_SUM           28.729104
# 286                               BURO_DAYS_CREDIT_VAR           28.155086
# 287                           PREV_APP_CREDIT_PERC_VAR           25.347432
# 288                     BURO_AMT_CREDIT_SUM_LIMIT_MEAN           22.815710
# 289                                       EXT_SOURCE_3           21.242699
# 290                      BURO_AMT_CREDIT_SUM_DEBT_MEAN           18.223565
# 291                       BURO_AMT_CREDIT_SUM_DEBT_MAX           18.223565
# 292                      BURO_DAYS_CREDIT_ENDDATE_MEAN           16.839879
# 293                       BURO_DAYS_CREDIT_ENDDATE_MIN           16.839879
# 294                       BURO_DAYS_CREDIT_ENDDATE_MAX           16.839879
# 295            BURO_CREDIT_TYPE_Anothertypeofloan_MEAN           15.975831
# 296                   BURO_AMT_CREDIT_SUM_OVERDUE_MEAN           15.975831
# 297                       BURO_AMT_CREDIT_SUM_DEBT_SUM           15.975831
# 298                            BURO_AMT_CREDIT_SUM_SUM           15.975831
# 299                           BURO_AMT_CREDIT_SUM_MEAN           15.975831
# 300                      BURO_CREDIT_CURRENCY_nan_MEAN           15.975831
# 301                       BURO_CREDIT_DAY_OVERDUE_MEAN           15.975831
# 302                        BURO_CREDIT_DAY_OVERDUE_MAX           15.975831
# 303                       BURO_DAYS_CREDIT_UPDATE_MEAN           15.975831
# 304                        BURO_CNT_CREDIT_PROLONG_SUM           15.975831
# 305                              BURO_DAYS_CREDIT_MEAN           15.975831
# 306                               BURO_DAYS_CREDIT_MAX           15.975831
# 307                               BURO_DAYS_CREDIT_MIN           15.975831
# 308                      BURO_AMT_CREDIT_SUM_LIMIT_SUM           15.975831
# 309                            BURO_AMT_CREDIT_SUM_MAX           15.975831
# 310                       BURO_MONTHS_BALANCE_SIZE_SUM           15.975831
# 311           BURO_CREDIT_TYPE_Mobileoperatorloan_MEAN           15.975831
# 312                      BURO_CREDIT_TYPE_Carloan_MEAN           15.975831
# 313         BURO_CREDIT_TYPE_Cashloannonearmarked_MEAN           15.975831
# 314               BURO_CREDIT_TYPE_Consumercredit_MEAN           15.975831
# 315                     BURO_CREDIT_ACTIVE_Active_MEAN           15.975831
# 316                   BURO_CREDIT_TYPE_Creditcard_MEAN           15.975831
# 317              BURO_CREDIT_TYPE_Interbankcredit_MEAN           15.975831
# 318   BURO_CREDIT_TYPE_Loanforbusinessdevelopment_MEAN           15.975831
# 319  BURO_CREDIT_TYPE_Loanforpurchaseofsharesmargin...           15.975831
# 320  BURO_CREDIT_TYPE_Loanforthepurchaseofequipment...           15.975831
# 321  BURO_CREDIT_TYPE_Loanforworkingcapitalreplenis...           15.975831
# 322                    BURO_CREDIT_TYPE_Microloan_MEAN           15.975831
# 323                BURO_CREDIT_CURRENCY_currency4_MEAN           15.975831
# 324                     BURO_CREDIT_TYPE_Mortgage_MEAN           15.975831
# 325            BURO_CREDIT_TYPE_Unknowntypeofloan_MEAN           15.975831
# 326                          BURO_CREDIT_TYPE_nan_MEAN           15.975831
# 327                BURO_CREDIT_CURRENCY_currency3_MEAN           15.975831
# 328                BURO_CREDIT_CURRENCY_currency2_MEAN           15.975831
# 329                    BURO_CREDIT_ACTIVE_Baddebt_MEAN           15.975831
# 330                BURO_CREDIT_CURRENCY_currency1_MEAN           15.975831
# 331                        BURO_CREDIT_ACTIVE_nan_MEAN           15.975831
# 332                     BURO_CREDIT_ACTIVE_Closed_MEAN           15.975831
# 333               BURO_CREDIT_TYPE_Realestateloan_MEAN           15.975831
# 334                       BURO_CREDIT_ACTIVE_Sold_MEAN           15.975831
# 335                         AMT_REQ_CREDIT_BUREAU_YEAR           15.238671
# 336                         AMT_REQ_CREDIT_BUREAU_HOUR           15.238671
# 337                          AMT_REQ_CREDIT_BUREAU_QRT           15.238671
# 338                         AMT_REQ_CREDIT_BUREAU_WEEK           15.238671
# 339                          AMT_REQ_CREDIT_BUREAU_DAY           15.238671
# 340                          AMT_REQ_CREDIT_BUREAU_MON           15.238671
# 341                                 DAYS_EMPLOYED_PERC           15.236657
# 342                                      DAYS_EMPLOYED           15.236657
# 343                     APPROVED_RATE_DOWN_PAYMENT_MIN           12.076536
# 344                     APPROVED_RATE_DOWN_PAYMENT_MAX           12.076536
# 345                    APPROVED_RATE_DOWN_PAYMENT_MEAN           12.076536
# 346                     APPROVED_AMT_DOWN_PAYMENT_MEAN           12.076536
# 347                      APPROVED_AMT_DOWN_PAYMENT_MAX           12.076536
# 348                      APPROVED_AMT_DOWN_PAYMENT_MIN           12.076536
# 349                          PREV_AMT_DOWN_PAYMENT_MIN           11.226586
# 350                         PREV_AMT_DOWN_PAYMENT_MEAN           11.226586
# 351                         PREV_RATE_DOWN_PAYMENT_MIN           11.226586
# 352                         PREV_RATE_DOWN_PAYMENT_MAX           11.226586
# 353                        PREV_RATE_DOWN_PAYMENT_MEAN           11.226586
# 354                          PREV_AMT_DOWN_PAYMENT_MAX           11.226586
# 355                                     POS_SK_DPD_MAX            5.496475
# 356                            POS_MONTHS_BALANCE_SIZE            5.496475
# 357             POS_NAME_CONTRACT_STATUS_Canceled_MEAN            5.496475
# 358               POS_NAME_CONTRACT_STATUS_Demand_MEAN            5.496475
# 359             POS_NAME_CONTRACT_STATUS_Approved_MEAN            5.496475
# 360        POS_NAME_CONTRACT_STATUS_Amortizeddebt_MEAN            5.496475
# 361               POS_NAME_CONTRACT_STATUS_Active_MEAN            5.496475
# 362   POS_NAME_CONTRACT_STATUS_Returnedtothestore_MEAN            5.496475
# 363               POS_NAME_CONTRACT_STATUS_Signed_MEAN            5.496475
# 364                  POS_NAME_CONTRACT_STATUS_XNA_MEAN            5.496475
# 365                                POS_SK_DPD_DEF_MEAN            5.496475
# 366            POS_NAME_CONTRACT_STATUS_Completed_MEAN            5.496475
# 367                                 POS_SK_DPD_DEF_MAX            5.496475
# 368                                    POS_SK_DPD_MEAN            5.496475
# 369                  POS_NAME_CONTRACT_STATUS_nan_MEAN            5.496475
# 370                                          POS_COUNT            5.496475
# 371                             POS_MONTHS_BALANCE_MAX            5.496475
# 372                            POS_MONTHS_BALANCE_MEAN            5.496475
# 373                       APPROVED_AMT_GOODS_PRICE_MIN            5.407855
# 374                      APPROVED_AMT_GOODS_PRICE_MEAN            5.407855
# 375                       APPROVED_AMT_GOODS_PRICE_MAX            5.407855
# 376                      APPROVED_APP_CREDIT_PERC_MEAN            5.115811
# 377                       APPROVED_APP_CREDIT_PERC_MAX            5.115811
# 378                       APPROVED_APP_CREDIT_PERC_MIN            5.115811
# 379                            APPROVED_AMT_CREDIT_MIN            5.113797
# 380                        APPROVED_DAYS_DECISION_MEAN            5.113797
# 381                      APPROVED_AMT_APPLICATION_MEAN            5.113797
# 382                          APPROVED_AMT_ANNUITY_MEAN            5.113797
# 383                            APPROVED_AMT_CREDIT_MAX            5.113797
# 384                           APPROVED_AMT_CREDIT_MEAN            5.113797
# 385                           APPROVED_AMT_ANNUITY_MAX            5.113797
# 386                           APPROVED_CNT_PAYMENT_SUM            5.113797
# 387                           APPROVED_AMT_ANNUITY_MIN            5.113797
# 388                       APPROVED_AMT_APPLICATION_MIN            5.113797
# 389                       APPROVED_AMT_APPLICATION_MAX            5.113797
# 390                         APPROVED_DAYS_DECISION_MAX            5.113797
# 391                         APPROVED_DAYS_DECISION_MIN            5.113797
# 392                          APPROVED_CNT_PAYMENT_MEAN            5.113797
# 393               APPROVED_HOUR_APPR_PROCESS_START_MIN            5.113797
# 394               APPROVED_HOUR_APPR_PROCESS_START_MAX            5.113797
# 395              APPROVED_HOUR_APPR_PROCESS_START_MEAN            5.113797
# 396                           PREV_AMT_GOODS_PRICE_MIN            5.069486
# 397                          PREV_AMT_GOODS_PRICE_MEAN            5.069486
# 398                           PREV_AMT_GOODS_PRICE_MAX            5.069486
# 399                              PREV_AMT_ANNUITY_MEAN            4.904330
# 400                               PREV_AMT_ANNUITY_MAX            4.904330
# 401                               PREV_AMT_ANNUITY_MIN            4.904330
# 402                              PREV_CNT_PAYMENT_MEAN            4.904330
# 403                            INSTAL_PAYMENT_PERC_VAR            4.878147
# 404                            INSTAL_PAYMENT_DIFF_VAR            4.870091
# 405                          PREV_APP_CREDIT_PERC_MEAN            4.853978
# 406                           PREV_APP_CREDIT_PERC_MIN            4.853978
# 407                           PREV_APP_CREDIT_PERC_MAX            4.853978
# 408                      PREV_NAME_PORTFOLIO_Cars_MEAN            4.783484
# 409                    PREV_NAME_PRODUCT_TYPE_nan_MEAN            4.783484
# 410                       PREV_NAME_PORTFOLIO_POS_MEAN            4.783484
# 411                       PREV_NAME_PORTFOLIO_XNA_MEAN            4.783484
# 412                       PREV_NAME_PORTFOLIO_nan_MEAN            4.783484
# 413                    PREV_NAME_PRODUCT_TYPE_XNA_MEAN            4.783484
# 414                 PREV_NAME_PRODUCT_TYPE_walkin_MEAN            4.783484
# 415                  PREV_NAME_PRODUCT_TYPE_xsell_MEAN            4.783484
# 416                  PREV_CHANNEL_TYPE_APCashloan_MEAN            4.783484
# 417               PREV_CHANNEL_TYPE_RegionalLocal_MEAN            4.783484
# 418                   PREV_CHANNEL_TYPE_Cardealer_MEAN            4.783484
# 419     PREV_CHANNEL_TYPE_Channelofcorporatesales_MEAN            4.783484
# 420               PREV_CHANNEL_TYPE_Contactcenter_MEAN            4.783484
# 421                 PREV_CHANNEL_TYPE_Countrywide_MEAN            4.783484
# 422        PREV_CHANNEL_TYPE_Creditandcashoffices_MEAN            4.783484
# 423                       PREV_CHANNEL_TYPE_Stone_MEAN            4.783484
# 424                      PREV_NAME_PORTFOLIO_Cash_MEAN            4.783484
# 425      PREV_NAME_GOODS_CATEGORY_MedicalSupplies_MEAN            4.783484
# 426                     PREV_NAME_PORTFOLIO_Cards_MEAN            4.783484
# 427     PREV_NAME_GOODS_CATEGORY_OfficeAppliances_MEAN            4.783484
# 428    PREV_NAME_GOODS_CATEGORY_HouseConstruction_MEAN            4.783484
# 429      PREV_NAME_SELLER_INDUSTRY_Autotechnology_MEAN            4.783484
# 430            PREV_NAME_GOODS_CATEGORY_Insurance_MEAN            4.783484
# 431              PREV_NAME_GOODS_CATEGORY_Jewelry_MEAN            4.783484
# 432             PREV_NAME_GOODS_CATEGORY_Medicine_MEAN            4.783484
# 433               PREV_NAME_GOODS_CATEGORY_Mobile_MEAN            4.783484
# 434                PREV_NAME_GOODS_CATEGORY_Other_MEAN            4.783484
# 435                  PREV_NAME_GOODS_CATEGORY_nan_MEAN            4.783484
# 436  PREV_NAME_GOODS_CATEGORY_PhotoCinemaEquipment_...            4.783484
# 437      PREV_NAME_GOODS_CATEGORY_SportandLeisure_MEAN            4.783484
# 438              PREV_NAME_GOODS_CATEGORY_Tourism_MEAN            4.783484
# 439             PREV_NAME_GOODS_CATEGORY_Vehicles_MEAN            4.783484
# 440               PREV_NAME_GOODS_CATEGORY_Weapon_MEAN            4.783484
# 441                  PREV_NAME_GOODS_CATEGORY_XNA_MEAN            4.783484
# 442                         PREV_CHANNEL_TYPE_nan_MEAN            4.783484
# 443      PREV_PRODUCT_COMBINATION_CashXSellmiddle_MEAN            4.783484
# 444            PREV_NAME_SELLER_INDUSTRY_Clothing_MEAN            4.783484
# 445        PREV_NAME_SELLER_INDUSTRY_Connectivity_MEAN            4.783484
# 446       PREV_PRODUCT_COMBINATION_CashStreethigh_MEAN            4.783484
# 447        PREV_PRODUCT_COMBINATION_CashStreetlow_MEAN            4.783484
# 448     PREV_PRODUCT_COMBINATION_CashStreetmiddle_MEAN            4.783484
# 449        PREV_PRODUCT_COMBINATION_CashXSellhigh_MEAN            4.783484
# 450         PREV_PRODUCT_COMBINATION_CashXSelllow_MEAN            4.783484
# 451  PREV_PRODUCT_COMBINATION_POShouseholdwithinter...            4.783484
# 452  PREV_PRODUCT_COMBINATION_POShouseholdwithoutin...            4.783484
# 453  PREV_PRODUCT_COMBINATION_POSindustrywithintere...            4.783484
# 454  PREV_PRODUCT_COMBINATION_POSindustrywithoutint...            4.783484
# 455  PREV_PRODUCT_COMBINATION_POSmobilewithinterest...            4.783484
# 456  PREV_PRODUCT_COMBINATION_POSmobilewithoutinter...            4.783484
# 457  PREV_PRODUCT_COMBINATION_POSotherwithinterest_...            4.783484
# 458  PREV_PRODUCT_COMBINATION_POSotherswithoutinter...            4.783484
# 459                  PREV_PRODUCT_COMBINATION_nan_MEAN            4.783484
# 460            PREV_NAME_GOODS_CATEGORY_Gardening_MEAN            4.783484
# 461                 PREV_PRODUCT_COMBINATION_Cash_MEAN            4.783484
# 462            PREV_PRODUCT_COMBINATION_CardXSell_MEAN            4.783484
# 463           PREV_PRODUCT_COMBINATION_CardStreet_MEAN            4.783484
# 464             PREV_NAME_SELLER_INDUSTRY_Tourism_MEAN            4.783484
# 465        PREV_NAME_SELLER_INDUSTRY_Construction_MEAN            4.783484
# 466  PREV_NAME_SELLER_INDUSTRY_Consumerelectronics_...            4.783484
# 467           PREV_NAME_SELLER_INDUSTRY_Furniture_MEAN            4.783484
# 468            PREV_NAME_SELLER_INDUSTRY_Industry_MEAN            4.783484
# 469             PREV_NAME_SELLER_INDUSTRY_Jewelry_MEAN            4.783484
# 470         PREV_NAME_SELLER_INDUSTRY_MLMpartners_MEAN            4.783484
# 471                 PREV_NAME_SELLER_INDUSTRY_XNA_MEAN            4.783484
# 472                     PREV_NAME_YIELD_GROUP_nan_MEAN            4.783484
# 473                 PREV_NAME_SELLER_INDUSTRY_nan_MEAN            4.783484
# 474                     PREV_NAME_YIELD_GROUP_XNA_MEAN            4.783484
# 475                    PREV_NAME_YIELD_GROUP_high_MEAN            4.783484
# 476              PREV_NAME_YIELD_GROUP_low_action_MEAN            4.783484
# 477              PREV_NAME_YIELD_GROUP_low_normal_MEAN            4.783484
# 478                  PREV_NAME_YIELD_GROUP_middle_MEAN            4.783484
# 479            PREV_NAME_GOODS_CATEGORY_Homewares_MEAN            4.783484
# 480        PREV_WEEKDAY_APPR_PROCESS_START_FRIDAY_MEAN            4.783484
# 481            PREV_NAME_GOODS_CATEGORY_Furniture_MEAN            4.783484
# 482           PREV_WEEKDAY_APPR_PROCESS_START_nan_MEAN            4.783484
# 483            PREV_FLAG_LAST_APPL_PER_CONTRACT_Y_MEAN            4.783484
# 484          PREV_FLAG_LAST_APPL_PER_CONTRACT_nan_MEAN            4.783484
# 485  PREV_NAME_CASH_LOAN_PURPOSE_Buildingahouseoran...            4.783484
# 486  PREV_NAME_CASH_LOAN_PURPOSE_Businessdevelopmen...            4.783484
# 487     PREV_NAME_CASH_LOAN_PURPOSE_Buyingagarage_MEAN            4.783484
# 488  PREV_NAME_CASH_LOAN_PURPOSE_Buyingaholidayhome...            4.783484
# 489       PREV_NAME_CASH_LOAN_PURPOSE_Buyingahome_MEAN            4.783484
# 490     PREV_NAME_CASH_LOAN_PURPOSE_Buyinganewcar_MEAN            4.783484
# 491    PREV_NAME_CASH_LOAN_PURPOSE_Buyingausedcar_MEAN            4.783484
# 492        PREV_NAME_CASH_LOAN_PURPOSE_Carrepairs_MEAN            4.783484
# 493         PREV_NAME_CASH_LOAN_PURPOSE_Education_MEAN            4.783484
# 494  PREV_NAME_CASH_LOAN_PURPOSE_Everydayexpenses_MEAN            4.783484
# 495         PREV_NAME_CASH_LOAN_PURPOSE_Furniture_MEAN            4.783484
# 496  PREV_NAME_CASH_LOAN_PURPOSE_Gasificationwaters...            4.783484
# 497             PREV_NAME_CASH_LOAN_PURPOSE_Hobby_MEAN            4.783484
# 498           PREV_NAME_CASH_LOAN_PURPOSE_Journey_MEAN            4.783484
# 499          PREV_NAME_CASH_LOAN_PURPOSE_Medicine_MEAN            4.783484
# 500  PREV_NAME_CASH_LOAN_PURPOSE_Moneyforathirdpers...            4.783484
# 501             PREV_NAME_CASH_LOAN_PURPOSE_Other_MEAN            4.783484
# 502  PREV_NAME_CASH_LOAN_PURPOSE_Paymentsonotherloa...            4.783484
# 503  PREV_NAME_CASH_LOAN_PURPOSE_Purchaseofelectron...            4.783484
# 504            PREV_FLAG_LAST_APPL_PER_CONTRACT_N_MEAN            4.783484
# 505     PREV_WEEKDAY_APPR_PROCESS_START_WEDNESDAY_MEAN            4.783484
# 506           PREV_NAME_CASH_LOAN_PURPOSE_Repairs_MEAN            4.783484
# 507       PREV_WEEKDAY_APPR_PROCESS_START_TUESDAY_MEAN            4.783484
# 508                          PREV_AMT_APPLICATION_MEAN            4.783484
# 509                                PREV_AMT_CREDIT_MIN            4.783484
# 510                                PREV_AMT_CREDIT_MAX            4.783484
# 511                               PREV_AMT_CREDIT_MEAN            4.783484
# 512                   PREV_HOUR_APPR_PROCESS_START_MIN            4.783484
# 513                   PREV_HOUR_APPR_PROCESS_START_MAX            4.783484
# 514                  PREV_HOUR_APPR_PROCESS_START_MEAN            4.783484
# 515                             PREV_DAYS_DECISION_MIN            4.783484
# 516                             PREV_DAYS_DECISION_MAX            4.783484
# 517                            PREV_DAYS_DECISION_MEAN            4.783484
# 518                               PREV_CNT_PAYMENT_SUM            4.783484
# 519             PREV_NAME_CONTRACT_TYPE_Cashloans_MEAN            4.783484
# 520         PREV_NAME_CONTRACT_TYPE_Consumerloans_MEAN            4.783484
# 521        PREV_NAME_CONTRACT_TYPE_Revolvingloans_MEAN            4.783484
# 522                   PREV_NAME_CONTRACT_TYPE_XNA_MEAN            4.783484
# 523                   PREV_NAME_CONTRACT_TYPE_nan_MEAN            4.783484
# 524              PREV_NAME_GOODS_CATEGORY_Fitness_MEAN            4.783484
# 525        PREV_WEEKDAY_APPR_PROCESS_START_MONDAY_MEAN            4.783484
# 526      PREV_WEEKDAY_APPR_PROCESS_START_SATURDAY_MEAN            4.783484
# 527        PREV_WEEKDAY_APPR_PROCESS_START_SUNDAY_MEAN            4.783484
# 528      PREV_WEEKDAY_APPR_PROCESS_START_THURSDAY_MEAN            4.783484
# 529  PREV_NAME_CASH_LOAN_PURPOSE_Refusaltonamethego...            4.783484
# 530       PREV_NAME_CASH_LOAN_PURPOSE_Urgentneeds_MEAN            4.783484
# 531                           PREV_AMT_APPLICATION_MIN            4.783484
# 532                 PREV_NAME_TYPE_SUITE_Children_MEAN            4.783484
# 533            PREV_NAME_TYPE_SUITE_Groupofpeople_MEAN            4.783484
# 534                  PREV_NAME_TYPE_SUITE_Other_A_MEAN            4.783484
# 535                  PREV_NAME_TYPE_SUITE_Other_B_MEAN            4.783484
# 536            PREV_NAME_TYPE_SUITE_Spousepartner_MEAN            4.783484
# 537            PREV_NAME_TYPE_SUITE_Unaccompanied_MEAN            4.783484
# 538                      PREV_NAME_TYPE_SUITE_nan_MEAN            4.783484
# 539                     PREV_NAME_CLIENT_TYPE_New_MEAN            4.783484
# 540               PREV_NAME_CLIENT_TYPE_Refreshed_MEAN            4.783484
# 541                PREV_NAME_CLIENT_TYPE_Repeater_MEAN            4.783484
# 542                     PREV_NAME_CLIENT_TYPE_XNA_MEAN            4.783484
# 543                     PREV_NAME_CLIENT_TYPE_nan_MEAN            4.783484
# 544    PREV_NAME_GOODS_CATEGORY_AdditionalService_MEAN            4.783484
# 545              PREV_NAME_GOODS_CATEGORY_Animals_MEAN            4.783484
# 546           PREV_NAME_GOODS_CATEGORY_AudioVideo_MEAN            4.783484
# 547      PREV_NAME_GOODS_CATEGORY_AutoAccessories_MEAN            4.783484
# 548  PREV_NAME_GOODS_CATEGORY_ClothingandAccessorie...            4.783484
# 549            PREV_NAME_GOODS_CATEGORY_Computers_MEAN            4.783484
# 550  PREV_NAME_GOODS_CATEGORY_ConstructionMaterials...            4.783484
# 551  PREV_NAME_GOODS_CATEGORY_ConsumerElectronics_MEAN            4.783484
# 552          PREV_NAME_GOODS_CATEGORY_DirectSales_MEAN            4.783484
# 553            PREV_NAME_GOODS_CATEGORY_Education_MEAN            4.783484
# 554                   PREV_NAME_TYPE_SUITE_Family_MEAN            4.783484
# 555                   PREV_CODE_REJECT_REASON_nan_MEAN            4.783484
# 556  PREV_NAME_CASH_LOAN_PURPOSE_Weddinggiftholiday...            4.783484
# 557                   PREV_CODE_REJECT_REASON_XNA_MEAN            4.783484
# 558               PREV_NAME_CASH_LOAN_PURPOSE_XAP_MEAN            4.783484
# 559               PREV_NAME_CASH_LOAN_PURPOSE_XNA_MEAN            4.783484
# 560               PREV_NAME_CASH_LOAN_PURPOSE_nan_MEAN            4.783484
# 561            PREV_NAME_CONTRACT_STATUS_Approved_MEAN            4.783484
# 562            PREV_NAME_CONTRACT_STATUS_Canceled_MEAN            4.783484
# 563             PREV_NAME_CONTRACT_STATUS_Refused_MEAN            4.783484
# 564         PREV_NAME_CONTRACT_STATUS_Unusedoffer_MEAN            4.783484
# 565                 PREV_NAME_CONTRACT_STATUS_nan_MEAN            4.783484
# 566     PREV_NAME_PAYMENT_TYPE_Cashthroughthebank_MEAN            4.783484
# 567  PREV_NAME_PAYMENT_TYPE_Cashlessfromtheaccounto...            4.783484
# 568  PREV_NAME_PAYMENT_TYPE_Noncashfromyouraccount_...            4.783484
# 569                    PREV_NAME_PAYMENT_TYPE_XNA_MEAN            4.783484
# 570                    PREV_NAME_PAYMENT_TYPE_nan_MEAN            4.783484
# 571                PREV_CODE_REJECT_REASON_CLIENT_MEAN            4.783484
# 572                    PREV_CODE_REJECT_REASON_HC_MEAN            4.783484
# 573                 PREV_CODE_REJECT_REASON_LIMIT_MEAN            4.783484
# 574                   PREV_CODE_REJECT_REASON_SCO_MEAN            4.783484
# 575                 PREV_CODE_REJECT_REASON_SCOFR_MEAN            4.783484
# 576                PREV_CODE_REJECT_REASON_SYSTEM_MEAN            4.783484
# 577                 PREV_CODE_REJECT_REASON_VERIF_MEAN            4.783484
# 578                   PREV_CODE_REJECT_REASON_XAP_MEAN            4.783484
# 579                           PREV_AMT_APPLICATION_MAX            4.783484
# 580                           INSTAL_PAYMENT_PERC_MEAN            4.638469
# 581                            INSTAL_PAYMENT_PERC_SUM            4.634441
# 582                      INSTAL_DAYS_ENTRY_PAYMENT_MAX            4.630413
# 583                     INSTAL_DAYS_ENTRY_PAYMENT_MEAN            4.630413
# 584                            INSTAL_AMT_PAYMENT_MEAN            4.630413
# 585                             INSTAL_AMT_PAYMENT_MAX            4.630413
# 586                             INSTAL_AMT_PAYMENT_MIN            4.630413
# 587                           INSTAL_PAYMENT_DIFF_MEAN            4.630413
# 588                            INSTAL_PAYMENT_DIFF_MAX            4.630413
# 589                            INSTAL_PAYMENT_PERC_MAX            4.630413
# 590              INSTAL_NUM_INSTALMENT_VERSION_NUNIQUE            4.626385
# 591                                     INSTAL_DPD_MAX            4.626385
# 592                                    INSTAL_DPD_MEAN            4.626385
# 593                                     INSTAL_DPD_SUM            4.626385
# 594                                    INSTAL_DBD_MEAN            4.626385
# 595                                     INSTAL_DBD_SUM            4.626385
# 596                                     INSTAL_DBD_MAX            4.626385
# 597                            INSTAL_PAYMENT_DIFF_SUM            4.626385
# 598                      INSTAL_DAYS_ENTRY_PAYMENT_SUM            4.626385
# 599                          INSTAL_AMT_INSTALMENT_MAX            4.626385
# 600                         INSTAL_AMT_INSTALMENT_MEAN            4.626385
# 601                          INSTAL_AMT_INSTALMENT_SUM            4.626385
# 602                             INSTAL_AMT_PAYMENT_SUM            4.626385
# 603                                       INSTAL_COUNT            4.626385
# 604                           OBS_30_CNT_SOCIAL_CIRCLE            0.300101
# 605                           DEF_60_CNT_SOCIAL_CIRCLE            0.300101
# 606                           OBS_60_CNT_SOCIAL_CIRCLE            0.300101
# 607                           DEF_30_CNT_SOCIAL_CIRCLE            0.300101
# 608                                       EXT_SOURCE_2            0.205438
# 609                                    AMT_GOODS_PRICE            0.108761
# 610                                   FLAG_DOCUMENT_18            0.000000
# 611                      NAME_TYPE_SUITE_Groupofpeople            0.000000
# 612                             NAME_TYPE_SUITE_Family            0.000000
# 613                       NAME_CONTRACT_TYPE_Cashloans            0.000000
# 614                           NAME_TYPE_SUITE_Children            0.000000
# 615                  NAME_CONTRACT_TYPE_Revolvingloans            0.000000
# 616                                   FLAG_DOCUMENT_21            0.000000
# 617                                   FLAG_DOCUMENT_20            0.000000
# 618                                   FLAG_DOCUMENT_19            0.000000
# 619                            NAME_TYPE_SUITE_Other_B            0.000000
# 620                            NAME_TYPE_SUITE_Other_A            0.000000
# 621                                       PAYMENT_RATE            0.000000
# 622                      NAME_TYPE_SUITE_Spousepartner            0.000000
# 623                      NAME_TYPE_SUITE_Unaccompanied            0.000000
# 624                            OCCUPATION_TYPE_Drivers            0.000000
# 625                          OCCUPATION_TYPE_Corestaff            0.000000
# 626                       OCCUPATION_TYPE_Cookingstaff            0.000000
# 627                      OCCUPATION_TYPE_Cleaningstaff            0.000000
# 628                        OCCUPATION_TYPE_Accountants            0.000000
# 629                      NAME_HOUSING_TYPE_Withparents            0.000000
# 630                  NAME_HOUSING_TYPE_Rentedapartment            0.000000
# 631                  NAME_HOUSING_TYPE_Officeapartment            0.000000
# 632               NAME_HOUSING_TYPE_Municipalapartment            0.000000
# 633                   NAME_HOUSING_TYPE_Houseapartment            0.000000
# 634                    NAME_HOUSING_TYPE_Coopapartment            0.000000
# 635                           NAME_FAMILY_STATUS_Widow            0.000000
# 636                         NAME_FAMILY_STATUS_Unknown            0.000000
# 637                NAME_FAMILY_STATUS_Singlenotmarried            0.000000
# 638                       NAME_FAMILY_STATUS_Separated            0.000000
# 639                         NAME_FAMILY_STATUS_Married            0.000000
# 640                   NAME_FAMILY_STATUS_Civilmarriage            0.000000
# 641      NAME_EDUCATION_TYPE_Secondarysecondaryspecial            0.000000
# 642                 NAME_EDUCATION_TYPE_Lowersecondary            0.000000
# 643               NAME_EDUCATION_TYPE_Incompletehigher            0.000000
# 644                NAME_EDUCATION_TYPE_Highereducation            0.000000
# 645                 NAME_EDUCATION_TYPE_Academicdegree            0.000000
# 646                           NAME_INCOME_TYPE_Working            0.000000
# 647                        NAME_INCOME_TYPE_Unemployed            0.000000
# 648                           NAME_INCOME_TYPE_Student            0.000000
# 649                      NAME_INCOME_TYPE_Stateservant            0.000000
# 650                         NAME_INCOME_TYPE_Pensioner            0.000000
# 651                    NAME_INCOME_TYPE_Maternityleave            0.000000
# 652                       NAME_INCOME_TYPE_Businessman            0.000000
# 653               NAME_INCOME_TYPE_Commercialassociate            0.000000
# 654                                   FLAG_DOCUMENT_16            0.000000
# 655                                   FLAG_DOCUMENT_17            0.000000
# 656                                  DAYS_REGISTRATION            0.000000
# 657                               REGION_RATING_CLIENT            0.000000
# 658                                    CNT_FAM_MEMBERS            0.000000
# 659                                         FLAG_EMAIL            0.000000
# 660                                         FLAG_PHONE            0.000000
# 661                                   FLAG_CONT_MOBILE            0.000000
# 662                                    FLAG_WORK_PHONE            0.000000
# 663                                     FLAG_EMP_PHONE            0.000000
# 664                                         FLAG_MOBIL            0.000000
# 665                                    DAYS_ID_PUBLISH            0.000000
# 666                                         DAYS_BIRTH            0.000000
# 667                 OCCUPATION_TYPE_Highskilltechstaff            0.000000
# 668                         REGION_POPULATION_RELATIVE            0.000000
# 669                                        AMT_ANNUITY            0.000000
# 670                                         AMT_CREDIT            0.000000
# 671                                   AMT_INCOME_TOTAL            0.000000
# 672                                       CNT_CHILDREN            0.000000
# 673                                    FLAG_OWN_REALTY            0.000000
# 674                                       FLAG_OWN_CAR            0.000000
# 675                                        CODE_GENDER            0.000000
# 676                                             TARGET            0.000000
# 677                        REGION_RATING_CLIENT_W_CITY            0.000000
# 678                            HOUR_APPR_PROCESS_START            0.000000
# 679                         REG_REGION_NOT_LIVE_REGION            0.000000
# 680                         REG_REGION_NOT_WORK_REGION            0.000000
# 681                                   FLAG_DOCUMENT_15            0.000000
# 682                                   FLAG_DOCUMENT_14            0.000000
# 683                                   FLAG_DOCUMENT_13            0.000000
# 684                                   FLAG_DOCUMENT_12            0.000000
# 685                                   FLAG_DOCUMENT_11            0.000000
# 686                                   FLAG_DOCUMENT_10            0.000000
# 687                                    FLAG_DOCUMENT_9            0.000000
# 688                                    FLAG_DOCUMENT_8            0.000000
# 689                                    FLAG_DOCUMENT_7            0.000000
# 690                                    FLAG_DOCUMENT_6            0.000000
# 691                                    FLAG_DOCUMENT_5            0.000000
# 692                                    FLAG_DOCUMENT_4            0.000000
# 693                                    FLAG_DOCUMENT_3            0.000000
# 694                                    FLAG_DOCUMENT_2            0.000000
# 695                             DAYS_LAST_PHONE_CHANGE            0.000000
# 696                            LIVE_CITY_NOT_WORK_CITY            0.000000
# 697                             REG_CITY_NOT_WORK_CITY            0.000000
# 698                             REG_CITY_NOT_LIVE_CITY            0.000000
# 699                        LIVE_REGION_NOT_WORK_REGION            0.000000
# 700                            OCCUPATION_TYPE_HRstaff            0.000000
# 701                  WEEKDAY_APPR_PROCESS_START_FRIDAY            0.000000
# 702                            OCCUPATION_TYPE_ITstaff            0.000000
# 703                           OCCUPATION_TYPE_Laborers            0.000000
# 704                       ORGANIZATION_TYPE_Tradetype7            0.000000
# 705                       ORGANIZATION_TYPE_Tradetype6            0.000000
# 706                       ORGANIZATION_TYPE_Tradetype5            0.000000
# 707                       ORGANIZATION_TYPE_Tradetype4            0.000000
# 708                       ORGANIZATION_TYPE_Tradetype3            0.000000
# 709                       ORGANIZATION_TYPE_Tradetype2            0.000000
# 710                       ORGANIZATION_TYPE_Tradetype1            0.000000
# 711                          ORGANIZATION_TYPE_Telecom            0.000000
# 712                         ORGANIZATION_TYPE_Services            0.000000
# 713                     ORGANIZATION_TYPE_Selfemployed            0.000000
# 714               ORGANIZATION_TYPE_SecurityMinistries            0.000000
# 715                         ORGANIZATION_TYPE_Security            0.000000
# 716                           ORGANIZATION_TYPE_School            0.000000
# 717                       ORGANIZATION_TYPE_Restaurant            0.000000
# 718                         ORGANIZATION_TYPE_Religion            0.000000
# 719                          ORGANIZATION_TYPE_Realtor            0.000000
# 720                           ORGANIZATION_TYPE_Postal            0.000000
# 721                           ORGANIZATION_TYPE_Police            0.000000
# 722                            ORGANIZATION_TYPE_Other            0.000000
# 723                           ORGANIZATION_TYPE_Mobile            0.000000
# 724                         ORGANIZATION_TYPE_Military            0.000000
# 725                   ORGANIZATION_TYPE_Transporttype1            0.000000
# 726                   ORGANIZATION_TYPE_Transporttype2            0.000000
# 727                   ORGANIZATION_TYPE_Transporttype3            0.000000
# 728                           WALLSMATERIAL_MODE_Mixed            0.000000
# 729                                  INCOME_PER_PERSON            0.000000
# 730                                 INCOME_CREDIT_PERC            0.000000
# 731                            EMERGENCYSTATE_MODE_Yes            0.000000
# 732                             EMERGENCYSTATE_MODE_No            0.000000
# 733                          WALLSMATERIAL_MODE_Wooden            0.000000
# 734                      WALLSMATERIAL_MODE_Stonebrick            0.000000
# 735                           WALLSMATERIAL_MODE_Panel            0.000000
# 736                          WALLSMATERIAL_MODE_Others            0.000000
# 737                      WALLSMATERIAL_MODE_Monolithic            0.000000
# 738                           WALLSMATERIAL_MODE_Block            0.000000
# 739                   ORGANIZATION_TYPE_Transporttype4            0.000000
# 740                       HOUSETYPE_MODE_terracedhouse            0.000000
# 741                     HOUSETYPE_MODE_specifichousing            0.000000
# 742                        HOUSETYPE_MODE_blockofflats            0.000000
# 743              FONDKAPREMONT_MODE_regoperspecaccount            0.000000
# 744                  FONDKAPREMONT_MODE_regoperaccount            0.000000
# 745                  FONDKAPREMONT_MODE_orgspecaccount            0.000000
# 746                    FONDKAPREMONT_MODE_notspecified            0.000000
# 747                              ORGANIZATION_TYPE_XNA            0.000000
# 748                       ORGANIZATION_TYPE_University            0.000000
# 749                         ORGANIZATION_TYPE_Medicine            0.000000
# 750                    ORGANIZATION_TYPE_LegalServices            0.000000
# 751                     ORGANIZATION_TYPE_Kindergarten            0.000000
# 752                  WEEKDAY_APPR_PROCESS_START_MONDAY            0.000000
# 753              ORGANIZATION_TYPE_BusinessEntityType1            0.000000
# 754                             ORGANIZATION_TYPE_Bank            0.000000
# 755                      ORGANIZATION_TYPE_Agriculture            0.000000
# 756                      ORGANIZATION_TYPE_Advertising            0.000000
# 757               WEEKDAY_APPR_PROCESS_START_WEDNESDAY            0.000000
# 758                 WEEKDAY_APPR_PROCESS_START_TUESDAY            0.000000
# 759                WEEKDAY_APPR_PROCESS_START_THURSDAY            0.000000
# 760                  WEEKDAY_APPR_PROCESS_START_SUNDAY            0.000000
# 761                WEEKDAY_APPR_PROCESS_START_SATURDAY            0.000000
# 762                                ANNUITY_INCOME_PERC            0.000000
# 763              ORGANIZATION_TYPE_BusinessEntityType3            0.000000
# 764                 OCCUPATION_TYPE_Waitersbarmenstaff            0.000000
# 765                      OCCUPATION_TYPE_Securitystaff            0.000000
# 766                        OCCUPATION_TYPE_Secretaries            0.000000
# 767                         OCCUPATION_TYPE_Salesstaff            0.000000
# 768                       OCCUPATION_TYPE_Realtyagents            0.000000
# 769                OCCUPATION_TYPE_Privateservicestaff            0.000000
# 770                      OCCUPATION_TYPE_Medicinestaff            0.000000
# 771                           OCCUPATION_TYPE_Managers            0.000000
# 772                   OCCUPATION_TYPE_LowskillLaborers            0.000000
# 773              ORGANIZATION_TYPE_BusinessEntityType2            0.000000
# 774                         ORGANIZATION_TYPE_Cleaning            0.000000
# 775                                         SK_ID_CURR            0.000000
# 776                   ORGANIZATION_TYPE_Industrytype13            0.000000
# 777                        ORGANIZATION_TYPE_Insurance            0.000000
# 778                    ORGANIZATION_TYPE_Industrytype9            0.000000
# 779                    ORGANIZATION_TYPE_Industrytype8            0.000000
# 780                    ORGANIZATION_TYPE_Industrytype7            0.000000
# 781                    ORGANIZATION_TYPE_Industrytype6            0.000000
# 782                    ORGANIZATION_TYPE_Industrytype5            0.000000
# 783                    ORGANIZATION_TYPE_Industrytype4            0.000000
# 784                    ORGANIZATION_TYPE_Industrytype3            0.000000
# 785                    ORGANIZATION_TYPE_Industrytype2            0.000000
# 786                   ORGANIZATION_TYPE_Industrytype12            0.000000
# 787                     ORGANIZATION_TYPE_Construction            0.000000
# 788                   ORGANIZATION_TYPE_Industrytype11            0.000000
# 789                   ORGANIZATION_TYPE_Industrytype10            0.000000
# 790                    ORGANIZATION_TYPE_Industrytype1            0.000000
# 791                          ORGANIZATION_TYPE_Housing            0.000000
# 792                            ORGANIZATION_TYPE_Hotel            0.000000
# 793                       ORGANIZATION_TYPE_Government            0.000000
# 794                        ORGANIZATION_TYPE_Emergency            0.000000
# 795                      ORGANIZATION_TYPE_Electricity            0.000000
# 796                          ORGANIZATION_TYPE_Culture            0.000000
# 797                                              index            0.000000
# 798                                              Total           25.753568

# %%
def missing_values_count(df):
    # Calculer le pourcentage de valeurs manquantes par colonne
    missing_percentages = df.isna().mean() * 100
    
    # Créer des bins pour les pourcentages de valeurs manquantes
    bins = [0, 0.01, 20, 40, 60, 100]  # 0%, 0-20%, 20-40%, 40-60%, 60-100%
    labels = ['0%', '0-20%', '20-40%', '40-60%', '60-100%']
    
    # Classer les caractéristiques dans les bins
    missing_bins = pd.cut(missing_percentages, bins=bins, labels=labels, right=False)
    
    # Compter le nombre de variables par bin
    bin_counts = missing_bins.value_counts().sort_index()
    
    # Calculer le pourcentage de variables dans chaque bin par rapport au total
    total_variables = len(missing_percentages)
    bin_percentages = (bin_counts / total_variables) * 100
    
    # Créer un DataFrame pour afficher les résultats
    bin_summary = pd.DataFrame({
        'Number of Variables': bin_counts,
        'Percentage of Total': bin_percentages
    })
    
    # Afficher le nombre de variables par bin et leur pourcentage par rapport au total
    print("Nombre de variables par bin de valeurs manquantes et leur pourcentage par rapport au total :")
    print(bin_summary)

# %%
missing_values_count(df)
# Out:
# Nombre de variables par bin de valeurs manquantes et leur pourcentage par rapport au total :
#          Number of Variables  Percentage of Total
# 0%                       184            23.057644
# 0-20%                    325            40.726817
# 20-40%                    44             5.513784
# 40-60%                    33             4.135338
# 60-100%                  212            26.566416

# %% [markdown]
# # Modélisations + feature importance

# %%
# Séparer les caractéristiques et la cible
X = X_train.drop(columns=['TARGET'])
y = X_train['TARGET']

# Remplacer les valeurs infinies par NaN ___ "XGBoostError : Check failed: valid: Input data contains `inf` or a value too large, while `missing` is not set to `inf`"
X.replace([np.inf, -np.inf], np.nan, inplace=True)

# Remplacer les NaN par la moyenne de la colonne
#X.fillna(X.mean(), inplace=True)

# %% [markdown]
# ## XGBoost

# %% [markdown]
# ### Model

# %%
# Convertir les données en DMatrix pour XGBoost
dtrain = xgb.DMatrix(X, label=y)

# Définir les paramètres du modèle XGBoost
params = {
    'objective': 'binary:logistic',
    'eval_metric': 'logloss',
    'max_depth': 3,
    'learning_rate': 0.1,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'seed': 42
}

# Entraîner le modèle XGBoost
xgb_model = xgb.train(params, dtrain, num_boost_round=100)

# %%
# Prédire les probabilités pour la classe positive
y_pred_proba = xgb_model.predict(dtrain)

# Calculer l'AUC-ROC
auc_roc = roc_auc_score(y, y_pred_proba)
auc_roc
# Out:
# 0.7887566342037768

# %% [markdown]
# ### Feature Importance (SHAPE)

# %%
# Calculer les valeurs SHAP
model1_explainer = shap.TreeExplainer(xgb_model)
model1_shap_values = explainer.shap_values(X)

# Visualiser les valeurs SHAP
shap.summary_plot(model1_shap_values, X)

# %% [markdown]
# ## LightGBM

# %% [markdown]
# ### Model

# %%
# Convertir les données en Dataset pour LightGBM
dtrain = lgb.Dataset(X, label=y)

# Définir les paramètres du modèle LightGBM
params = {
    'objective': 'binary',
    'metric': 'binary_logloss',
    'max_depth': 3,
    'learning_rate': 0.1,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'seed': 42
}

# Entraîner le modèle LightGBM
LGBM_model = lgb.train(params, dtrain, num_boost_round=100)
# Out:
# [LightGBM] [Info] Number of positive: 24825, number of negative: 24825
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.166651 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 95152
# [LightGBM] [Info] Number of data points in the train set: 49650, number of used features: 775
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
# Prédire les probabilités pour la classe positive
y_pred_proba = LGBM_model.predict(X)

# Calculer l'AUC-ROC
auc_roc = roc_auc_score(y, y_pred_proba)

print(f"AUC-ROC: {auc_roc}")
# Out:
# AUC-ROC: 0.7898412383157429

# %% [markdown]
# ### Feature Importance (SHAPE)

# %%
# Calculer les valeurs SHAP
model2_explainer = shap.TreeExplainer(LGBM_model)
model2_shap_values = explainer.shap_values(X)

# Visualiser les valeurs SHAP
shap.summary_plot(model2_shap_values, X)

# %% [markdown]
# ## Random Forest

# %% [markdown]
# ### Model

# %%
# Initialiser le modèle Random Forest
model = RandomForestClassifier(n_estimators=100, random_state=42)

# Entraîner le modèle
model.fit(X, y)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Prédire les probabilités pour la classe positive
y_pred_proba = model.predict_proba(X)[:, 1]

# Calculer l'AUC-ROC
auc_roc = roc_auc_score(y, y_pred_proba)

print(f"AUC-ROC: {auc_roc}")
# Out:
# AUC-ROC: 1.0

# %% [markdown]
# ### Feature Importance (most important features)

# %%
# Obtenir l'importance des caractéristiques
feature_importances = model.feature_importances_

# Créer un DataFrame pour afficher les importances des caractéristiques
feature_importance_df = pd.DataFrame({
    'Feature': X.columns,
    'Importance': feature_importances
}).sort_values(by='Importance', ascending=False)

# Afficher l'importance des caractéristiques
print("Importance des caractéristiques :")
print(feature_importance_df)
# Out:
# Importance des caractéristiques :
#                                                Feature    Importance
# 33                                        EXT_SOURCE_2  2.241689e-02
# 34                                        EXT_SOURCE_3  2.104813e-02
# 32                                        EXT_SOURCE_1  1.081096e-02
# 12                                       DAYS_EMPLOYED  9.796544e-03
# 242                                 DAYS_EMPLOYED_PERC  8.550296e-03
# 11                                          DAYS_BIRTH  7.637101e-03
# 249                              BURO_DAYS_CREDIT_MEAN  5.997345e-03
# 254                       BURO_DAYS_CREDIT_UPDATE_MEAN  5.789214e-03
# 246                                       PAYMENT_RATE  5.571071e-03
# 248                               BURO_DAYS_CREDIT_MAX  5.500348e-03
# 310                             ACTIVE_DAYS_CREDIT_MAX  5.166711e-03
# 648                             INSTAL_AMT_PAYMENT_MIN  4.919688e-03
# 13                                   DAYS_REGISTRATION  4.909586e-03
# 8                                          AMT_ANNUITY  4.771275e-03
# 14                                     DAYS_ID_PUBLISH  4.768056e-03
# 253                      BURO_DAYS_CREDIT_ENDDATE_MEAN  4.744924e-03
# 7                                           AMT_CREDIT  4.714428e-03
# 245                                ANNUITY_INCOME_PERC  4.666353e-03
# 247                               BURO_DAYS_CREDIT_MIN  4.599299e-03
# 82                              DAYS_LAST_PHONE_CHANGE  4.594893e-03
# 243                                 INCOME_CREDIT_PERC  4.500560e-03
# 336                             CLOSED_DAYS_CREDIT_MIN  4.448993e-03
# 348                         CLOSED_AMT_CREDIT_SUM_MEAN  4.401793e-03
# 338                            CLOSED_DAYS_CREDIT_MEAN  4.392599e-03
# 9                                      AMT_GOODS_PRICE  4.340333e-03
# 635                                    INSTAL_DBD_MEAN  4.338177e-03
# 636                                     INSTAL_DBD_SUM  4.320946e-03
# 651                             INSTAL_AMT_PAYMENT_SUM  4.318594e-03
# 1                                           SK_ID_CURR  4.306723e-03
# 374                          PREV_APP_CREDIT_PERC_MEAN  4.297175e-03
# 390                            PREV_DAYS_DECISION_MEAN  4.262663e-03
# 653                     INSTAL_DAYS_ENTRY_PAYMENT_MEAN  4.260171e-03
# 0                                                index  4.178163e-03
# 649                             INSTAL_AMT_PAYMENT_MAX  4.153506e-03
# 311                            ACTIVE_DAYS_CREDIT_MEAN  4.151337e-03
# 388                             PREV_DAYS_DECISION_MIN  4.148109e-03
# 276                     BURO_CREDIT_ACTIVE_Closed_MEAN  4.126183e-03
# 250                               BURO_DAYS_CREDIT_VAR  4.115010e-03
# 262                      BURO_AMT_CREDIT_SUM_DEBT_MEAN  4.073069e-03
# 579                        APPROVED_DAYS_DECISION_MEAN  4.037952e-03
# 645                          INSTAL_AMT_INSTALMENT_MAX  4.023654e-03
# 577                         APPROVED_DAYS_DECISION_MIN  4.019661e-03
# 650                            INSTAL_AMT_PAYMENT_MEAN  4.005287e-03
# 251                       BURO_DAYS_CREDIT_ENDDATE_MIN  3.984856e-03
# 314                     ACTIVE_DAYS_CREDIT_ENDDATE_MAX  3.982519e-03
# 349                          CLOSED_AMT_CREDIT_SUM_SUM  3.970507e-03
# 563                      APPROVED_APP_CREDIT_PERC_MEAN  3.967767e-03
# 252                       BURO_DAYS_CREDIT_ENDDATE_MAX  3.966336e-03
# 554                          APPROVED_AMT_ANNUITY_MEAN  3.955105e-03
# 578                         APPROVED_DAYS_DECISION_MAX  3.942278e-03
# 632                                    INSTAL_DPD_MEAN  3.923165e-03
# 613                            POS_MONTHS_BALANCE_MEAN  3.906496e-03
# 647                          INSTAL_AMT_INSTALMENT_SUM  3.898529e-03
# 654                      INSTAL_DAYS_ENTRY_PAYMENT_SUM  3.881191e-03
# 315                    ACTIVE_DAYS_CREDIT_ENDDATE_MEAN  3.875400e-03
# 562                       APPROVED_APP_CREDIT_PERC_MAX  3.862614e-03
# 337                             CLOSED_DAYS_CREDIT_MAX  3.844761e-03
# 389                             PREV_DAYS_DECISION_MAX  3.836694e-03
# 10                          REGION_POPULATION_RELATIVE  3.835922e-03
# 553                           APPROVED_AMT_ANNUITY_MAX  3.834919e-03
# 343                     CLOSED_DAYS_CREDIT_UPDATE_MEAN  3.821308e-03
# 638                           INSTAL_PAYMENT_PERC_MEAN  3.817613e-03
# 364                               PREV_AMT_ANNUITY_MAX  3.808806e-03
# 347                          CLOSED_AMT_CREDIT_SUM_MAX  3.795189e-03
# 274                     BURO_CREDIT_ACTIVE_Active_MEAN  3.791357e-03
# 244                                  INCOME_PER_PERSON  3.782009e-03
# 339                             CLOSED_DAYS_CREDIT_VAR  3.751553e-03
# 652                      INSTAL_DAYS_ENTRY_PAYMENT_MAX  3.748730e-03
# 629                                          POS_COUNT  3.722873e-03
# 634                                     INSTAL_DBD_MAX  3.710496e-03
# 614                            POS_MONTHS_BALANCE_SIZE  3.699303e-03
# 340                     CLOSED_DAYS_CREDIT_ENDDATE_MIN  3.697181e-03
# 365                              PREV_AMT_ANNUITY_MEAN  3.697052e-03
# 259                           BURO_AMT_CREDIT_SUM_MEAN  3.679311e-03
# 313                     ACTIVE_DAYS_CREDIT_ENDDATE_MIN  3.672150e-03
# 316                     ACTIVE_DAYS_CREDIT_UPDATE_MEAN  3.661199e-03
# 642                           INSTAL_PAYMENT_DIFF_MEAN  3.658529e-03
# 566                      APPROVED_AMT_DOWN_PAYMENT_MAX  3.620463e-03
# 384                  PREV_HOUR_APPR_PROCESS_START_MEAN  3.614103e-03
# 375                           PREV_APP_CREDIT_PERC_VAR  3.601271e-03
# 309                             ACTIVE_DAYS_CREDIT_MIN  3.590817e-03
# 552                           APPROVED_AMT_ANNUITY_MIN  3.570912e-03
# 373                           PREV_APP_CREDIT_PERC_MAX  3.568287e-03
# 559                            APPROVED_AMT_CREDIT_MAX  3.559557e-03
# 260                            BURO_AMT_CREDIT_SUM_SUM  3.553051e-03
# 342                    CLOSED_DAYS_CREDIT_ENDDATE_MEAN  3.531102e-03
# 560                           APPROVED_AMT_CREDIT_MEAN  3.524117e-03
# 558                            APPROVED_AMT_CREDIT_MIN  3.511449e-03
# 325                     ACTIVE_AMT_CREDIT_SUM_DEBT_SUM  3.508784e-03
# 258                            BURO_AMT_CREDIT_SUM_MAX  3.497567e-03
# 322                          ACTIVE_AMT_CREDIT_SUM_SUM  3.488911e-03
# 377                          PREV_AMT_DOWN_PAYMENT_MAX  3.488360e-03
# 569                       APPROVED_AMT_GOODS_PRICE_MAX  3.473678e-03
# 646                         INSTAL_AMT_INSTALMENT_MEAN  3.468419e-03
# 639                            INSTAL_PAYMENT_PERC_SUM  3.468088e-03
# 570                      APPROVED_AMT_GOODS_PRICE_MEAN  3.461305e-03
# 573              APPROVED_HOUR_APPR_PROCESS_START_MEAN  3.452458e-03
# 363                               PREV_AMT_ANNUITY_MIN  3.440779e-03
# 564                       APPROVED_APP_CREDIT_PERC_VAR  3.430088e-03
# 6                                     AMT_INCOME_TOTAL  3.426708e-03
# 324                    ACTIVE_AMT_CREDIT_SUM_DEBT_MEAN  3.423658e-03
# 381                          PREV_AMT_GOODS_PRICE_MEAN  3.405615e-03
# 320                          ACTIVE_AMT_CREDIT_SUM_MAX  3.404681e-03
# 568                       APPROVED_AMT_GOODS_PRICE_MIN  3.389367e-03
# 391                              PREV_CNT_PAYMENT_MEAN  3.387501e-03
# 368                          PREV_AMT_APPLICATION_MEAN  3.385806e-03
# 323                     ACTIVE_AMT_CREDIT_SUM_DEBT_MAX  3.377275e-03
# 556                       APPROVED_AMT_APPLICATION_MAX  3.368709e-03
# 557                      APPROVED_AMT_APPLICATION_MEAN  3.366677e-03
# 371                               PREV_AMT_CREDIT_MEAN  3.362622e-03
# 321                         ACTIVE_AMT_CREDIT_SUM_MEAN  3.352886e-03
# 372                           PREV_APP_CREDIT_PERC_MIN  3.323293e-03
# 341                     CLOSED_DAYS_CREDIT_ENDDATE_MAX  3.320346e-03
# 580                          APPROVED_CNT_PAYMENT_MEAN  3.246379e-03
# 567                     APPROVED_AMT_DOWN_PAYMENT_MEAN  3.243700e-03
# 367                           PREV_AMT_APPLICATION_MAX  3.236314e-03
# 379                           PREV_AMT_GOODS_PRICE_MIN  3.224475e-03
# 370                                PREV_AMT_CREDIT_MAX  3.218256e-03
# 312                             ACTIVE_DAYS_CREDIT_VAR  3.210456e-03
# 263                       BURO_AMT_CREDIT_SUM_DEBT_SUM  3.166979e-03
# 380                           PREV_AMT_GOODS_PRICE_MAX  3.147800e-03
# 378                         PREV_AMT_DOWN_PAYMENT_MEAN  3.141694e-03
# 619               POS_NAME_CONTRACT_STATUS_Active_MEAN  3.132265e-03
# 643                            INSTAL_PAYMENT_DIFF_SUM  3.115270e-03
# 261                       BURO_AMT_CREDIT_SUM_DEBT_MAX  3.112674e-03
# 561                       APPROVED_APP_CREDIT_PERC_MIN  3.070545e-03
# 633                                     INSTAL_DPD_SUM  3.060738e-03
# 623            POS_NAME_CONTRACT_STATUS_Completed_MEAN  3.019772e-03
# 655                                       INSTAL_COUNT  3.002033e-03
# 386                         PREV_RATE_DOWN_PAYMENT_MAX  2.923491e-03
# 575                     APPROVED_RATE_DOWN_PAYMENT_MAX  2.913152e-03
# 555                       APPROVED_AMT_APPLICATION_MIN  2.912104e-03
# 25                             HOUR_APPR_PROCESS_START  2.854881e-03
# 257                   BURO_AMT_CREDIT_MAX_OVERDUE_MEAN  2.846960e-03
# 392                               PREV_CNT_PAYMENT_SUM  2.846609e-03
# 576                    APPROVED_RATE_DOWN_PAYMENT_MEAN  2.840760e-03
# 77                                      TOTALAREA_MODE  2.791635e-03
# 15                                         OWN_CAR_AGE  2.789857e-03
# 608                          REFUSED_DAYS_DECISION_MAX  2.781015e-03
# 631                                     INSTAL_DPD_MAX  2.780102e-03
# 387                        PREV_RATE_DOWN_PAYMENT_MEAN  2.767549e-03
# 74                                     LIVINGAREA_MEDI  2.698100e-03
# 435            PREV_NAME_CONTRACT_STATUS_Approved_MEAN  2.693093e-03
# 572               APPROVED_HOUR_APPR_PROCESS_START_MAX  2.664465e-03
# 581                           APPROVED_CNT_PAYMENT_SUM  2.662541e-03
# 612                             POS_MONTHS_BALANCE_MAX  2.610154e-03
# 383                   PREV_HOUR_APPR_PROCESS_START_MAX  2.556564e-03
# 46                                      LIVINGAREA_AVG  2.554549e-03
# 60                                     LIVINGAREA_MODE  2.544827e-03
# 37                         YEARS_BEGINEXPLUATATION_AVG  2.539641e-03
# 571               APPROVED_HOUR_APPR_PROCESS_START_MIN  2.536292e-03
# 641                            INSTAL_PAYMENT_DIFF_MAX  2.535897e-03
# 369                                PREV_AMT_CREDIT_MIN  2.494271e-03
# 382                   PREV_HOUR_APPR_PROCESS_START_MIN  2.473248e-03
# 63                                     APARTMENTS_MEDI  2.465058e-03
# 35                                      APARTMENTS_AVG  2.438208e-03
# 51                        YEARS_BEGINEXPLUATATION_MODE  2.435649e-03
# 49                                     APARTMENTS_MODE  2.357127e-03
# 640                            INSTAL_PAYMENT_PERC_VAR  2.352216e-03
# 529                    PREV_NAME_YIELD_GROUP_high_MEAN  2.283211e-03
# 65                        YEARS_BEGINEXPLUATATION_MEDI  2.281399e-03
# 644                            INSTAL_PAYMENT_DIFF_VAR  2.256423e-03
# 607                          REFUSED_DAYS_DECISION_MIN  2.203247e-03
# 591                        REFUSED_APP_CREDIT_PERC_MIN  2.184144e-03
# 609                         REFUSED_DAYS_DECISION_MEAN  2.132920e-03
# 366                           PREV_AMT_APPLICATION_MIN  2.127383e-03
# 287               BURO_CREDIT_TYPE_Consumercredit_MEAN  2.105469e-03
# 462                      PREV_NAME_TYPE_SUITE_nan_MEAN  2.072792e-03
# 452                   PREV_CODE_REJECT_REASON_XAP_MEAN  2.039588e-03
# 58                                       LANDAREA_MODE  2.017487e-03
# 64                                   BASEMENTAREA_MEDI  2.016980e-03
# 44                                        LANDAREA_AVG  2.016404e-03
# 72                                       LANDAREA_MEDI  2.013240e-03
# 50                                   BASEMENTAREA_MODE  2.011212e-03
# 288                   BURO_CREDIT_TYPE_Creditcard_MEAN  2.008758e-03
# 565                      APPROVED_AMT_DOWN_PAYMENT_MIN  2.007577e-03
# 440     PREV_NAME_PAYMENT_TYPE_Cashthroughthebank_MEAN  1.977637e-03
# 319                 ACTIVE_AMT_CREDIT_MAX_OVERDUE_MEAN  1.976420e-03
# 574                     APPROVED_RATE_DOWN_PAYMENT_MIN  1.972272e-03
# 437             PREV_NAME_CONTRACT_STATUS_Refused_MEAN  1.961264e-03
# 531              PREV_NAME_YIELD_GROUP_low_normal_MEAN  1.960463e-03
# 463                     PREV_NAME_CLIENT_TYPE_New_MEAN  1.959188e-03
# 272                      BURO_MONTHS_BALANCE_SIZE_MEAN  1.941535e-03
# 36                                    BASEMENTAREA_AVG  1.933207e-03
# 346                 CLOSED_AMT_CREDIT_MAX_OVERDUE_MEAN  1.900332e-03
# 465                PREV_NAME_CLIENT_TYPE_Repeater_MEAN  1.851828e-03
# 300                            BURO_STATUS_0_MEAN_MEAN  1.846539e-03
# 583                            REFUSED_AMT_ANNUITY_MAX  1.843686e-03
# 443                    PREV_NAME_PAYMENT_TYPE_XNA_MEAN  1.836557e-03
# 376                          PREV_AMT_DOWN_PAYMENT_MIN  1.821545e-03
# 80                            OBS_60_CNT_SOCIAL_CIRCLE  1.805875e-03
# 78                            OBS_30_CNT_SOCIAL_CIRCLE  1.803659e-03
# 461            PREV_NAME_TYPE_SUITE_Unaccompanied_MEAN  1.793890e-03
# 532                  PREV_NAME_YIELD_GROUP_middle_MEAN  1.784250e-03
# 588                             REFUSED_AMT_CREDIT_MIN  1.766253e-03
# 270                        BURO_MONTHS_BALANCE_MIN_MIN  1.754148e-03
# 593                       REFUSED_APP_CREDIT_PERC_MEAN  1.733023e-03
# 127                NAME_EDUCATION_TYPE_Highereducation  1.718287e-03
# 511                 PREV_CHANNEL_TYPE_Countrywide_MEAN  1.709220e-03
# 385                         PREV_RATE_DOWN_PAYMENT_MIN  1.699793e-03
# 48                                   NONLIVINGAREA_AVG  1.660578e-03
# 730                        CC_CNT_DRAWINGS_CURRENT_VAR  1.657431e-03
# 52                                    YEARS_BUILD_MODE  1.648662e-03
# 361                    CLOSED_MONTHS_BALANCE_SIZE_MEAN  1.644175e-03
# 76                                  NONLIVINGAREA_MEDI  1.630383e-03
# 600                       REFUSED_AMT_GOODS_PRICE_MEAN  1.624446e-03
# 39                                      COMMONAREA_AVG  1.624379e-03
# 500                       PREV_NAME_PORTFOLIO_POS_MEAN  1.610973e-03
# 590                            REFUSED_AMT_CREDIT_MEAN  1.609264e-03
# 603               REFUSED_HOUR_APPR_PROCESS_START_MEAN  1.606501e-03
# 399        PREV_WEEKDAY_APPR_PROCESS_START_MONDAY_MEAN  1.593904e-03
# 520  PREV_NAME_SELLER_INDUSTRY_Consumerelectronics_...  1.590976e-03
# 306                            BURO_STATUS_C_MEAN_MEAN  1.589978e-03
# 66                                    YEARS_BUILD_MEDI  1.589356e-03
# 307                            BURO_STATUS_X_MEAN_MEAN  1.583690e-03
# 504                 PREV_NAME_PRODUCT_TYPE_walkin_MEAN  1.576119e-03
# 433               PREV_NAME_CASH_LOAN_PURPOSE_XNA_MEAN  1.575732e-03
# 618                                POS_SK_DPD_DEF_MEAN  1.574514e-03
# 2                                          CODE_GENDER  1.566812e-03
# 38                                     YEARS_BUILD_AVG  1.566641e-03
# 73                               LIVINGAPARTMENTS_MEDI  1.565870e-03
# 503                    PREV_NAME_PRODUCT_TYPE_XNA_MEAN  1.561741e-03
# 41                                       ENTRANCES_AVG  1.546533e-03
# 327                   ACTIVE_AMT_CREDIT_SUM_LIMIT_MEAN  1.543669e-03
# 402      PREV_WEEKDAY_APPR_PROCESS_START_THURSDAY_MEAN  1.538409e-03
# 55                                      ENTRANCES_MODE  1.533336e-03
# 505                  PREV_NAME_PRODUCT_TYPE_xsell_MEAN  1.531625e-03
# 394         PREV_NAME_CONTRACT_TYPE_Consumerloans_MEAN  1.529429e-03
# 393             PREV_NAME_CONTRACT_TYPE_Cashloans_MEAN  1.529061e-03
# 404     PREV_WEEKDAY_APPR_PROCESS_START_WEDNESDAY_MEAN  1.520078e-03
# 53                                     COMMONAREA_MODE  1.518205e-03
# 582                            REFUSED_AMT_ANNUITY_MIN  1.518110e-03
# 518        PREV_NAME_SELLER_INDUSTRY_Connectivity_MEAN  1.516087e-03
# 334                    ACTIVE_MONTHS_BALANCE_SIZE_MEAN  1.509070e-03
# 543  PREV_PRODUCT_COMBINATION_POShouseholdwithinter...  1.508374e-03
# 598                        REFUSED_AMT_GOODS_PRICE_MIN  1.500478e-03
# 592                        REFUSED_APP_CREDIT_PERC_MAX  1.497921e-03
# 599                        REFUSED_AMT_GOODS_PRICE_MAX  1.496467e-03
# 584                           REFUSED_AMT_ANNUITY_MEAN  1.494763e-03
# 398        PREV_WEEKDAY_APPR_PROCESS_START_FRIDAY_MEAN  1.485582e-03
# 69                                      ENTRANCES_MEDI  1.480332e-03
# 495                  PREV_NAME_GOODS_CATEGORY_XNA_MEAN  1.475754e-03
# 45                                LIVINGAPARTMENTS_AVG  1.473667e-03
# 67                                     COMMONAREA_MEDI  1.473094e-03
# 403       PREV_WEEKDAY_APPR_PROCESS_START_TUESDAY_MEAN  1.464190e-03
# 528                     PREV_NAME_YIELD_GROUP_XNA_MEAN  1.460532e-03
# 432               PREV_NAME_CASH_LOAN_PURPOSE_XAP_MEAN  1.459781e-03
# 512        PREV_CHANNEL_TYPE_Creditandcashoffices_MEAN  1.457930e-03
# 725                    CC_CNT_DRAWINGS_ATM_CURRENT_VAR  1.451748e-03
# 265                     BURO_AMT_CREDIT_SUM_LIMIT_MEAN  1.442359e-03
# 728                       CC_CNT_DRAWINGS_CURRENT_MEAN  1.435284e-03
# 501                       PREV_NAME_PORTFOLIO_XNA_MEAN  1.427803e-03
# 611                            REFUSED_CNT_PAYMENT_SUM  1.427499e-03
# 587                       REFUSED_AMT_APPLICATION_MEAN  1.427302e-03
# 514                       PREV_CHANNEL_TYPE_Stone_MEAN  1.425675e-03
# 125                           NAME_INCOME_TYPE_Working  1.424366e-03
# 362                     CLOSED_MONTHS_BALANCE_SIZE_SUM  1.420564e-03
# 335                     ACTIVE_MONTHS_BALANCE_SIZE_SUM  1.420319e-03
# 59                               LIVINGAPARTMENTS_MODE  1.420104e-03
# 108                         AMT_REQ_CREDIT_BUREAU_YEAR  1.419326e-03
# 400      PREV_WEEKDAY_APPR_PROCESS_START_SATURDAY_MEAN  1.412710e-03
# 62                                  NONLIVINGAREA_MODE  1.409577e-03
# 268                              BURO_AMT_ANNUITY_MEAN  1.404432e-03
# 332                      ACTIVE_MONTHS_BALANCE_MIN_MIN  1.400960e-03
# 526                 PREV_NAME_SELLER_INDUSTRY_XNA_MEAN  1.400448e-03
# 487               PREV_NAME_GOODS_CATEGORY_Mobile_MEAN  1.395338e-03
# 456                   PREV_NAME_TYPE_SUITE_Family_MEAN  1.379146e-03
# 359                      CLOSED_MONTHS_BALANCE_MIN_MIN  1.378912e-03
# 70                                      FLOORSMAX_MEDI  1.368176e-03
# 616                                    POS_SK_DPD_MEAN  1.357436e-03
# 585                        REFUSED_AMT_APPLICATION_MIN  1.356209e-03
# 273                       BURO_MONTHS_BALANCE_SIZE_SUM  1.348271e-03
# 22                                     CNT_FAM_MEMBERS  1.345363e-03
# 436            PREV_NAME_CONTRACT_STATUS_Canceled_MEAN  1.340080e-03
# 586                        REFUSED_AMT_APPLICATION_MAX  1.338675e-03
# 499                      PREV_NAME_PORTFOLIO_Cash_MEAN  1.329967e-03
# 615                                     POS_SK_DPD_MAX  1.329280e-03
# 475  PREV_NAME_GOODS_CATEGORY_ConsumerElectronics_MEAN  1.325912e-03
# 601                REFUSED_HOUR_APPR_PROCESS_START_MIN  1.301003e-03
# 56                                      FLOORSMAX_MODE  1.299798e-03
# 547  PREV_PRODUCT_COMBINATION_POSmobilewithinterest...  1.296282e-03
# 42                                       FLOORSMAX_AVG  1.294277e-03
# 267                               BURO_AMT_ANNUITY_MAX  1.292429e-03
# 301                            BURO_STATUS_1_MEAN_MEAN  1.277399e-03
# 401        PREV_WEEKDAY_APPR_PROCESS_START_SUNDAY_MEAN  1.277042e-03
# 23                                REGION_RATING_CLIENT  1.276705e-03
# 328                    ACTIVE_AMT_CREDIT_SUM_LIMIT_SUM  1.274163e-03
# 589                             REFUSED_AMT_CREDIT_MAX  1.259570e-03
# 723                   CC_CNT_DRAWINGS_ATM_CURRENT_MEAN  1.247031e-03
# 626               POS_NAME_CONTRACT_STATUS_Signed_MEAN  1.246987e-03
# 602                REFUSED_HOUR_APPR_PROCESS_START_MAX  1.236080e-03
# 24                         REGION_RATING_CLIENT_W_CITY  1.224860e-03
# 329                             ACTIVE_AMT_ANNUITY_MAX  1.206203e-03
# 610                           REFUSED_CNT_PAYMENT_MEAN  1.193083e-03
# 536                 PREV_PRODUCT_COMBINATION_Cash_MEAN  1.191729e-03
# 266                      BURO_AMT_CREDIT_SUM_LIMIT_SUM  1.185326e-03
# 669                     CC_AMT_CREDIT_LIMIT_ACTUAL_SUM  1.164740e-03
# 330                            ACTIVE_AMT_ANNUITY_MEAN  1.149882e-03
# 541         PREV_PRODUCT_COMBINATION_CashXSelllow_MEAN  1.142391e-03
# 530              PREV_NAME_YIELD_GROUP_low_action_MEAN  1.111677e-03
# 617                                 POS_SK_DPD_DEF_MAX  1.101402e-03
# 473            PREV_NAME_GOODS_CATEGORY_Computers_MEAN  1.101366e-03
# 464               PREV_NAME_CLIENT_TYPE_Refreshed_MEAN  1.100798e-03
# 545  PREV_PRODUCT_COMBINATION_POSindustrywithintere...  1.075535e-03
# 130      NAME_EDUCATION_TYPE_Secondarysecondaryspecial  1.075405e-03
# 668                    CC_AMT_CREDIT_LIMIT_ACTUAL_MEAN  1.067411e-03
# 708                   CC_AMT_RECEIVABLE_PRINCIPAL_MEAN  1.055803e-03
# 594                        REFUSED_APP_CREDIT_PERC_VAR  1.052081e-03
# 513               PREV_CHANNEL_TYPE_RegionalLocal_MEAN  1.042909e-03
# 544  PREV_PRODUCT_COMBINATION_POShouseholdwithoutin...  1.033688e-03
# 663                                CC_AMT_BALANCE_MEAN  1.032378e-03
# 357                            CLOSED_AMT_ANNUITY_MEAN  1.028071e-03
# 470           PREV_NAME_GOODS_CATEGORY_AudioVideo_MEAN  1.018691e-03
# 713                              CC_AMT_RECIVABLE_MEAN  1.007348e-03
# 540        PREV_PRODUCT_COMBINATION_CashXSellhigh_MEAN  1.006410e-03
# 630              INSTAL_NUM_INSTALMENT_VERSION_NUNIQUE  9.993924e-04
# 718                       CC_AMT_TOTAL_RECEIVABLE_MEAN  9.989945e-04
# 673                   CC_AMT_DRAWINGS_ATM_CURRENT_MEAN  9.965456e-04
# 356                             CLOSED_AMT_ANNUITY_MAX  9.951573e-04
# 542      PREV_PRODUCT_COMBINATION_CashXSellmiddle_MEAN  9.873021e-04
# 40                                       ELEVATORS_AVG  9.833439e-04
# 658                             CC_MONTHS_BALANCE_MEAN  9.725212e-04
# 678                       CC_AMT_DRAWINGS_CURRENT_MEAN  9.695288e-04
# 479            PREV_NAME_GOODS_CATEGORY_Furniture_MEAN  9.680261e-04
# 395        PREV_NAME_CONTRACT_TYPE_Revolvingloans_MEAN  9.655325e-04
# 759                 CC_NAME_CONTRACT_STATUS_Active_SUM  9.638931e-04
# 659                              CC_MONTHS_BALANCE_SUM  9.543918e-04
# 660                              CC_MONTHS_BALANCE_VAR  9.265101e-04
# 84                                     FLAG_DOCUMENT_3  9.260288e-04
# 727                        CC_CNT_DRAWINGS_CURRENT_MAX  9.232243e-04
# 446                    PREV_CODE_REJECT_REASON_HC_MEAN  9.179162e-04
# 68                                      ELEVATORS_MEDI  9.172170e-04
# 71                                      FLOORSMIN_MEDI  9.121409e-04
# 54                                      ELEVATORS_MODE  9.072130e-04
# 497                     PREV_NAME_PORTFOLIO_Cards_MEAN  8.926835e-04
# 700                         CC_AMT_PAYMENT_CURRENT_VAR  8.904118e-04
# 680                        CC_AMT_DRAWINGS_CURRENT_VAR  8.799083e-04
# 702                   CC_AMT_PAYMENT_TOTAL_CURRENT_MAX  8.745692e-04
# 695                     CC_AMT_INST_MIN_REGULARITY_VAR  8.730369e-04
# 656                              CC_MONTHS_BALANCE_MIN  8.701642e-04
# 796                                           CC_COUNT  8.657511e-04
# 43                                       FLOORSMIN_AVG  8.506119e-04
# 460            PREV_NAME_TYPE_SUITE_Spousepartner_MEAN  8.485685e-04
# 698                        CC_AMT_PAYMENT_CURRENT_MEAN  8.480314e-04
# 693                    CC_AMT_INST_MIN_REGULARITY_MEAN  8.477386e-04
# 5                                         CNT_CHILDREN  8.465180e-04
# 697                         CC_AMT_PAYMENT_CURRENT_MAX  8.447924e-04
# 521           PREV_NAME_SELLER_INDUSTRY_Furniture_MEAN  8.446679e-04
# 57                                      FLOORSMIN_MODE  8.405507e-04
# 679                        CC_AMT_DRAWINGS_CURRENT_SUM  8.366617e-04
# 704                   CC_AMT_PAYMENT_TOTAL_CURRENT_SUM  8.263783e-04
# 707                    CC_AMT_RECEIVABLE_PRINCIPAL_MAX  8.147879e-04
# 675                    CC_AMT_DRAWINGS_ATM_CURRENT_VAR  8.138871e-04
# 745                   CC_CNT_INSTALMENT_MATURE_CUM_VAR  8.124313e-04
# 664                                 CC_AMT_BALANCE_SUM  8.082325e-04
# 729                        CC_CNT_DRAWINGS_CURRENT_SUM  8.028567e-04
# 710                    CC_AMT_RECEIVABLE_PRINCIPAL_VAR  7.973792e-04
# 534           PREV_PRODUCT_COMBINATION_CardStreet_MEAN  7.958205e-04
# 715                               CC_AMT_RECIVABLE_VAR  7.908675e-04
# 47                             NONLIVINGAPARTMENTS_AVG  7.896868e-04
# 705                   CC_AMT_PAYMENT_TOTAL_CURRENT_VAR  7.870057e-04
# 703                  CC_AMT_PAYMENT_TOTAL_CURRENT_MEAN  7.829552e-04
# 75                            NONLIVINGAPARTMENTS_MEDI  7.807256e-04
# 667                     CC_AMT_CREDIT_LIMIT_ACTUAL_MAX  7.801894e-04
# 714                               CC_AMT_RECIVABLE_SUM  7.752661e-04
# 662                                 CC_AMT_BALANCE_MAX  7.720500e-04
# 740                    CC_CNT_DRAWINGS_POS_CURRENT_VAR  7.691304e-04
# 665                                 CC_AMT_BALANCE_VAR  7.622303e-04
# 743                  CC_CNT_INSTALMENT_MATURE_CUM_MEAN  7.576204e-04
# 670                     CC_AMT_CREDIT_LIMIT_ACTUAL_VAR  7.540814e-04
# 699                         CC_AMT_PAYMENT_CURRENT_SUM  7.421732e-04
# 537       PREV_PRODUCT_COMBINATION_CashStreethigh_MEAN  7.421146e-04
# 720                        CC_AMT_TOTAL_RECEIVABLE_VAR  7.394058e-04
# 510               PREV_CHANNEL_TYPE_Contactcenter_MEAN  7.390488e-04
# 674                    CC_AMT_DRAWINGS_ATM_CURRENT_SUM  7.376947e-04
# 79                            DEF_30_CNT_SOCIAL_CIRCLE  7.257060e-04
# 672                    CC_AMT_DRAWINGS_ATM_CURRENT_MAX  7.194790e-04
# 61                            NONLIVINGAPARTMENTS_MODE  7.071773e-04
# 717                        CC_AMT_TOTAL_RECEIVABLE_MAX  7.069126e-04
# 637                            INSTAL_PAYMENT_PERC_MAX  7.018576e-04
# 712                               CC_AMT_RECIVABLE_MAX  6.957307e-04
# 738                   CC_CNT_DRAWINGS_POS_CURRENT_MEAN  6.953348e-04
# 719                        CC_AMT_TOTAL_RECEIVABLE_SUM  6.939963e-04
# 677                        CC_AMT_DRAWINGS_CURRENT_MAX  6.920898e-04
# 724                    CC_CNT_DRAWINGS_ATM_CURRENT_SUM  6.913877e-04
# 694                     CC_AMT_INST_MIN_REGULARITY_SUM  6.890480e-04
# 744                   CC_CNT_INSTALMENT_MATURE_CUM_SUM  6.850948e-04
# 692                     CC_AMT_INST_MIN_REGULARITY_MAX  6.838575e-04
# 507                  PREV_CHANNEL_TYPE_APCashloan_MEAN  6.736789e-04
# 81                            DEF_60_CNT_SOCIAL_CIRCLE  6.724053e-04
# 742                   CC_CNT_INSTALMENT_MATURE_CUM_MAX  6.649705e-04
# 709                    CC_AMT_RECEIVABLE_PRINCIPAL_SUM  6.534315e-04
# 535            PREV_PRODUCT_COMBINATION_CardXSell_MEAN  6.437840e-04
# 666                     CC_AMT_CREDIT_LIMIT_ACTUAL_MIN  6.313199e-04
# 107                          AMT_REQ_CREDIT_BUREAU_QRT  6.258517e-04
# 690                    CC_AMT_DRAWINGS_POS_CURRENT_VAR  6.094992e-04
# 132                         NAME_FAMILY_STATUS_Married  6.094987e-04
# 151                           OCCUPATION_TYPE_Laborers  6.029145e-04
# 30                              REG_CITY_NOT_WORK_CITY  5.999863e-04
# 711                               CC_AMT_RECIVABLE_MIN  5.936804e-04
# 17                                      FLAG_EMP_PHONE  5.874958e-04
# 722                    CC_CNT_DRAWINGS_ATM_CURRENT_MAX  5.819024e-04
# 687                    CC_AMT_DRAWINGS_POS_CURRENT_MAX  5.804604e-04
# 110                  NAME_CONTRACT_TYPE_Revolvingloans  5.765963e-04
# 4                                      FLAG_OWN_REALTY  5.760600e-04
# 519        PREV_NAME_SELLER_INDUSTRY_Construction_MEAN  5.752296e-04
# 689                    CC_AMT_DRAWINGS_POS_CURRENT_SUM  5.660227e-04
# 3                                         FLAG_OWN_CAR  5.612039e-04
# 606                     REFUSED_RATE_DOWN_PAYMENT_MEAN  5.583090e-04
# 490  PREV_NAME_GOODS_CATEGORY_PhotoCinemaEquipment_...  5.543897e-04
# 173              ORGANIZATION_TYPE_BusinessEntityType3  5.530801e-04
# 688                   CC_AMT_DRAWINGS_POS_CURRENT_MEAN  5.512894e-04
# 109                       NAME_CONTRACT_TYPE_Cashloans  5.489491e-04
# 739                    CC_CNT_DRAWINGS_POS_CURRENT_SUM  5.420501e-04
# 106                          AMT_REQ_CREDIT_BUREAU_MON  5.387795e-04
# 605                      REFUSED_RATE_DOWN_PAYMENT_MAX  5.356854e-04
# 597                      REFUSED_AMT_DOWN_PAYMENT_MEAN  5.164268e-04
# 20                                          FLAG_PHONE  5.082247e-04
# 165                WEEKDAY_APPR_PROCESS_START_THURSDAY  5.072386e-04
# 455                 PREV_NAME_TYPE_SUITE_Children_MEAN  5.033313e-04
# 31                             LIVE_CITY_NOT_WORK_CITY  5.012550e-04
# 166                 WEEKDAY_APPR_PROCESS_START_TUESDAY  5.012272e-04
# 134                NAME_FAMILY_STATUS_Singlenotmarried  5.005180e-04
# 445                PREV_CODE_REJECT_REASON_CLIENT_MEAN  4.977943e-04
# 225                              ORGANIZATION_TYPE_XNA  4.949213e-04
# 549  PREV_PRODUCT_COMBINATION_POSotherwithinterest_...  4.912138e-04
# 18                                     FLAG_WORK_PHONE  4.890457e-04
# 119               NAME_INCOME_TYPE_Commercialassociate  4.885368e-04
# 548  PREV_PRODUCT_COMBINATION_POSmobilewithoutinter...  4.822825e-04
# 474  PREV_NAME_GOODS_CATEGORY_ConstructionMaterials...  4.754734e-04
# 716                        CC_AMT_TOTAL_RECEIVABLE_MIN  4.741947e-04
# 162                  WEEKDAY_APPR_PROCESS_START_MONDAY  4.740473e-04
# 447                 PREV_CODE_REJECT_REASON_LIMIT_MEAN  4.726013e-04
# 438         PREV_NAME_CONTRACT_STATUS_Unusedoffer_MEAN  4.700289e-04
# 737                    CC_CNT_DRAWINGS_POS_CURRENT_MAX  4.698539e-04
# 539     PREV_PRODUCT_COMBINATION_CashStreetmiddle_MEAN  4.665623e-04
# 352                     CLOSED_AMT_CREDIT_SUM_DEBT_SUM  4.644170e-04
# 121                         NAME_INCOME_TYPE_Pensioner  4.604905e-04
# 117                      NAME_TYPE_SUITE_Unaccompanied  4.578288e-04
# 167               WEEKDAY_APPR_PROCESS_START_WEDNESDAY  4.567893e-04
# 350                     CLOSED_AMT_CREDIT_SUM_DEBT_MAX  4.520831e-04
# 596                       REFUSED_AMT_DOWN_PAYMENT_MAX  4.510902e-04
# 285                      BURO_CREDIT_TYPE_Carloan_MEAN  4.474354e-04
# 360                      CLOSED_MONTHS_BALANCE_MAX_MAX  4.456841e-04
# 157                         OCCUPATION_TYPE_Salesstaff  4.396691e-04
# 161                  WEEKDAY_APPR_PROCESS_START_FRIDAY  4.350586e-04
# 112                             NAME_TYPE_SUITE_Family  4.348846e-04
# 472  PREV_NAME_GOODS_CATEGORY_ClothingandAccessorie...  4.278641e-04
# 131                   NAME_FAMILY_STATUS_Civilmarriage  4.258174e-04
# 604                      REFUSED_RATE_DOWN_PAYMENT_MIN  4.257633e-04
# 351                    CLOSED_AMT_CREDIT_SUM_DEBT_MEAN  4.247577e-04
# 696                         CC_AMT_PAYMENT_CURRENT_MIN  4.238211e-04
# 146                          OCCUPATION_TYPE_Corestaff  4.228786e-04
# 522            PREV_NAME_SELLER_INDUSTRY_Industry_MEAN  4.185388e-04
# 147                            OCCUPATION_TYPE_Drivers  4.163407e-04
# 138                   NAME_HOUSING_TYPE_Houseapartment  4.145200e-04
# 210                     ORGANIZATION_TYPE_Selfemployed  4.144165e-04
# 29                              REG_CITY_NOT_LIVE_CITY  4.108327e-04
# 595                       REFUSED_AMT_DOWN_PAYMENT_MIN  3.863942e-04
# 517            PREV_NAME_SELLER_INDUSTRY_Clothing_MEAN  3.796957e-04
# 163                WEEKDAY_APPR_PROCESS_START_SATURDAY  3.734787e-04
# 459                  PREV_NAME_TYPE_SUITE_Other_B_MEAN  3.707999e-04
# 429           PREV_NAME_CASH_LOAN_PURPOSE_Repairs_MEAN  3.645853e-04
# 296                     BURO_CREDIT_TYPE_Mortgage_MEAN  3.633488e-04
# 122                      NAME_INCOME_TYPE_Stateservant  3.631948e-04
# 661                                 CC_AMT_BALANCE_MIN  3.585967e-04
# 448                   PREV_CODE_REJECT_REASON_SCO_MEAN  3.540868e-04
# 449                 PREV_CODE_REJECT_REASON_SCOFR_MEAN  3.484008e-04
# 538        PREV_PRODUCT_COMBINATION_CashStreetlow_MEAN  3.377033e-04
# 237                           WALLSMATERIAL_MODE_Panel  3.300188e-04
# 87                                     FLAG_DOCUMENT_6  3.240946e-04
# 240                             EMERGENCYSTATE_MODE_No  3.239106e-04
# 758                CC_NAME_CONTRACT_STATUS_Active_MEAN  3.205441e-04
# 133                       NAME_FAMILY_STATUS_Separated  3.128576e-04
# 230                        HOUSETYPE_MODE_blockofflats  3.121553e-04
# 142                      NAME_HOUSING_TYPE_Withparents  3.112312e-04
# 657                              CC_MONTHS_BALANCE_MAX  3.091360e-04
# 748                                     CC_SK_DPD_MEAN  3.054184e-04
# 425             PREV_NAME_CASH_LOAN_PURPOSE_Other_MEAN  3.037929e-04
# 201                            ORGANIZATION_TYPE_Other  3.011878e-04
# 238                      WALLSMATERIAL_MODE_Stonebrick  2.998068e-04
# 27                          REG_REGION_NOT_WORK_REGION  2.960113e-04
# 706                    CC_AMT_RECEIVABLE_PRINCIPAL_MIN  2.945490e-04
# 153                           OCCUPATION_TYPE_Managers  2.938608e-04
# 89                                     FLAG_DOCUMENT_8  2.833887e-04
# 302                            BURO_STATUS_2_MEAN_MEAN  2.833728e-04
# 750                                      CC_SK_DPD_VAR  2.794437e-04
# 760                 CC_NAME_CONTRACT_STATUS_Active_VAR  2.771355e-04
# 294                    BURO_CREDIT_TYPE_Microloan_MEAN  2.767607e-04
# 228                  FONDKAPREMONT_MODE_regoperaccount  2.689561e-04
# 354                   CLOSED_AMT_CREDIT_SUM_LIMIT_MEAN  2.676534e-04
# 471      PREV_NAME_GOODS_CATEGORY_AutoAccessories_MEAN  2.575792e-04
# 21                                          FLAG_EMAIL  2.512131e-04
# 770              CC_NAME_CONTRACT_STATUS_Completed_VAR  2.508599e-04
# 749                                      CC_SK_DPD_SUM  2.505430e-04
# 136                           NAME_FAMILY_STATUS_Widow  2.460725e-04
# 139               NAME_HOUSING_TYPE_Municipalapartment  2.457271e-04
# 164                  WEEKDAY_APPR_PROCESS_START_SUNDAY  2.398352e-04
# 172              ORGANIZATION_TYPE_BusinessEntityType2  2.376827e-04
# 458                  PREV_NAME_TYPE_SUITE_Other_A_MEAN  2.323848e-04
# 625   POS_NAME_CONTRACT_STATUS_Returnedtothestore_MEAN  2.312265e-04
# 116                      NAME_TYPE_SUITE_Spousepartner  2.310198e-04
# 430       PREV_NAME_CASH_LOAN_PURPOSE_Urgentneeds_MEAN  2.303450e-04
# 175                     ORGANIZATION_TYPE_Construction  2.288890e-04
# 755                                  CC_SK_DPD_DEF_VAR  2.282259e-04
# 128               NAME_EDUCATION_TYPE_Incompletehigher  2.273079e-04
# 546  PREV_PRODUCT_COMBINATION_POSindustrywithoutint...  2.272578e-04
# 442  PREV_NAME_PAYMENT_TYPE_Noncashfromyouraccount_...  2.251736e-04
# 149                 OCCUPATION_TYPE_Highskilltechstaff  2.227797e-04
# 753                                 CC_SK_DPD_DEF_MEAN  2.131796e-04
# 769              CC_NAME_CONTRACT_STATUS_Completed_SUM  2.094961e-04
# 754                                  CC_SK_DPD_DEF_SUM  2.090881e-04
# 28                         LIVE_REGION_NOT_WORK_REGION  2.087681e-04
# 179                       ORGANIZATION_TYPE_Government  2.079546e-04
# 277                       BURO_CREDIT_ACTIVE_Sold_MEAN  2.056778e-04
# 143                        OCCUPATION_TYPE_Accountants  2.027572e-04
# 768             CC_NAME_CONTRACT_STATUS_Completed_MEAN  2.026914e-04
# 159                      OCCUPATION_TYPE_Securitystaff  2.005701e-04
# 355                    CLOSED_AMT_CREDIT_SUM_LIMIT_SUM  1.997971e-04
# 271                        BURO_MONTHS_BALANCE_MAX_MAX  1.991789e-04
# 196                     ORGANIZATION_TYPE_Kindergarten  1.980312e-04
# 171              ORGANIZATION_TYPE_BusinessEntityType1  1.974747e-04
# 331                      ACTIVE_CNT_CREDIT_PROLONG_SUM  1.956260e-04
# 326                 ACTIVE_AMT_CREDIT_SUM_OVERDUE_MEAN  1.955645e-04
# 198                         ORGANIZATION_TYPE_Medicine  1.914968e-04
# 105                         AMT_REQ_CREDIT_BUREAU_WEEK  1.885572e-04
# 264                   BURO_AMT_CREDIT_SUM_OVERDUE_MEAN  1.871262e-04
# 741                   CC_CNT_INSTALMENT_MATURE_CUM_MIN  1.827652e-04
# 207                           ORGANIZATION_TYPE_School  1.826798e-04
# 269                        BURO_CNT_CREDIT_PROLONG_SUM  1.820988e-04
# 141                  NAME_HOUSING_TYPE_Rentedapartment  1.813196e-04
# 333                      ACTIVE_MONTHS_BALANCE_MAX_MAX  1.786870e-04
# 317                      ACTIVE_CREDIT_DAY_OVERDUE_MAX  1.728337e-04
# 219                       ORGANIZATION_TYPE_Tradetype7  1.702160e-04
# 682                  CC_AMT_DRAWINGS_OTHER_CURRENT_MAX  1.678487e-04
# 223                   ORGANIZATION_TYPE_Transporttype4  1.668410e-04
# 26                          REG_REGION_NOT_LIVE_REGION  1.644200e-04
# 621             POS_NAME_CONTRACT_STATUS_Approved_MEAN  1.642355e-04
# 256                       BURO_CREDIT_DAY_OVERDUE_MEAN  1.628952e-04
# 154                      OCCUPATION_TYPE_Medicinestaff  1.628059e-04
# 129                 NAME_EDUCATION_TYPE_Lowersecondary  1.626260e-04
# 318                     ACTIVE_CREDIT_DAY_OVERDUE_MEAN  1.605428e-04
# 685                  CC_AMT_DRAWINGS_OTHER_CURRENT_VAR  1.599225e-04
# 145                       OCCUPATION_TYPE_Cookingstaff  1.595221e-04
# 747                                      CC_SK_DPD_MAX  1.583112e-04
# 493             PREV_NAME_GOODS_CATEGORY_Vehicles_MEAN  1.582421e-04
# 229              FONDKAPREMONT_MODE_regoperspecaccount  1.580437e-04
# 303                            BURO_STATUS_3_MEAN_MEAN  1.560685e-04
# 733                 CC_CNT_DRAWINGS_OTHER_CURRENT_MEAN  1.507584e-04
# 735                  CC_CNT_DRAWINGS_OTHER_CURRENT_VAR  1.474637e-04
# 255                        BURO_CREDIT_DAY_OVERDUE_MAX  1.453922e-04
# 111                           NAME_TYPE_SUITE_Children  1.447698e-04
# 691                     CC_AMT_INST_MIN_REGULARITY_MIN  1.442153e-04
# 86                                     FLAG_DOCUMENT_5  1.436733e-04
# 233                           WALLSMATERIAL_MODE_Block  1.407439e-04
# 683                 CC_AMT_DRAWINGS_OTHER_CURRENT_MEAN  1.387258e-04
# 516      PREV_NAME_SELLER_INDUSTRY_Autotechnology_MEAN  1.361844e-04
# 684                  CC_AMT_DRAWINGS_OTHER_CURRENT_SUM  1.343990e-04
# 208                         ORGANIZATION_TYPE_Security  1.309514e-04
# 215                       ORGANIZATION_TYPE_Tradetype3  1.304885e-04
# 484              PREV_NAME_GOODS_CATEGORY_Jewelry_MEAN  1.299722e-04
# 169                      ORGANIZATION_TYPE_Agriculture  1.253403e-04
# 481            PREV_NAME_GOODS_CATEGORY_Homewares_MEAN  1.249805e-04
# 485      PREV_NAME_GOODS_CATEGORY_MedicalSupplies_MEAN  1.235935e-04
# 304                            BURO_STATUS_4_MEAN_MEAN  1.231664e-04
# 188                    ORGANIZATION_TYPE_Industrytype3  1.223514e-04
# 144                      OCCUPATION_TYPE_Cleaningstaff  1.201094e-04
# 756                 CC_NAME_CONTRACT_STATUS_Active_MIN  1.187371e-04
# 305                            BURO_STATUS_5_MEAN_MEAN  1.151551e-04
# 686                    CC_AMT_DRAWINGS_POS_CURRENT_MIN  1.105616e-04
# 767              CC_NAME_CONTRACT_STATUS_Completed_MAX  1.100726e-04
# 184                   ORGANIZATION_TYPE_Industrytype11  1.083280e-04
# 406            PREV_FLAG_LAST_APPL_PER_CONTRACT_N_MEAN  1.076152e-04
# 734                  CC_CNT_DRAWINGS_OTHER_CURRENT_SUM  1.072150e-04
# 788                CC_NAME_CONTRACT_STATUS_Signed_MEAN  1.027139e-04
# 790                 CC_NAME_CONTRACT_STATUS_Signed_VAR  1.018059e-04
# 226                    FONDKAPREMONT_MODE_notspecified  1.016119e-04
# 199                         ORGANIZATION_TYPE_Military  9.964572e-05
# 453                   PREV_CODE_REJECT_REASON_XNA_MEAN  9.889220e-05
# 407            PREV_FLAG_LAST_APPL_PER_CONTRACT_Y_MEAN  9.791785e-05
# 789                 CC_NAME_CONTRACT_STATUS_Signed_SUM  9.748974e-05
# 99                                    FLAG_DOCUMENT_18  9.599140e-05
# 732                  CC_CNT_DRAWINGS_OTHER_CURRENT_MAX  9.474937e-05
# 155                OCCUPATION_TYPE_Privateservicestaff  9.437448e-05
# 140                  NAME_HOUSING_TYPE_Officeapartment  9.321221e-05
# 239                          WALLSMATERIAL_MODE_Wooden  9.186867e-05
# 752                                  CC_SK_DPD_DEF_MAX  9.144023e-05
# 227                  FONDKAPREMONT_MODE_orgspecaccount  8.987705e-05
# 480            PREV_NAME_GOODS_CATEGORY_Gardening_MEAN  8.505624e-05
# 221                   ORGANIZATION_TYPE_Transporttype2  8.435872e-05
# 97                                    FLAG_DOCUMENT_16  8.368513e-05
# 206                       ORGANIZATION_TYPE_Restaurant  8.349396e-05
# 194                    ORGANIZATION_TYPE_Industrytype9  8.312773e-05
# 415    PREV_NAME_CASH_LOAN_PURPOSE_Buyingausedcar_MEAN  8.159818e-05
# 358                      CLOSED_CNT_CREDIT_PROLONG_SUM  8.159491e-05
# 701                   CC_AMT_PAYMENT_TOTAL_CURRENT_MIN  8.126618e-05
# 160                 OCCUPATION_TYPE_Waitersbarmenstaff  8.117317e-05
# 787                 CC_NAME_CONTRACT_STATUS_Signed_MAX  8.091780e-05
# 152                   OCCUPATION_TYPE_LowskillLaborers  7.979393e-05
# 736                    CC_CNT_DRAWINGS_POS_CURRENT_MIN  7.967289e-05
# 523             PREV_NAME_SELLER_INDUSTRY_Jewelry_MEAN  7.955157e-05
# 451                 PREV_CODE_REJECT_REASON_VERIF_MEAN  7.766811e-05
# 234                           WALLSMATERIAL_MODE_Mixed  7.650810e-05
# 92                                    FLAG_DOCUMENT_11  7.543926e-05
# 491      PREV_NAME_GOODS_CATEGORY_SportandLeisure_MEAN  7.494703e-05
# 104                          AMT_REQ_CREDIT_BUREAU_DAY  7.494181e-05
# 353                 CLOSED_AMT_CREDIT_SUM_OVERDUE_MEAN  7.167122e-05
# 231                     HOUSETYPE_MODE_specifichousing  7.039180e-05
# 488     PREV_NAME_GOODS_CATEGORY_OfficeAppliances_MEAN  6.988193e-05
# 676                        CC_AMT_DRAWINGS_CURRENT_MIN  6.859346e-05
# 550  PREV_PRODUCT_COMBINATION_POSotherswithoutinter...  6.755616e-05
# 202                           ORGANIZATION_TYPE_Police  6.729072e-05
# 181                          ORGANIZATION_TYPE_Housing  6.673874e-05
# 509     PREV_CHANNEL_TYPE_Channelofcorporatesales_MEAN  6.546827e-05
# 222                   ORGANIZATION_TYPE_Transporttype3  6.354796e-05
# 189                    ORGANIZATION_TYPE_Industrytype4  6.178153e-05
# 236                          WALLSMATERIAL_MODE_Others  6.169804e-05
# 209               ORGANIZATION_TYPE_SecurityMinistries  6.107993e-05
# 726                        CC_CNT_DRAWINGS_CURRENT_MIN  6.096072e-05
# 418  PREV_NAME_CASH_LOAN_PURPOSE_Everydayexpenses_MEAN  6.046588e-05
# 290   BURO_CREDIT_TYPE_Loanforbusinessdevelopment_MEAN  5.952567e-05
# 489                PREV_NAME_GOODS_CATEGORY_Other_MEAN  5.884837e-05
# 158                        OCCUPATION_TYPE_Secretaries  5.870283e-05
# 211                         ORGANIZATION_TYPE_Services  5.819024e-05
# 409  PREV_NAME_CASH_LOAN_PURPOSE_Buildingahouseoran...  5.777926e-05
# 115                            NAME_TYPE_SUITE_Other_B  5.776761e-05
# 671                    CC_AMT_DRAWINGS_ATM_CURRENT_MIN  5.628789e-05
# 214                       ORGANIZATION_TYPE_Tradetype2  5.592700e-05
# 103                         AMT_REQ_CREDIT_BUREAU_HOUR  5.524190e-05
# 241                            EMERGENCYSTATE_MODE_Yes  5.393043e-05
# 137                    NAME_HOUSING_TYPE_Coopapartment  5.185189e-05
# 466                     PREV_NAME_CLIENT_TYPE_XNA_MEAN  5.155122e-05
# 192                    ORGANIZATION_TYPE_Industrytype7  5.072132e-05
# 203                           ORGANIZATION_TYPE_Postal  4.927724e-05
# 423          PREV_NAME_CASH_LOAN_PURPOSE_Medicine_MEAN  4.900011e-05
# 457            PREV_NAME_TYPE_SUITE_Groupofpeople_MEAN  4.899525e-05
# 177                      ORGANIZATION_TYPE_Electricity  4.807367e-05
# 232                       HOUSETYPE_MODE_terracedhouse  4.497202e-05
# 170                             ORGANIZATION_TYPE_Bank  4.452374e-05
# 426  PREV_NAME_CASH_LOAN_PURPOSE_Paymentsonotherloa...  4.356075e-05
# 416        PREV_NAME_CASH_LOAN_PURPOSE_Carrepairs_MEAN  4.290672e-05
# 284            BURO_CREDIT_TYPE_Anothertypeofloan_MEAN  4.238253e-05
# 486             PREV_NAME_GOODS_CATEGORY_Medicine_MEAN  4.189832e-05
# 224                       ORGANIZATION_TYPE_University  4.167491e-05
# 422           PREV_NAME_CASH_LOAN_PURPOSE_Journey_MEAN  4.111604e-05
# 417         PREV_NAME_CASH_LOAN_PURPOSE_Education_MEAN  3.745905e-05
# 90                                     FLAG_DOCUMENT_9  3.726162e-05
# 156                       OCCUPATION_TYPE_Realtyagents  3.588834e-05
# 178                        ORGANIZATION_TYPE_Emergency  3.469930e-05
# 524         PREV_NAME_SELLER_INDUSTRY_MLMpartners_MEAN  3.384718e-05
# 427  PREV_NAME_CASH_LOAN_PURPOSE_Purchaseofelectron...  3.349983e-05
# 190                    ORGANIZATION_TYPE_Industrytype5  3.244283e-05
# 182                    ORGANIZATION_TYPE_Industrytype1  3.217906e-05
# 235                      WALLSMATERIAL_MODE_Monolithic  3.167846e-05
# 150                            OCCUPATION_TYPE_ITstaff  3.147219e-05
# 180                            ORGANIZATION_TYPE_Hotel  3.084050e-05
# 19                                    FLAG_CONT_MOBILE  2.990144e-05
# 114                            NAME_TYPE_SUITE_Other_A  2.980548e-05
# 94                                    FLAG_DOCUMENT_13  2.801916e-05
# 279                BURO_CREDIT_CURRENCY_currency1_MEAN  2.722852e-05
# 204                          ORGANIZATION_TYPE_Realtor  2.695187e-05
# 492              PREV_NAME_GOODS_CATEGORY_Tourism_MEAN  2.518522e-05
# 280                BURO_CREDIT_CURRENCY_currency2_MEAN  2.477357e-05
# 298            BURO_CREDIT_TYPE_Unknowntypeofloan_MEAN  2.469907e-05
# 624               POS_NAME_CONTRACT_STATUS_Demand_MEAN  2.293466e-05
# 185                   ORGANIZATION_TYPE_Industrytype12  2.269260e-05
# 431  PREV_NAME_CASH_LOAN_PURPOSE_Weddinggiftholiday...  2.195199e-05
# 148                            OCCUPATION_TYPE_HRstaff  2.177545e-05
# 551                  PREV_PRODUCT_COMBINATION_nan_MEAN  2.058456e-05
# 212                          ORGANIZATION_TYPE_Telecom  1.945856e-05
# 195                        ORGANIZATION_TYPE_Insurance  1.933657e-05
# 419         PREV_NAME_CASH_LOAN_PURPOSE_Furniture_MEAN  1.923946e-05
# 218                       ORGANIZATION_TYPE_Tradetype6  1.904014e-05
# 721                    CC_CNT_DRAWINGS_ATM_CURRENT_MIN  1.896071e-05
# 441  PREV_NAME_PAYMENT_TYPE_Cashlessfromtheaccounto...  1.863305e-05
# 187                    ORGANIZATION_TYPE_Industrytype2  1.781173e-05
# 95                                    FLAG_DOCUMENT_14  1.779832e-05
# 200                           ORGANIZATION_TYPE_Mobile  1.759422e-05
# 414     PREV_NAME_CASH_LOAN_PURPOSE_Buyinganewcar_MEAN  1.652331e-05
# 281                BURO_CREDIT_CURRENCY_currency3_MEAN  1.566702e-05
# 413       PREV_NAME_CASH_LOAN_PURPOSE_Buyingahome_MEAN  1.547102e-05
# 293  BURO_CREDIT_TYPE_Loanforworkingcapitalreplenis...  1.538440e-05
# 96                                    FLAG_DOCUMENT_15  1.495221e-05
# 213                       ORGANIZATION_TYPE_Tradetype1  1.485207e-05
# 220                   ORGANIZATION_TYPE_Transporttype1  1.451126e-05
# 168                      ORGANIZATION_TYPE_Advertising  1.420160e-05
# 410  PREV_NAME_CASH_LOAN_PURPOSE_Businessdevelopmen...  1.211599e-05
# 412  PREV_NAME_CASH_LOAN_PURPOSE_Buyingaholidayhome...  1.189189e-05
# 477            PREV_NAME_GOODS_CATEGORY_Education_MEAN  1.189060e-05
# 197                    ORGANIZATION_TYPE_LegalServices  1.185527e-05
# 396                   PREV_NAME_CONTRACT_TYPE_XNA_MEAN  1.050131e-05
# 783          CC_NAME_CONTRACT_STATUS_Sentproposal_MEAN  9.883296e-06
# 183                   ORGANIZATION_TYPE_Industrytype10  9.337151e-06
# 98                                    FLAG_DOCUMENT_17  9.135351e-06
# 344                      CLOSED_CREDIT_DAY_OVERDUE_MAX  8.712331e-06
# 176                          ORGANIZATION_TYPE_Culture  8.184963e-06
# 420  PREV_NAME_CASH_LOAN_PURPOSE_Gasificationwaters...  7.636835e-06
# 450                PREV_CODE_REJECT_REASON_SYSTEM_MEAN  7.608143e-06
# 468    PREV_NAME_GOODS_CATEGORY_AdditionalService_MEAN  7.511263e-06
# 498                      PREV_NAME_PORTFOLIO_Cars_MEAN  7.410660e-06
# 779                CC_NAME_CONTRACT_STATUS_Refused_SUM  7.115945e-06
# 476          PREV_NAME_GOODS_CATEGORY_DirectSales_MEAN  6.596161e-06
# 784           CC_NAME_CONTRACT_STATUS_Sentproposal_SUM  6.315688e-06
# 174                         ORGANIZATION_TYPE_Cleaning  6.265305e-06
# 508                   PREV_CHANNEL_TYPE_Cardealer_MEAN  6.085106e-06
# 478              PREV_NAME_GOODS_CATEGORY_Fitness_MEAN  5.810996e-06
# 216                       ORGANIZATION_TYPE_Tradetype4  5.754247e-06
# 191                    ORGANIZATION_TYPE_Industrytype6  5.718349e-06
# 113                      NAME_TYPE_SUITE_Groupofpeople  5.346368e-06
# 186                   ORGANIZATION_TYPE_Industrytype13  5.290526e-06
# 525             PREV_NAME_SELLER_INDUSTRY_Tourism_MEAN  4.971443e-06
# 785           CC_NAME_CONTRACT_STATUS_Sentproposal_VAR  4.903369e-06
# 421             PREV_NAME_CASH_LOAN_PURPOSE_Hobby_MEAN  4.277316e-06
# 411     PREV_NAME_CASH_LOAN_PURPOSE_Buyingagarage_MEAN  3.910943e-06
# 102                                   FLAG_DOCUMENT_21  3.748575e-06
# 483            PREV_NAME_GOODS_CATEGORY_Insurance_MEAN  3.670715e-06
# 622             POS_NAME_CONTRACT_STATUS_Canceled_MEAN  2.775338e-06
# 773                CC_NAME_CONTRACT_STATUS_Demand_MEAN  2.680052e-06
# 494               PREV_NAME_GOODS_CATEGORY_Weapon_MEAN  2.645430e-06
# 205                         ORGANIZATION_TYPE_Religion  2.159548e-06
# 286         BURO_CREDIT_TYPE_Cashloannonearmarked_MEAN  2.156721e-06
# 100                                   FLAG_DOCUMENT_19  2.148972e-06
# 217                       ORGANIZATION_TYPE_Tradetype5  2.128744e-06
# 782           CC_NAME_CONTRACT_STATUS_Sentproposal_MAX  2.049213e-06
# 101                                   FLAG_DOCUMENT_20  2.048249e-06
# 297               BURO_CREDIT_TYPE_Realestateloan_MEAN  1.448310e-06
# 124                        NAME_INCOME_TYPE_Unemployed  1.422099e-06
# 757                 CC_NAME_CONTRACT_STATUS_Active_MAX  1.366018e-06
# 772                 CC_NAME_CONTRACT_STATUS_Demand_MAX  1.359552e-06
# 126                 NAME_EDUCATION_TYPE_Academicdegree  1.335069e-06
# 345                     CLOSED_CREDIT_DAY_OVERDUE_MEAN  7.838918e-07
# 764               CC_NAME_CONTRACT_STATUS_Approved_SUM  0.000000e+00
# 763              CC_NAME_CONTRACT_STATUS_Approved_MEAN  0.000000e+00
# 762               CC_NAME_CONTRACT_STATUS_Approved_MAX  0.000000e+00
# 761               CC_NAME_CONTRACT_STATUS_Approved_MIN  0.000000e+00
# 408          PREV_FLAG_LAST_APPL_PER_CONTRACT_nan_MEAN  0.000000e+00
# 765               CC_NAME_CONTRACT_STATUS_Approved_VAR  0.000000e+00
# 766              CC_NAME_CONTRACT_STATUS_Completed_MIN  0.000000e+00
# 795                    CC_NAME_CONTRACT_STATUS_nan_VAR  0.000000e+00
# 405           PREV_WEEKDAY_APPR_PROCESS_START_nan_MEAN  0.000000e+00
# 794                    CC_NAME_CONTRACT_STATUS_nan_SUM  0.000000e+00
# 771                 CC_NAME_CONTRACT_STATUS_Demand_MIN  0.000000e+00
# 467                     PREV_NAME_CLIENT_TYPE_nan_MEAN  0.000000e+00
# 793                   CC_NAME_CONTRACT_STATUS_nan_MEAN  0.000000e+00
# 792                    CC_NAME_CONTRACT_STATUS_nan_MAX  0.000000e+00
# 786                 CC_NAME_CONTRACT_STATUS_Signed_MIN  0.000000e+00
# 774                 CC_NAME_CONTRACT_STATUS_Demand_SUM  0.000000e+00
# 775                 CC_NAME_CONTRACT_STATUS_Demand_VAR  0.000000e+00
# 776                CC_NAME_CONTRACT_STATUS_Refused_MIN  0.000000e+00
# 791                    CC_NAME_CONTRACT_STATUS_nan_MIN  0.000000e+00
# 778               CC_NAME_CONTRACT_STATUS_Refused_MEAN  0.000000e+00
# 123                           NAME_INCOME_TYPE_Student  0.000000e+00
# 780                CC_NAME_CONTRACT_STATUS_Refused_VAR  0.000000e+00
# 781           CC_NAME_CONTRACT_STATUS_Sentproposal_MIN  0.000000e+00
# 120                    NAME_INCOME_TYPE_Maternityleave  0.000000e+00
# 118                       NAME_INCOME_TYPE_Businessman  0.000000e+00
# 777                CC_NAME_CONTRACT_STATUS_Refused_MAX  0.000000e+00
# 289              BURO_CREDIT_TYPE_Interbankcredit_MEAN  0.000000e+00
# 93                                    FLAG_DOCUMENT_12  0.000000e+00
# 275                    BURO_CREDIT_ACTIVE_Baddebt_MEAN  0.000000e+00
# 515                         PREV_CHANNEL_TYPE_nan_MEAN  0.000000e+00
# 444                    PREV_NAME_PAYMENT_TYPE_nan_MEAN  0.000000e+00
# 16                                          FLAG_MOBIL  0.000000e+00
# 506                    PREV_NAME_PRODUCT_TYPE_nan_MEAN  0.000000e+00
# 502                       PREV_NAME_PORTFOLIO_nan_MEAN  0.000000e+00
# 308                          BURO_STATUS_nan_MEAN_MEAN  0.000000e+00
# 299                          BURO_CREDIT_TYPE_nan_MEAN  0.000000e+00
# 496                  PREV_NAME_GOODS_CATEGORY_nan_MEAN  0.000000e+00
# 193                    ORGANIZATION_TYPE_Industrytype8  0.000000e+00
# 278                        BURO_CREDIT_ACTIVE_nan_MEAN  0.000000e+00
# 681                  CC_AMT_DRAWINGS_OTHER_CURRENT_MIN  0.000000e+00
# 454                   PREV_CODE_REJECT_REASON_nan_MEAN  0.000000e+00
# 282                BURO_CREDIT_CURRENCY_currency4_MEAN  0.000000e+00
# 283                      BURO_CREDIT_CURRENCY_nan_MEAN  0.000000e+00
# 295           BURO_CREDIT_TYPE_Mobileoperatorloan_MEAN  0.000000e+00
# 292  BURO_CREDIT_TYPE_Loanforthepurchaseofequipment...  0.000000e+00
# 439                 PREV_NAME_CONTRACT_STATUS_nan_MEAN  0.000000e+00
# 469              PREV_NAME_GOODS_CATEGORY_Animals_MEAN  0.000000e+00
# 91                                    FLAG_DOCUMENT_10  0.000000e+00
# 533                     PREV_NAME_YIELD_GROUP_nan_MEAN  0.000000e+00
# 751                                  CC_SK_DPD_DEF_MIN  0.000000e+00
# 482    PREV_NAME_GOODS_CATEGORY_HouseConstruction_MEAN  0.000000e+00
# 397                   PREV_NAME_CONTRACT_TYPE_nan_MEAN  0.000000e+00
# 291  BURO_CREDIT_TYPE_Loanforpurchaseofsharesmargin...  0.000000e+00
# 746                                      CC_SK_DPD_MIN  0.000000e+00
# 88                                     FLAG_DOCUMENT_7  0.000000e+00
# 85                                     FLAG_DOCUMENT_4  0.000000e+00
# 83                                     FLAG_DOCUMENT_2  0.000000e+00
# 628                  POS_NAME_CONTRACT_STATUS_nan_MEAN  0.000000e+00
# 428  PREV_NAME_CASH_LOAN_PURPOSE_Refusaltonamethego...  0.000000e+00
# 135                         NAME_FAMILY_STATUS_Unknown  0.000000e+00
# 527                 PREV_NAME_SELLER_INDUSTRY_nan_MEAN  0.000000e+00
# 620        POS_NAME_CONTRACT_STATUS_Amortizeddebt_MEAN  0.000000e+00
# 434               PREV_NAME_CASH_LOAN_PURPOSE_nan_MEAN  0.000000e+00
# 731                  CC_CNT_DRAWINGS_OTHER_CURRENT_MIN  0.000000e+00
# 627                  POS_NAME_CONTRACT_STATUS_XNA_MEAN  0.000000e+00
# 424  PREV_NAME_CASH_LOAN_PURPOSE_Moneyforathirdpers...  0.000000e+00

# %%
feature_importance_df.shape
# Out:
# (50, 2)

# %%
# Visualiser l'importance des caractéristiques
plt.figure(figsize=(10, 6))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'])
plt.xlabel('Importance')
plt.title('Importance des caractéristiques')
plt.gca().invert_yaxis()  # Inverser l'axe y pour afficher la caractéristique la plus importante en haut
plt.show()

# %%
# Sélectionner le top des caractéristiques les plus importantes
top_features = feature_importance_df.head(25)

# Visualiser l'importance des caractéristiques
plt.figure(figsize=(10, 8))
plt.barh(top_features['Feature'], top_features['Importance'])
plt.xlabel('Importance')
plt.title('Top 50 des caractéristiques les plus importantes')
plt.gca().invert_yaxis()  # Inverser l'axe y pour afficher la caractéristique la plus importante en haut
plt.show()

# %% [markdown]
# ## Consolidation / Sélection Features

# %%
# Calculer l'importance moyenne absolue des valeurs SHAP pour chaque modèle
shap_importance_model1 = np.mean(np.abs(model1_shap_values), axis=0)
shap_importance_model2 = np.mean(np.abs(model2_shap_values), axis=0)

# Créer des DataFrames pour les importances SHAP
shap_importance_df_model1 = pd.DataFrame({
    'Feature': [f'Feature_{i}' for i in range(model1_shap_values.shape[1])],
    'Importance': shap_importance_model1
})

shap_importance_df_model2 = pd.DataFrame({
    'Feature': [f'Feature_{i}' for i in range(model2_shap_values.shape[1])],
    'Importance': shap_importance_model2
})

# Normaliser les importances pour chaque modèle
def normalize_importance(df):
    df['Importance'] = (df['Importance'] - df['Importance'].min()) / (df['Importance'].max() - df['Importance'].min())
    return df

shap_importance_df_model1 = normalize_importance(shap_importance_df_model1)
shap_importance_df_model2 = normalize_importance(shap_importance_df_model2)
feature_importance_df = normalize_importance(feature_importance_df)

# Combiner les importances normalisées
combined_importance = pd.DataFrame({
    'Feature': feature_importance_df['Feature'],
    'Combined_Importance': (shap_importance_df_model1['Importance'] +
                             shap_importance_df_model2['Importance'] +
                             feature_importance_df['Importance']) / 3
})

# Trier les caractéristiques par leur importance combinée
combined_importance = combined_importance.sort_values(by='Combined_Importance', ascending=False)

# Sélectionner les 40 caractéristiques les plus importantes
top_40_features = combined_importance.head(40)

# Afficher les 40 caractéristiques les plus importantes
print("Top 40 des caractéristiques les plus importantes :")
print(top_40_features)
# Out:
# Top 40 des caractéristiques les plus importantes :
#                                  Feature  Combined_Importance
# 33                          EXT_SOURCE_2             1.000000
# 34                          EXT_SOURCE_3             0.960159
# 32                          EXT_SOURCE_1             0.427377
# 12                         DAYS_EMPLOYED             0.337354
# 246                         PAYMENT_RATE             0.220917
# 2                            CODE_GENDER             0.216074
# 632                      INSTAL_DPD_MEAN             0.203682
# 651               INSTAL_AMT_PAYMENT_SUM             0.185615
# 11                            DAYS_BIRTH             0.176184
# 242                   DAYS_EMPLOYED_PERC             0.158860
# 8                            AMT_ANNUITY             0.157501
# 391                PREV_CNT_PAYMENT_MEAN             0.146311
# 15                           OWN_CAR_AGE             0.142878
# 262        BURO_AMT_CREDIT_SUM_DEBT_MEAN             0.137259
# 9                        AMT_GOODS_PRICE             0.135026
# 566        APPROVED_AMT_DOWN_PAYMENT_MAX             0.134714
# 7                             AMT_CREDIT             0.130587
# 249                BURO_DAYS_CREDIT_MEAN             0.129427
# 374            PREV_APP_CREDIT_PERC_MEAN             0.129319
# 127  NAME_EDUCATION_TYPE_Highereducation             0.119139
# 276       BURO_CREDIT_ACTIVE_Closed_MEAN             0.113859
# 648               INSTAL_AMT_PAYMENT_MIN             0.110075
# 580            APPROVED_CNT_PAYMENT_MEAN             0.108631
# 638             INSTAL_PAYMENT_PERC_MEAN             0.104270
# 254         BURO_DAYS_CREDIT_UPDATE_MEAN             0.103632
# 248                 BURO_DAYS_CREDIT_MAX             0.103616
# 310               ACTIVE_DAYS_CREDIT_MAX             0.102400
# 14                       DAYS_ID_PUBLISH             0.097877
# 723     CC_CNT_DRAWINGS_ATM_CURRENT_MEAN             0.097284
# 372             PREV_APP_CREDIT_PERC_MIN             0.096039
# 314       ACTIVE_DAYS_CREDIT_ENDDATE_MAX             0.095506
# 614              POS_MONTHS_BALANCE_SIZE             0.093939
# 245                  ANNUITY_INCOME_PERC             0.093434
# 653       INSTAL_DAYS_ENTRY_PAYMENT_MEAN             0.092235
# 315      ACTIVE_DAYS_CREDIT_ENDDATE_MEAN             0.091337
# 529      PREV_NAME_YIELD_GROUP_high_MEAN             0.090677
# 554            APPROVED_AMT_ANNUITY_MEAN             0.090042
# 654        INSTAL_DAYS_ENTRY_PAYMENT_SUM             0.089811
# 642             INSTAL_PAYMENT_DIFF_MEAN             0.083795
# 553             APPROVED_AMT_ANNUITY_MAX             0.081106

# %% [markdown]
# ## Réduction DF

# %%
top_40_features_target = top_40_features.copy()
top_40_features_target.loc[-1] = 'TARGET'

# %%
# Réduire dataframe
df_reduced = df[top_40_features_target['Feature']]
df_reduced.shape
# Out:
# (356251, 41)

# %%
# Calculer le nombre total de valeurs manquantes
total_missing = df_reduced.isna().sum().sum()

# Calculer le pourcentage de valeurs manquantes
total_cells = df_reduced.size
percentage_missing = (total_missing / total_cells) * 100

# Afficher le total et le pourcentage de valeurs manquantes
print(f"Total de cellules dans df_reduced: {total_cells}")
print(f"Total de valeurs manquantes dans df_reduced: {total_missing}")
print(f"Pourcentage de valeurs manquantes dans df_reduced: {percentage_missing:.2f}%")
# Out:
# Total de cellules dans df_reduced: 14606291
# Total de valeurs manquantes dans df_reduced: 1858968
# Pourcentage de valeurs manquantes dans df_reduced: 12.73%

# %%
missing_values_count(df_reduced)
# Out:
# Nombre de variables par bin de valeurs manquantes et leur pourcentage par rapport au total :
#          Number of Variables  Percentage of Total
# 0%                         5            12.195122
# 0-20%                     30            73.170732
# 20-40%                     3             7.317073
# 40-60%                     1             2.439024
# 60-100%                    2             4.878049

# %%
missing_values = df_reduced.isna().sum()

# Afficher les valeurs manquantes par colonne
print("Valeurs manquantes dans X_train_reduced :")
print(missing_values)
# Out:
# Valeurs manquantes dans X_train_reduced :
# EXT_SOURCE_2                              668
# EXT_SOURCE_3                            69633
# EXT_SOURCE_1                           193908
# DAYS_EMPLOYED                           64648
# PAYMENT_RATE                               36
# CODE_GENDER                                 0
# INSTAL_DPD_MEAN                         16668
# INSTAL_AMT_PAYMENT_SUM                  16668
# DAYS_BIRTH                                  0
# DAYS_EMPLOYED_PERC                      64648
# AMT_ANNUITY                                36
# PREV_CNT_PAYMENT_MEAN                   17876
# OWN_CAR_AGE                            235239
# BURO_AMT_CREDIT_SUM_DEBT_MEAN           58816
# AMT_GOODS_PRICE                           278
# APPROVED_AMT_DOWN_PAYMENT_MAX           40203
# AMT_CREDIT                                  0
# BURO_DAYS_CREDIT_MEAN                   50444
# PREV_APP_CREDIT_PERC_MEAN               17651
# NAME_EDUCATION_TYPE_Highereducation         0
# BURO_CREDIT_ACTIVE_Closed_MEAN          50444
# INSTAL_AMT_PAYMENT_MIN                  16677
# APPROVED_CNT_PAYMENT_MEAN               18557
# INSTAL_PAYMENT_PERC_MEAN                16696
# BURO_DAYS_CREDIT_UPDATE_MEAN            50444
# BURO_DAYS_CREDIT_MAX                    50444
# ACTIVE_DAYS_CREDIT_MAX                 104440
# DAYS_ID_PUBLISH                             0
# CC_CNT_DRAWINGS_ATM_CURRENT_MEAN       284057
# PREV_APP_CREDIT_PERC_MIN                17650
# ACTIVE_DAYS_CREDIT_ENDDATE_MAX         114909
# POS_MONTHS_BALANCE_SIZE                 19003
# ANNUITY_INCOME_PERC                        36
# INSTAL_DAYS_ENTRY_PAYMENT_MEAN          16677
# ACTIVE_DAYS_CREDIT_ENDDATE_MEAN        114909
# PREV_NAME_YIELD_GROUP_high_MEAN         17398
# APPROVED_AMT_ANNUITY_MEAN               18559
# INSTAL_DAYS_ENTRY_PAYMENT_SUM           16668
# INSTAL_PAYMENT_DIFF_MEAN                16677
# APPROVED_AMT_ANNUITY_MAX                18559
# TARGET                                  48744
# dtype: int64

# %%
# Affichage de la heatmap des corrélations
plt.figure(figsize=(30,30))
sns.heatmap(df_reduced.corr() , annot=True, linewidths=.2, cmap="YlGnBu")
plt.title("Heatmap des corrélations - 'application_train'")
# Out:
# Text(0.5, 1.0, "Heatmap des corrélations - 'application_train'")

# %% [markdown]
# ## Export

# %%
output_name = 'df_reduced.csv'

X_train_reduced.to_csv(csv_path_output + output_name, encoding='ISO-8859-1')

print('Export terminé')
# Out:
# Export terminé
