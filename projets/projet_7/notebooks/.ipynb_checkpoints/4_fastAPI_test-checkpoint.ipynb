# %% [markdown]
# Data source : https://www.kaggle.com/c/home-credit-default-risk/data

# %% [markdown]
# But notebook : Test API

# %% [markdown]
# # Imports

# %%
import requests
import os
import pickle
import pandas as pd

# %% [markdown]
# # Tests points d'entrée

# %% [markdown]
# ## /data

# %%
# Créer le répertoire s'il n'existe pas
output_dir = "../data/api_output"
os.makedirs(output_dir, exist_ok=True)

# %%
# Format parquet
response = requests.get("http://127.0.0.1:8000/data?format=parquet")

# Afficher les 100 premiers octets pour un aperçu
preview = response.content[:100]
print("Aperçu des données Parquet :", preview)

# Écrire le contenu complet dans un fichier dans le répertoire spécifique
parquet_output_path = os.path.join(output_dir, "data.parquet")
with open(parquet_output_path, "wb") as f:
    f.write(response.content)
# Out:
# Aperçu des données Parquet : b'PAR1\x15\x04\x15\xb8\xb4Q\x15\x80\xb5QL\x15\x8e\xad\x14\x15\x00\x12\x00\x00\x9c\xda(\xf4\xff\xffPd\x18?\xae!(?\xb0s\x89>\xd8\x02-?\xc4i\x14?\x02\x94\x14?0\xc1\x17?\xb9\xf1+?F\x939?\xd6\xf4 ?\xc6\xe3\x17?\xde=\x10;|z.?\x1dp\xa1>\xc5\x10\xbe>\xc9\xbeF?\x02_4?q\x00'

# %%
df = pd.read_parquet(parquet_output_path)
df.shape
# Out:
# (210118, 38)

# %%
df.head()
# Out:
#    EXT_SOURCE_2  EXT_SOURCE_3  PAYMENT_RATE  INSTAL_DPD_MEAN  \
# 0      0.595281      0.706205      0.039660         0.461538
# 1      0.656764      0.071055      0.032398         4.256757
# 2      0.268461      0.256706      0.047191         0.125000
# 3      0.675825      0.355639      0.067940         0.000000
# 4      0.579739      0.363945      0.029348         0.000000
#
#    INSTAL_AMT_PAYMENT_SUM  AMT_ANNUITY  DAYS_BIRTH  CODE_GENDER  \
# 0            7.992843e+05      53541.0      -16961            1
# 1            2.602840e+06      30033.0      -12187            1
# 2            3.242952e+05      10737.0      -15445            0
# 3            6.519330e+04      30573.0      -13321            0
# 4            5.055732e+05      34578.0      -19486            0
#
#    ANNUITY_INCOME_PERC  APPROVED_AMT_DOWN_PAYMENT_MAX  ...  \
# 0             0.198300                        90000.0  ...
# 1             0.222467                        14931.0  ...
# 2             0.119300                        22441.5  ...
# 3             0.104523                         4500.0  ...
# 4             0.284593                        45000.0  ...
#
#    PREV_APP_CREDIT_PERC_MIN  APPROVED_DAYS_DECISION_MIN  \
# 0                  1.137779                     -2208.0
# 1                  0.824513                     -2604.0
# 2                  1.111116                     -2289.0
# 3                  1.000000                     -2473.0
# 4                  0.884721                     -1049.0
#
#    INSTAL_AMT_PAYMENT_MEAN  INSTAL_DBD_SUM  INSTAL_AMT_INSTALMENT_MAX  \
# 0             61483.410156           295.0               66693.781250
# 1             35173.523438           897.0              922513.062500
# 2             13512.297852           113.0               13531.634766
# 3              5926.663574           157.0                7696.529785
# 4             25278.662109           289.0              190605.640625
#
#    INCOME_CREDIT_PERC  INSTAL_DAYS_ENTRY_PAYMENT_MEAN  \
# 0            0.200000                    -2021.538452
# 1            0.145631                    -1484.216187
# 2            0.395570                    -1916.583374
# 3            0.650000                    -2305.454590
# 4            0.103122                     -559.349976
#
#    INSTAL_PAYMENT_DIFF_MEAN  SK_ID_CURR  TARGET
# 0               5050.211426      442623     0.0
# 1               8585.831055      164728     0.0
# 2                  0.000000      136291     0.0
# 3                  0.000000      190853     0.0
# 4                  0.000000      198244     0.0
#
# [5 rows x 38 columns]

# %%
# Format CSV
response = requests.get("http://127.0.0.1:8000/data?format=csv")

# Afficher les 100 premiers octets pour un aperçu
preview = response.content[:100]
print("Aperçu des données CSV :", preview.decode('utf-8'))  # Décoder en chaîne de caractères pour CSV

# Écrire le contenu complet dans un fichier dans le répertoire spécifique
csv_output_path = os.path.join(output_dir, "data.csv")
with open(csv_output_path, "wb") as f:
    f.write(response.content)
# Out:
# Aperçu des données CSV : EXT_SOURCE_2,EXT_SOURCE_3,PAYMENT_RATE,INSTAL_DPD_MEAN,INSTAL_AMT_PAYMENT_SUM,AMT_ANNUITY,DAYS_BIRTH

# %% [markdown]
# ## /user_data

# %%
user_id = {"SK_ID_CURR": 442623}
response = requests.post("http://127.0.0.1:8000/user_data", json=user_id)
print(response.json())
# Out:
# [{'EXT_SOURCE_2': 0.595280647277832, 'EXT_SOURCE_3': 0.7062051296234131, 'PAYMENT_RATE': 0.039659999310970306, 'INSTAL_DPD_MEAN': 0.4615384638309479, 'INSTAL_AMT_PAYMENT_SUM': 799284.3125, 'AMT_ANNUITY': 53541.0, 'DAYS_BIRTH': -16961, 'CODE_GENDER': 1, 'ANNUITY_INCOME_PERC': 0.19830000400543213, 'APPROVED_AMT_DOWN_PAYMENT_MAX': 90000.0, 'DAYS_EMPLOYED_PERC': 0.24149519205093384, 'BURO_DAYS_CREDIT_MEAN': -1695.3333740234375, 'PREV_CNT_PAYMENT_MEAN': 12.0, 'AMT_GOODS_PRICE': 1350000.0, 'BURO_AMT_CREDIT_SUM_DEBT_MEAN': 3197173.5, 'ACTIVE_DAYS_CREDIT_MAX': -252.0, 'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': 3401.0, 'PREV_APP_CREDIT_PERC_MEAN': 1.1377789974212646, 'INSTAL_PAYMENT_PERC_MEAN': 0.9230769276618958, 'NAME_EDUCATION_TYPE_Highereducation': 1, 'DAYS_ID_PUBLISH': -497, 'APPROVED_CNT_PAYMENT_MEAN': 12.0, 'BURO_DAYS_CREDIT_MAX': -252.0, 'INSTAL_AMT_PAYMENT_MIN': 2652.75, 'INSTAL_DAYS_ENTRY_PAYMENT_SUM': -26280.0, 'POS_MONTHS_BALANCE_SIZE': 12.0, 'PREV_NAME_CONTRACT_STATUS_Refused_MEAN': 0.0, 'DAYS_REGISTRATION': -2108.0, 'PREV_APP_CREDIT_PERC_MIN': 1.1377789974212646, 'APPROVED_DAYS_DECISION_MIN': -2208.0, 'INSTAL_AMT_PAYMENT_MEAN': 61483.41015625, 'INSTAL_DBD_SUM': 295.0, 'INSTAL_AMT_INSTALMENT_MAX': 66693.78125, 'INCOME_CREDIT_PERC': 0.20000000298023224, 'INSTAL_DAYS_ENTRY_PAYMENT_MEAN': -2021.5384521484375, 'INSTAL_PAYMENT_DIFF_MEAN': 5050.21142578125, 'SK_ID_CURR': 442623, 'TARGET': 0.0}]

# %% [markdown]
# ## /shap

# %%
user_id = {"SK_ID_CURR": 442623}
response = requests.post("http://127.0.0.1:8000/shap", json=user_id)

# Afficher la réponse brute
print("Status Code:", response.status_code)
print("Response Content:", response.content)
# Out:
# Status Code: 200
# Response Content: b'[[-0.09884810711278333,-0.9087273810548296,-0.4862894508062103,-0.0038103171121508755,-0.5164578030072821,0.2787360971885895,0.21096897889990812,-0.41697294025361276,0.07246233215172414,-0.40851885085710987,-0.1829500406128059,-0.4326394508588534,-0.09713726458832095,-0.9069609235551122,-0.5325417567285784,0.02442001880829064,0.07732741274793546,-0.058288799930034024,-0.4768370469975532,-0.6946742617880585,-0.6446111853859515,-0.7086948206957202,-0.030530575596624886,0.27450849519330084,-0.04313259911460158,-0.23734111456000198,-0.6012613081655561,-0.1353336282413134,-0.20283993674459985,-0.15306459661968594,-0.2277443102768239,-0.04677080289382549,-0.11666147591623267,-0.2689067479248998,-0.21361183709045709,0.01603975892331572]]'

# %% [markdown]
# ## /predict

# %% [markdown]
# ### Vérification features modèle

# %%
# Charger le modèle
with open('../app_API/app/model.pkl', 'rb') as file:
    model = pickle.load(file)

# Afficher le nombre de caractéristiques attendu par le modèle
print(f"Number of features expected by the model: {model.n_features_in_}")
# Out:
# Number of features expected by the model: 36

# %%
dir(model)
# Out:
# ['_Booster',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__sklearn_clone__',
#  '__sklearn_is_fitted__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_base_doc',
#  '_best_iteration',
#  '_best_score',
#  '_build_request_for_signature',
#  '_check_feature_names',
#  '_check_n_features',
#  '_class_map',
#  '_class_weight',
#  '_classes',
#  '_doc_link_module',
#  '_doc_link_template',
#  '_doc_link_url_param_generator',
#  '_estimator_type',
#  '_evals_result',
#  '_get_default_requests',
#  '_get_doc_link',
#  '_get_metadata_request',
#  '_get_param_names',
#  '_get_tags',
#  '_le',
#  '_more_tags',
#  '_n_classes',
#  '_n_features',
#  '_n_features_in',
#  '_objective',
#  '_other_params',
#  '_process_n_jobs',
#  '_process_params',
#  '_repr_html_',
#  '_repr_html_inner',
#  '_repr_mimebundle_',
#  '_validate_data',
#  '_validate_params',
#  'best_iteration_',
#  'best_score_',
#  'booster_',
#  'boosting_type',
#  'class_weight',
#  'classes_',
#  'colsample_bytree',
#  'evals_result_',
#  'feature_importances_',
#  'feature_name_',
#  'fit',
#  'fitted_',
#  'get_metadata_routing',
#  'get_params',
#  'importance_type',
#  'learning_rate',
#  'max_depth',
#  'min_child_samples',
#  'min_child_weight',
#  'min_split_gain',
#  'n_classes_',
#  'n_estimators',
#  'n_estimators_',
#  'n_features_',
#  'n_features_in_',
#  'n_iter_',
#  'n_jobs',
#  'num_leaves',
#  'objective',
#  'objective_',
#  'predict',
#  'predict_proba',
#  'random_state',
#  'reg_alpha',
#  'reg_lambda',
#  'score',
#  'set_fit_request',
#  'set_params',
#  'set_predict_proba_request',
#  'set_predict_request',
#  'set_score_request',
#  'subsample',
#  'subsample_for_bin',
#  'subsample_freq']

# %%
model.get_params
# Out:
# <bound method LGBMModel.get_params of LGBMClassifier(learning_rate=0.2, max_depth=7, n_estimators=300, num_leaves=50)>

# %% [markdown]
# ### Vérification dtypes

# %%
import pandas as pd
csv_path_output = '../data/output/'
X_train_filename = 'train_df_cleaned_smote.parquet.gzip'
X_test_filename = 'test_df_cleaned.parquet.gzip'

X_train = pd.read_parquet(csv_path_output + X_train_filename)

# %%
X_train.head()
# Out:
#    EXT_SOURCE_2  EXT_SOURCE_3  PAYMENT_RATE  INSTAL_DPD_MEAN  \
# 0      0.595281      0.706205      0.039660         0.461538
# 1      0.656764      0.071055      0.032398         4.256757
# 2      0.268461      0.256706      0.047191         0.125000
# 3      0.675825      0.355639      0.067940         0.000000
# 4      0.579739      0.363945      0.029348         0.000000
#
#    INSTAL_AMT_PAYMENT_SUM  AMT_ANNUITY  DAYS_BIRTH  CODE_GENDER  \
# 0            7.992843e+05      53541.0      -16961            1
# 1            2.602840e+06      30033.0      -12187            1
# 2            3.242952e+05      10737.0      -15445            0
# 3            6.519330e+04      30573.0      -13321            0
# 4            5.055732e+05      34578.0      -19486            0
#
#    ANNUITY_INCOME_PERC  APPROVED_AMT_DOWN_PAYMENT_MAX  ...  \
# 0             0.198300                        90000.0  ...
# 1             0.222467                        14931.0  ...
# 2             0.119300                        22441.5  ...
# 3             0.104523                         4500.0  ...
# 4             0.284593                        45000.0  ...
#
#    PREV_APP_CREDIT_PERC_MIN  APPROVED_DAYS_DECISION_MIN  \
# 0                  1.137779                     -2208.0
# 1                  0.824513                     -2604.0
# 2                  1.111116                     -2289.0
# 3                  1.000000                     -2473.0
# 4                  0.884721                     -1049.0
#
#    INSTAL_AMT_PAYMENT_MEAN  INSTAL_DBD_SUM  INSTAL_AMT_INSTALMENT_MAX  \
# 0             61483.410156           295.0               66693.781250
# 1             35173.523438           897.0              922513.062500
# 2             13512.297852           113.0               13531.634766
# 3              5926.663574           157.0                7696.529785
# 4             25278.662109           289.0              190605.640625
#
#    INCOME_CREDIT_PERC  INSTAL_DAYS_ENTRY_PAYMENT_MEAN  \
# 0            0.200000                    -2021.538452
# 1            0.145631                    -1484.216187
# 2            0.395570                    -1916.583374
# 3            0.650000                    -2305.454590
# 4            0.103122                     -559.349976
#
#    INSTAL_PAYMENT_DIFF_MEAN  SK_ID_CURR  TARGET
# 0               5050.211426      442623     0.0
# 1               8585.831055      164728     0.0
# 2                  0.000000      136291     0.0
# 3                  0.000000      190853     0.0
# 4                  0.000000      198244     0.0
#
# [5 rows x 38 columns]

# %%
X_train.shape
# Out:
# (210118, 38)

# %%
X_train.dtypes
# Out:
# EXT_SOURCE_2                              float32
# EXT_SOURCE_3                              float32
# PAYMENT_RATE                              float32
# INSTAL_DPD_MEAN                           float32
# INSTAL_AMT_PAYMENT_SUM                    float32
# AMT_ANNUITY                               float32
# DAYS_BIRTH                                  int16
# CODE_GENDER                                  int8
# ANNUITY_INCOME_PERC                       float32
# APPROVED_AMT_DOWN_PAYMENT_MAX             float32
# DAYS_EMPLOYED_PERC                        float32
# BURO_DAYS_CREDIT_MEAN                     float32
# PREV_CNT_PAYMENT_MEAN                     float32
# AMT_GOODS_PRICE                           float32
# BURO_AMT_CREDIT_SUM_DEBT_MEAN             float32
# ACTIVE_DAYS_CREDIT_MAX                    float32
# ACTIVE_DAYS_CREDIT_ENDDATE_MEAN           float32
# PREV_APP_CREDIT_PERC_MEAN                 float32
# INSTAL_PAYMENT_PERC_MEAN                  float32
# NAME_EDUCATION_TYPE_Highereducation          int8
# DAYS_ID_PUBLISH                             int16
# APPROVED_CNT_PAYMENT_MEAN                 float32
# BURO_DAYS_CREDIT_MAX                      float32
# INSTAL_AMT_PAYMENT_MIN                    float32
# INSTAL_DAYS_ENTRY_PAYMENT_SUM             float32
# POS_MONTHS_BALANCE_SIZE                   float32
# PREV_NAME_CONTRACT_STATUS_Refused_MEAN    float32
# DAYS_REGISTRATION                         float32
# PREV_APP_CREDIT_PERC_MIN                  float32
# APPROVED_DAYS_DECISION_MIN                float32
# INSTAL_AMT_PAYMENT_MEAN                   float32
# INSTAL_DBD_SUM                            float32
# INSTAL_AMT_INSTALMENT_MAX                 float32
# INCOME_CREDIT_PERC                        float32
# INSTAL_DAYS_ENTRY_PAYMENT_MEAN            float32
# INSTAL_PAYMENT_DIFF_MEAN                  float32
# SK_ID_CURR                                  int32
# TARGET                                    float32
# dtype: object

# %% [markdown]
# ### Query API

# %%
# query mock data
query_data = {
    "EXT_SOURCE_2": 0.1,
    "EXT_SOURCE_3": 0.2,
    "PAYMENT_RATE": 0.5,
    "INSTAL_DPD_MEAN": 0.0,
    "INSTAL_AMT_PAYMENT_SUM": 10000.0,
    "AMT_ANNUITY": 10000.0,
    "DAYS_BIRTH": -10000,
    "CODE_GENDER": 0.0,
    "ANNUITY_INCOME_PERC": 0.1,
    "APPROVED_AMT_DOWN_PAYMENT_MAX": 10000.0,
    "DAYS_EMPLOYED_PERC": 0.1,
    "BURO_DAYS_CREDIT_MEAN": -1000,
    "PREV_CNT_PAYMENT_MEAN": 10.0,
    "AMT_GOODS_PRICE": 100000.0,
    "BURO_AMT_CREDIT_SUM_DEBT_MEAN": 10000.0,
    "ACTIVE_DAYS_CREDIT_MAX": -1000,
    "ACTIVE_DAYS_CREDIT_ENDDATE_MEAN": -1000,
    "PREV_APP_CREDIT_PERC_MEAN": 0.1,
    "INSTAL_PAYMENT_PERC_MEAN": 0.1,
    "NAME_EDUCATION_TYPE_Highereducation": 1.0,
    "DAYS_ID_PUBLISH": -1000,
    "APPROVED_CNT_PAYMENT_MEAN": 10.0,
    "BURO_DAYS_CREDIT_MAX": -1000,
    "INSTAL_AMT_PAYMENT_MIN": 10000.0,
    "INSTAL_DAYS_ENTRY_PAYMENT_SUM": -1000,
    "POS_MONTHS_BALANCE_SIZE": 10.0,
    "PREV_NAME_CONTRACT_STATUS_Refused_MEAN": 0.0,
    "DAYS_REGISTRATION": -1000,
    "PREV_APP_CREDIT_PERC_MIN": 0.1,
    "APPROVED_DAYS_DECISION_MIN": -1000,
    "INSTAL_AMT_PAYMENT_MEAN": 10000.0,
    "INSTAL_DBD_SUM": 0.0,
    "INSTAL_AMT_INSTALMENT_MAX": 10000.0,
    "INCOME_CREDIT_PERC": 0.1,
    "INSTAL_DAYS_ENTRY_PAYMENT_MEAN": -1000,
    "INSTAL_PAYMENT_DIFF_MEAN": 0.0
}

response = requests.post("http://127.0.0.1:8000/predict", json=query_data)

# Afficher la réponse brute
print("Status Code:", response.status_code)
print("Response Content:", response.content)
# Out:
# Status Code: 200
# Response Content: b'{"prediction":[1.0]}'

# %%
len(query_data)
# Out:
# 37

# %%
# query predict with user fetched data
user_id = {"SK_ID_CURR": 442623}
user_info = requests.post("http://127.0.0.1:8000/user_data", json=user_id)
user_data = user_info.json()
print(user_data)
# Out:
# {'EXT_SOURCE_2': 0.595280647277832, 'EXT_SOURCE_3': 0.7062051296234131, 'PAYMENT_RATE': 0.039659999310970306, 'INSTAL_DPD_MEAN': 0.4615384638309479, 'INSTAL_AMT_PAYMENT_SUM': 799284.3125, 'AMT_ANNUITY': 53541.0, 'DAYS_BIRTH': -16961, 'CODE_GENDER': 1, 'ANNUITY_INCOME_PERC': 0.19830000400543213, 'APPROVED_AMT_DOWN_PAYMENT_MAX': 90000.0, 'DAYS_EMPLOYED_PERC': 0.24149519205093384, 'BURO_DAYS_CREDIT_MEAN': -1695.3333740234375, 'PREV_CNT_PAYMENT_MEAN': 12.0, 'AMT_GOODS_PRICE': 1350000.0, 'BURO_AMT_CREDIT_SUM_DEBT_MEAN': 3197173.5, 'ACTIVE_DAYS_CREDIT_MAX': -252.0, 'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': 3401.0, 'PREV_APP_CREDIT_PERC_MEAN': 1.1377789974212646, 'INSTAL_PAYMENT_PERC_MEAN': 0.9230769276618958, 'NAME_EDUCATION_TYPE_Highereducation': 1, 'DAYS_ID_PUBLISH': -497, 'APPROVED_CNT_PAYMENT_MEAN': 12.0, 'BURO_DAYS_CREDIT_MAX': -252.0, 'INSTAL_AMT_PAYMENT_MIN': 2652.75, 'INSTAL_DAYS_ENTRY_PAYMENT_SUM': -26280.0, 'POS_MONTHS_BALANCE_SIZE': 12.0, 'PREV_NAME_CONTRACT_STATUS_Refused_MEAN': 0.0, 'DAYS_REGISTRATION': -2108.0, 'PREV_APP_CREDIT_PERC_MIN': 1.1377789974212646, 'APPROVED_DAYS_DECISION_MIN': -2208.0, 'INSTAL_AMT_PAYMENT_MEAN': 61483.41015625, 'INSTAL_DBD_SUM': 295.0, 'INSTAL_AMT_INSTALMENT_MAX': 66693.78125, 'INCOME_CREDIT_PERC': 0.20000000298023224, 'INSTAL_DAYS_ENTRY_PAYMENT_MEAN': -2021.5384521484375, 'INSTAL_PAYMENT_DIFF_MEAN': 5050.21142578125, 'SK_ID_CURR': 442623, 'TARGET': 0.0}

# %%
user_data = user_data[0]

# %%
if "TARGET" in user_data:
    user_data.pop("TARGET")

if "SK_ID_CURR" in user_data:
    user_data.pop("SK_ID_CURR")

# %%
user_data
# Out:
# {'EXT_SOURCE_2': 0.595280647277832,
#  'EXT_SOURCE_3': 0.7062051296234131,
#  'PAYMENT_RATE': 0.039659999310970306,
#  'INSTAL_DPD_MEAN': 0.4615384638309479,
#  'INSTAL_AMT_PAYMENT_SUM': 799284.3125,
#  'AMT_ANNUITY': 53541.0,
#  'DAYS_BIRTH': -16961,
#  'CODE_GENDER': 1,
#  'ANNUITY_INCOME_PERC': 0.19830000400543213,
#  'APPROVED_AMT_DOWN_PAYMENT_MAX': 90000.0,
#  'DAYS_EMPLOYED_PERC': 0.24149519205093384,
#  'BURO_DAYS_CREDIT_MEAN': -1695.3333740234375,
#  'PREV_CNT_PAYMENT_MEAN': 12.0,
#  'AMT_GOODS_PRICE': 1350000.0,
#  'BURO_AMT_CREDIT_SUM_DEBT_MEAN': 3197173.5,
#  'ACTIVE_DAYS_CREDIT_MAX': -252.0,
#  'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN': 3401.0,
#  'PREV_APP_CREDIT_PERC_MEAN': 1.1377789974212646,
#  'INSTAL_PAYMENT_PERC_MEAN': 0.9230769276618958,
#  'NAME_EDUCATION_TYPE_Highereducation': 1,
#  'DAYS_ID_PUBLISH': -497,
#  'APPROVED_CNT_PAYMENT_MEAN': 12.0,
#  'BURO_DAYS_CREDIT_MAX': -252.0,
#  'INSTAL_AMT_PAYMENT_MIN': 2652.75,
#  'INSTAL_DAYS_ENTRY_PAYMENT_SUM': -26280.0,
#  'POS_MONTHS_BALANCE_SIZE': 12.0,
#  'PREV_NAME_CONTRACT_STATUS_Refused_MEAN': 0.0,
#  'DAYS_REGISTRATION': -2108.0,
#  'PREV_APP_CREDIT_PERC_MIN': 1.1377789974212646,
#  'APPROVED_DAYS_DECISION_MIN': -2208.0,
#  'INSTAL_AMT_PAYMENT_MEAN': 61483.41015625,
#  'INSTAL_DBD_SUM': 295.0,
#  'INSTAL_AMT_INSTALMENT_MAX': 66693.78125,
#  'INCOME_CREDIT_PERC': 0.20000000298023224,
#  'INSTAL_DAYS_ENTRY_PAYMENT_MEAN': -2021.5384521484375,
#  'INSTAL_PAYMENT_DIFF_MEAN': 5050.21142578125}

# %%
response = requests.post("http://127.0.0.1:8000/predict", json=user_data)
# Afficher la réponse brute
print("Status Code:", response.status_code)
print("Response Content:", response.content)
# Out:
# Status Code: 200
# Response Content: b'{"prediction":[0.0]}'
