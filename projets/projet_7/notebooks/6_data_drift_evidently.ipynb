# %% [markdown]
# Data source : https://www.kaggle.com/c/home-credit-default-risk/data

# %% [markdown]
# But notebook : Feature Engineering / Reduction
#
# - utiliser les donnes agrégées précédemment
# - réduire le dataframe (optimisation de futurs temps de calcul / temps de modélisation) tout en ayant le moins de données manquantes dans les features restantes
#    - verification des types et choix de types plus avantageux en poids si possible
#    - entrainement sur différents modèles et extraction des features notables via SHAPE ou autre (knn most important features)
#    - éviter de "créer" des informations ex-nihilo avec de l'inputing : favoriser la sélection / suppression en préservant au mieux l'intégrité des données

# %% [markdown]
# # Imports

# %% [markdown]
# # Data Drift

# %%
import pandas as pd
from evidently import Dataset
from evidently import DataDefinition
from evidently import Report
from evidently.presets import TextEvals
from evidently.metrics import *
from evidently.tests import *
from evidently.descriptors import *
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[19], line 5
#       3 from evidently import DataDefinition
#       4 from evidently import Report
# ----> 5 from evidently.presets import TextEvals
#       6 from evidently.metrics import *
#       7 from evidently.tests import *
#
# File ~/.pyenv/versions/3.9.7/lib/python3.9/site-packages/evidently/presets/__init__.py:1
# ----> 1 from .classification import ClassificationDummyQuality
#       2 from .classification import ClassificationPreset
#       3 from .classification import ClassificationQuality
#
# File ~/.pyenv/versions/3.9.7/lib/python3.9/site-packages/evidently/presets/classification.py:26
#      24 from evidently.legacy.model.widget import BaseWidgetInfo
#      25 from evidently.legacy.model.widget import link_metric
# ---> 26 from evidently.metrics import FNR
#      27 from evidently.metrics import FPR
#      28 from evidently.metrics import TNR
#
# File ~/.pyenv/versions/3.9.7/lib/python3.9/site-packages/evidently/metrics/__init__.py:1
# ----> 1 from .classification import FNR
#       2 from .classification import FPR
#       3 from .classification import TNR
#
# File ~/.pyenv/versions/3.9.7/lib/python3.9/site-packages/evidently/metrics/classification.py:11
#       8 from typing import Type
#       9 from typing import TypeVar
# ---> 11 from evidently.core.base_types import Label
#      12 from evidently.core.metric_types import BoundTest
#      13 from evidently.core.metric_types import ByLabelCalculation
#
# File ~/.pyenv/versions/3.9.7/lib/python3.9/site-packages/evidently/core/base_types.py:3
#       1 from typing import Union
# ----> 3 from evidently._pydantic_compat import StrictBool
#       5 Label = Union[StrictBool, int, str, None]
#
# ImportError: cannot import name 'StrictBool' from 'evidently._pydantic_compat' (/home/mijka/.pyenv/versions/3.9.7/lib/python3.9/site-packages/evidently/_pydantic_compat.py)

# %%
import pandas as pd
from sklearn import datasets

# %%
from evidently import Dataset

# %%
from evidently import DataDefinition

# %%
from evidently import Report

# %%
from evidently.presets import DataDriftPreset #or try DataDriftPreset
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 from evidently.presets import DataDriftPreset #or try DataDriftPreset
#
# File ~/.pyenv/versions/3.9.7/lib/python3.9/site-packages/evidently/presets/__init__.py:1
# ----> 1 from .classification import ClassificationDummyQuality
#       2 from .classification import ClassificationPreset
#       3 from .classification import ClassificationQuality
#
# File ~/.pyenv/versions/3.9.7/lib/python3.9/site-packages/evidently/presets/classification.py:26
#      24 from evidently.legacy.model.widget import BaseWidgetInfo
#      25 from evidently.legacy.model.widget import link_metric
# ---> 26 from evidently.metrics import FNR
#      27 from evidently.metrics import FPR
#      28 from evidently.metrics import TNR
#
# File ~/.pyenv/versions/3.9.7/lib/python3.9/site-packages/evidently/metrics/__init__.py:1
# ----> 1 from .classification import FNR
#       2 from .classification import FPR
#       3 from .classification import TNR
#
# File ~/.pyenv/versions/3.9.7/lib/python3.9/site-packages/evidently/metrics/classification.py:11
#       8 from typing import Type
#       9 from typing import TypeVar
# ---> 11 from evidently.core.base_types import Label
#      12 from evidently.core.metric_types import BoundTest
#      13 from evidently.core.metric_types import ByLabelCalculation
#
# File ~/.pyenv/versions/3.9.7/lib/python3.9/site-packages/evidently/core/base_types.py:3
#       1 from typing import Union
# ----> 3 from evidently._pydantic_compat import StrictBool
#       5 Label = Union[StrictBool, int, str, None]
#
# ImportError: cannot import name 'StrictBool' from 'evidently._pydantic_compat' (/home/mijka/.pyenv/versions/3.9.7/lib/python3.9/site-packages/evidently/_pydantic_compat.py)
