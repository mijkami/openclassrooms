# %%
## début novembre 2021

# %%
## en 1 an : 140h faites
## restantes : 480h faites
## rythme pas tenable

# %%
172 / 7
# Out:
# 24.571428571428573

# %%
460 / 25
# Out:
# 18.4

# %%
# => doit faire 18h  /sem

# %%
# ex p4 : 100
100 / 18.4
# Out:
# 5.434782608695652

# %%
# p4 - 100h : 2023-01-01
# p5 - 70h  : 2023-01-29
# p6 - 100h : 2023-03-12
# p7 - 120h : 2023-04-16
# p8 - 70H  : 2023-05-14

# %%
# /!\ dispersion, tenir à ses choix et avancer séquentiellement
