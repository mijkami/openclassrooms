# %%
import pandas as pd
import numpy as np
import re

# %%
data = pd.read_csv('operations.csv')
data.head()
# Out:
#   date_operation                                       libelle  montant  \
# 0     2023-03-31                      DON XX XX XX XX XX XX XX    -1.44
# 1     2023-04-03                           CARTE XX XX RAPT XX   -24.00
# 2     2023-04-03                           CARTE XX XX RAPT XX   -73.00
# 3     2023-04-03  VIREMENT XX XX XX XX XX XX XX XX XX XX XX XX   676.00
# 4     2023-04-03                    VIREMENT XX XX XX XX XX XX     4.80
#
#    solde_avt_ope      categ
# 0        1515.25      AUTRE
# 1        1513.81  TRANSPORT
# 2        1489.81  TRANSPORT
# 3        1416.81      AUTRE
# 4        2092.81      AUTRE

# %%
data.shape
# Out:
# (309, 5)

# %%
data.head(110)
# Out:
#     date_operation                                       libelle  montant  \
# 0       2023-03-31                      DON XX XX XX XX XX XX XX    -1.44
# 1       2023-04-03                           CARTE XX XX RAPT XX   -24.00
# 2       2023-04-03                           CARTE XX XX RAPT XX   -73.00
# 3       2023-04-03  VIREMENT XX XX XX XX XX XX XX XX XX XX XX XX   676.00
# 4       2023-04-03                    VIREMENT XX XX XX XX XX XX     4.80
# ..             ...                                           ...      ...
# 106     2023-06-12                       CARTE XX XX XX XX XX XX    -2.32
# 107     2023-06-12           CARTE XX XX LES ANCIENS ROBINSON XX      NaN
# 108     2023-06-12                       CARTE XX XX CHEZ LUC XX    -9.20
# 109     2023-06-13                       CARTE XX XX XX XX XX XX    -7.99
# 110     2023-06-15                          CARTE XX XX XX XX XX   -19.20
#
#      solde_avt_ope       categ
# 0          1515.25       AUTRE
# ...

# %%
4640.61 - 4667.19
# Out:
# -26.579999999999927

# %%
#missing data

data.isnull().sum()
# Out:
# date_operation    0
# libelle           0
# montant           2
# solde_avt_ope     0
# categ             1
# dtype: int64

# %%
data.loc[data['montant'].isnull(),:].shift(1)
# Out:
#     date_operation                              libelle  montant  \
# 107            NaN                                  NaN      NaN
# 269     2023-06-12  CARTE XX XX LES ANCIENS ROBINSON XX      NaN
#
#      solde_avt_ope    categ
# 107            NaN      NaN
# 269        4667.19  COURSES

# %%
data.loc[data['categ'].isnull(),:]
# Out:
#     date_operation                         libelle  montant  solde_avt_ope  \
# 156     2023-07-06  PRELEVEMENT XX TELEPHONE XX XX   -36.48        3295.68
#
#     categ
# 156   NaN

# %%
# duplicates

# %%
data.duplicated().sum()
# Out:
# 1

# %%
data.loc[data.duplicated(keep=False)]
# Out:
#    date_operation                              libelle  montant  \
# 43     2023-04-25  CARTE XX XX LES ANCIENS ROBINSON XX   -32.67
# 44     2023-04-25  CARTE XX XX LES ANCIENS ROBINSON XX   -32.67
#
#     solde_avt_ope    categ
# 43        3647.67  COURSES
# 44        3647.67  COURSES

# %%
data = data.drop_duplicates()
